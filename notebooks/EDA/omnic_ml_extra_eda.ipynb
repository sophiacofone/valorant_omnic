# %% [markdown]
# # Purpose of notebook

# %%
import json
import pandas as pd

# %% [markdown]
# ## updated eda w/ larger dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns



# Group the data by 'map' and calculate win ratio
map_win_ratios = combined_df.groupby('map')['round_info_round_won'].mean()

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=map_win_ratios.index, y=map_win_ratios.values)
plt.title('Win Ratio for Different Maps')
plt.ylabel('Win Ratio')
plt.xlabel('Map')
plt.xticks(rotation=90)  # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns



# Group the data by 'map' and calculate win ratio
map_win_ratios = combined_df.groupby('self_character')['round_info_round_won'].mean()

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=map_win_ratios.index, y=map_win_ratios.values)
plt.title('Win Ratio for ult_used')
plt.ylabel('Win Ratio')
plt.xlabel('Map')
plt.xticks(rotation=90)  # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns



# Group the data by 'map' and calculate win ratio
map_win_ratios = combined_df.groupby('self_ultimate_usage')['round_info_round_won'].mean()

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=map_win_ratios.index, y=map_win_ratios.values)
plt.title('Win Ratio for ult_used')
plt.ylabel('Win Ratio')
plt.xlabel('Map')
plt.xticks(rotation=90)  # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns



# Group the data by 'map' and calculate win ratio
map_win_ratios = combined_df.groupby('round_info_ally_side')['round_info_round_won'].mean()

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=map_win_ratios.index, y=map_win_ratios.values)
plt.title('Win Ratio for ally_side')
plt.ylabel('Win Ratio')
plt.xlabel('Map')
plt.xticks(rotation=90)  # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns



# Group the data by 'map' and calculate win ratio
map_win_ratios = combined_df.groupby('spike_planted')['round_info_round_won'].mean()

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=map_win_ratios.index, y=map_win_ratios.values)
plt.title('Win Ratio for spike_planted')
plt.ylabel('Win Ratio')
plt.xlabel('Map')
plt.xticks(rotation=90)  # Rotates X-Axis Ticks by 90-degrees
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already combined the CSV files into `combined_df`

# Group the combined DataFrame by 'spike_planted' column
grouped_df = combined_df.groupby('spike_planted').size()

# Plot the grouped data using a bar plot
grouped_df.plot(kind='bar')

# Set plot labels and title
plt.xlabel('Spike Planted')
plt.ylabel('Count')
plt.title('Grouped Data by Spike Planted')

# Display the plot
plt.show()

# %% [markdown]
# ### Thoughts
# - There doesnt seem to be one character or one map or one anything that is at a much higher ratio
# - If you can somehow use ur ult 3 times ur more likely to win lol
