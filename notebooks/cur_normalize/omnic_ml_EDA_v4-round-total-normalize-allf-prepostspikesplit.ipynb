# %% [markdown]
# # Purpose of notebook
# This notebook is to continue to explore the data, in particular the time-series and bi-modal distributions from previous version.
#
# Topics covered:
# - data normalization by round
# - data cleaning/flattening

# %%
import json
import pandas as pd

# %% [markdown]
# ## Loading the data

# %%
# Load JSON data from file
with open('pro2_data.json', 'r') as f:
    data = json.load(f)

# Access an element to retrieve the keys
sample_element = data[0]
columns = sample_element.keys()
print("Columns:", columns)

num_rows = len(data)
print("Number of rows:", num_rows)
# Out:
# Columns: dict_keys(['id', 'game_id', 'map_id', 'processed', 'process_date', 'created_at', 'updated_at', 'match_id', 'result', 'score', 'statistics', 'totals', 'ten_minute_averages', 'character_id', 'user_id', 'match_length', 'video_id', 'card_url', 'total_time', 'totals_to_date', 'start_time', 'end_time', 'start_frame', 'end_frame', 'status', 'report', 'analysis_processed', 'analysis_status'])
# Number of rows: 448

# %% [markdown]
# ## Create Rounds DF
# - Create DF
# - Go to statistics col

# %%
from pandas import json_normalize

# Create df
df = pd.read_json('pro2_data.json')
print(df.shape)

# Drop the all cols besides 'statistics' and 'user_id'
df_stats = df[['user_id','statistics']]
print(df_stats.shape)
df_stats
# Out:
# (448, 28)
# (448, 2)
#      user_id                                         statistics
# 0       3807  {'map': 'Pearl', 'score': '6-13', 'allies': ['...
# 1       3804  {'map': 'unknown', 'score': '12-14', 'allies':...
# 2       3806  {'map': 'Split', 'score': '4-13', 'allies': ['...
# 3       3808  {'map': 'Haven', 'score': '8-13', 'allies': ['...
# 4       3807  {'map': 'Ascent', 'score': '13-8', 'allies': [...
# ..       ...                                                ...
# 443     3799  {'map': 'Ascent', 'score': '9-13', 'allies': [...
# 444     3798  {'map': 'Bind', 'score': '13-10', 'allies': ['...
# 445     3795  {'map': 'unknown', 'score': '16-14', 'allies':...
# 446     3795  {'map': 'unknown', 'score': '3-13', 'allies': ...
# 447     3795  {'map': 'unknown', 'score': '13-9', 'allies': ...
#
# [448 rows x 2 columns]

# %%
df['statistics'].iloc[0]
# Out:
# {'map': 'Pearl',
#  'score': '6-13',
#  'allies': ['0', '1', '2', '3', '4'],
#  'player': '2',
#  'result': 'loss',
#  'rounds': {'0': {'alive': {'0': [[89993, True],
#      [134989, False],
#      [140189, True],
#      [172187, False]],
#     '1': [[89993, True], [141989, False]],
#     '2': [[89993, True], [156988, False]],
#     '3': [[89993, True], [159787, False]],
#     '4': [[89993, True], [161187, False]],
#     '5': [[89993, True], [144789, False]],
#     '6': [[89993, True], [156388, False]],
#     '7': [[89993, True], [147988, False]],
#     '8': [[89993, True], [159987, False]],
#     '9': [[89993, True]]},
#    'elims': [[147988,
#      {'source': '4',
#       'target': '7',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'ally'}],
#     [156388,
#      {'source': '4',
#       'target': '6',
#       'assisted': ['2'],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [159987,
#      {'source': '4',
#       'target': '8',
#       'assisted': ['3'],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 3,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [161187,
#      {'source': '9',
#       'target': '4',
#       'assisted': ['6'],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [161987,
#      {'source': '8',
#       'target': '3',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [172386,
#      {'source': '9',
#       'target': '0',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'opponent'}]],
#    'health': {'0': [[89993, 100],
#      [93992, 96],
#      [94992, 100],
#      [140389, 96],
#      [142989, 100],
#      [148388, 96],
#      [149788, 100],
#      [154388, 96],
#      [154788, 100],
#      [156588, 96],
#      [157988, 100],
#      [158388, 92],
#      [158788, 96],
#      [159787, 0]],
#     '1': [[89993, 100],
#      [95592, 96],
#      [96792, 100],
#      [105792, 96],
#      [106791, 100],
#      [139389, 96],
#      [141189, 100]],
#     '2': [[89993, 100], [153188, 79], [154388, 100], [156988, 0]],
#     '3': [[89993, 100],
#      [91593, 96],
#      [92393, 93],
#      [92793, 96],
#      [93992, 93],
#      [94392, 96],
#      [95592, 93],
#      [96392, 0],
#      [97392, 96],
#      [108591, 0],
#      [109991, 96],
#      [111591, 93],
#      [112591, 96],
#      [115591, 93],
#      [116791, 96],
#      [117591, 100],
#      [119390, 96],
#      [120190, 100],
#      [121390, 96],
#      [122790, 100],
#      [123390, 96],
#      [131390, 100],
#      [132390, 96],
#      [138389, 93],
#      [139389, 96],
#      [142189, 89],
#      [143189, 96],
#      [144389, 93],
#      [144989, 96],
#      [147988, 78],
#      [151188, 81],
#      [152588, 78],
#      [156188, 0]],
#     '4': [[89993, 100], [91193, 0], [118391, 4], [119990, 0]]},
#    'phases': [[89795, 'buy_start'],
#     [134795, 'round_start'],
#     [171579, 'round_scored'],
#     [178579, 'round_end']],
#    'shield': [[89993, 0], [109391, 25], [156988, 0]],
#    'credits': [[89993, 0], [91193, 800], [109591, 50]],
#    'ammo_mag': [[91193, 12],
#     [146988, 15],
#     [153788, 4],
#     [154188, 6],
#     [154388, 15],
#     [155188, 13],
#     [155388, 12],
#     [155588, 11],
#     [155788, 9],
#     [155988, 8],
#     [156388, 7],
#     [156588, 6]],
#    'inv_state': [[91593, 'melee'],
#     [123190, 'none'],
#     [137989, 'melee'],
#     [139589, 'secondary'],
#     [144189, 'none'],
#     [146988, 'secondary'],
#     [150788, 'none'],
#     [152788, 'secondary']],
#    'ult_state': {'0': [[89993, False]],
#     '1': [[89993, False]],
#     '2': [[89993, False]],
#     '3': [[89993, False]],
#     '4': [[89993, False]],
#     '5': [[89993, False]],
#     '6': [[89993, False]],
#     '7': [[89993, False]],
#     '8': [[89993, False]],
#     '9': [[89993, False]]},
#    'map_region': [[91193, 'Defender Side Spawn'],
#     [92593, 'Defender Side Water'],
#     [96992, 'Mid Connector'],
#     [100592, 'Mid Doors'],
#     [101192, 'B Link'],
#     [104192, 'Mid Doors'],
#     [104792, 'Mid Connector'],
#     [116191, 'Mid Doors'],
#     [139989, 'Mid Plaza'],
#     [148788, 'Mid Shops'],
#     [153188, 'B Link'],
#     [154388, 'B Tower'],
#     [155188, 'B Hall']],
#    'elims_count': [[89993, 0, 0]],
#    'inv_primary': [[89993, 'none']],
#    'ammo_reserve': [[91193, 36], [146988, 45], [153188, 18], [153588, 45]],
#    'firing_state': [[89993, False], [155188, True], [158788, False]],
#    'assists_count': [[89993, 0, 0], [156388, 1, 1]],
#    'inv_secondary': [[89993, 'classic'], [143389, 'none'], [146988, 'ghost']],
#    'loadout_value': [[89993, 0],
#     [109391, 400.0],
#     [134989, 900.0],
#     [143389, 900.0],
#     [144189, 400.0],
#     [146988, 1400.0],
#     [153188, 900.0],
#     [155188, 900.0],
#     [156988, 500.0]],
#    'spike_planted': [[89993, False]],
#    'assisted_count': [[89993, 0, 0]],
#    'ability_charges_1': [[89993, 0]],
#    'ability_charges_2': [[89993, 0],
#     [134989, 2],
#     [144189, 0],
#     [146988, 2],
#     [153188, 0]],
#    'ability_charges_3': [[89993, 0], [155188, 1]],
#    'ability_charges_4': [[89993, 0]]},
#   '1': {'alive': {'0': [[178586, True],
#      [208584, False],
#      [215583, True],
#      [228382, False]],
#     '1': [[178586, True], [231382, False]],
#     '2': [[178586, True], [281378, False]],
#     '3': [[178586, True], [231382, False]],
#     '4': [[178586, True], [264380, False]],
#     '5': [[178586, True], [232382, False]],
#     '6': [[178586, True]],
#     '7': [[178586, True]],
#     '8': [[178586, True]],
#     '9': [[178586, True]]},
#    'elims': [[231582,
#      {'source': '7',
#       'target': '3',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'opponent'}],
#     [231982,
#      {'source': '7',
#       'target': '0',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [264380,
#      {'source': '7',
#       'target': '4',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 3,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [281578,
#      {'source': '7',
#       'target': '2',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 4,
#       'first_blood': False,
#       'team_credit': 'opponent'}]],
#    'health': {'0': [[178586, 100],
#      [182586, 92],
#      [182986, 100],
#      [220583, 96],
#      [222383, 100]],
#     '1': [[178586, 100],
#      [180386, 96],
#      [181586, 100],
#      [189985, 96],
#      [190385, 100],
#      [195785, 96],
#      [198385, 100],
#      [209584, 96],
#      [209984, 100],
#      [212583, 96],
#      [213983, 100],
#      [224383, 96],
#      [225383, 100]],
#     '2': [[178586, 100],
#      [237382, 65],
#      [244981, 100],
#      [280978, 22],
#      [281378, 0]],
#     '3': [[178586, 100],
#      [179586, 96],
#      [181586, 93],
#      [181986, 96],
#      [184986, 93],
#      [186585, 96],
#      [186985, 89],
#      [187585, 96],
#      [188585, 93],
#      [189185, 96],
#      [189785, 93],
#      [190185, 96],
#      [191385, 93],
#      [192585, 96],
#      [195185, 93],
#      [196585, 96],
#      [197385, 93],
#      [197985, 96],
#      [198385, 93],
#      [199384, 96],
#      [201784, 93],
#      [202184, 96],
#      [204384, 100],
#      [205184, 96],
#      [207984, 0],
#      [208784, 96],
#      [211184, 93],
#      [211784, 96],
#      [212583, 93],
#      [214183, 96],
#      [222583, 93],
#      [222983, 96],
#      [225383, 93],
#      [226382, 96],
#      [230382, 89],
#      [230982, 93]],
#     '4': [[178586, 100], [179586, 0]]},
#    'phases': [[178579, 'buy_start'],
#     [208579, 'round_start'],
#     [280772, 'round_scored'],
#     [287772, 'round_end']],
#    'shield': [[178586, 0]],
#    'credits': [[178586, 50], [179386, 1950], [208584, 1150]],
#    'ammo_mag': [[181386, 12],
#     [213383, 6],
#     [216183, 9],
#     [216383, 6],
#     [216983, 9],
#     [218383, 6],
#     [229582, 5],
#     [233582, 3],
#     [236782, 4],
#     [236982, 3],
#     [237382, 2],
#     [238582, 24],
#     [239381, 0],
#     [239581, 22],
#     [242981, 6],
#     [249381, 9],
#     [249981, 6],
#     [251381, 5],
#     [253980, 6],
#     [258780, 9],
#     [259180, 6],
#     [262180, 66],
#     [265979, 6],
#     [267779, 10],
#     [267979, 6],
#     [268979, 9],
#     [269179, 6],
#     [269379, 9],
#     [269579, 6],
#     [270579, 9],
#     [271379, 66],
#     [271579, 6],
#     [280378, 9],
#     [280578, 6],
#     [281178, 5]],
#    'inv_state': [[179586, 'melee'],
#     [204984, 'none'],
#     [212983, 'secondary'],
#     [233782, 'none'],
#     [236582, 'secondary'],
#     [240781, 'none'],
#     [242381, 'secondary'],
#     [262380, 'melee'],
#     [265979, 'secondary']],
#    'ult_state': {'0': [[178586, False]],
#     '1': [[178586, False]],
#     '2': [[178586, False]],
#     '3': [[178586, False]],
#     '4': [[178586, False]],
#     '5': [[178586, False]],
#     '6': [[178586, False]],
#     '7': [[178586, False]],
#     '8': [[178586, False]],
#     '9': [[178586, False]]},
#    'map_region': [[179586, 'Defender Side Spawn'],
#     [182186, 'A Flowers'],
#     [184986, 'A Site'],
#     [186985, 'A Link'],
#     [194785, 'A Art'],
#     [197985, 'A Link'],
#     [200384, 'A Art'],
#     [232982, 'Mid Plaza'],
#     [236582, 'Mid Doors'],
#     [240381, 'B Link'],
#     [247381, 'Mid Doors'],
#     [254780, 'Mid Connector'],
#     [260580, 'Defender Side Water'],
#     [267779, 'Defender Side Spawn'],
#     [270379, 'A Flowers'],
#     [277179, 'A Secret']],
#    'elims_count': [[178786, 0, 0]],
#    'inv_primary': [[178586, 'none']],
#    'ammo_reserve': [[181386, 36],
#     [212983, 24],
#     [239781, 18],
#     [250981, 24],
#     [253980, 22]],
#    'firing_state': [[178586, False],
#     [216383, True],
#     [220583, False],
#     [229582, True],
#     [231782, False],
#     [233582, True],
#     [235782, False],
#     [236982, True],
#     [239581, False],
#     [249981, True],
#     [253580, False],
#     [259180, True],
#     [261380, False],
#     [267979, True],
#     [271779, False],
#     [280578, True],
#     [283378, False]],
#    'assists_count': [[178786, 0, 1]],
#    'inv_secondary': [[178586, 'classic'],
#     [212583, 'sheriff'],
#     [233982, 'none'],
#     [236582, 'sheriff'],
#     [263180, 'classic'],
#     [265979, 'sheriff']],
#    'loadout_value': [[178586, 0],
#     [208584, 0.0],
#     [208784, 500.0],
#     [212583, 1300.0],
#     [233782, 800.0],
#     [233982, 0.0],
#     [236582, 800.0],
#     [241581, 800.0],
#     [263180, 0.0],
#     [265979, 800.0]],
#    'spike_planted': [[178586, False], [257180, True], [281378, False]],
#    'assisted_count': [[178786, 0, 0]],
#    'ability_charges_1': [[178586, 0]],
#    'ability_charges_2': [[178586, 0], [208784, 2], [233782, 0]],
#    'ability_charges_3': [[178586, 1], [208584, 0], [236582, 1], [241581, 0]],
#    'ability_charges_4': [[178586, 0]]},
#   '2': {'alive': {'0': [[287778, True], [317776, False], [339574, True]],
#     '1': [[287778, True], [344574, False]],
#     '2': [[287778, True], [346973, False]],
#     '3': [[287778, True]],
#     '4': [[287778, True]],
#     '5': [[287778, True], [330975, False]],
#     '6': [[287778, True], [352973, False]],
#     '7': [[287778, True], [370972, False]],
#     '8': [[287778, True], [371571, False]],
#     '9': [[287778, True], [330975, False]]},
#    'elims': [[344773,
#      {'source': '7',
#       'target': '2',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'opponent'}],
#     [371172,
#      {'source': '3',
#       'target': '7',
#       'assisted': ['2'],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [371571,
#      {'source': '3',
#       'target': '8',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'ally'}]],
#    'health': {'0': [[287778, 100],
#      [292577, 96],
#      [293177, 100],
#      [310376, 96],
#      [312576, 100],
#      [322975, 96],
#      [324375, 100],
#      [334974, 85],
#      [346173, 88],
#      [346573, 85],
#      [349773, 88],
#      [350373, 85],
#      [350973, 88],
#      [351373, 85],
#      [355773, 92],
#      [356173, 100],
#      [357373, 85],
#      [357773, 88],
#      [358372, 96],
#      [359572, 100],
#      [368172, 96],
#      [368572, 100],
#      [370772, 85],
#      [373171, 77],
#      [374371, 85],
#      [375971, 92],
#      [377171, 81],
#      [377571, 85]],
#     '1': [[287778, 100],
#      [309776, 96],
#      [311176, 100],
#      [318775, 96],
#      [319575, 100],
#      [331574, 92],
#      [332174, 96],
#      [333174, 100]],
#     '2': [[287778, 100], [330575, 86], [346973, 0]],
#     '3': [[287778, 100],
#      [288778, 96],
#      [292777, 89],
#      [293177, 93],
#      [293577, 96],
#      [295577, 0],
#      [296577, 96],
#      [297177, 93],
#      [299377, 96],
#      [300977, 93],
#      [301977, 96],
#      [302377, 93],
#      [303977, 96],
#      [312376, 93],
#      [312776, 96],
#      [314776, 93],
#      [315376, 96],
#      [316176, 100],
#      [316776, 96],
#      [318575, 93],
#      [319775, 96],
#      [328775, 93],
#      [329575, 96],
#      [331974, 93],
#      [332774, 96],
#      [346573, 93],
#      [347573, 96],
#      [349573, 70],
#      [350173, 78],
#      [352573, 59],
#      [353173, 70],
#      [353973, 74],
#      [355373, 78],
#      [355773, 89],
#      [357573, 78],
#      [358172, 74],
#      [368772, 56],
#      [374771, 52],
#      [375571, 56]],
#     '4': [[287778, 100], [288778, 0]]},
#    'phases': [[287772, 'buy_start'],
#     [317772, 'round_start'],
#     [370967, 'round_scored'],
#     [377967, 'round_end']],
#    'shield': [[287778, 0], [295777, 25], [330575, 0]],
#    'credits': [[287778, 1150], [288578, 3550], [296177, 100]],
#    'ammo_mag': [[288778, 12],
#     [295577, 30],
#     [305576, 25],
#     [330575, 24],
#     [330775, 22],
#     [330975, 20],
#     [337174, 19],
#     [344973, 18],
#     [345173, 17],
#     [345573, 15],
#     [346173, 14]],
#    'inv_state': [[288778, 'secondary'],
#     [292377, 'melee'],
#     [296177, 'primary'],
#     [297977, 'melee'],
#     [305576, 'primary'],
#     [309576, 'melee'],
#     [314376, 'none'],
#     [321775, 'melee'],
#     [326575, 'none'],
#     [327775, 'melee'],
#     [328975, 'primary'],
#     [331175, 'melee'],
#     [337374, 'none'],
#     [339174, 'primary']],
#    'ult_state': {'0': [[287778, False]],
#     '1': [[287778, False]],
#     '2': [[287778, False]],
#     '3': [[287778, False]],
#     '4': [[287778, False], [288378, True], [318975, False]],
#     '5': [[287778, False]],
#     '6': [[287778, False]],
#     '7': [[287778, False]],
#     '8': [[287778, False]],
#     '9': [[287778, False]]},
#    'map_region': [[288778, 'Defender Side Spawn'],
#     [298377, 'Defender Side Water'],
#     [304177, 'Mid Connector'],
#     [312776, 'A Link'],
#     [314176, 'A Art'],
#     [322575, 'A Link'],
#     [324575, 'Mid Connector'],
#     [330575, 'Mid Doors'],
#     [331774, 'B Link'],
#     [336374, 'B Site']],
#    'elims_count': [[287978, 0, 0]],
#    'inv_primary': [[287778, 'none'],
#     [296177, 'phantom'],
#     [305576, 'vandal'],
#     [322175, 'spectre'],
#     [326575, 'vandal']],
#    'ammo_reserve': [[288778, 36], [295577, 90], [305576, 75]],
#    'firing_state': [[287778, False],
#     [305576, True],
#     [307776, False],
#     [330575, True],
#     [333174, False],
#     [337174, True],
#     [339374, False],
#     [344973, True],
#     [348373, False]],
#    'assists_count': [[287978, 0, 1], [371172, 1, 2]],
#    'inv_secondary': [[287778, 'classic']],
#    'loadout_value': [[287778, 0],
#     [295777, 400.0],
#     [296177, 3300.0],
#     [305576, 3300.0],
#     [317776, 3800.0],
#     [322175, 2500.0],
#     [326575, 3800.0],
#     [330575, 3400.0]],
#    'spike_planted': [[287778, False]],
#    'assisted_count': [[287978, 0, 0]],
#    'ability_charges_1': [[287778, 0]],
#    'ability_charges_2': [[287778, 0], [317776, 2]],
#    'ability_charges_3': [[287778, 0]],
#    'ability_charges_4': [[287778, 0]]},
#   '3': {'alive': {'0': [[377971, True],
#      [407969, False],
#      [416168, True],
#      [480963, False]],
#     '1': [[377971, True], [438966, False]],
#     '2': [[377971, True],
#      [438966, False],
#      [443566, True],
#      [460565, False],
#      [472964, True],
#      [479763, False]],
#     '3': [[377971, True], [441166, False]],
#     '4': [[377971, True], [477963, False]],
#     '5': [[377971, True], [426567, False]],
#     '6': [[377971, True], [479363, False]],
#     '7': [[377971, True], [449966, False]],
#     '8': [[377971, True], [480363, False]],
#     '9': [[377971, True]]},
#    'elims': [[441166,
#      {'source': '9',
#       'target': '3',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'opponent'}],
#     [478363,
#      {'source': '6',
#       'target': '4',
#       'assisted': ['7'],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [479563,
#      {'source': '0',
#       'target': '6',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [479963,
#      {'source': '8',
#       'target': '2',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [481963,
#      {'source': '5',
#       'target': '2',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [482363,
#      {'source': '0',
#       'target': '8',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [483563,
#      {'source': '9',
#       'target': '0',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'opponent'}]],
#    'health': {'0': [[377971, 100],
#      [468164, 88],
#      [468564, 96],
#      [469364, 100],
#      [474764, 96],
#      [475764, 100],
#      [476964, 96],
#      [477563, 100],
#      [477963, 96],
#      [479763, 0]],
#     '1': [[377971, 100],
#      [378971, 96],
#      [380571, 100],
#      [385770, 96],
#      [386570, 100],
#      [408969, 96],
#      [410569, 100],
#      [435167, 96],
#      [435567, 100],
#      [438166, 96],
#      [438566, 100]],
#     '2': [[377971, 100],
#      [438966, 0],
#      [443566, 100],
#      [460565, 0],
#      [472964, 100],
#      [479763, 0]],
#     '3': [[377971, 100],
#      [378971, 93],
#      [379571, 0],
#      [380571, 96],
#      [385970, 93],
#      [386570, 96],
#      [393570, 100],
#      [393970, 96],
#      [400769, 100],
#      [401169, 96],
#      [404169, 100],
#      [407769, 96],
#      [408969, 93],
#      [410169, 96],
#      [414368, 93],
#      [416568, 96],
#      [421968, 93],
#      [422568, 96],
#      [422968, 93],
#      [423368, 96],
#      [423968, 93],
#      [424567, 96],
#      [429767, 26],
#      [433167, 19],
#      [433767, 30],
#      [434567, 19],
#      [435167, 26],
#      [438566, 19],
#      [439566, 26]],
#     '4': [[377971, 100], [378971, 0]]},
#    'phases': [[377967, 'buy_start'],
#     [407967, 'round_start'],
#     [480358, 'round_scored'],
#     [487358, 'round_end']],
#    'shield': [[377971, 0],
#     [380371, 50],
#     [438966, 0],
#     [443566, 50],
#     [460565, 0],
#     [472964, 50],
#     [479763, 0]],
#    'credits': [[377971, 100], [378771, 3500], [380571, 2200]],
#    'ammo_mag': [[378171, 12],
#     [381571, 25],
#     [449766, 24],
#     [449966, 23],
#     [450166, 21],
#     [450366, 19],
#     [479363, 18],
#     [479563, 17]],
#    'inv_state': [[380571, 'melee'],
#     [390570, 'none'],
#     [410169, 'melee'],
#     [412968, 'primary'],
#     [413968, 'none'],
#     [423568, 'primary'],
#     [437766, 'none']],
#    'ult_state': {'0': [[377971, False], [480363, True]],
#     '1': [[377971, False]],
#     '2': [[377971, False]],
#     '3': [[377971, False]],
#     '4': [[377971, False]],
#     '5': [[377971, False]],
#     '6': [[377971, False]],
#     '7': [[377971, False]],
#     '8': [[377971, False]],
#     '9': [[377971, False], [441166, True]]},
#    'map_region': [[378971, 'Defender Side Spawn'],
#     [381371, 'Defender Side Water'],
#     [385970, 'Mid Connector'],
#     [388170, 'A Link'],
#     [389970, 'A Art'],
#     [410969, 'A Link'],
#     [412768, 'A Art'],
#     [418968, 'A Link'],
#     [421568, 'Mid Connector'],
#     [443566, 'Mid Doors'],
#     [453165, 'B Link'],
#     [472964, 'B Site'],
#     [475364, 'B Main']],
#    'elims_count': [[377971, 0, 0]],
#    'inv_primary': [[377971, 'none'], [381571, 'vandal'], [476564, 'none']],
#    'ammo_reserve': [[377971, 28], [378971, 36], [412968, 75]],
#    'firing_state': [[377971, False],
#     [449766, True],
#     [452565, False],
#     [479363, True],
#     [481763, False]],
#    'assists_count': [[377971, 0, 2]],
#    'inv_secondary': [[377971, 'classic']],
#    'loadout_value': [[377971, 0],
#     [380371, 1500.0],
#     [381571, 4400.0],
#     [407969, 4550.0],
#     [422968, 4400.0],
#     [438966, 3400.0],
#     [443566, 4400.0],
#     [460565, 3400.0],
#     [472964, 3900.0],
#     [476564, 1000.0],
#     [479763, 0.0]],
#    'spike_planted': [[377971, False], [471764, True], [480963, False]],
#    'assisted_count': [[377971, 0, 0]],
#    'ability_charges_1': [[377971, 0], [407969, 1], [422968, 0]],
#    'ability_charges_2': [[377971, 2], [472964, 0]],
#    'ability_charges_3': [[377971, 0]],
#    'ability_charges_4': [[377971, 0]]},
#   '4': {'alive': {'0': [[487363, True], [517360, False]],
#     '1': [[487363, True], [530959, False]],
#     '2': [[487363, True], [562557, False]],
#     '3': [[487363, True], [571556, False]],
#     '4': [[487363, True], [574156, False]],
#     '5': [[487363, True], [549758, False]],
#     '6': [[487363, True]],
#     '7': [[487363, True]],
#     '8': [[487363, True], [560157, False]],
#     '9': [[487363, True]]},
#    'elims': [[531159,
#      {'source': '9',
#       'target': '0',
#       'assisted': ['8'],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'opponent'}],
#     [560357,
#      {'source': '3',
#       'target': '8',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [562757,
#      {'source': '9',
#       'target': '2',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [571556,
#      {'source': '7',
#       'target': '3',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [574356,
#      {'source': '7',
#       'target': '4',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'opponent'}]],
#    'health': {'0': [[487363, 100]],
#     '1': [[487363, 100],
#      [500162, 96],
#      [501162, 100],
#      [508761, 96],
#      [509361, 100]],
#     '2': [[487363, 100], [539759, 95], [541959, 100], [562557, 0]],
#     '3': [[487363, 100],
#      [488363, 96],
#      [490762, 93],
#      [491162, 96],
#      [493562, 93],
#      [493962, 96],
#      [500762, 93],
#      [502362, 96],
#      [503162, 93],
#      [504761, 0],
#      [505961, 96],
#      [508761, 93],
#      [509561, 96],
#      [514561, 100],
#      [516961, 96],
#      [517560, 100],
#      [518360, 96],
#      [519560, 93],
#      [520160, 96],
#      [521760, 93],
#      [522360, 96],
#      [522760, 93],
#      [523160, 96],
#      [524960, 93],
#      [525560, 96],
#      [526360, 89],
#      [527560, 96],
#      [527960, 93],
#      [528760, 96],
#      [529760, 89],
#      [530759, 93],
#      [533559, 96],
#      [534359, 93],
#      [536359, 96],
#      [536759, 93],
#      [537159, 96],
#      [538959, 93],
#      [539759, 96],
#      [546558, 93],
#      [547558, 96],
#      [548758, 93],
#      [549558, 96],
#      [550158, 93],
#      [550558, 96],
#      [556358, 89],
#      [556758, 93],
#      [557557, 96],
#      [562957, 93],
#      [564157, 96],
#      [564757, 93],
#      [565357, 96],
#      [566357, 89],
#      [567557, 78],
#      [568157, 89]],
#     '4': [[487363, 100], [488363, 0]]},
#    'phases': [[487358, 'buy_start'],
#     [517358, 'round_start'],
#     [573547, 'round_scored'],
#     [580547, 'round_end']],
#    'shield': [[487363, 0],
#     [504761, 25],
#     [536959, 50],
#     [539759, 40],
#     [541959, 25],
#     [548758, 50],
#     [562557, 0]],
#    'credits': [[487363, 2200], [488363, 4300], [505361, 350]],
#    'ammo_mag': [[503162, 12],
#     [504561, 30],
#     [534359, 9],
#     [535159, 6],
#     [535759, 5],
#     [536159, 9],
#     [536359, 6],
#     [536559, 5],
#     [538159, 6],
#     [538759, 5],
#     [539159, 21],
#     [539959, 3],
#     [541959, 6],
#     [546358, 21],
#     [546758, 6],
#     [547358, 65],
#     [548358, 6],
#     [548958, 21],
#     [549358, 1],
#     [549558, 20],
#     [549758, 17],
#     [549958, 16],
#     [550358, 9],
#     [550558, 16],
#     [554758, 5],
#     [555158, 16],
#     [557557, 5],
#     [557957, 16],
#     [559957, 15],
#     [560157, 13],
#     [560357, 11]],
#    'inv_state': [[489163, 'melee'],
#     [510161, 'none'],
#     [522760, 'melee'],
#     [524360, 'none'],
#     [527760, 'primary'],
#     [531359, 'none'],
#     [537959, 'secondary'],
#     [550558, 'primary'],
#     [556358, 'none'],
#     [557957, 'primary']],
#    'ult_state': {'0': [[487363, False]],
#     '1': [[487363, False], [488163, True]],
#     '2': [[487363, False]],
#     '3': [[487363, False], [560157, True], [563557, False]],
#     '4': [[487363, False]],
#     '5': [[487363, False]],
#     '6': [[487363, False], [527560, True]],
#     '7': [[487363, False]],
#     '8': [[487363, False]],
#     '9': [[487363, True], [519960, False]]},
#    'map_region': [[488363, 'Defender Side Spawn'],
#     [490163, 'Defender Side Water'],
#     [494762, 'Mid Connector'],
#     [498362, 'Mid Doors'],
#     [499162, 'B Link'],
#     [500562, 'Mid Doors'],
#     [501162, 'Mid Connector'],
#     [507161, 'A Link'],
#     [509561, 'A Art'],
#     [523960, 'A Link'],
#     [527360, 'A Site'],
#     [534159, 'Mid Top'],
#     [536159, 'Attacker Side Spawn'],
#     [541959, 'Defender Side Spawn'],
#     [548758, 'A Art'],
#     [551158, 'A Link']],
#    'elims_count': [[487563, 0, 0]],
#    'inv_primary': [[487363, 'none'],
#     [505761, 'phantom'],
#     [511161, 'vandal'],
#     [522760, 'phantom'],
#     [531359, 'none'],
#     [550558, 'vandal']],
#    'ammo_reserve': [[504561, 90], [534159, 24], [541959, 23], [548958, 75]],
#    'firing_state': [[487363, False],
#     [535159, True],
#     [540959, False],
#     [549758, True],
#     [552158, False],
#     [559957, True],
#     [562557, False]],
#    'assists_count': [[487563, 0, 2]],
#    'inv_secondary': [[487363, 'classic'],
#     [537959, 'sheriff'],
#     [550558, 'classic']],
#    'loadout_value': [[487363, 0],
#     [504761, 400.0],
#     [505761, 3300.0],
#     [511161, 3300.0],
#     [517360, 3950.0],
#     [520160, 3950.0],
#     [522760, 3950.0],
#     [525360, 3450.0],
#     [527160, 3300.0],
#     [531359, 400.0],
#     [534159, 1050.0],
#     [536959, 1650.0],
#     [537959, 2450.0],
#     [539759, 2210.0],
#     [541959, 1850.0],
#     [548758, 2300.0],
#     [550558, 4400.0],
#     [560157, 4400.0],
#     [561757, 4400.0],
#     [562557, 3400.0]],
#    'spike_planted': [[487363, False], [540359, True], [574156, False]],
#    'assisted_count': [[487563, 0, 0]],
#    'ability_charges_1': [[487363, 0],
#     [517360, 1],
#     [527160, 0],
#     [534159, 1],
#     [548758, 0]],
#    'ability_charges_2': [[487363, 0], [517360, 2], [525360, 0], [534159, 2]],
#    'ability_charges_3': [[487363, 0],
#     [517360, 1],
#     [520160, 0],
#     [534159, 1],
#     [548758, 0],
#     [561757, 1]],
#    'ability_charges_4': [[487363, 0], [517360, 1], [531359, 0], [560157, 1]]},
#   '5': {'alive': {'0': [[580556, True],
#      [615353, False],
#      [620953, True],
#      [655150, False]],
#     '1': [[580556, True], [620753, False]],
#     '2': [[580556, True], [642151, False]],
#     '3': [[580556, True], [644151, False]],
#     '4': [[580556, True], [629352, False]],
#     '5': [[580556, True], [618553, False]],
#     '6': [[580556, True]],
#     '7': [[580556, True], [641351, False]],
#     '8': [[580556, True], [646551, False]],
#     '9': [[580556, True], [618753, False]]},
#    'elims': [[630752,
#      {'source': '8',
#       'target': '4',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'opponent'}],
#     [641551,
#      {'source': '3',
#       'target': '7',
#       'assisted': ['2'],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [646751,
#      {'source': '0',
#       'target': '8',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [655150,
#      {'source': '6',
#       'target': '0',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}]],
#    'health': {'0': [[580556, 100],
#      [630352, 96],
#      [632352, 100],
#      [632752, 92],
#      [634352, 96],
#      [634952, 100],
#      [642751, 0]],
#     '1': [[580556, 100],
#      [588155, 96],
#      [588555, 100],
#      [596954, 96],
#      [598954, 100],
#      [617753, 96],
#      [618153, 100]],
#     '2': [[580556, 100],
#      [618753, 69],
#      [623752, 100],
#      [627952, 45],
#      [629752, 100],
#      [642151, 0]],
#     '3': [[580556, 100],
#      [581756, 89],
#      [582556, 93],
#      [582956, 96],
#      [583955, 93],
#      [584955, 96],
#      [587155, 93],
#      [587955, 96],
#      [589555, 93],
#      [589955, 96],
#      [591555, 93],
#      [592955, 96],
#      [607954, 0],
#      [609154, 96],
#      [617953, 93],
#      [618353, 96],
#      [619153, 93],
#      [620753, 96],
#      [621753, 0],
#      [624752, 67],
#      [625752, 33],
#      [626552, 44],
#      [627552, 19],
#      [627952, 44],
#      [629352, 0]],
#     '4': [[580556, 100], [581556, 0]]},
#    'phases': [[580547, 'buy_start'],
#     [610547, 'round_start'],
#     [654544, 'round_scored'],
#     [661544, 'round_end']],
#    'shield': [[580556, 0],
#     [623752, 50],
#     [627952, 0],
#     [629752, 50],
#     [642151, 0]],
#    'credits': [[580556, 350],
#     [581356, 2750],
#     [594555, 1950],
#     [598754, 1800],
#     [608754, 1300]],
#    'ammo_mag': [[581556, 12],
#     [594755, 6],
#     [598354, 12],
#     [599154, 5],
#     [616753, 12],
#     [618553, 3],
#     [620153, 33],
#     [626752, 6],
#     [627352, 5],
#     [628552, 4],
#     [629152, 3],
#     [630952, 2],
#     [639751, 9],
#     [639951, 5],
#     [640351, 4],
#     [641351, 3],
#     [641951, 2]],
#    'inv_state': [[581756, 'melee'],
#     [598954, 'primary'],
#     [621153, 'none'],
#     [623752, 'melee'],
#     [627952, 'secondary'],
#     [631752, 'melee'],
#     [632752, 'none'],
#     [639151, 'secondary']],
#    'ult_state': {'0': [[580556, False],
#      [581156, True],
#      [614753, False],
#      [620953, True],
#      [630952, False],
#      [638751, True],
#      [648351, False]],
#     '1': [[580556, False], [581356, True]],
#     '2': [[580556, False]],
#     '3': [[580556, False]],
#     '4': [[580556, False]],
#     '5': [[580556, False]],
#     '6': [[580556, True], [630952, False], [639551, True]],
#     '7': [[580556, False]],
#     '8': [[580556, False], [581156, True], [617153, False]],
#     '9': [[580556, False]]},
#    'map_region': [[581556, 'Defender Side Spawn'],
#     [584355, 'Defender Side Records'],
#     [587355, 'B Tunnel'],
#     [590355, 'B Site'],
#     [623752, 'A Link'],
#     [625352, 'Mid Connector'],
#     [626752, 'B Site'],
#     [627952, 'B Main'],
#     [630552, 'B Site']],
#    'elims_count': [[580756, 0, 0]],
#    'inv_primary': [[580556, 'none'], [598954, 'marshal'], [620953, 'none']],
#    'ammo_reserve': [[581556, 36],
#     [594555, 24],
#     [598754, 15],
#     [626752, 24],
#     [639151, 20]],
#    'firing_state': [[580556, False],
#     [627352, True],
#     [633152, False],
#     [639951, True],
#     [644151, False]],
#    'assists_count': [[580756, 0, 2], [641551, 1, 3]],
#    'inv_secondary': [[580556, 'classic'],
#     [595555, 'sheriff'],
#     [598954, 'classic'],
#     [623752, 'sheriff'],
#     [632952, 'shorty'],
#     [639151, 'sheriff']],
#    'loadout_value': [[580556, 0],
#     [595555, 1300.0],
#     [598954, 1450.0],
#     [610553, 1600.0],
#     [620953, 0.0],
#     [623752, 2450.0],
#     [626752, 2450.0],
#     [627952, 1450.0],
#     [629752, 2450.0],
#     [632952, 1950.0],
#     [638551, 1700.0],
#     [639151, 2200.0],
#     [642151, 1200.0]],
#    'spike_planted': [[580556, False]],
#    'assisted_count': [[580756, 0, 0]],
#    'ability_charges_1': [[580556, 0], [610553, 1], [620953, 0], [623752, 1]],
#    'ability_charges_2': [[580556, 2], [620953, 0], [623752, 2], [638551, 1]],
#    'ability_charges_3': [[580556, 1], [620953, 0]],
#    'ability_charges_4': [[580556, 1], [620953, 0], [623752, 1], [626752, 0]]},
#   '6': {'alive': {'0': [[661550, True], [693347, False]],
#     '1': [[661550, True], [707946, False]],
#     '2': [[661550, True], [707946, False]],
#     '3': [[661550, True]],
#     '4': [[661550, True]],
#     '5': [[661550, True], [703546, False]],
#     '6': [[661550, True], [718545, False]],
#     '7': [[661550, True], [731944, False]],
#     '8': [[661550, True], [706146, False]],
#     '9': [[661550, True], [705746, False]]},
#    'elims': [[705546,
#      {'source': '7',
#       'target': '0',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'opponent'}],
#     [706346,
#      {'source': '2',
#       'target': '8',
#       'weapon': 'melee',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally',
#       'weapon_type': 'melee'}],
#     [707946,
#      {'source': '7',
#       'target': '3',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [708346,
#      {'source': '7',
#       'target': '2',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 3,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [718745,
#      {'source': '4',
#       'target': '6',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [731944,
#      {'source': '4',
#       'target': '7',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'ally'}]],
#    'health': {'0': [[661550, 100]],
#     '1': [[661550, 100]],
#     '2': [[661550, 100], [707946, 0]],
#     '3': [[661550, 100],
#      [662550, 93],
#      [663149, 96],
#      [663749, 93],
#      [664149, 96],
#      [666549, 0],
#      [666949, 96],
#      [667749, 93],
#      [668749, 96],
#      [674749, 93],
#      [677148, 96],
#      [678348, 93],
#      [678748, 96],
#      [696547, 93],
#      [697347, 96],
#      [702547, 93],
#      [703146, 96],
#      [703746, 93],
#      [704546, 96],
#      [706346, 93],
#      [707746, 96],
#      [711746, 93],
#      [712146, 96],
#      [713946, 93],
#      [714546, 96],
#      [715346, 93],
#      [715746, 96],
#      [717545, 93],
#      [718545, 96],
#      [718945, 93],
#      [719545, 96],
#      [721945, 93],
#      [722745, 96],
#      [728145, 93],
#      [728545, 96],
#      [728945, 93],
#      [729744, 96],
#      [738344, 93],
#      [738744, 96],
#      [741744, 93]],
#     '4': [[661550, 100],
#      [662550, 0],
#      [718545, 78],
#      [720145, 74],
#      [720545, 78],
#      [721745, 81],
#      [723145, 78],
#      [725745, 81],
#      [726945, 74],
#      [727545, 81],
#      [727945, 15],
#      [728545, 0]]},
#    'phases': [[661544, 'buy_start'],
#     [691544, 'round_start'],
#     [735541, 'round_scored'],
#     [742541, 'round_end']],
#    'shield': [[661550, 0], [666549, 25], [707946, 0]],
#    'credits': [[661550, 1300], [662550, 4400], [666749, 1100]],
#    'ammo_mag': [[662750, 12],
#     [666349, 30],
#     [668549, 12],
#     [674549, 25],
#     [705346, 24],
#     [705546, 22],
#     [705746, 20],
#     [705946, 19]],
#    'inv_state': [[662550, 'melee'],
#     [677348, 'none'],
#     [695147, 'melee'],
#     [701747, 'none'],
#     [704546, 'primary'],
#     [706146, 'melee']],
#    'ult_state': {'0': [[661550, False]],
#     '1': [[661550, False], [662350, True]],
#     '2': [[661550, False], [662350, True], [701947, False]],
#     '3': [[661550, False]],
#     '4': [[661550, False]],
#     '5': [[661550, False], [662350, True]],
#     '6': [[661550, True], [713946, False]],
#     '7': [[661550, False], [713546, True]],
#     '8': [[661550, False]],
#     '9': [[661550, False]]},
#    'map_region': [[662550, 'Defender Side Spawn'],
#     [664549, 'Defender Side Water'],
#     [669149, 'Mid Connector'],
#     [672749, 'Mid Doors'],
#     [674749, 'Mid Connector'],
#     [679148, 'Mid Doors'],
#     [695147, 'B Link'],
#     [697147, 'Mid Connector']],
#    'elims_count': [[661550, 0, 0], [706346, 1, 1]],
#    'inv_primary': [[661550, 'none'],
#     [668549, 'vandal'],
#     [695547, 'spectre'],
#     [696547, 'vandal']],
#    'ammo_reserve': [[666349, 90], [704546, 75]],
#    'firing_state': [[661550, False], [705346, True], [708146, False]],
#    'assists_count': [[661550, 0, 3]],
#    'inv_secondary': [[661550, 'classic']],
#    'loadout_value': [[661550, 0],
#     [666549, 800.0],
#     [668549, 3700.0],
#     [691547, 3950.0],
#     [695547, 2650.0],
#     [696547, 3950.0],
#     [703946, 3800.0],
#     [707946, 3400.0]],
#    'spike_planted': [[661550, False]],
#    'assisted_count': [[661550, 0, 0]],
#    'ability_charges_1': [[661550, 1], [703946, 0]],
#    'ability_charges_2': [[661550, 1], [691547, 2]],
#    'ability_charges_3': [[661550, 0]],
#    'ability_charges_4': [[661550, 0], [691547, 1]]},
#   '7': {'alive': {'0': [[742544, True],
#      [773941, False],
#      [781141, True],
#      [791540, False]],
#     '1': [[742544, True], [782141, False]],
#     '2': [[742544, True], [816138, False], [828537, True], [840336, False]],
#     '3': [[742544, True], [788740, False]],
#     '4': [[742544, True], [816138, False], [828537, True], [837736, False]],
#     '5': [[742544, True], [778941, False]],
#     '6': [[742544, True], [795939, False], [816138, True], [828537, False]],
#     '7': [[742544, True], [793340, False]],
#     '8': [[742544, True], [784940, False]],
#     '9': [[742544, True], [788540, False]]},
#    'elims': [[785940,
#      {'source': '3',
#       'target': '8',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'ally'}],
#     [788740,
#      {'source': '3',
#       'target': '9',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [793540,
#      {'source': '4',
#       'target': '7',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [795939,
#      {'source': '2',
#       'target': '6',
#       'weapon': 'vandal',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally',
#       'weapon_type': 'primary'}],
#     [842736,
#      {'source': '5',
#       'target': '4',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}]],
#    'health': {'0': [[742544, 100],
#      [779341, 96],
#      [781141, 100],
#      [785740, 92],
#      [786740, 100],
#      [790140, 96]],
#     '1': [[742544, 100], [776741, 96], [778741, 100]],
#     '2': [[742544, 100],
#      [816138, 0],
#      [828537, 100],
#      [835337, 75],
#      [838136, 100],
#      [839536, 60],
#      [839936, 20],
#      [840336, 0]],
#     '3': [[742544, 100],
#      [744543, 0],
#      [744943, 96],
#      [747143, 93],
#      [747543, 96],
#      [749343, 93],
#      [750943, 96],
#      [752143, 89],
#      [752743, 96],
#      [757342, 93],
#      [758142, 96],
#      [758942, 93],
#      [760142, 96],
#      [775941, 93],
#      [776341, 96],
#      [783340, 100],
#      [784140, 93],
#      [785340, 74],
#      [786540, 70]],
#     '4': [[742544, 100], [743543, 0]]},
#    'phases': [[742541, 'buy_start'],
#     [772541, 'round_start'],
#     [839727, 'round_scored'],
#     [846727, 'round_end']],
#    'shield': [[742544, 0], [744543, 25], [787340, 50], [816138, 0]],
#    'credits': [[742544, 1100], [744743, 850]],
#    'ammo_mag': [[744143, 25],
#     [784340, 24],
#     [790540, 10],
#     [795340, 24],
#     [795540, 22],
#     [795739, 20],
#     [795939, 19],
#     [796139, 17],
#     [796739, 16],
#     [797739, 15],
#     [798339, 30],
#     [810138, 90],
#     [810338, 30],
#     [833337, 29],
#     [833737, 27],
#     [834137, 5],
#     [838736, 27],
#     [839336, 25],
#     [839736, 23],
#     [839936, 22],
#     [840136, 21]],
#    'inv_state': [[745143, 'melee'],
#     [758942, 'none'],
#     [775541, 'primary'],
#     [780741, 'none'],
#     [782340, 'primary'],
#     [784540, 'none'],
#     [787340, 'melee'],
#     [790540, 'primary'],
#     [791540, 'none'],
#     [794140, 'primary'],
#     [830137, 'none'],
#     [832937, 'primary'],
#     [837736, 'none'],
#     [838936, 'primary']],
#    'ult_state': {'0': [[742544, False]],
#     '1': [[742544, False]],
#     '2': [[742544, False]],
#     '3': [[742544, False]],
#     '4': [[742544, False], [793540, True]],
#     '5': [[742544, False], [743343, True]],
#     '6': [[742544, False], [816138, True]],
#     '7': [[742544, False], [743143, True], [773541, False]],
#     '8': [[742544, False]],
#     '9': [[742544, False]]},
#    'map_region': [[743543, 'Defender Side Spawn'],
#     [746343, 'Defender Side Records'],
#     [749343, 'B Tunnel'],
#     [752743, 'B Site'],
#     [754943, 'B Link'],
#     [759742, 'Mid Doors'],
#     [776141, 'B Link'],
#     [787340, 'Mid Connector'],
#     [794140, 'B Ramp']],
#    'elims_count': [[742743, 0, 1], [795939, 1, 2]],
#    'inv_primary': [[742544, 'none'],
#     [745143, 'vandal'],
#     [784540, 'none'],
#     [790340, 'vandal'],
#     [791540, 'none'],
#     [794140, 'vandal'],
#     [798139, 'phantom'],
#     [835337, 'operator'],
#     [838936, 'phantom']],
#    'ammo_reserve': [[744343, 75], [798339, 90], [834137, 10], [838936, 90]],
#    'firing_state': [[742544, False],
#     [784340, True],
#     [786540, False],
#     [795540, True],
#     [799939, False],
#     [833337, True],
#     [835936, False],
#     [839336, True],
#     [842336, False]],
#    'assists_count': [[742743, 0, 3]],
#    'inv_secondary': [[742544, 'classic'],
#     [792940, 'none'],
#     [794140, 'classic']],
#    'loadout_value': [[742544, 0],
#     [744543, 900.0],
#     [745143, 3800.0],
#     [772741, 3950.0],
#     [781741, 3800.0],
#     [784540, 400.0],
#     [787340, 1650.0],
#     [790340, 4550.0],
#     [791540, 1000.0],
#     [792940, 1000.0],
#     [794140, 4550.0],
#     [798139, 4550.0],
#     [816138, 3550.0],
#     [832137, 3300.0],
#     [834137, 3150.0],
#     [835337, 4950.0],
#     [837736, 4700.0],
#     [838136, 4850.0],
#     [838936, 3050.0]],
#    'spike_planted': [[742544, False]],
#    'assisted_count': [[742743, 0, 0]],
#    'ability_charges_1': [[742544, 0],
#     [772741, 1],
#     [781741, 0],
#     [787340, 1],
#     [791540, 0],
#     [794140, 1],
#     [834137, 0],
#     [838136, 1]],
#    'ability_charges_2': [[742544, 2],
#     [784540, 0],
#     [787340, 2],
#     [791540, 0],
#     [794140, 2],
#     [832137, 1],
#     [837736, 0]],
#    'ability_charges_3': [[742544, 0],
#     [787340, 1],
#     [791540, 0],
#     [794140, 1],
#     [834137, 0],
#     [838136, 1]],
#    'ability_charges_4': [[742544, 1], [772741, 0], [834137, 1], [837736, 0]]},
#   '8': {'alive': {'0': [[846736, True], [887333, False]],
#     '1': [[846736, True], [904531, False], [909531, True], [913531, False]],
#     '2': [[846736, True], [914331, False]],
#     '3': [[846736, True], [916130, False]],
#     '4': [[846736, True], [921130, False]],
#     '5': [[846736, True]],
#     '6': [[846736, True]],
#     '7': [[846736, True]],
#     '8': [[846736, True]],
#     '9': [[846736, True]]},
#    'elims': [[913531,
#      {'source': '7',
#       'target': '0',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'opponent'}],
#     [917130,
#      {'source': '7',
#       'target': '2',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [922330,
#      {'source': '7',
#       'target': '4',
#       'assisted': ['9'],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 3,
#       'first_blood': False,
#       'team_credit': 'opponent'}]],
#    'health': {'0': [[846736, 100], [852935, 96], [859335, 100]],
#     '1': [[846736, 100],
#      [852935, 96],
#      [853535, 100],
#      [892732, 31],
#      [893732, 50],
#      [894132, 54],
#      [894932, 58],
#      [895732, 65],
#      [896532, 69],
#      [896932, 73],
#      [897732, 77],
#      [898132, 81],
#      [900132, 92],
#      [900932, 96],
#      [901332, 100],
#      [904731, 92],
#      [905531, 100],
#      [907731, 96],
#      [911331, 100],
#      [912331, 96],
#      [912931, 100]],
#     '2': [[846736, 100], [914331, 0]],
#     '3': [[846736, 100],
#      [847736, 96],
#      [851735, 93],
#      [852335, 96],
#      [853335, 93],
#      [853735, 96],
#      [855135, 0],
#      [856735, 96],
#      [857335, 93],
#      [859335, 96],
#      [862934, 93],
#      [863734, 96],
#      [867934, 93],
#      [868334, 96],
#      [870934, 93],
#      [871334, 96],
#      [879333, 93],
#      [880533, 96],
#      [889532, 93],
#      [890332, 96],
#      [892532, 89],
#      [892932, 93],
#      [893732, 96],
#      [895732, 93],
#      [896532, 96],
#      [899932, 70],
#      [900332, 67],
#      [900732, 70],
#      [905331, 30],
#      [905931, 26],
#      [906731, 30],
#      [907531, 22],
#      [908931, 30],
#      [909331, 22],
#      [909931, 19],
#      [911531, 26],
#      [912331, 22],
#      [913931, 30]],
#     '4': [[846736, 100], [847736, 0]]},
#    'phases': [[846727, 'buy_start'],
#     [876727, 'round_start'],
#     [924320, 'round_scored'],
#     [931320, 'round_end']],
#    'shield': [[846736, 0]],
#    'credits': [[846736, 850], [847536, 2750], [856535, 2450]],
#    'ammo_mag': [[856535, 2],
#     [880333, 12],
#     [880533, 2],
#     [901332, 22],
#     [901931, 2],
#     [910331, 29],
#     [911331, 2],
#     [911931, 19],
#     [912931, 12],
#     [913131, 1],
#     [913331, 27],
#     [913531, 2],
#     [913931, 27],
#     [914131, 2]],
#    'inv_state': [[847736, 'melee'],
#     [861934, 'none'],
#     [879733, 'secondary'],
#     [889332, 'melee'],
#     [891732, 'none'],
#     [894932, 'melee'],
#     [897532, 'none'],
#     [899932, 'secondary'],
#     [903931, 'none'],
#     [905731, 'melee'],
#     [907931, 'secondary']],
#    'ult_state': {'0': [[846736, False]],
#     '1': [[846736, False]],
#     '2': [[846736, False]],
#     '3': [[846736, False], [847336, True], [911131, False]],
#     '4': [[846736, False], [847336, True]],
#     '5': [[846736, False], [851335, True], [888532, False]],
#     '6': [[846736, False]],
#     '7': [[846736, False]],
#     '8': [[846736, False]],
#     '9': [[846736, False]]},
#    'map_region': [[847736, 'Defender Side Spawn'],
#     [849935, 'Defender Side Water'],
#     [854535, 'Mid Connector'],
#     [856935, 'A Link'],
#     [858735, 'Mid Connector'],
#     [864334, 'Mid Doors'],
#     [890532, 'Mid Connector'],
#     [894532, 'Defender Side Water'],
#     [899132, 'Defender Side Spawn'],
#     [900132, 'A Flowers'],
#     [906531, 'A Site']],
#    'elims_count': [[846736, 0, 2]],
#    'inv_primary': [[846736, 'none']],
#    'ammo_reserve': [[856335, 10], [913331, 9]],
#    'firing_state': [[846736, False]],
#    'assists_count': [[846736, 0, 3]],
#    'inv_secondary': [[846736, 'classic'],
#     [856935, 'ghost'],
#     [861934, 'shorty'],
#     [894932, 'ghost'],
#     [897132, 'shorty']],
#    'loadout_value': [[846736, 0],
#     [856935, 650.0],
#     [861934, 450.0],
#     [876733, 950.0],
#     [877733, 950.0],
#     [894332, 800.0],
#     [894932, 1000.0],
#     [897132, 800.0],
#     [905131, 300.0]],
#    'spike_planted': [[846736, False], [906931, True], [924930, False]],
#    'assisted_count': [[846736, 0, 0]],
#    'ability_charges_1': [[846736, 1], [894332, 0]],
# ...
#    'ammo_mag': [[1687672, 12], [1688672, 25], [1704871, 24], [1707871, 25]],
#    'inv_state': [[1690072, 'melee'],
#     [1701671, 'primary'],
#     [1706671, 'melee'],
#     [1714470, 'none'],
#     [1718270, 'melee'],
#     [1739268, 'primary'],
#     [1743268, 'none'],
#     [1745068, 'primary'],
#     [1751467, 'melee']],
#    'ult_state': {'0': [[1686672, False]],
#     '1': [[1686672, False]],
#     '2': [[1686672, False], [1687472, True], [1727869, False]],
#     '3': [[1686672, False]],
#     '4': [[1686672, False], [1687472, True]],
#     '5': [[1686672, False], [1686872, True]],
#     '6': [[1686672, False], [1687272, True], [1738068, False]],
#     '7': [[1686672, False]],
#     '8': [[1686672, False], [1687272, True]],
#     '9': [[1686672, False], [1687272, True]]},
#    'map_region': [[1687672, 'Attacker Side Spawn'],
#     [1693072, 'Mid Shops'],
#     [1696072, 'Attacker Side Spawn'],
#     [1712270, 'Mid Shops'],
#     [1713270, 'B Club'],
#     [1720670, 'Mid Shops'],
#     [1723070, 'Attacker Side Spawn'],
#     [1739068, 'A Main'],
#     [1753067, 'A Site']],
#    'elims_count': [[1686672, 0, 9]],
#    'inv_primary': [[1686672, 'none'], [1691872, 'vandal']],
#    'ammo_reserve': [[1701671, 75]],
#    'firing_state': [[1686672, False], [1704871, True], [1707071, False]],
#    'assists_count': [[1686672, 0, 3]],
#    'inv_secondary': [[1686672, 'classic']],
#    'loadout_value': [[1686672, 0],
#     [1688872, 1500.0],
#     [1691872, 4400.0],
#     [1726469, 3400.0],
#     [1739068, 4400.0],
#     [1746668, 3400.0],
#     [1750667, 3900.0],
#     [1754867, 2900.0]],
#    'spike_planted': [[1686672, False], [1774066, True], [1809863, False]],
#    'assisted_count': [[1686672, 0, 1]],
#    'ability_charges_1': [[1686672, 0]],
#    'ability_charges_2': [[1686672, 2], [1750667, 0]],
#    'ability_charges_3': [[1686672, 1], [1739068, 0]],
#    'ability_charges_4': [[1686672, 0]]}},
#  'status': 'success: completed - valorant postprocess',
#  'totals': {'elims': 9,
#   'deaths': 14,
#   'assists': 3,
#   'healing': 1433,
#   'headshots': 8,
#   'shielding': 1159,
#   'wallbangs': 0,
#   'first_bloods': 0,
#   'seconds_dead': 442,
#   'was_assisted': 1,
#   'credits_spent': 39000,
#   'first_blooded': 2,
#   'seconds_alive': 1261,
#   'credits_earned': 43400,
#   'hp_damage_taken': 3144,
#   'shield_damage_taken': 1159},
#  'version': '1.0.0',
#  'end_time': 8239379,
#  'gametype': 'swiftplay',
#  'opponents': ['5', '6', '7', '8', '9'],
#  'ally_score': 6,
#  'player_ids': {'0': {'role': 'ally', 'character': 'gekko'},
#   '1': {'role': 'ally', 'character': 'viper'},
#   '2': {'role': 'self', 'character': 'phoenix'},
#   '3': {'role': 'ally', 'character': 'astra'},
#   '4': {'role': 'ally', 'character': 'jett'},
#   '5': {'role': 'opponent', 'character': 'harbor'},
#   '6': {'role': 'opponent', 'character': 'killjoy'},
#   '7': {'role': 'opponent', 'character': 'jett'},
#   '8': {'role': 'opponent', 'character': 'astra'},
#   '9': {'role': 'opponent', 'character': 'yoru'}},
#  'round_info': {'0': {'score': '0-0',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 89795,
#    'round_end': 178579,
#    'round_won': False,
#    'ally_score': 0,
#    'round_start': 134795,
#    'round_scored': 171579,
#    'spike_planted': False,
#    'opponent_score': 0},
#   '1': {'score': '0-1',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 178579,
#    'round_end': 287772,
#    'round_won': False,
#    'ally_score': 0,
#    'round_start': 208579,
#    'round_scored': 280772,
#    'spike_planted': True,
#    'opponent_score': 1},
#   '2': {'score': '0-2',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 287772,
#    'round_end': 377967,
#    'round_won': True,
#    'ally_score': 0,
#    'round_start': 317772,
#    'round_scored': 370967,
#    'spike_planted': False,
#    'opponent_score': 2},
#   '3': {'score': '1-2',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 377967,
#    'round_end': 487358,
#    'round_won': False,
#    'ally_score': 1,
#    'round_start': 407967,
#    'round_scored': 480358,
#    'spike_planted': True,
#    'opponent_score': 2},
#   '4': {'score': '1-3',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 487358,
#    'round_end': 580547,
#    'round_won': False,
#    'ally_score': 1,
#    'round_start': 517358,
#    'round_scored': 573547,
#    'spike_planted': True,
#    'opponent_score': 3},
#   '5': {'score': '1-4',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 580547,
#    'round_end': 661544,
#    'round_won': False,
#    'ally_score': 1,
#    'round_start': 610547,
#    'round_scored': 654544,
#    'spike_planted': False,
#    'opponent_score': 4},
#   '6': {'score': '1-5',
#    'ult_used': True,
#    'ally_side': 'defender',
#    'buy_start': 661544,
#    'round_end': 742541,
#    'round_won': True,
#    'ally_score': 1,
#    'round_start': 691544,
#    'round_scored': 735541,
#    'spike_planted': False,
#    'opponent_score': 5},
#   '7': {'score': '2-5',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 742541,
#    'round_end': 846727,
#    'round_won': False,
#    'ally_score': 2,
#    'round_start': 772541,
#    'round_scored': 839727,
#    'spike_planted': False,
#    'opponent_score': 5},
#   '8': {'score': '2-6',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 846727,
#    'round_end': 931320,
#    'round_won': False,
#    'ally_score': 2,
#    'round_start': 876727,
#    'round_scored': 924320,
#    'spike_planted': True,
#    'opponent_score': 6},
#   '9': {'score': '2-7',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 931320,
#    'round_end': 998116,
#    'round_won': False,
#    'ally_score': 2,
#    'round_start': 961320,
#    'round_scored': 991116,
#    'spike_planted': False,
#    'opponent_score': 7},
#   '10': {'score': '2-8',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 998116,
#    'round_end': 1069316,
#    'round_won': False,
#    'ally_score': 2,
#    'round_start': 1028116,
#    'round_scored': 1062316,
#    'spike_planted': True,
#    'opponent_score': 8},
#   '11': {'score': '2-9',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 1069316,
#    'round_end': 1158710,
#    'round_won': False,
#    'ally_score': 2,
#    'round_start': 1099316,
#    'round_scored': 1151710,
#    'spike_planted': True,
#    'opponent_score': 9},
#   '12': {'score': '2-10',
#    'ult_used': False,
#    'ally_side': 'attacker',
#    'buy_start': 1158710,
#    'round_end': 1244699,
#    'round_won': False,
#    'ally_score': 2,
#    'round_start': 1203710,
#    'round_scored': 1237699,
#    'spike_planted': False,
#    'opponent_score': 10},
#   '13': {'score': '2-11',
#    'ult_used': False,
#    'ally_side': 'attacker',
#    'buy_start': 1244699,
#    'round_end': 1351102,
#    'round_won': True,
#    'ally_score': 2,
#    'round_start': 1274699,
#    'round_scored': 1344102,
#    'spike_planted': True,
#    'opponent_score': 11},
#   '14': {'score': '3-11',
#    'ult_used': False,
#    'ally_side': 'attacker',
#    'buy_start': 1351102,
#    'round_end': 1424089,
#    'round_won': True,
#    'ally_score': 3,
#    'round_start': 1381102,
#    'round_scored': 1417089,
#    'spike_planted': False,
#    'opponent_score': 11},
#   '15': {'score': '4-11',
#    'ult_used': True,
#    'ally_side': 'attacker',
#    'buy_start': 1424089,
#    'round_end': 1526478,
#    'round_won': True,
#    'ally_score': 4,
#    'round_start': 1454089,
#    'round_scored': 1519478,
#    'spike_planted': False,
#    'opponent_score': 11},
#   '16': {'score': '5-11',
#    'ult_used': False,
#    'ally_side': 'attacker',
#    'buy_start': 1526478,
#    'round_end': 1593875,
#    'round_won': True,
#    'ally_score': 5,
#    'round_start': 1556478,
#    'round_scored': 1586875,
#    'spike_planted': False,
#    'opponent_score': 11},
#   '17': {'score': '6-11',
#    'ult_used': False,
#    'ally_side': 'attacker',
#    'buy_start': 1593875,
#    'round_end': 1686665,
#    'round_won': False,
#    'ally_score': 6,
#    'round_start': 1623875,
#    'round_scored': 1679665,
#    'spike_planted': True,
#    'opponent_score': 11},
#   '18': {'score': '6-12',
#    'ult_used': True,
#    'ally_side': 'attacker',
#    'buy_start': 1686665,
#    'round_end': 1816863,
#    'round_won': False,
#    'ally_score': 6,
#    'round_start': 1716665,
#    'round_scored': 1809863,
#    'spike_planted': True,
#    'opponent_score': 12}},
#  'start_time': 6422515,
#  'best_weapon': 'classic',
#  'round_totals': {'0': {'elims': 0,
#    'deaths': 0,
#    'assists': 1,
#    'healing': 21,
#    'headshots': 0,
#    'shielding': 25,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 21,
#    'was_assisted': 0,
#    'credits_spent': 750,
#    'first_blooded': 0,
#    'seconds_alive': 66,
#    'credits_earned': 800,
#    'hp_damage_taken': 121,
#    'shield_damage_taken': 25},
#   '1': {'elims': 0,
#    'deaths': 1,
#    'assists': 0,
#    'healing': 35,
#    'headshots': 0,
#    'shielding': 0,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 6,
#    'was_assisted': 0,
#    'credits_spent': 800,
#    'first_blooded': 0,
#    'seconds_alive': 102,
#    'credits_earned': 1900,
#    'hp_damage_taken': 135,
#    'shield_damage_taken': 0},
#   '2': {'elims': 0,
#    'deaths': 1,
#    'assists': 1,
#    'healing': 0,
#    'headshots': 0,
#    'shielding': 25,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 30,
#    'was_assisted': 0,
#    'credits_spent': 3450,
#    'first_blooded': 1,
#    'seconds_alive': 59,
#    'credits_earned': 2400,
#    'hp_damage_taken': 100,
#    'shield_damage_taken': 25},
#   '3': {'elims': 0,
#    'deaths': 2,
#    'assists': 0,
#    'healing': 200,
#    'headshots': 0,
#    'shielding': 150,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 24,
#    'was_assisted': 0,
#    'credits_spent': 1300,
#    'first_blooded': 0,
#    'seconds_alive': 84,
#    'credits_earned': 3400,
#    'hp_damage_taken': 300,
#    'shield_damage_taken': 150},
#   '4': {'elims': 0,
#    'deaths': 1,
#    'assists': 0,
#    'healing': 5,
#    'headshots': 0,
#    'shielding': 75,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 17,
#    'was_assisted': 0,
#    'credits_spent': 3950,
#    'first_blooded': 0,
#    'seconds_alive': 75,
#    'credits_earned': 2100,
#    'hp_damage_taken': 105,
#    'shield_damage_taken': 75},
#   '5': {'elims': 0,
#    'deaths': 0,
#    'assists': 1,
#    'healing': 86,
#    'headshots': 0,
#    'shielding': 100,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 19,
#    'was_assisted': 0,
#    'credits_spent': 1450,
#    'first_blooded': 0,
#    'seconds_alive': 61,
#    'credits_earned': 2400,
#    'hp_damage_taken': 186,
#    'shield_damage_taken': 100},
#   '6': {'elims': 1,
#    'deaths': 1,
#    'assists': 0,
#    'healing': 0,
#    'headshots': 1,
#    'shielding': 25,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 34,
#    'was_assisted': 0,
#    'credits_spent': 3300,
#    'first_blooded': 0,
#    'seconds_alive': 46,
#    'credits_earned': 3100,
#    'hp_damage_taken': 100,
#    'shield_damage_taken': 25},
#   '7': {'elims': 1,
#    'deaths': 0,
#    'assists': 0,
#    'healing': 125,
#    'headshots': 1,
#    'shielding': 50,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 18,
#    'was_assisted': 0,
#    'credits_spent': 250,
#    'first_blooded': 0,
#    'seconds_alive': 85,
#    'credits_earned': 0,
#    'hp_damage_taken': 225,
#    'shield_damage_taken': 50},
#   '8': {'elims': 0,
#    'deaths': 1,
#    'assists': 0,
#    'healing': 0,
#    'headshots': 0,
#    'shielding': 0,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 16,
#    'was_assisted': 0,
#    'credits_spent': 300,
#    'first_blooded': 0,
#    'seconds_alive': 67,
#    'credits_earned': 1900,
#    'hp_damage_taken': 100,
#    'shield_damage_taken': 0},
#   '9': {'elims': 0,
#    'deaths': 1,
#    'assists': 0,
#    'healing': 0,
#    'headshots': 0,
#    'shielding': 25,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 15,
#    'was_assisted': 0,
#    'credits_spent': 1550,
#    'first_blooded': 1,
#    'seconds_alive': 51,
#    'credits_earned': 0,
#    'hp_damage_taken': 100,
#    'shield_damage_taken': 25},
#   '10': {'elims': 0,
#    'deaths': 1,
#    'assists': 0,
#    'healing': 100,
#    'headshots': 0,
#    'shielding': 75,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 19,
#    'was_assisted': 0,
#    'credits_spent': 3300,
#    'first_blooded': 0,
#    'seconds_alive': 51,
#    'credits_earned': 2900,
#    'hp_damage_taken': 200,
#    'shield_damage_taken': 75},
#   '11': {'elims': 1,
#    'deaths': 0,
#    'assists': 0,
#    'healing': 0,
#    'headshots': 1,
#    'shielding': 50,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 22,
#    'was_assisted': 0,
#    'credits_spent': 3300,
#    'first_blooded': 0,
#    'seconds_alive': 66,
#    'credits_earned': 2900,
#    'hp_damage_taken': 100,
#    'shield_damage_taken': 50},
#   '12': {'elims': 0,
#    'deaths': 1,
#    'assists': 0,
#    'healing': 0,
#    'headshots': 0,
#    'shielding': 25,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 17,
#    'was_assisted': 0,
#    'credits_spent': 750,
#    'first_blooded': 0,
#    'seconds_alive': 68,
#    'credits_earned': 800,
#    'hp_damage_taken': 100,
#    'shield_damage_taken': 25},
#   '13': {'elims': 3,
#    'deaths': 0,
#    'assists': 0,
#    'healing': 290,
#    'headshots': 3,
#    'shielding': 100,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 22,
#    'was_assisted': 0,
#    'credits_spent': 2150,
#    'first_blooded': 0,
#    'seconds_alive': 84,
#    'credits_earned': 2400,
#    'hp_damage_taken': 290,
#    'shield_damage_taken': 50},
#   '14': {'elims': 0,
#    'deaths': 1,
#    'assists': 0,
#    'healing': 0,
#    'headshots': 0,
#    'shielding': 0,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 23,
#    'was_assisted': 0,
#    'credits_spent': 1650,
#    'first_blooded': 0,
#    'seconds_alive': 48,
#    'credits_earned': 3300,
#    'hp_damage_taken': 100,
#    'shield_damage_taken': 50},
#   '15': {'elims': 2,
#    'deaths': 1,
#    'assists': 0,
#    'healing': 184,
#    'headshots': 2,
#    'shielding': 134,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 3,
#    'was_assisted': 1,
#    'credits_spent': 500,
#    'first_blooded': 0,
#    'seconds_alive': 98,
#    'credits_earned': 3600,
#    'hp_damage_taken': 282,
#    'shield_damage_taken': 134},
#   '16': {'elims': 0,
#    'deaths': 0,
#    'assists': 0,
#    'healing': 187,
#    'headshots': 0,
#    'shielding': 124,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 24,
#    'was_assisted': 0,
#    'credits_spent': 4550,
#    'first_blooded': 0,
#    'seconds_alive': 42,
#    'credits_earned': 3600,
#    'hp_damage_taken': 200,
#    'shield_damage_taken': 100},
#   '17': {'elims': 1,
#    'deaths': 1,
#    'assists': 0,
#    'healing': 0,
#    'headshots': 0,
#    'shielding': 26,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 34,
#    'was_assisted': 0,
#    'credits_spent': 1150,
#    'first_blooded': 0,
#    'seconds_alive': 57,
#    'credits_earned': 3700,
#    'hp_damage_taken': 100,
#    'shield_damage_taken': 50},
#   '18': {'elims': 0,
#    'deaths': 1,
#    'assists': 0,
#    'healing': 200,
#    'headshots': 0,
#    'shielding': 150,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 78,
#    'was_assisted': 0,
#    'credits_spent': 4550,
#    'first_blooded': 0,
#    'seconds_alive': 51,
#    'credits_earned': 2200,
#    'hp_damage_taken': 300,
#    'shield_damage_taken': 150}},
#  'player_totals': {'seconds_using_melee': 258,
#   'elims_with_type_melee': 1,
#   'seconds_using_ability': 203,
#   'elims_with_type_primary': 3,
#   'elims_with_weapon_melee': 1,
#   'elims_with_weapon_vandal': 1,
#   'elims_with_weapon_classic': 3,
#   'elims_with_weapon_phantom': 1,
#   'elims_with_weapon_spectre': 1,
#   'seconds_holding_primary_none': 486,
#   'seconds_holding_primary_vandal': 445,
#   'seconds_holding_secondary_none': 6,
#   'seconds_holding_primary_bulldog': 8,
#   'seconds_holding_primary_marshal': 43,
#   'seconds_holding_primary_phantom': 87,
#   'seconds_holding_primary_spectre': 115,
#   'seconds_holding_primary_stinger': 45,
#   'seconds_holding_secondary_ghost': 33,
#   'seconds_holding_primary_guardian': 4,
#   'seconds_holding_primary_operator': 3,
#   'seconds_holding_secondary_shorty': 39,
#   'seconds_holding_secondary_classic': 1288,
#   'seconds_holding_secondary_sheriff': 62},
#  'opponent_score': 13,
#  'best_weapon_type': 'primary',
#  'best_weapon_elims': 3,
#  'most_used_primary': 'vandal',
#  'most_used_secondary': 'sheriff',
#  'best_weapon_type_elims': 3,
#  'most_used_primary_seconds': 445,
#  'most_used_secondary_seconds': 62}

# %% [markdown]
# ### Flattening the stats col by 1 level

# %%
flat1_df_stats = pd.json_normalize(df_stats['statistics'], max_level=0)
flat1_df_stats = pd.concat([df_stats['user_id'], flat1_df_stats], axis=1)
print(flat1_df_stats.shape)
flat1_df_stats
# Out:
# (448, 34)
#      user_id      map  score           allies player result  \
# 0       3807    Pearl   6-13  [0, 1, 2, 3, 4]      2   loss
# 1       3804  unknown  12-14  [0, 1, 2, 3, 4]      4   loss
# 2       3806    Split   4-13  [0, 1, 2, 3, 4]      2   loss
# 3       3808    Haven   8-13  [0, 1, 2, 3, 4]      4   loss
# 4       3807   Ascent   13-8  [0, 1, 2, 3, 4]      2    win
# ..       ...      ...    ...              ...    ...    ...
# 443     3799   Ascent   9-13  [0, 1, 2, 3, 4]      4   loss
# 444     3798     Bind  13-10  [0, 1, 2, 3, 4]      0    win
# 445     3795  unknown  16-14  [0, 1, 2, 3, 4]      1    win
# 446     3795  unknown   3-13  [0, 1, 2, 3, 4]      3   loss
# 447     3795  unknown   13-9  [0, 1, 2, 3, 4]      0    win
#
#                                                 rounds  \
# 0    {'0': {'alive': {'0': [[89993, True], [134989,...
# 1    {'0': {'alive': {'0': [[3600, True], [105400, ...
# 2    {'0': {'alive': {'0': [[0, True], [41600, Fals...
# 3    {'0': {'alive': {'0': [[1200, True], [53800, F...
# 4    {'0': {'alive': {'0': [[2999, True], [62795, F...
# ..                                                 ...
# 443  {'9': {'alive': {'0': [[0, True], [50200, Fals...
# 444  {'0': {'alive': {'0': [[3999, True], [101999, ...
# 445  {'0': {'alive': {'0': [[75813, True], [151027,...
# 446  {'0': {'alive': {'0': [[3200, True], [75813, F...
# 447  {'0': {'alive': {'0': [[84015, True], [137624,...
#
#                                         status  \
# 0    success: completed - valorant postprocess
# 1    success: completed - valorant postprocess
# 2    success: completed - valorant postprocess
# 3    success: completed - valorant postprocess
# 4    success: completed - valorant postprocess
# ..                                         ...
# 443        success: completed - valorant final
# 444        success: completed - valorant final
# 445        success: completed - valorant final
# 446        success: completed - valorant final
# 447        success: completed - valorant final
#
#                                                 totals version  ...  \
# 0    {'elims': 9, 'deaths': 14, 'assists': 3, 'heal...   1.0.0  ...
# 1    {'elims': 20, 'deaths': 17, 'assists': 5, 'hea...   1.0.0  ...
# 2    {'elims': 13, 'deaths': 16, 'assists': 3, 'hea...   1.0.0  ...
# 3    {'elims': 16, 'deaths': 12, 'assists': 4, 'hea...   1.0.0  ...
# 4    {'elims': 19, 'deaths': 10, 'assists': 15, 'he...   1.0.0  ...
# ..                                                 ...     ...  ...
# 443  {'elims': 10, 'deaths': 10, 'assists': 7, 'hea...   1.0.0  ...
# 444  {'elims': 25, 'deaths': 14, 'assists': 3, 'hea...   1.0.0  ...
# 445  {'elims': 25, 'deaths': 19, 'assists': 17, 'he...   1.0.0  ...
# 446  {'elims': 16, 'deaths': 13, 'assists': 0, 'hea...   1.0.0  ...
# 447  {'elims': 17, 'deaths': 17, 'assists': 2, 'hea...   1.0.0  ...
#
#      most_used_secondary best_weapon_type_elims most_used_primary_seconds  \
# 0                sheriff                      3                       445
# 1                sheriff                     10                      1528
# 2                sheriff                      6                       659
# 3                  ghost                      8                       475
# 4                  ghost                     11                      1082
# ..                   ...                    ...                       ...
# 443               frenzy                      7                       338
# 444                ghost                     12                       448
# 445                ghost                     10                      1655
# 446                ghost                      8                       280
# 447                ghost                      6                       395
#
#      most_used_secondary_seconds processed  \
# 0                             62       NaN
# 1                            164       NaN
# 2                            115       NaN
# 3                             96       NaN
# 4                            256       NaN
# ..                           ...       ...
# 443                          176      True
# 444                           67      True
# 445                          153      True
# 446                          205      True
# 447                          149      True
#
#                                        allies_onscreen  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 443  {'7150': 1, '14100': 2, '14200': 1, '16400': 0...
# 444  {'5449': 0, '9649': 1, '46999': 2, '47849': 1,...
# 445  {'33': 1, '79847': 2, '79981': 1, '80247': 2, ...
# 446  {'8901': 1, '14169': 0, '14202': 1, '39473': 2...
# 447  {'4367': 1, '119988': 2, '120055': 1, '120088'...
#
#                                   analysis_status  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 443  completed: processing - anyalysis (insights)
# 444  completed: processing - anyalysis (insights)
# 445  completed: processing - anyalysis (insights)
# 446  completed: processing - anyalysis (insights)
# 447  completed: processing - anyalysis (insights)
#
#                                      detections_totals analysis_processed  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2                                                  NaN                NaN
# 3                                                  NaN                NaN
# 4                                                  NaN                NaN
# ..                                                 ...                ...
# 443  {'23': {'final_time': 16500, 'initial_size': {...               True
# 444  {'2': {'final_time': 5749, 'initial_size': {'h...               True
# 445  {'83': {'final_time': 125222, 'initial_size': ...               True
# 446  {'4': {'final_time': 14302, 'initial_size': {'...               True
# 447  {'161': {'final_time': 157861, 'initial_size':...               True
#
#                                     opponents_onscreen
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 443  {'7150': 0, '16400': 1, '20500': 0, '21850': 1...
# 444  {'5449': 1, '9649': 0, '88399': 1, '90699': 0,...
# 445  {'33': 0, '125022': 1, '125056': 0, '125089': ...
# 446  {'8901': 0, '14169': 1, '14202': 0, '14235': 1...
# 447  {'4367': 0, '157228': 1, '157728': 2, '157828'...
#
# [448 rows x 34 columns]

# %% [markdown]
# ### Removing some cols we don't care about from the ROUND perspective
# - Keep in mind the 'totals', 'result' are from the MATCH perspective
# - even though the map is from match perspective I need it so I am adding it in (similar to userID)
# - weapon stuff is all from match perspective, so I am dropping (some exists in rounds data anyway)
# - I think its possible to do something with 'allies_onscreen', 'opponents_onscreen', and 'detections_totals' but I am dropping for now

# %%
flat1_df_stats = flat1_df_stats.drop(['totals','score', 'allies','result', 'status','gametype','version','end_time','opponents','processed','ally_score','start_time','opponent_score','detections_totals','best_weapon_elims','most_used_primary_seconds','analysis_processed','most_used_secondary_seconds','best_weapon_type_elims','opponents_onscreen','allies_onscreen','analysis_status','player_totals','best_weapon_type','best_weapon','most_used_secondary','most_used_primary','best_weapon_type_elims'], axis=1)
print(flat1_df_stats.shape)
flat1_df_stats
# Out:
# (448, 7)
#      user_id      map player  \
# 0       3807    Pearl      2
# 1       3804  unknown      4
# 2       3806    Split      2
# 3       3808    Haven      4
# 4       3807   Ascent      2
# ..       ...      ...    ...
# 443     3799   Ascent      4
# 444     3798     Bind      0
# 445     3795  unknown      1
# 446     3795  unknown      3
# 447     3795  unknown      0
#
#                                                 rounds  \
# 0    {'0': {'alive': {'0': [[89993, True], [134989,...
# 1    {'0': {'alive': {'0': [[3600, True], [105400, ...
# 2    {'0': {'alive': {'0': [[0, True], [41600, Fals...
# 3    {'0': {'alive': {'0': [[1200, True], [53800, F...
# 4    {'0': {'alive': {'0': [[2999, True], [62795, F...
# ..                                                 ...
# 443  {'9': {'alive': {'0': [[0, True], [50200, Fals...
# 444  {'0': {'alive': {'0': [[3999, True], [101999, ...
# 445  {'0': {'alive': {'0': [[75813, True], [151027,...
# 446  {'0': {'alive': {'0': [[3200, True], [75813, F...
# 447  {'0': {'alive': {'0': [[84015, True], [137624,...
#
#                                             player_ids  \
# 0    {'0': {'role': 'ally', 'character': 'gekko'}, ...
# 1    {'0': {'role': 'ally', 'character': 'raze'}, '...
# 2    {'0': {'role': 'ally', 'character': 'brimstone...
# 3    {'0': {'role': 'ally', 'character': 'yoru'}, '...
# 4    {'0': {'role': 'ally', 'character': 'neon'}, '...
# ..                                                 ...
# 443  {'0': {'role': 'ally', 'character': 'cypher'},...
# 444  {'0': {'role': 'self', 'character': 'sage'}, '...
# 445  {'0': {'role': 'ally', 'character': 'raze'}, '...
# 446  {'0': {'role': 'ally', 'character': 'omen'}, '...
# 447  {'0': {'role': 'self', 'character': 'jett'}, '...
#
#                                             round_info  \
# 0    {'0': {'score': '0-0', 'ult_used': False, 'all...
# 1    {'0': {'score': '0-0', 'ult_used': False, 'all...
# 2    {'0': {'score': '0-0', 'ult_used': False, 'all...
# 3    {'0': {'score': '0-0', 'ult_used': False, 'all...
# 4    {'0': {'score': '0-0', 'ult_used': False, 'all...
# ..                                                 ...
# 443  {'9': {'score': '6-3', 'ult_used': False, 'all...
# 444  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 445  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 446  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 447  {'0': {'score': '0-0', 'ult_used': True, 'ally...
#
#                                           round_totals
# 0    {'0': {'elims': 0, 'deaths': 0, 'assists': 1, ...
# 1    {'0': {'elims': 1, 'deaths': 1, 'assists': 0, ...
# 2    {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...
# 3    {'0': {'elims': 1, 'deaths': 1, 'assists': 0, ...
# 4    {'0': {'elims': 2, 'deaths': 0, 'assists': 1, ...
# ..                                                 ...
# 443  {'9': {'elims': 1, 'deaths': 0, 'assists': 1, ...
# 444  {'0': {'elims': 1, 'deaths': 1, 'assists': 0, ...
# 445  {'0': {'elims': 1, 'deaths': 0, 'assists': 0, ...
# 446  {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...
# 447  {'0': {'elims': 1, 'deaths': 1, 'assists': 0, ...
#
# [448 rows x 7 columns]

# %% [markdown]
# ### Flattening the player_ids col by 1 level
# - this is getting all the teammates and opponents, as well as mapping the 'player' to an ally

# %%
# Create an empty list to hold the expanded player ids
expanded_player_ids_list = []

for i, player_ids in enumerate(flat1_df_stats['player_ids']):
    mapping = {}
    for player_id, player_info in player_ids.items():
        # If the role is 'self', map it to 'ally'
        role = 'ally' if player_info['role'] == 'self' else player_info['role']
        column_name = f"{role}{player_id}_character"
        mapping[column_name] = player_info['character']
    
    # If mapping is not empty
    if mapping:
        expanded_player_ids_list.append(mapping)
        
# Create the expanded_player_ids DataFrame
expanded_player_ids = pd.DataFrame(expanded_player_ids_list)

# Concatenate the original DataFrame with the expanded columns
flat2_df_stats_chars = pd.concat([flat1_df_stats.drop('player_ids', axis=1), expanded_player_ids], axis=1)

print(flat2_df_stats_chars.shape)
flat2_df_stats_chars
# Out:
# (448, 16)
#      user_id      map player  \
# 0       3807    Pearl      2
# 1       3804  unknown      4
# 2       3806    Split      2
# 3       3808    Haven      4
# 4       3807   Ascent      2
# ..       ...      ...    ...
# 443     3799   Ascent      4
# 444     3798     Bind      0
# 445     3795  unknown      1
# 446     3795  unknown      3
# 447     3795  unknown      0
#
#                                                 rounds  \
# 0    {'0': {'alive': {'0': [[89993, True], [134989,...
# 1    {'0': {'alive': {'0': [[3600, True], [105400, ...
# 2    {'0': {'alive': {'0': [[0, True], [41600, Fals...
# 3    {'0': {'alive': {'0': [[1200, True], [53800, F...
# 4    {'0': {'alive': {'0': [[2999, True], [62795, F...
# ..                                                 ...
# 443  {'9': {'alive': {'0': [[0, True], [50200, Fals...
# 444  {'0': {'alive': {'0': [[3999, True], [101999, ...
# 445  {'0': {'alive': {'0': [[75813, True], [151027,...
# 446  {'0': {'alive': {'0': [[3200, True], [75813, F...
# 447  {'0': {'alive': {'0': [[84015, True], [137624,...
#
#                                             round_info  \
# 0    {'0': {'score': '0-0', 'ult_used': False, 'all...
# 1    {'0': {'score': '0-0', 'ult_used': False, 'all...
# 2    {'0': {'score': '0-0', 'ult_used': False, 'all...
# 3    {'0': {'score': '0-0', 'ult_used': False, 'all...
# 4    {'0': {'score': '0-0', 'ult_used': False, 'all...
# ..                                                 ...
# 443  {'9': {'score': '6-3', 'ult_used': False, 'all...
# 444  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 445  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 446  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 447  {'0': {'score': '0-0', 'ult_used': True, 'ally...
#
#                                           round_totals ally0_character  \
# 0    {'0': {'elims': 0, 'deaths': 0, 'assists': 1, ...           gekko
# 1    {'0': {'elims': 1, 'deaths': 1, 'assists': 0, ...            raze
# 2    {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...       brimstone
# 3    {'0': {'elims': 1, 'deaths': 1, 'assists': 0, ...            yoru
# 4    {'0': {'elims': 2, 'deaths': 0, 'assists': 1, ...            neon
# ..                                                 ...             ...
# 443  {'9': {'elims': 1, 'deaths': 0, 'assists': 1, ...          cypher
# 444  {'0': {'elims': 1, 'deaths': 1, 'assists': 0, ...            sage
# 445  {'0': {'elims': 1, 'deaths': 0, 'assists': 0, ...            raze
# 446  {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...            omen
# 447  {'0': {'elims': 1, 'deaths': 1, 'assists': 0, ...            jett
#
#     ally1_character ally2_character ally3_character ally4_character  \
# 0             viper         phoenix           astra            jett
# 1           killjoy            sage            skye            omen
# 2             reyna         killjoy            jett            skye
# 3              jett         chamber         killjoy            sova
# 4              sova            omen          breach         phoenix
# ..              ...             ...             ...             ...
# 443           astra            raze            sova            sage
# 444            raze            jett         chamber           reyna
# 445           viper            jett       brimstone            skye
# 446            jett           kay/o         killjoy            yoru
# 447            skye            sova           reyna          breach
#
#     opponent5_character opponent6_character opponent7_character  \
# 0                harbor             killjoy                jett
# 1             brimstone                raze             killjoy
# 2                  omen             killjoy                jett
# 3                  jett                omen             killjoy
# 4               killjoy                sova                jett
# ..                  ...                 ...                 ...
# 443               kay/o             killjoy                omen
# 444             phoenix                sova                raze
# 445                raze                sova                jett
# 446               astra                jett               reyna
# 447                jett               gekko                omen
#
#     opponent8_character opponent9_character
# 0                 astra                yoru
# 1                  jett                skye
# 2                  skye                raze
# 3                 reyna                fade
# 4                  omen               reyna
# ..                  ...                 ...
# 443                sova                jett
# 444           brimstone             chamber
# 445               viper           brimstone
# 446                raze                sova
# 447             killjoy                sova
#
# [448 rows x 16 columns]

# %% [markdown]
# ### Flattening the round_info/round_totals cols by 1 level
# - This is where the DF expands into rounds being the rows instead of matches being the rows
# - Have to parse the round info/round totals at the same time

# %%
# Initialize an empty dictionary to store map names and unique areas
map_areas = {}
for index, row in flat2_df_stats_chars.iterrows():
    # for all the rounds in each match
    for round_number, round_data in row['round_info'].items():
        # get the current/original row.
        new_row = row.to_dict()
        # exclude the original complex columns that we're flattening
        new_row.pop('rounds', None)
        new_row.pop('round_info', None)
        
        # get current map
        cur_map = new_row['map']

        # Initialize a new set for this map if it doesn't exist in map_areas
        if cur_map not in map_areas:
            map_areas[cur_map] = set()
            
        # Add round number to the new row
        new_row['round_number'] = round_number
        

        # Flatten rounds data into the new row
        for key, value in row['rounds'][round_number].items():
            if key == 'map_region':
                # value should be a list of lists where each sublist's second element is an area
                for sublist in value:
                    # Add the area to the set corresponding to the current map
                    map_areas[cur_map].add(sublist[1])

# %%
flat2_df_stats_chars.iloc[10:20]
# Out:
#     user_id      map player  \
# 10     3806    Lotus      3
# 11     3804    Lotus      4
# 12     3806   Ascent      3
# 13     3808    Lotus      3
# 14     3806    Haven      3
# 15     3804  unknown      1
# 16     3806    Lotus      0
# 17     3806    Split      1
# 18     3806    Lotus      2
# 19     3808     Bind      4
#
#                                                rounds  \
# 10  {'0': {'alive': {'0': [[3600, True], [88200, F...
# 11  {'0': {'alive': {'0': [[3600, True], [73000, F...
# 12  {'0': {'alive': {'0': [[53600, True], [131800,...
# 13  {'0': {'alive': {'0': [[2200, True], [71000, F...
# 14  {'0': {'alive': {'0': [[3400, True], [129400, ...
# 15  {'0': {'alive': {'0': [[3600, True], [80400, F...
# 16  {'0': {'alive': {'0': [[118000, True], [191800...
# 17  {'0': {'alive': {'0': [[95400, True], [173200,...
# 18  {'0': {'alive': {'0': [[18000, True], [100200,...
# 19  {'0': {'alive': {'0': [[39400, True], [157800,...
#
#                                            round_info  \
# 10  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 11  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 12  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 13  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 14  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 15  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 16  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 17  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 18  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 19  {'0': {'score': '0-0', 'ult_used': True, 'ally...
#
#                                          round_totals ally0_character  \
# 10  {'0': {'elims': 0, 'deaths': 1, 'assists': 1, ...         killjoy
# 11  {'0': {'elims': 0, 'deaths': 1, 'assists': 1, ...            raze
# 12  {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...            omen
# 13  {'0': {'elims': 1, 'deaths': 1, 'assists': 0, ...            raze
# 14  {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...            jett
# 15  {'0': {'elims': 0, 'deaths': 0, 'assists': 2, ...            jett
# 16  {'0': {'elims': 0, 'deaths': 1, 'assists': 1, ...            skye
# 17  {'0': {'elims': 0, 'deaths': 0, 'assists': 0, ...            skye
# 18  {'0': {'elims': 1, 'deaths': 0, 'assists': 1, ...            jett
# 19  {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...            jett
#
#    ally1_character ally2_character ally3_character ally4_character  \
# 10            jett           reyna            skye            omen
# 11       brimstone            jett         killjoy            skye
# 12            jett            fade          cypher            sage
# 13            omen            sova            skye            jett
# 14            skye           viper         killjoy            omen
# 15            omen         killjoy            sova           reyna
# 16          cypher           reyna            jett            omen
# 17           astra            sage          cypher            raze
# 18            omen            skye         chamber         killjoy
# 19            omen            skye           reyna            sage
#
#    opponent5_character opponent6_character opponent7_character  \
# 10                jett                skye              breach
# 11                omen             phoenix                raze
# 12                jett             killjoy                omen
# 13             chamber                omen                jett
# 14                omen             killjoy                jett
# 15                raze                jett                omen
# 16                omen             killjoy              breach
# 17             killjoy                omen               reyna
# 18                omen                skye                jett
# 19             chamber                jett              harbor
#
#    opponent8_character opponent9_character
# 10               astra              cypher
# 11               reyna               viper
# 12               reyna                sova
# 13                raze                skye
# 14                sova               reyna
# 15             killjoy                sova
# 16                neon                jett
# 17                skye                sage
# 18             killjoy               reyna
# 19                skye               viper

# %%
def calculate_metrics(key, value, cur_player, new_row, spike_time):
    pre_spike_total = 0
    post_spike_total = 0
    pre_spike_entries = 0
    post_spike_entries = 0
    pre_spike_max_loss = 0
    post_spike_max_loss = 0
    pre_spike_total_loss = 0
    post_spike_total_loss = 0
    last_value = None

    for entry in value:
        entry_time = entry[0]
        entry_value = entry[1]

        if last_value is not None:
            value_loss = max(0, last_value - entry_value)
            if spike_time is None or entry_time < spike_time:
                pre_spike_max_loss = max(pre_spike_max_loss, value_loss)
                pre_spike_total_loss += value_loss
            elif spike_time:
                post_spike_max_loss = max(post_spike_max_loss, value_loss)
                post_spike_total_loss += value_loss

        last_value = entry_value

        if spike_time is None or entry_time < spike_time:
            pre_spike_total += entry_value
            pre_spike_entries += 1
        elif spike_time:
            post_spike_total += entry_value
            post_spike_entries += 1

    pre_spike_avg = pre_spike_total / pre_spike_entries if pre_spike_entries > 0 else 0
    post_spike_avg = post_spike_total / post_spike_entries if post_spike_entries > 0 else 0

    new_row[f'ally{cur_player}_pre_spike_avg_{key}'] = pre_spike_avg
    new_row[f'ally{cur_player}_post_spike_avg_{key}'] = post_spike_avg
    new_row[f'ally{cur_player}_pre_spike_max_{key}_loss'] = pre_spike_max_loss
    new_row[f'ally{cur_player}_post_spike_max_{key}_loss'] = post_spike_max_loss
    new_row[f'ally{cur_player}_pre_spike_total_{key}_loss'] = pre_spike_total_loss
    new_row[f'ally{cur_player}_post_spike_total_{key}_loss'] = post_spike_total_loss

# %%
def calculate_longest_duration(key, value, cur_player, new_row, spike_time):
    current_item = None
    longest_duration = 0
    longest_item = None
    pre_spike_longest_item = None
    post_spike_longest_item = None
    pre_spike_longest_duration = 0
    post_spike_longest_duration = 0

    for entry in value:
        timestamp = entry[0]
        item = entry[1]

        if current_item is None:
            current_item = item
            start_time = timestamp
        elif item != current_item:
            duration = timestamp - start_time
            if duration > longest_duration:
                longest_duration = duration
                longest_item = current_item

            if spike_time is None or start_time < spike_time:  # pre-spike or no spike
                if duration > pre_spike_longest_duration:
                    pre_spike_longest_duration = duration
                    pre_spike_longest_item = current_item
            elif spike_time and start_time >= spike_time:  # post-spike
                if duration > post_spike_longest_duration:
                    post_spike_longest_duration = duration
                    post_spike_longest_item = current_item

            current_item = item
            start_time = timestamp

    new_row[f'ally{cur_player}_longest_{key}'] = longest_item
    new_row[f'ally{cur_player}_pre_spike_longest_{key}'] = pre_spike_longest_item
    new_row[f'ally{cur_player}_post_spike_longest_{key}'] = post_spike_longest_item

# %%
def calculate_ability_usage(cur_player, ability_charges, spike_time, identifier, new_row):
    pre_spike_total_ability_usage = 0
    post_spike_total_ability_usage = 0

    for i in range(len(ability_charges) - 1):
        ability_time = ability_charges[i + 1][0]
        if ability_charges[i + 1][1] == 1:
            if spike_time is None or ability_time < spike_time:  # pre-spike or no spike
                pre_spike_total_ability_usage += 1
            elif spike_time:  # post-spike
                post_spike_total_ability_usage += 1

    new_row[f'ally{cur_player}_pre_spike_total_ability_usage_{identifier}'] = pre_spike_total_ability_usage
    new_row[f'ally{cur_player}_post_spike_total_ability_usage_{identifier}'] = post_spike_total_ability_usage

#     def calculate_ability_usage(cur_player, ability_charges, spike_time, identifier, new_row):
#     pre_spike_total_ability_usage = 0
#     post_spike_total_ability_usage = 0

#     for i in range(len(ability_charges) - 1):
#         ability_time = ability_charges[i + 1][0]
#         current_charge = ability_charges[i + 1][1]
#         previous_charge = ability_charges[i][1]

#         if previous_charge > current_charge:
#             if spike_time is None or ability_time < spike_time:  # pre-spike or no spike
#                 pre_spike_total_ability_usage += previous_charge - current_charge
#             elif spike_time:  # post-spike
#                 post_spike_total_ability_usage += previous_charge - current_charge

#     new_row[f'ally{cur_player}_pre_spike_total_ability_usage_{identifier}'] = pre_spike_total_ability_usage
#     new_row[f'ally{cur_player}_post_spike_total_ability_usage_{identifier}'] = post_spike_total_ability_usage

# %%
# First pass: get spike plant time for each round
spike_times = {}  # Create a dictionary to store the spike_time for each round
for index, row in flat2_df_stats_chars.iterrows():
    for round_number, round_data in row['round_info'].items():
        for key, value in row['rounds'][round_number].items():
            if key == 'spike_planted':
                # Initialize default values
                spike_yn = False
                time = 0
                rounds_spike_planted = value
                # Iterate over the list to find the first instance of spike planted
                for item in value:
                    if item[1]:  # Check if spike was planted
                        spike_yn = item[1]
                        time = item[0]
                        break  # Stop iterating after finding the first instance
   
                spike_times[(index, round_number)] = time if spike_yn else None

# %%
spike_times
# Out:
# {(0, '0'): None,
#  (0, '1'): 257180,
#  (0, '2'): None,
#  (0, '3'): 471764,
#  (0, '4'): 540359,
#  (0, '5'): None,
#  (0, '6'): None,
#  (0, '7'): None,
#  (0, '8'): 906931,
#  (0, '9'): None,
#  (0, '10'): 1045321,
#  (0, '11'): 1122715,
#  (0, '12'): None,
#  (0, '13'): 1322700,
#  (0, '14'): None,
#  (0, '15'): None,
#  (0, '16'): None,
#  (0, '17'): 1655875,
#  (0, '18'): 1774066,
#  (1, '0'): 111800,
#  (1, '1'): None,
#  (1, '2'): 282600,
#  (1, '3'): None,
#  (1, '4'): None,
#  (1, '5'): 605200,
#  (1, '6'): None,
#  (1, '7'): 812800,
#  (1, '8'): None,
#  (1, '9'): None,
#  (1, '10'): 1075800,
#  (1, '11'): 1174200,
#  (1, '12'): 1273800,
#  (1, '13'): 1376200,
#  (1, '14'): 1494000,
#  (1, '15'): 1570600,
#  (1, '16'): None,
#  (1, '17'): None,
#  (1, '18'): 1860800,
#  (1, '19'): None,
#  (1, '20'): 2108600,
#  (1, '21'): 2260200,
#  (1, '22'): 2359400,
#  (1, '23'): None,
#  (1, '24'): 2569800,
#  (1, '25'): None,
#  (2, '0'): None,
#  (2, '1'): None,
#  (2, '2'): 201600,
#  (2, '3'): 318000,
#  (2, '4'): None,
#  (2, '5'): None,
#  (2, '6'): None,
#  (2, '7'): 661600,
#  (2, '8'): None,
#  (2, '9'): None,
#  (2, '10'): 895600,
#  (2, '11'): 982201,
#  (2, '12'): None,
#  (2, '13'): None,
#  (2, '14'): None,
#  (2, '15'): None,
#  (2, '16'): None,
#  (3, '0'): 65600,
#  (3, '1'): 158600,
#  (3, '2'): None,
#  (3, '3'): 342800,
#  (3, '4'): None,
#  (3, '5'): 598200,
#  (3, '6'): 698200,
#  (3, '7'): 778601,
#  (3, '8'): None,
#  (3, '9'): None,
#  (3, '10'): 1006201,
#  (3, '11'): 1107001,
#  (3, '12'): None,
#  (3, '13'): None,
#  (3, '14'): None,
#  (3, '15'): None,
#  (3, '16'): 1581602,
#  (3, '17'): None,
#  (3, '18'): 1754202,
#  (3, '19'): 1856802,
#  (3, '20'): 1986802,
#  (4, '0'): 68194,
#  (4, '1'): 156988,
#  (4, '2'): 248381,
#  (4, '3'): None,
#  (4, '4'): 458165,
#  (4, '5'): 560557,
#  (4, '6'): 649351,
#  (4, '7'): 742943,
#  (4, '8'): None,
#  (4, '9'): None,
#  (4, '10'): None,
#  (4, '11'): None,
#  (4, '12'): 1150713,
#  (4, '13'): 1250705,
#  (4, '14'): None,
#  (4, '15'): None,
#  (4, '16'): None,
#  (4, '17'): 1707271,
#  (4, '18'): None,
#  (4, '19'): 1906056,
#  (4, '20'): None,
#  (5, '0'): None,
#  (5, '1'): None,
#  (5, '2'): 235400,
#  (5, '3'): None,
#  (5, '4'): 415400,
#  (5, '5'): 496600,
#  (5, '6'): None,
#  (5, '7'): None,
#  (5, '8'): None,
#  (5, '9'): 839200,
#  (5, '10'): None,
#  (5, '11'): None,
#  (5, '12'): None,
#  (5, '13'): 1240001,
#  (5, '14'): 1311801,
#  (5, '15'): None,
#  (5, '16'): None,
#  (5, '17'): None,
#  (5, '18'): None,
#  (6, '0'): 160400,
#  (6, '1'): None,
#  (6, '2'): None,
#  (6, '3'): None,
#  (6, '4'): 525800,
#  (6, '5'): None,
#  (6, '6'): None,
#  (6, '7'): 876000,
#  (6, '8'): None,
#  (6, '9'): 1006600,
#  (6, '10'): 1086800,
#  (6, '11'): 1202600,
#  (6, '12'): 1294600,
#  (6, '13'): 1424000,
#  (6, '14'): None,
#  (6, '15'): None,
#  (6, '16'): None,
#  (6, '17'): None,
#  (6, '18'): None,
#  (6, '19'): None,
#  (6, '20'): 2070600,
#  (6, '21'): None,
#  (6, '22'): None,
#  (6, '23'): None,
#  (6, '24'): None,
#  (6, '25'): 2558000,
#  (6, '26'): None,
#  (6, '27'): 2711600,
#  (7, '0'): 150000,
#  (7, '1'): 284200,
#  (7, '2'): 370000,
#  (7, '3'): None,
#  (7, '4'): None,
#  (7, '5'): None,
#  (7, '6'): 783800,
#  (7, '7'): 947200,
#  (7, '8'): 1039200,
#  (7, '9'): 1185600,
#  (7, '10'): None,
#  (7, '11'): 1384201,
#  (7, '12'): None,
#  (7, '13'): 1570601,
#  (7, '14'): None,
#  (7, '15'): None,
#  (7, '16'): 1865601,
#  (7, '17'): 1971801,
#  (8, '0'): 99792,
#  (8, '1'): 186585,
#  (8, '2'): None,
#  (8, '3'): 374371,
#  (8, '4'): 515361,
#  (8, '5'): None,
#  (8, '6'): 732744,
#  (8, '7'): 847936,
#  (8, '8'): 956527,
#  (8, '9'): None,
#  (8, '10'): None,
#  (8, '11'): None,
#  (8, '12'): 1311301,
#  (8, '13'): 1390695,
#  (8, '14'): None,
#  (8, '15'): 1603279,
#  (8, '16'): None,
#  (8, '17'): 1804463,
#  (8, '18'): 1936053,
#  (8, '19'): None,
#  (8, '20'): None,
#  (8, '21'): None,
#  (9, '0'): None,
#  (9, '1'): None,
#  (9, '2'): None,
#  (9, '3'): 416000,
#  (9, '4'): None,
#  (9, '5'): None,
#  (9, '6'): 694800,
#  (9, '7'): None,
#  (9, '8'): None,
#  (9, '9'): 972801,
#  (9, '10'): 1067001,
#  (9, '11'): None,
#  (9, '12'): None,
#  (9, '13'): None,
#  (9, '14'): 1395601,
#  (9, '15'): None,
#  (9, '16'): 1568002,
#  (9, '17'): 1643002,
#  (9, '18'): None,
#  (9, '19'): None,
#  (9, '20'): None,
#  (9, '21'): None,
#  (9, '22'): None,
#  (10, '0'): None,
#  (10, '1'): 211200,
#  (10, '2'): 345000,
#  (10, '3'): None,
#  (10, '4'): None,
#  (10, '5'): 607200,
#  (10, '6'): 744400,
#  (10, '7'): 857000,
#  (10, '8'): 932400,
#  (10, '9'): None,
#  (10, '10'): None,
#  (10, '11'): None,
#  (10, '12'): 1289201,
#  (10, '13'): None,
#  (10, '14'): 1468601,
#  (10, '15'): 1564201,
#  (10, '16'): 1657201,
#  (10, '17'): None,
#  (10, '18'): 1825001,
#  (10, '19'): None,
#  (10, '20'): 2011802,
#  (10, '21'): None,
#  (10, '22'): 2136402,
#  (11, '0'): 82200,
#  (11, '1'): 165600,
#  (11, '2'): 252800,
#  (11, '3'): None,
#  (11, '4'): None,
#  (11, '5'): 472600,
#  (11, '6'): None,
#  (11, '7'): None,
#  (11, '8'): None,
#  (11, '9'): None,
#  (11, '10'): None,
#  (11, '11'): 999400,
#  (11, '12'): None,
#  (11, '13'): None,
#  (11, '14'): 1224200,
#  (11, '15'): None,
#  (11, '16'): 1401200,
#  (11, '17'): 1515400,
#  (11, '18'): None,
#  (11, '19'): None,
#  (11, '20'): 1775000,
#  (11, '21'): 1858600,
#  (11, '22'): 1939400,
#  (12, '0'): 122600,
#  (12, '1'): 217800,
#  (12, '2'): None,
#  (12, '3'): None,
#  (12, '4'): None,
#  (12, '5'): 538400,
#  (12, '6'): None,
#  (12, '7'): None,
#  (12, '8'): None,
#  (12, '9'): None,
#  (12, '10'): 923600,
#  (12, '11'): None,
#  (12, '12'): None,
#  (12, '13'): None,
#  (12, '14'): 1272000,
#  (12, '15'): 1337401,
#  (12, '16'): 1460601,
#  (12, '17'): 1568401,
#  (12, '18'): 1659801,
#  (12, '19'): None,
#  (12, '20'): None,
#  (12, '21'): None,
#  (13, '0'): 68400,
#  (13, '1'): 153400,
#  (13, '2'): 255200,
#  (13, '3'): 352200,
#  (13, '4'): None,
#  (13, '5'): 547200,
#  (13, '6'): None,
#  (13, '7'): 726600,
#  (13, '8'): None,
#  (13, '9'): 860201,
#  (13, '10'): 982201,
#  (13, '11'): 1074001,
#  (13, '12'): 1220201,
#  (13, '13'): 1329401,
#  (13, '14'): 1421401,
#  (13, '15'): 1538002,
#  (13, '16'): 1636602,
#  (13, '17'): 1758602,
#  (13, '18'): 1889202,
#  (13, '19'): None,
#  (13, '20'): 2078402,
#  (13, '21'): None,
#  (13, '22'): 2294603,
#  (13, '23'): None,
#  (14, '0'): 100400,
#  (14, '1'): None,
#  (14, '2'): None,
#  (14, '3'): None,
#  (14, '4'): None,
#  (14, '5'): None,
#  (14, '6'): 644400,
#  (14, '7'): None,
#  (14, '8'): 780200,
#  (14, '9'): None,
#  (14, '10'): 962401,
#  (14, '11'): None,
#  (14, '12'): 1200001,
#  (14, '13'): 1269401,
#  (14, '14'): None,
#  (14, '15'): None,
#  (14, '16'): 1567001,
#  (14, '17'): 1716801,
#  (14, '18'): None,
#  (14, '19'): 1894202,
#  (14, '20'): None,
#  (14, '21'): None,
#  (14, '22'): None,
#  (14, '23'): 2207602,
#  (15, '0'): 70200,
#  (15, '1'): 175200,
#  (15, '2'): 279400,
#  (15, '3'): None,
#  (15, '4'): None,
#  (15, '5'): None,
#  (15, '6'): 617800,
#  (15, '7'): 714400,
#  (15, '8'): 839200,
#  (15, '9'): 925000,
#  (15, '10'): None,
#  (15, '11'): None,
#  (15, '12'): 1164200,
#  (15, '13'): 1261600,
#  (15, '14'): 1359600,
#  (15, '15'): 1453800,
#  (15, '16'): 1551200,
#  (15, '17'): None,
#  (15, '18'): None,
#  (15, '19'): 1800400,
#  (15, '20'): 1934600,
#  (15, '21'): 2041000,
#  (15, '22'): 2151600,
#  (16, '0'): 176400,
#  (16, '1'): 281200,
#  (16, '2'): None,
#  (16, '3'): 435800,
#  (16, '4'): None,
#  (16, '5'): None,
#  (16, '6'): 664800,
#  (16, '7'): None,
#  (16, '8'): None,
#  (16, '9'): 914800,
#  (16, '10'): 1036800,
#  (16, '11'): None,
#  (16, '12'): None,
#  (16, '13'): None,
#  (16, '14'): None,
#  (16, '15'): None,
#  (16, '16'): None,
#  (16, '17'): None,
#  (16, '18'): 1682801,
#  (16, '19'): 1822401,
#  (16, '20'): None,
#  (16, '21'): 2036401,
#  (17, '0'): None,
#  (17, '1'): 306800,
#  (17, '2'): 412400,
#  (17, '3'): None,
#  (17, '4'): 557800,
#  (17, '5'): None,
#  (17, '6'): 807000,
#  (17, '7'): None,
#  (17, '8'): 1028201,
#  (17, '9'): 1147201,
#  (17, '10'): 1223401,
#  (17, '11'): 1379801,
#  (17, '12'): 1517201,
#  (17, '13'): 1626601,
#  (17, '14'): 1739601,
#  (17, '15'): None,
#  (17, '16'): None,
#  (17, '17'): None,
#  (17, '18'): None,
#  (17, '19'): None,
#  (17, '20'): 2262202,
#  (17, '21'): None,
#  (17, '22'): 2816003,
#  (17, '23'): 4620004,
#  (17, '24'): None,
#  (17, '25'): None,
#  (18, '0'): None,
#  (18, '1'): 167800,
#  (18, '2'): 266800,
#  (18, '3'): 387200,
#  (18, '4'): 484200,
#  (18, '5'): None,
#  (18, '6'): 647200,
#  (18, '7'): None,
#  (18, '8'): None,
#  (18, '9'): None,
#  (18, '10'): 970200,
#  (18, '11'): None,
#  (18, '12'): 1138600,
#  (18, '13'): 1258800,
#  (18, '14'): 1338601,
#  (18, '15'): None,
#  (18, '16'): 1498601,
#  (18, '17'): None,
#  (18, '18'): None,
#  (19, '0'): None,
#  (19, '1'): 226200,
#  (19, '2'): None,
#  (19, '3'): 375800,
#  (19, '4'): None,
#  (19, '5'): None,
#  (19, '6'): None,
#  (19, '7'): None,
#  (19, '8'): 816401,
#  (19, '9'): None,
#  (19, '10'): None,
#  (19, '11'): 1062801,
#  (19, '12'): None,
#  (19, '13'): None,
#  (19, '14'): 1367601,
#  (19, '15'): 1478001,
#  (19, '16'): None,
#  (19, '17'): 1650402,
#  (19, '18'): 1817602,
#  (19, '19'): None,
#  (19, '20'): 2009002,
#  (19, '21'): 2146402,
#  (19, '22'): 2260203,
#  (20, '0'): 90800,
#  (20, '1'): 232600,
#  (20, '2'): 336000,
#  (20, '3'): None,
#  (20, '4'): 521200,
#  (20, '5'): None,
#  (20, '6'): None,
#  (20, '7'): None,
#  (20, '8'): 897600,
#  (20, '9'): 1006800,
#  (20, '10'): 1109600,
#  (20, '11'): None,
#  (20, '12'): 1300000,
#  (20, '13'): None,
#  (20, '14'): None,
#  (20, '15'): None,
#  (20, '16'): 1644400,
#  (20, '17'): 1763400,
#  (20, '18'): 1841200,
#  (20, '19'): None,
#  (20, '20'): None,
#  (20, '21'): 2072000,
#  (20, '22'): 2157600,
#  (20, '23'): None,
#  (21, '0'): None,
#  (21, '1'): None,
#  (21, '2'): 315800,
#  (21, '3'): None,
#  (21, '4'): 544000,
#  (21, '5'): 703800,
#  (21, '6'): 792200,
#  (21, '7'): 880000,
#  (21, '8'): 986400,
#  (21, '9'): 1073200,
#  (21, '10'): None,
#  (21, '11'): None,
#  (21, '12'): None,
#  (21, '13'): 1430601,
#  (21, '14'): None,
#  (21, '15'): None,
#  (21, '16'): None,
#  (22, '0'): 173400,
#  (22, '1'): 250000,
#  (22, '2'): 328600,
#  (22, '3'): None,
#  (22, '4'): 474400,
#  (22, '5'): 543800,
#  (22, '6'): None,
#  (22, '7'): None,
#  (22, '8'): None,
#  (22, '9'): None,
#  (22, '10'): None,
#  (22, '11'): 993800,
#  (22, '12'): 1091000,
#  (22, '13'): 1168000,
#  (22, '14'): None,
#  (22, '15'): None,
#  (22, '16'): 1390800,
#  (22, '17'): None,
#  (22, '18'): 1554000,
#  (22, '19'): None,
#  (22, '20'): 1706400,
#  (22, '21'): 1821600,
#  (22, '22'): 1895800,
#  (22, '23'): 2015800,
#  (23, '0'): None,
#  (23, '1'): None,
#  (23, '2'): None,
#  (23, '3'): None,
#  (23, '4'): 464200,
#  (23, '5'): 583600,
#  (23, '6'): 682800,
#  (23, '7'): 801201,
#  (23, '8'): None,
#  (23, '9'): 1017001,
#  (23, '10'): 1143201,
#  (23, '11'): None,
#  (23, '12'): None,
#  (23, '13'): None,
#  (23, '14'): 1460801,
#  (23, '15'): None,
#  (23, '16'): 1671202,
#  (23, '17'): 1784802,
#  (23, '18'): None,
#  (23, '19'): None,
#  (23, '20'): None,
#  (24, '0'): None,
#  (24, '1'): None,
#  (24, '2'): 212183,
#  (24, '3'): 319775,
#  (24, '4'): None,
#  (24, '5'): 521560,
#  (24, '6'): None,
#  (24, '7'): 671749,
#  (24, '8'): 807539,
#  (24, '9'): None,
#  (24, '10'): 945728,
#  (24, '11'): 1034921,
#  (24, '12'): None,
#  (24, '13'): None,
#  (24, '14'): 1326099,
#  (24, '15'): None,
#  (24, '16'): None,
#  (24, '17'): 1644675,
#  (24, '18'): 1778265,
#  (24, '19'): 1908456,
#  (25, '0'): 112000,
#  (25, '1'): 179200,
#  (25, '2'): None,
#  (25, '3'): 333600,
#  (25, '4'): 420800,
#  (25, '5'): None,
#  (25, '6'): None,
#  (25, '7'): 646600,
#  (25, '8'): 746800,
#  (25, '9'): None,
#  (25, '10'): 953800,
#  (25, '11'): None,
#  (25, '12'): 1138200,
#  (25, '13'): None,
#  (25, '14'): None,
#  (25, '15'): None,
#  (25, '16'): None,
#  (25, '17'): None,
#  (25, '18'): 1669201,
#  (25, '19'): None,
#  (25, '20'): 1826401,
#  (26, '0'): None,
#  (26, '1'): None,
#  (26, '2'): None,
#  (26, '3'): None,
#  (26, '4'): None,
#  (26, '5'): 532800,
#  (26, '6'): 639400,
#  (26, '7'): None,
#  (26, '8'): None,
#  (26, '9'): 938601,
#  (26, '10'): None,
#  (26, '11'): None,
#  (26, '12'): 1263401,
#  (26, '13'): 1352201,
#  (26, '14'): None,
#  (26, '15'): 1544801,
#  (26, '16'): 1641201,
#  (26, '17'): 1724801,
#  (26, '18'): None,
#  (26, '19'): None,
#  (26, '20'): None,
#  (26, '21'): None,
#  (26, '22'): 2234802,
#  (27, '0'): None,
#  (27, '1'): None,
#  (27, '2'): 267779,
#  (27, '3'): 349373,
#  (27, '4'): None,
#  (27, '5'): 556158,
#  (27, '6'): None,
#  (27, '7'): None,
#  (27, '8'): None,
#  (27, '9'): 927130,
#  (27, '10'): None,
#  (27, '11'): 1082718,
#  (27, '12'): 1173111,
#  (27, '13'): None,
#  (27, '14'): 1401294,
#  (27, '15'): None,
#  (27, '16'): None,
#  (27, '17'): None,
#  (27, '18'): 1735269,
#  (27, '19'): 1849660,
#  (27, '20'): 1943253,
#  (27, '21'): 2052645,
#  (27, '22'): None,
#  (27, '23'): None,
#  (27, '24'): None,
#  (27, '25'): 2404018,
#  (27, '26'): None,
#  (27, '27'): None,
#  (28, '0'): 111800,
#  (28, '1'): None,
#  (28, '2'): 282600,
#  (28, '3'): None,
#  (28, '4'): None,
#  (28, '5'): 605200,
#  (28, '6'): None,
#  (28, '7'): 812800,
#  (28, '8'): None,
#  (28, '9'): None,
#  (28, '10'): 1075800,
#  (28, '11'): 1174200,
#  (28, '12'): 1273800,
#  (28, '13'): 1376200,
#  (28, '14'): 1494000,
#  (28, '15'): 1570600,
#  (28, '16'): None,
#  (28, '17'): None,
#  (28, '18'): 1860800,
#  (28, '19'): None,
#  (28, '20'): 2108600,
#  (28, '21'): 2260200,
#  (28, '22'): 2359400,
#  (28, '23'): None,
#  (28, '24'): 2569800,
#  (28, '25'): None,
#  (29, '0'): 114800,
#  (29, '1'): None,
#  (29, '2'): None,
#  (29, '3'): None,
#  (29, '4'): None,
#  (29, '5'): 506000,
#  (29, '6'): None,
#  (29, '7'): None,
#  (29, '8'): 783801,
#  (29, '9'): None,
#  (29, '10'): 990401,
#  (29, '11'): None,
#  (29, '12'): None,
#  (29, '13'): 1297801,
#  (29, '14'): None,
#  (29, '15'): 1547802,
#  (29, '16'): 1692002,
#  (29, '17'): None,
#  (29, '18'): 1877602,
#  (29, '19'): 1972402,
#  (29, '20'): 2078202,
#  (30, '0'): 111800,
#  (30, '1'): None,
#  (30, '2'): 285200,
#  (30, '3'): 379200,
#  (30, '4'): None,
#  (30, '5'): 517400,
#  (30, '6'): None,
#  (30, '7'): 664600,
#  (30, '8'): 790800,
#  (30, '9'): 918400,
#  (30, '10'): None,
#  (30, '11'): None,
#  (30, '12'): None,
#  (30, '13'): None,
#  (30, '14'): None,
#  (30, '15'): 1388001,
#  (30, '16'): 1505601,
#  (30, '17'): None,
#  (31, '0'): None,
#  (31, '1'): None,
#  (31, '2'): 201600,
#  (31, '3'): 318000,
#  (31, '4'): None,
#  (31, '5'): None,
#  (31, '6'): None,
#  (31, '7'): 661600,
#  (31, '8'): None,
#  (31, '9'): None,
#  (31, '10'): 895600,
#  (31, '11'): 982201,
#  (31, '12'): None,
#  (31, '13'): None,
#  (31, '14'): None,
#  (31, '15'): None,
#  (31, '16'): None,
#  (32, '0'): None,
#  (32, '1'): None,
#  (32, '2'): 322000,
#  (32, '3'): None,
#  (32, '4'): None,
#  (32, '5'): None,
#  (32, '6'): 697000,
#  (32, '7'): 811000,
#  (32, '8'): None,
#  (32, '9'): 1003400,
#  (32, '10'): 1120200,
#  (32, '11'): 1248800,
#  (32, '12'): None,
#  (32, '13'): None,
#  (32, '14'): 1501601,
#  (32, '15'): 1660201,
#  (32, '16'): 1800001,
#  (32, '17'): 1887401,
#  (32, '18'): 1965201,
#  (32, '19'): None,
#  (32, '20'): None,
#  (32, '21'): None,
#  (32, '22'): None,
#  (32, '23'): 2384001,
#  (33, '0'): None,
#  (33, '1'): None,
#  (33, '2'): 235400,
#  (33, '3'): None,
#  (33, '4'): 415400,
#  (33, '5'): 496600,
#  (33, '6'): None,
#  (33, '7'): None,
#  (33, '8'): None,
#  (33, '9'): 839200,
#  (33, '10'): None,
#  (33, '11'): None,
#  (33, '12'): None,
#  (33, '13'): 1240001,
#  (33, '14'): 1311801,
#  (33, '15'): None,
#  (33, '16'): None,
#  (33, '17'): None,
#  (33, '18'): None,
#  (34, '0'): None,
#  (34, '1'): 153600,
#  (34, '2'): None,
#  (34, '3'): None,
#  (34, '4'): None,
#  (34, '5'): 450000,
#  (34, '6'): None,
#  (34, '7'): None,
#  (34, '8'): None,
#  (34, '9'): None,
#  (34, '10'): None,
#  (34, '11'): None,
#  (34, '12'): 1116801,
#  (34, '13'): 1241401,
#  (34, '14'): 1330401,
#  (34, '15'): None,
#  (34, '16'): 1462201,
#  (34, '17'): 1570802,
#  (34, '18'): 1670802,
#  (34, '19'): 1813802,
#  (34, '20'): 1885802,
#  (34, '21'): 1978202,
#  (34, '22'): 2078802,
#  (35, '0'): 160400,
#  (35, '1'): None,
#  (35, '2'): None,
#  (35, '3'): None,
#  (35, '4'): 525800,
#  (35, '5'): None,
#  (35, '6'): None,
#  (35, '7'): 876000,
#  (35, '8'): None,
#  (35, '9'): 1006600,
#  (35, '10'): 1086800,
#  (35, '11'): 1202600,
#  (35, '12'): 1294600,
#  (35, '13'): 1424000,
#  (35, '14'): None,
#  (35, '15'): None,
#  (35, '16'): None,
#  (35, '17'): None,
#  (35, '18'): None,
#  (35, '19'): None,
#  (35, '20'): 2070600,
#  (35, '21'): None,
#  (35, '22'): None,
#  (35, '23'): None,
#  (35, '24'): None,
#  (35, '25'): 2558000,
#  (35, '26'): None,
#  (35, '27'): 2711600,
#  (36, '0'): 109791,
#  (36, '1'): 177786,
#  (36, '2'): None,
#  (36, '3'): 429767,
#  (36, '4'): None,
#  (36, '5'): 558957,
#  (36, '6'): None,
#  (36, '7'): 762542,
#  (36, '8'): 852935,
#  (36, '9'): None,
#  (36, '10'): 988525,
#  (36, '11'): None,
#  (36, '12'): 1154312,
#  (36, '13'): 1280103,
#  (36, '14'): 1356497,
#  (36, '15'): 1428292,
#  (36, '16'): 1493887,
#  (36, '17'): 1580080,
#  (36, '18'): None,
#  (37, '0'): None,
#  (37, '1'): None,
#  (37, '2'): 319800,
#  (37, '3'): 420200,
#  (37, '4'): None,
#  (37, '5'): 618000,
#  (37, '6'): 709000,
#  (37, '7'): 795200,
#  (37, '8'): None,
#  (37, '9'): None,
#  (37, '10'): 1062400,
#  (37, '11'): 1168600,
#  (37, '12'): None,
#  (37, '13'): 1349001,
#  (37, '14'): 1428401,
#  (37, '15'): None,
#  (37, '16'): 1604001,
#  (37, '17'): 1736201,
#  (37, '18'): 1877201,
#  (37, '19'): 2011401,
#  (37, '20'): None,
#  (37, '21'): 2331201,
#  (37, '22'): 3314402,
#  (37, '23'): 3519602,
#  (37, '24'): 3526602,
#  (37, '25'): 4411403,
#  (38, '0'): None,
#  (38, '1'): 211200,
#  (38, '2'): 345000,
#  (38, '3'): None,
#  (38, '4'): None,
#  (38, '5'): 607200,
#  (38, '6'): 744400,
#  (38, '7'): 857000,
#  (38, '8'): 932400,
#  (38, '9'): None,
#  (38, '10'): None,
#  (38, '11'): None,
#  (38, '12'): 1289201,
#  (38, '13'): None,
#  (38, '14'): 1468601,
#  (38, '15'): 1564201,
#  (38, '16'): 1657201,
#  (38, '17'): None,
#  (38, '18'): 1825001,
#  (38, '19'): None,
#  (38, '20'): 2011802,
#  (38, '21'): None,
#  (38, '22'): 2136402,
#  (39, '0'): 103192,
#  (39, '1'): None,
#  (39, '2'): None,
#  (39, '3'): None,
#  (39, '4'): 410569,
#  (39, '5'): None,
#  (39, '6'): None,
#  (39, '7'): None,
#  (39, '8'): None,
#  (39, '9'): 804339,
#  (39, '10'): None,
#  (39, '11'): None,
#  (39, '12'): None,
#  (39, '13'): 1194509,
#  (39, '14'): 1275503,
#  (39, '15'): 1378096,
#  (39, '16'): 1472688,
#  (39, '17'): 1629477,
#  (39, '18'): 1701871,
#  (39, '19'): 1788865,
#  (40, '0'): 72800,
#  (40, '1'): None,
#  (40, '2'): None,
#  (40, '3'): 351400,
#  (40, '4'): None,
#  (40, '5'): 550800,
#  (40, '6'): 631800,
#  (40, '7'): 727400,
#  (40, '8'): 863201,
#  (40, '9'): None,
#  (40, '10'): 1067001,
#  (40, '11'): None,
#  (40, '12'): None,
#  (40, '13'): 1377801,
#  (40, '14'): 1522002,
#  (40, '15'): 1599002,
#  (40, '16'): None,
#  (40, '17'): None,
#  (40, '18'): None,
#  (40, '19'): None,
#  (40, '20'): None,
#  (40, '21'): None,
#  (40, '22'): 2254403,
#  (40, '23'): 2415603,
#  (40, '24'): 2559003,
#  (40, '25'): None,
#  (40, '26'): 2763203,
#  (40, '27'): None,
#  (41, '0'): 82200,
#  (41, '1'): 165600,
#  (41, '2'): 252800,
#  (41, '3'): None,
#  (41, '4'): None,
#  (41, '5'): 472600,
#  (41, '6'): None,
#  (41, '7'): None,
#  (41, '8'): None,
#  (41, '9'): None,
#  (41, '10'): None,
#  (41, '11'): 999400,
#  (41, '12'): None,
#  (41, '13'): None,
#  (41, '14'): 1224200,
#  (41, '15'): None,
#  (41, '16'): 1401200,
#  (41, '17'): 1515400,
#  (41, '18'): None,
#  (41, '19'): None,
#  (41, '20'): 1775000,
#  (41, '21'): 1858600,
#  (41, '22'): 1939400,
#  (42, '0'): 100400,
#  (42, '1'): None,
#  (42, '2'): None,
#  (42, '3'): None,
#  (42, '4'): None,
#  (42, '5'): None,
#  (42, '6'): 644400,
#  (42, '7'): None,
#  (42, '8'): 780200,
#  (42, '9'): None,
#  (42, '10'): 962401,
#  (42, '11'): None,
#  (42, '12'): 1200001,
#  (42, '13'): 1269401,
#  (42, '14'): None,
#  (42, '15'): None,
#  (42, '16'): 1567001,
#  (42, '17'): 1716801,
#  (42, '18'): None,
#  (42, '19'): 1894202,
#  (42, '20'): None,
#  (42, '21'): None,
#  (42, '22'): None,
#  (42, '23'): 2207602,
#  (43, '0'): 112191,
#  (43, '1'): None,
#  (43, '2'): 253980,
#  (43, '3'): None,
#  (43, '4'): None,
#  (43, '5'): None,
#  (43, '6'): 597554,
#  (43, '7'): None,
#  (43, '8'): 769141,
#  (43, '9'): 859335,
#  (43, '10'): 934929,
#  (43, '11'): None,
#  (43, '12'): 1136714,
#  (43, '13'): 1230107,
#  (43, '14'): None,
#  (43, '15'): None,
#  (43, '16'): None,
#  (43, '17'): None,
#  (44, '0'): 70200,
#  (44, '1'): 175200,
#  (44, '2'): 279400,
#  (44, '3'): None,
#  (44, '4'): None,
#  (44, '5'): None,
#  (44, '6'): 617800,
#  (44, '7'): 714400,
#  (44, '8'): 839200,
#  (44, '9'): 925000,
#  (44, '10'): None,
#  (44, '11'): None,
#  (44, '12'): 1164200,
#  (44, '13'): 1261600,
#  (44, '14'): 1359600,
#  (44, '15'): 1453800,
#  (44, '16'): 1551200,
#  (44, '17'): None,
#  (44, '18'): None,
#  (44, '19'): 1800400,
#  (44, '20'): 1934600,
#  (44, '21'): 2041000,
#  ...}

# %%
new_rows = []

# Second pass: compute metrics
# for index, row in flat2_df_stats_chars.iterrows():
for index, row in flat2_df_stats_chars.iterrows():
    for round_number, round_data in row['round_info'].items():
        # get the current/original row.
        new_row = row.to_dict()
        # Get spike time for this round
        spike_time = spike_times[(index, round_number)]
        if spike_time:
            new_row['spike_planted'] = True
            new_row['spike_time'] = spike_time
        else:
            new_row['spike_planted'] = False
            new_row['spike_time'] = 0
        # get current map
        cur_map = new_row['map']
        # get current player
        cur_player = new_row['player']
        # Add round number to the new row
        new_row['round_number'] = round_number
        # Flatten round_info data into the new row
        for key, value in round_data.items():
            new_row[f'round_info_{key}'] = value
        # get side
        side = new_row['round_info_ally_side']
        # get won 
#             won = new_row['round_info_round_won']


        for key, value in row['rounds'][round_number].items():
            ## COUNTING ELIMINATIONS ##
            if key == 'elims':

                rounds_elims = value

                # Initialize the stats for all players
                player_stats = {str(player): {
                "pre_spike_elims": 0, "post_spike_elims": 0,
                "pre_spike_deaths": 0, "post_spike_deaths": 0,
                "pre_spike_assists": 0, "post_spike_assists": 0,
                "pre_spike_headshots": 0, "post_spike_headshots": 0,
                "pre_spike_wallbangs": 0, "post_spike_wallbangs": 0,
                "pre_spike_first_bloods": 0, "post_spike_first_bloods": 0} for player in range(10)}

                ally_deaths = 0
                opponent_deaths = 0

                # Then, for each elimination:
                for elimination in rounds_elims:
                    elim_data = elimination[1]
                    source = elim_data['source']
                    target = elim_data['target']
                    assisted = elim_data['assisted']

                    # check if the elimination happened before or after the spike
                    if spike_time is None or elimination[0] < spike_time:  # pre-spike
                        player_stats[source]['pre_spike_elims'] += 1
                        player_stats[target]['pre_spike_deaths'] += 1
                        for assist_player in assisted:
                            player_stats[assist_player]['pre_spike_assists'] += 1
                        if elim_data['headshot']:
                            player_stats[source]['pre_spike_headshots'] += 1
                        if elim_data['wallbang']:
                            player_stats[source]['pre_spike_wallbangs'] += 1
                        if elim_data['first_blood']:
                            player_stats[source]['pre_spike_first_bloods'] += 1
                    elif spike_time:  # post-spike, only if spike_time is not None
                        player_stats[source]['post_spike_elims'] += 1
                        player_stats[target]['post_spike_deaths'] += 1
                        for assist_player in assisted:
                            player_stats[assist_player]['post_spike_assists'] += 1
                        if elim_data['headshot']:
                            player_stats[source]['post_spike_headshots'] += 1
                        if elim_data['wallbang']:
                            player_stats[source]['post_spike_wallbangs'] += 1
                        if elim_data['first_blood']:
                            player_stats[source]['post_spike_first_bloods'] += 1

                    if int(target) < 5:  # If the target is an ally
                        ally_deaths += 1
                    else:  # If the target is an opponent
                        opponent_deaths += 1

                all_ally_dead = ally_deaths >= 5
                all_opponent_dead = opponent_deaths >= 5

                # Add these stats to the new_row, outside the eliminations loop:
                for player, stats in player_stats.items():
                    prefix = 'ally' if int(player) < 5 else 'opponent'
                    player_num = player if int(player) < 5 else str(int(player) - 5)
                    for stat, count in stats.items():
                        new_row[f'{prefix}{player_num}_{stat}'] = count

                new_row['all_ally_dead'] = all_ally_dead
                new_row['all_opponent_dead'] = all_opponent_dead

            ## CALC AVG HEALTH AND MAX/TOTAL HEALTH LOSS ##
            if key == 'health':
                rounds_health = value
                for player, health_data in rounds_health.items():
                    pre_spike_total_health = 0
                    post_spike_total_health = 0
                    pre_spike_entries = 0
                    post_spike_entries = 0
                    pre_spike_max_health_loss = 0
                    post_spike_max_health_loss = 0
                    pre_spike_total_health_loss = 0
                    post_spike_total_health_loss = 0
                    last_health = None
                    for entry in health_data:
                        health_time = entry[0]
                        health_value = entry[1]

                        if last_health is not None:  # if there is a previous health value, calculate the health loss
                            health_loss = max(0, last_health - health_value)  # don't let health loss be negative
                            if spike_time is None or health_time < spike_time:  # pre-spike or no spike
                                pre_spike_max_health_loss = max(pre_spike_max_health_loss, health_loss)
                                pre_spike_total_health_loss += health_loss
                            elif spike_time:  # post-spike
                                post_spike_max_health_loss = max(post_spike_max_health_loss, health_loss)
                                post_spike_total_health_loss += health_loss

                        last_health = health_value  # store the current health value as the last health value for the next iteration

                        if spike_time is None or health_time < spike_time:  # pre-spike or no spike
                            pre_spike_total_health += health_value
                            pre_spike_entries += 1
                        elif spike_time:  # post-spike
                            post_spike_total_health += health_value
                            post_spike_entries += 1

                    pre_spike_average_health = pre_spike_total_health / pre_spike_entries if pre_spike_entries > 0 else 0
                    post_spike_average_health = post_spike_total_health / post_spike_entries if post_spike_entries > 0 else 0

                    new_row[f'ally{player}_pre_spike_avg_health'] = pre_spike_average_health
                    new_row[f'ally{player}_post_spike_avg_health'] = post_spike_average_health
                    new_row[f'ally{player}_pre_spike_max_health_loss'] = pre_spike_max_health_loss
                    new_row[f'ally{player}_post_spike_max_health_loss'] = post_spike_max_health_loss
                    new_row[f'ally{player}_pre_spike_total_health_loss'] = pre_spike_total_health_loss
                    new_row[f'ally{player}_post_spike_total_health_loss'] = post_spike_total_health_loss
                    
            
            ## CALC AVG SHIELD AND MAX/TOTAL SHIELD LOSS ##
            if key == 'shield':
                calculate_metrics(key, value, cur_player, new_row, spike_time)
            ## CALC AVG CREDITS AND MAX/TOTAL CREDIT LOSS ##
            if key == 'credits':
                calculate_metrics(key, value, cur_player, new_row, spike_time)
            ## CALC AVG AMMO MAG AND MAX/TOTAL AMMO MAG LOSS ##  
            if key == 'ammo_mag':
                calculate_metrics(key, value, cur_player, new_row, spike_time)
            ## MOST TIME/MAX INV STATE ##
            if key == 'inv_state':
                calculate_longest_duration('inv_state', value, cur_player, new_row, spike_time)
            
            ## COUNTING ULTIMATE USAGE ##
            if key == 'ult_state':
                rounds_ult_state = value

                for player, ultimate_data in rounds_ult_state.items():
                    ultimate_usage = 0
                    pre_spike_ultimate_usage = 0
                    post_spike_ultimate_usage = 0
                    previous_state = None
                    for entry in ultimate_data:
                        ultimate_state_time = entry[0]
                        ultimate_state = entry[1]
                        if previous_state is not None and previous_state is True and ultimate_state is False:
                            ultimate_usage += 1
                            if spike_time is None or ultimate_state_time < spike_time:  # pre-spike or no spike
                                pre_spike_ultimate_usage += 1
                            elif spike_time and ultimate_state_time >= spike_time:  # post-spike
                                post_spike_ultimate_usage += 1
                        previous_state = ultimate_state
                    if int(player) < 5:
                        new_row[f'ally{player}_ultimate_usage'] = ultimate_usage
                        new_row[f'ally{player}_pre_spike_ultimate_usage'] = pre_spike_ultimate_usage
                        new_row[f'ally{player}_post_spike_ultimate_usage'] = post_spike_ultimate_usage
                    else:
                        new_row[f'opponent{int(player)-5}_ultimate_usage'] = ultimate_usage
                        new_row[f'opponent{int(player)-5}_pre_spike_ultimate_usage'] = pre_spike_ultimate_usage
                        new_row[f'opponent{int(player)-5}_post_spike_ultimate_usage'] = post_spike_ultimate_usage

            ## GETTING % MAP COVERED AND MOVEMENT METRIC"
            if key == 'map_region':
                rounds_map_region = value

                # % map covered
                available_places = map_areas[cur_map]
                visited_places_pre_spike = set()
                visited_places_post_spike = set()

                transitions_pre_spike = set()
                transitions_post_spike = set()

                previous_place_pre_spike = None
                previous_place_post_spike = None

                for entry in rounds_map_region:
                    timestamp = entry[0]
                    place = entry[1]

                    if spike_time is None or timestamp < spike_time:  # Pre spike or no spike planted
                        if place in available_places:
                            visited_places_pre_spike.add(place)

                        if previous_place_pre_spike is not None:
                            transition = (previous_place_pre_spike, place)
                            transitions_pre_spike.add(transition)

                        previous_place_pre_spike = place
                    else:  # Post spike
                        if place in available_places:
                            visited_places_post_spike.add(place)

                        if previous_place_post_spike is not None:
                            transition = (previous_place_post_spike, place)
                            transitions_post_spike.add(transition)

                        previous_place_post_spike = place

                metric_pre_spike = len(visited_places_pre_spike) / len(available_places)
                new_row[f'ally{cur_player}_pre_spike_map_covered'] = metric_pre_spike
                movement_metric_pre_spike = len(transitions_pre_spike)
                new_row[f'ally{cur_player}_pre_spike_movement_metric'] = movement_metric_pre_spike

                metric_post_spike = len(visited_places_post_spike) / len(available_places)
                new_row[f'ally{cur_player}_post_spike_map_covered'] = metric_post_spike
                movement_metric_post_spike = len(transitions_post_spike)
                new_row[f'ally{cur_player}_post_spike_movement_metric'] = movement_metric_post_spike

            
            ## MOST TIME/MAX PRIMARY GUN ##
            if key == 'inv_primary':
                calculate_longest_duration('gun_primary', value, cur_player, new_row, spike_time)
            ## CALC AVG AMMO RESERVE AND MAX/TOTAL AMMO RESERVE LOSS ##  
            if key == 'ammo_reserve':
                calculate_metrics(key, value, cur_player, new_row, spike_time)
            
            ## TOTAL FIRING TIME ##
            if key == 'firing_state':
                firing_state = value

                total_fire_time = 0
                pre_spike_total_fire_time = 0
                post_spike_total_fire_time = 0
                start_fire = 0
                firing = 0

                for i in range(len(firing_state) - 1):
                    if firing_state[i + 1][1] == True:
                        start_fire = firing_state[i + 1][0]
                    elif firing_state[i + 1][1] == False:
                        end_fire = firing_state[i + 1][0]
                        firing = end_fire - start_fire
                        total_fire_time += firing

                        if spike_time is None or start_fire < spike_time:  # pre-spike or no spike
                            pre_spike_total_fire_time += firing
                        elif spike_time and start_fire >= spike_time:  # post-spike
                            post_spike_total_fire_time += firing

                new_row[f'ally{cur_player}_total_firing_time'] = total_fire_time
                new_row[f'ally{cur_player}_pre_spike_total_firing_time'] = pre_spike_total_fire_time
                new_row[f'ally{cur_player}_post_spike_total_firing_time'] = post_spike_total_fire_time
            else:
                new_row[f'rounds_{key}'] = value   
            
            ## MOST TIME/MAX SECONDARY GUN ##
            if key == 'inv_secondary':
                calculate_longest_duration('gun_secondary', value, cur_player, new_row, spike_time)
            ## CALC AVG LOADOUT VALUE AND MAX/TOTAL LOADOUT VALUE LOSS ##
            if key == 'loadout_value':
                calculate_metrics(key, value, cur_player, new_row, spike_time)
            
            ## CALC ABILITY USE ##
            if key in ['ability_charges_1', 'ability_charges_2', 'ability_charges_3', 'ability_charges_4']:
                ability_charges = value
                identifier = key.split('_')[-1]  # extract the ability identifier from the key
                calculate_ability_usage(cur_player, ability_charges, spike_time, identifier, new_row)

        
        
        
        # Getting rid of cols that don't need 
        new_row.pop('rounds_alive', None)
        new_row.pop('rounds_phases', None)
        new_row.pop('rounds_spike_planted', None)
        new_row.pop('rounds_assisted_count', None)
        new_row.pop('rounds_assists_count', None)
        new_row.pop('rounds_elims_count', None)
        new_row.pop('round_totals', None)
        new_row.pop('round_info_ally_score', None)
        new_row.pop('round_info_opponent_score', None)

        # Getting rid of cols that we just parsed
        new_row.pop('rounds_elims', None)
        new_row.pop('rounds_health', None)
        new_row.pop('rounds_shield', None)
        new_row.pop('rounds_credits', None)
        new_row.pop('rounds_ammo_mag', None)
        new_row.pop('rounds_inv_state', None)
        new_row.pop('rounds_ult_state', None)
        new_row.pop('rounds_map_region', None)
        new_row.pop('rounds_inv_primary', None)
        new_row.pop('rounds_ammo_reserve', None)
        new_row.pop('rounds_firing_state', None)
        new_row.pop('rounds_inv_secondary', None)
        new_row.pop('rounds_loadout_value', None)
        new_row.pop('rounds_ability_charges_1', None)
        new_row.pop('rounds_ability_charges_2', None)
        new_row.pop('rounds_ability_charges_3', None)
        new_row.pop('rounds_ability_charges_4', None)
        
        # Getting rid of cols that we don't want/need    
        new_row.pop('round_info_score', None)
        new_row.pop('round_info_round_scored', None)
        new_row.pop('round_info_buy_start', None)
        new_row.pop('round_info_ult_used', None)
        new_row.pop('round_info_spike_planted', None)

        # exclude the original complex columns that we're flattening
        new_row.pop('rounds', None)
        new_row.pop('round_info', None)

        # fixing the naming of the players
        def adjust_keys(new_row, cur_player):
            adjusted_row = {}
            cur_player = int(cur_player)

            allies_count = 5  # define total number of allies, including 'self'

            for key, value in new_row.items():
                if key.startswith(f'ally{cur_player}'):
                    adjusted_key = key.replace(f'ally{cur_player}', 'self')
                elif key.startswith('ally'):
                    # correctly parse the ally number as an integer and remaining part of the key
                    ally_number = int(key[4:].split('_')[0])
                    ally_remaining = '_'.join(key.split('_')[1:])

                    # calculate new ally number
                    new_ally_number = (ally_number - cur_player) % allies_count

                    # construct new key with updated ally number
                    adjusted_key = 'ally' + str(new_ally_number) + '_' + ally_remaining
                else:
                    adjusted_key = key

                adjusted_row[adjusted_key] = value

            return adjusted_row

        new_row = adjust_keys(new_row, cur_player)

        # Append this new row to the list
        new_rows.append(new_row)

# Convert the list of new rows into a dataframe
new_df = pd.DataFrame(new_rows)

# %%
new_df
# Out:
#       user_id      map player ally3_character ally4_character self_character  \
# 0        3807    Pearl      2           gekko           viper        phoenix
# 1        3807    Pearl      2           gekko           viper        phoenix
# 2        3807    Pearl      2           gekko           viper        phoenix
# 3        3807    Pearl      2           gekko           viper        phoenix
# 4        3807    Pearl      2           gekko           viper        phoenix
# ...       ...      ...    ...             ...             ...            ...
# 9893     3795  unknown      0           reyna          breach           jett
# 9894     3795  unknown      0           reyna          breach           jett
# 9895     3795  unknown      0           reyna          breach           jett
# 9896     3795  unknown      0           reyna          breach           jett
# 9897     3795  unknown      0           reyna          breach           jett
#
#      ally1_character ally2_character opponent5_character opponent6_character  \
# 0              astra            jett              harbor             killjoy
# 1              astra            jett              harbor             killjoy
# 2              astra            jett              harbor             killjoy
# 3              astra            jett              harbor             killjoy
# 4              astra            jett              harbor             killjoy
# ...              ...             ...                 ...                 ...
# 9893            skye            sova                jett               gekko
# 9894            skye            sova                jett               gekko
# 9895            skye            sova                jett               gekko
# 9896            skye            sova                jett               gekko
# 9897            skye            sova                jett               gekko
#
#       ... self_pre_spike_total_loadout_value_loss  \
# 0     ...                                  1400.0
# 1     ...                                  1300.0
# 2     ...                                  1700.0
# 3     ...                                  2150.0
# 4     ...                                  3790.0
# ...   ...                                     ...
# 9893  ...                                  5800.0
# 9894  ...                                  2800.0
# 9895  ...                                  2000.0
# 9896  ...                                  2200.0
# 9897  ...                                  5800.0
#
#      self_post_spike_total_loadout_value_loss  \
# 0                                         0.0
# 1                                       800.0
# 2                                         0.0
# 3                                      3900.0
# 4                                      1360.0
# ...                                       ...
# 9893                                      0.0
# 9894                                      0.0
# 9895                                   1200.0
# 9896                                   3000.0
# 9897                                      0.0
#
#      self_pre_spike_total_ability_usage_1  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       1
# 4                                       2
# ...                                   ...
# 9893                                    1
# 9894                                    1
# 9895                                    0
# 9896                                    1
# 9897                                    0
#
#       self_post_spike_total_ability_usage_1  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         0
# ...                                     ...
# 9893                                      0
# 9894                                      0
# 9895                                      0
# 9896                                      0
# 9897                                      0
#
#       self_pre_spike_total_ability_usage_2  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 9893                                     0
# 9894                                     0
# 9895                                     0
# 9896                                     0
# 9897                                     0
#
#      self_post_spike_total_ability_usage_2  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        0
# ...                                    ...
# 9893                                     0
# 9894                                     0
# 9895                                     0
# 9896                                     0
# 9897                                     0
#
#      self_pre_spike_total_ability_usage_3  \
# 0                                       1
# 1                                       1
# 2                                       0
# 3                                       0
# 4                                       2
# ...                                   ...
# 9893                                    1
# 9894                                    1
# 9895                                    0
# 9896                                    0
# 9897                                    0
#
#       self_post_spike_total_ability_usage_3  \
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         1
# ...                                     ...
# 9893                                      0
# 9894                                      0
# 9895                                      0
# 9896                                      0
# 9897                                      0
#
#       self_pre_spike_total_ability_usage_4  \
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 4                                        1
# ...                                    ...
# 9893                                     0
# 9894                                     0
# 9895                                     0
# 9896                                     1
# 9897                                     0
#
#       self_post_spike_total_ability_usage_4
# 0                                         0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                         1
# ...                                     ...
# 9893                                      0
# 9894                                      0
# 9895                                      0
# 9896                                      0
# 9897                                      0
#
# [9898 rows x 256 columns]

# %% [markdown]
# ### Data cleaning
# - I noticed some NaNs. This happens when there is missing information
# - self_longest_gun_primary, self_longest_inv_state, self_longest_gun_secondaryis coming up as None but i think it should be 'none', so i am replacing with that
# - After investigating it seems like the elims data isnt always captured, its only 123 rows so im going to drop it

# %%
new_df['self_pre_spike_longest_gun_primary'] = new_df['self_pre_spike_longest_gun_primary'].fillna('none')
new_df['self_post_spike_longest_gun_primary'] = new_df['self_post_spike_longest_gun_primary'].fillna('none')
new_df['self_pre_spike_longest_gun_secondary'] = new_df['self_pre_spike_longest_gun_secondary'].fillna('none')
new_df['self_post_spike_longest_gun_secondary'] = new_df['self_post_spike_longest_gun_secondary'].fillna('none')
new_df['self_pre_spike_longest_inv_state'] = new_df['self_pre_spike_longest_inv_state'].fillna('none')
new_df['self_post_spike_longest_inv_state'] = new_df['self_post_spike_longest_inv_state'].fillna('none')
new_df['self_longest_inv_state'] = new_df['self_longest_inv_state'].fillna('none')
new_df['self_longest_gun_primary'] = new_df['self_longest_gun_primary'].fillna('none')
new_df['self_longest_gun_secondary'] = new_df['self_longest_gun_secondary'].fillna('none')

# %%
cols_with_nans = new_df.columns[new_df.isnull().any()].tolist()

# Print the list of columns with NaN values
cols_with_nans
# Out:
# []

# %%
# Find rows with NaN values
nan_rows = new_df[new_df.isnull().any(axis=1)]

# Print the rows with NaN values
nan_rows
# Out:
# Empty DataFrame
# Columns: [user_id, map, player, ally3_character, ally4_character, self_character, ally1_character, ally2_character, opponent5_character, opponent6_character, opponent7_character, opponent8_character, opponent9_character, spike_planted, spike_time, round_number, round_info_ally_side, round_info_round_end, round_info_round_won, round_info_round_start, ally3_pre_spike_elims, ally3_post_spike_elims, ally3_pre_spike_deaths, ally3_post_spike_deaths, ally3_pre_spike_assists, ally3_post_spike_assists, ally3_pre_spike_headshots, ally3_post_spike_headshots, ally3_pre_spike_wallbangs, ally3_post_spike_wallbangs, ally3_pre_spike_first_bloods, ally3_post_spike_first_bloods, ally4_pre_spike_elims, ally4_post_spike_elims, ally4_pre_spike_deaths, ally4_post_spike_deaths, ally4_pre_spike_assists, ally4_post_spike_assists, ally4_pre_spike_headshots, ally4_post_spike_headshots, ally4_pre_spike_wallbangs, ally4_post_spike_wallbangs, ally4_pre_spike_first_bloods, ally4_post_spike_first_bloods, self_pre_spike_elims, self_post_spike_elims, self_pre_spike_deaths, self_post_spike_deaths, self_pre_spike_assists, self_post_spike_assists, self_pre_spike_headshots, self_post_spike_headshots, self_pre_spike_wallbangs, self_post_spike_wallbangs, self_pre_spike_first_bloods, self_post_spike_first_bloods, ally1_pre_spike_elims, ally1_post_spike_elims, ally1_pre_spike_deaths, ally1_post_spike_deaths, ally1_pre_spike_assists, ally1_post_spike_assists, ally1_pre_spike_headshots, ally1_post_spike_headshots, ally1_pre_spike_wallbangs, ally1_post_spike_wallbangs, ally1_pre_spike_first_bloods, ally1_post_spike_first_bloods, ally2_pre_spike_elims, ally2_post_spike_elims, ally2_pre_spike_deaths, ally2_post_spike_deaths, ally2_pre_spike_assists, ally2_post_spike_assists, ally2_pre_spike_headshots, ally2_post_spike_headshots, ally2_pre_spike_wallbangs, ally2_post_spike_wallbangs, ally2_pre_spike_first_bloods, ally2_post_spike_first_bloods, opponent0_pre_spike_elims, opponent0_post_spike_elims, opponent0_pre_spike_deaths, opponent0_post_spike_deaths, opponent0_pre_spike_assists, opponent0_post_spike_assists, opponent0_pre_spike_headshots, opponent0_post_spike_headshots, opponent0_pre_spike_wallbangs, opponent0_post_spike_wallbangs, opponent0_pre_spike_first_bloods, opponent0_post_spike_first_bloods, opponent1_pre_spike_elims, opponent1_post_spike_elims, opponent1_pre_spike_deaths, opponent1_post_spike_deaths, opponent1_pre_spike_assists, opponent1_post_spike_assists, opponent1_pre_spike_headshots, opponent1_post_spike_headshots, ...]
# Index: []
#
# [0 rows x 256 columns]

# %%
clean_df = new_df.dropna()
clean_df = clean_df.reset_index(drop=True)

# %%
# Find rows with NaN values
nan_rows = clean_df[clean_df.isnull().any(axis=1)]

# Print the rows with NaN values
nan_rows
# Out:
# Empty DataFrame
# Columns: [user_id, map, player, ally3_character, ally4_character, self_character, ally1_character, ally2_character, opponent5_character, opponent6_character, opponent7_character, opponent8_character, opponent9_character, spike_planted, spike_time, round_number, round_info_ally_side, round_info_round_end, round_info_round_won, round_info_round_start, ally3_pre_spike_elims, ally3_post_spike_elims, ally3_pre_spike_deaths, ally3_post_spike_deaths, ally3_pre_spike_assists, ally3_post_spike_assists, ally3_pre_spike_headshots, ally3_post_spike_headshots, ally3_pre_spike_wallbangs, ally3_post_spike_wallbangs, ally3_pre_spike_first_bloods, ally3_post_spike_first_bloods, ally4_pre_spike_elims, ally4_post_spike_elims, ally4_pre_spike_deaths, ally4_post_spike_deaths, ally4_pre_spike_assists, ally4_post_spike_assists, ally4_pre_spike_headshots, ally4_post_spike_headshots, ally4_pre_spike_wallbangs, ally4_post_spike_wallbangs, ally4_pre_spike_first_bloods, ally4_post_spike_first_bloods, self_pre_spike_elims, self_post_spike_elims, self_pre_spike_deaths, self_post_spike_deaths, self_pre_spike_assists, self_post_spike_assists, self_pre_spike_headshots, self_post_spike_headshots, self_pre_spike_wallbangs, self_post_spike_wallbangs, self_pre_spike_first_bloods, self_post_spike_first_bloods, ally1_pre_spike_elims, ally1_post_spike_elims, ally1_pre_spike_deaths, ally1_post_spike_deaths, ally1_pre_spike_assists, ally1_post_spike_assists, ally1_pre_spike_headshots, ally1_post_spike_headshots, ally1_pre_spike_wallbangs, ally1_post_spike_wallbangs, ally1_pre_spike_first_bloods, ally1_post_spike_first_bloods, ally2_pre_spike_elims, ally2_post_spike_elims, ally2_pre_spike_deaths, ally2_post_spike_deaths, ally2_pre_spike_assists, ally2_post_spike_assists, ally2_pre_spike_headshots, ally2_post_spike_headshots, ally2_pre_spike_wallbangs, ally2_post_spike_wallbangs, ally2_pre_spike_first_bloods, ally2_post_spike_first_bloods, opponent0_pre_spike_elims, opponent0_post_spike_elims, opponent0_pre_spike_deaths, opponent0_post_spike_deaths, opponent0_pre_spike_assists, opponent0_post_spike_assists, opponent0_pre_spike_headshots, opponent0_post_spike_headshots, opponent0_pre_spike_wallbangs, opponent0_post_spike_wallbangs, opponent0_pre_spike_first_bloods, opponent0_post_spike_first_bloods, opponent1_pre_spike_elims, opponent1_post_spike_elims, opponent1_pre_spike_deaths, opponent1_post_spike_deaths, opponent1_pre_spike_assists, opponent1_post_spike_assists, opponent1_pre_spike_headshots, opponent1_post_spike_headshots, ...]
# Index: []
#
# [0 rows x 256 columns]

# %%
clean_df.shape
# Out:
# (9898, 256)

# %%
clean_df.columns[:50]
# Out:
# Index(['user_id', 'map', 'player', 'ally3_character', 'ally4_character',
#        'self_character', 'ally1_character', 'ally2_character',
#        'opponent5_character', 'opponent6_character', 'opponent7_character',
#        'opponent8_character', 'opponent9_character', 'spike_planted',
#        'spike_time', 'round_number', 'round_info_ally_side',
#        'round_info_round_end', 'round_info_round_won',
#        'round_info_round_start', 'ally3_pre_spike_elims',
#        'ally3_post_spike_elims', 'ally3_pre_spike_deaths',
#        'ally3_post_spike_deaths', 'ally3_pre_spike_assists',
#        'ally3_post_spike_assists', 'ally3_pre_spike_headshots',
#        'ally3_post_spike_headshots', 'ally3_pre_spike_wallbangs',
#        'ally3_post_spike_wallbangs', 'ally3_pre_spike_first_bloods',
#        'ally3_post_spike_first_bloods', 'ally4_pre_spike_elims',
#        'ally4_post_spike_elims', 'ally4_pre_spike_deaths',
#        'ally4_post_spike_deaths', 'ally4_pre_spike_assists',
#        'ally4_post_spike_assists', 'ally4_pre_spike_headshots',
#        'ally4_post_spike_headshots', 'ally4_pre_spike_wallbangs',
#        'ally4_post_spike_wallbangs', 'ally4_pre_spike_first_bloods',
#        'ally4_post_spike_first_bloods', 'self_pre_spike_elims',
#        'self_post_spike_elims', 'self_pre_spike_deaths',
#        'self_post_spike_deaths', 'self_pre_spike_assists',
#        'self_post_spike_assists'],
#       dtype='object')

# %%
clean_df.columns[50:100]
# Out:
# Index(['self_pre_spike_headshots', 'self_post_spike_headshots',
#        'self_pre_spike_wallbangs', 'self_post_spike_wallbangs',
#        'self_pre_spike_first_bloods', 'self_post_spike_first_bloods',
#        'ally1_pre_spike_elims', 'ally1_post_spike_elims',
#        'ally1_pre_spike_deaths', 'ally1_post_spike_deaths',
#        'ally1_pre_spike_assists', 'ally1_post_spike_assists',
#        'ally1_pre_spike_headshots', 'ally1_post_spike_headshots',
#        'ally1_pre_spike_wallbangs', 'ally1_post_spike_wallbangs',
#        'ally1_pre_spike_first_bloods', 'ally1_post_spike_first_bloods',
#        'ally2_pre_spike_elims', 'ally2_post_spike_elims',
#        'ally2_pre_spike_deaths', 'ally2_post_spike_deaths',
#        'ally2_pre_spike_assists', 'ally2_post_spike_assists',
#        'ally2_pre_spike_headshots', 'ally2_post_spike_headshots',
#        'ally2_pre_spike_wallbangs', 'ally2_post_spike_wallbangs',
#        'ally2_pre_spike_first_bloods', 'ally2_post_spike_first_bloods',
#        'opponent0_pre_spike_elims', 'opponent0_post_spike_elims',
#        'opponent0_pre_spike_deaths', 'opponent0_post_spike_deaths',
#        'opponent0_pre_spike_assists', 'opponent0_post_spike_assists',
#        'opponent0_pre_spike_headshots', 'opponent0_post_spike_headshots',
#        'opponent0_pre_spike_wallbangs', 'opponent0_post_spike_wallbangs',
#        'opponent0_pre_spike_first_bloods', 'opponent0_post_spike_first_bloods',
#        'opponent1_pre_spike_elims', 'opponent1_post_spike_elims',
#        'opponent1_pre_spike_deaths', 'opponent1_post_spike_deaths',
#        'opponent1_pre_spike_assists', 'opponent1_post_spike_assists',
#        'opponent1_pre_spike_headshots', 'opponent1_post_spike_headshots'],
#       dtype='object')

# %%
clean_df.columns[100:150]
# Out:
# Index(['opponent1_pre_spike_wallbangs', 'opponent1_post_spike_wallbangs',
#        'opponent1_pre_spike_first_bloods', 'opponent1_post_spike_first_bloods',
#        'opponent2_pre_spike_elims', 'opponent2_post_spike_elims',
#        'opponent2_pre_spike_deaths', 'opponent2_post_spike_deaths',
#        'opponent2_pre_spike_assists', 'opponent2_post_spike_assists',
#        'opponent2_pre_spike_headshots', 'opponent2_post_spike_headshots',
#        'opponent2_pre_spike_wallbangs', 'opponent2_post_spike_wallbangs',
#        'opponent2_pre_spike_first_bloods', 'opponent2_post_spike_first_bloods',
#        'opponent3_pre_spike_elims', 'opponent3_post_spike_elims',
#        'opponent3_pre_spike_deaths', 'opponent3_post_spike_deaths',
#        'opponent3_pre_spike_assists', 'opponent3_post_spike_assists',
#        'opponent3_pre_spike_headshots', 'opponent3_post_spike_headshots',
#        'opponent3_pre_spike_wallbangs', 'opponent3_post_spike_wallbangs',
#        'opponent3_pre_spike_first_bloods', 'opponent3_post_spike_first_bloods',
#        'opponent4_pre_spike_elims', 'opponent4_post_spike_elims',
#        'opponent4_pre_spike_deaths', 'opponent4_post_spike_deaths',
#        'opponent4_pre_spike_assists', 'opponent4_post_spike_assists',
#        'opponent4_pre_spike_headshots', 'opponent4_post_spike_headshots',
#        'opponent4_pre_spike_wallbangs', 'opponent4_post_spike_wallbangs',
#        'opponent4_pre_spike_first_bloods', 'opponent4_post_spike_first_bloods',
#        'all_ally_dead', 'all_opponent_dead', 'ally3_pre_spike_avg_health',
#        'ally3_post_spike_avg_health', 'ally3_pre_spike_max_health_loss',
#        'ally3_post_spike_max_health_loss', 'ally3_pre_spike_total_health_loss',
#        'ally3_post_spike_total_health_loss', 'ally4_pre_spike_avg_health',
#        'ally4_post_spike_avg_health'],
#       dtype='object')

# %%
clean_df.columns[150:200]
# Out:
# Index(['ally4_pre_spike_max_health_loss', 'ally4_post_spike_max_health_loss',
#        'ally4_pre_spike_total_health_loss',
#        'ally4_post_spike_total_health_loss', 'self_pre_spike_avg_health',
#        'self_post_spike_avg_health', 'self_pre_spike_max_health_loss',
#        'self_post_spike_max_health_loss', 'self_pre_spike_total_health_loss',
#        'self_post_spike_total_health_loss', 'ally1_pre_spike_avg_health',
#        'ally1_post_spike_avg_health', 'ally1_pre_spike_max_health_loss',
#        'ally1_post_spike_max_health_loss', 'ally1_pre_spike_total_health_loss',
#        'ally1_post_spike_total_health_loss', 'ally2_pre_spike_avg_health',
#        'ally2_post_spike_avg_health', 'ally2_pre_spike_max_health_loss',
#        'ally2_post_spike_max_health_loss', 'ally2_pre_spike_total_health_loss',
#        'ally2_post_spike_total_health_loss', 'self_pre_spike_avg_shield',
#        'self_post_spike_avg_shield', 'self_pre_spike_max_shield_loss',
#        'self_post_spike_max_shield_loss', 'self_pre_spike_total_shield_loss',
#        'self_post_spike_total_shield_loss', 'self_pre_spike_avg_credits',
#        'self_post_spike_avg_credits', 'self_pre_spike_max_credits_loss',
#        'self_post_spike_max_credits_loss', 'self_pre_spike_total_credits_loss',
#        'self_post_spike_total_credits_loss', 'self_pre_spike_avg_ammo_mag',
#        'self_post_spike_avg_ammo_mag', 'self_pre_spike_max_ammo_mag_loss',
#        'self_post_spike_max_ammo_mag_loss',
#        'self_pre_spike_total_ammo_mag_loss',
#        'self_post_spike_total_ammo_mag_loss', 'self_longest_inv_state',
#        'self_pre_spike_longest_inv_state', 'self_post_spike_longest_inv_state',
#        'ally3_ultimate_usage', 'ally3_pre_spike_ultimate_usage',
#        'ally3_post_spike_ultimate_usage', 'ally4_ultimate_usage',
#        'ally4_pre_spike_ultimate_usage', 'ally4_post_spike_ultimate_usage',
#        'self_ultimate_usage'],
#       dtype='object')

# %%
clean_df.columns[200:]
# Out:
# Index(['self_pre_spike_ultimate_usage', 'self_post_spike_ultimate_usage',
#        'ally1_ultimate_usage', 'ally1_pre_spike_ultimate_usage',
#        'ally1_post_spike_ultimate_usage', 'ally2_ultimate_usage',
#        'ally2_pre_spike_ultimate_usage', 'ally2_post_spike_ultimate_usage',
#        'opponent0_ultimate_usage', 'opponent0_pre_spike_ultimate_usage',
#        'opponent0_post_spike_ultimate_usage', 'opponent1_ultimate_usage',
#        'opponent1_pre_spike_ultimate_usage',
#        'opponent1_post_spike_ultimate_usage', 'opponent2_ultimate_usage',
#        'opponent2_pre_spike_ultimate_usage',
#        'opponent2_post_spike_ultimate_usage', 'opponent3_ultimate_usage',
#        'opponent3_pre_spike_ultimate_usage',
#        'opponent3_post_spike_ultimate_usage', 'opponent4_ultimate_usage',
#        'opponent4_pre_spike_ultimate_usage',
#        'opponent4_post_spike_ultimate_usage', 'self_pre_spike_map_covered',
#        'self_pre_spike_movement_metric', 'self_post_spike_map_covered',
#        'self_post_spike_movement_metric', 'self_longest_gun_primary',
#        'self_pre_spike_longest_gun_primary',
#        'self_post_spike_longest_gun_primary',
#        'self_pre_spike_avg_ammo_reserve', 'self_post_spike_avg_ammo_reserve',
#        'self_pre_spike_max_ammo_reserve_loss',
#        'self_post_spike_max_ammo_reserve_loss',
#        'self_pre_spike_total_ammo_reserve_loss',
#        'self_post_spike_total_ammo_reserve_loss', 'self_total_firing_time',
#        'self_pre_spike_total_firing_time', 'self_post_spike_total_firing_time',
#        'self_longest_gun_secondary', 'self_pre_spike_longest_gun_secondary',
#        'self_post_spike_longest_gun_secondary',
#        'self_pre_spike_avg_loadout_value', 'self_post_spike_avg_loadout_value',
#        'self_pre_spike_max_loadout_value_loss',
#        'self_post_spike_max_loadout_value_loss',
#        'self_pre_spike_total_loadout_value_loss',
#        'self_post_spike_total_loadout_value_loss',
#        'self_pre_spike_total_ability_usage_1',
#        'self_post_spike_total_ability_usage_1',
#        'self_pre_spike_total_ability_usage_2',
#        'self_post_spike_total_ability_usage_2',
#        'self_pre_spike_total_ability_usage_3',
#        'self_post_spike_total_ability_usage_3',
#        'self_pre_spike_total_ability_usage_4',
#        'self_post_spike_total_ability_usage_4'],
#       dtype='object')

# %%
clean_df.to_csv("pro2_data_norm_round_spikesplit.csv", index=False)
