# %% [markdown]
# # Purpose of notebook
# This notebook is to continue to explore the data, in particular the time-series and bi-modal distributions from previous version.
#
# Topics covered:
# - data normalization by round
# - data cleaning/flattening

# %%
import json
import pandas as pd

# %% [markdown]
# ## Loading the data

# %%
# Load JSON data from file
with open('dev_data.json', 'r') as f:
    data = json.load(f)

# Access an element to retrieve the keys
sample_element = data[0]
columns = sample_element.keys()
print("Columns:", columns)

num_rows = len(data)
print("Number of rows:", num_rows)
# Out:
# Columns: dict_keys(['id', 'game_id', 'map_id', 'processed', 'process_date', 'created_at', 'updated_at', 'match_id', 'result', 'score', 'statistics', 'totals', 'ten_minute_averages', 'character_id', 'user_id', 'match_length', 'video_id', 'card_url', 'total_time', 'totals_to_date', 'start_time', 'end_time', 'start_frame', 'end_frame', 'status', 'report', 'analysis_processed', 'analysis_status'])
# Number of rows: 534

# %%
# Observing a random entry
data[533]
# Out:
# {'id': 1461,
#  'game_id': 3,
#  'map_id': 134,
#  'processed': True,
#  'process_date': None,
#  'created_at': '2023-02-27T21:05:53.784Z',
#  'updated_at': '2023-03-01T16:36:13.672Z',
#  'match_id': None,
#  'result': 'win',
#  'score': '13-7',
#  'statistics': {'map': 'Lotus',
#   'score': '13-7',
#   'allies': ['0', '1', '2', '3', '4'],
#   'player': '2',
#   'result': 'win',
#   'rounds': {'0': {'alive': {'0': [[194, True], [56987, False]],
#      '1': [[194, True], [78984, False]],
#      '2': [[194, True], [74584, False]],
#      '3': [[194, True], [48388, False]],
#      '4': [[194, True], [63186, False]],
#      '5': [[194, True],
#       [56587, False],
#       [64386, True],
#       [77384, False],
#       [79384, True]],
#      '6': [[194, True]],
#      '7': [[194, True]],
#      '8': [[194, True]],
#      '9': [[194, True]]},
#     'elims': [[48388,
#       {'source': '7',
#        'target': '3',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': True,
#        'team_credit': 'opponent'}],
#      [57187,
#       {'source': '8',
#        'target': '0',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [63586,
#       {'source': '6',
#        'target': '4',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [64386,
#       {'source': '5',
#        'target': '4',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [74784,
#       {'source': '8',
#        'target': '2',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [79584,
#       {'source': '9',
#        'target': '1',
#        'assisted': ['5', '6'],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}]],
#     'health': {'0': [[194, 100],
#       [2794, 96],
#       [3594, 100],
#       [3994, 0],
#       [5394, 93],
#       [12993, 100],
#       [14992, 93],
#       [15592, 89],
#       [16392, 93],
#       [17192, 81],
#       [18192, 89],
#       [19792, 93],
#       [20792, 85],
#       [22191, 89],
#       [22991, 93],
#       [30590, 89],
#       [30990, 93],
#       [31390, 89],
#       [32390, 93],
#       [35990, 96],
#       [36989, 93],
#       [37589, 96],
#       [38389, 89],
#       [38989, 93],
#       [40989, 89],
#       [41589, 85],
#       [42989, 89],
#       [44388, 93],
#       [48388, 96],
#       [49588, 92],
#       [50188, 100],
#       [50588, 92],
#       [50988, 96],
#       [51388, 92],
#       [51787, 96],
#       [52587, 92],
#       [54987, 96]],
#      '1': [[194, 100],
#       [1194, 92],
#       [1994, 96],
#       [2594, 100],
#       [4794, 0],
#       [5394, 92],
#       [5794, 88],
#       [6794, 92],
#       [12993, 96],
#       [13593, 100],
#       [14393, 92],
#       [14992, 96],
#       [15992, 88],
#       [18992, 96],
#       [19592, 92],
#       [20592, 88],
#       [21192, 81],
#       [21991, 88],
#       [22391, 92],
#       [25391, 96],
#       [26991, 92],
#       [30790, 96],
#       [31390, 92],
#       [32990, 96],
#       [33390, 92],
#       [33790, 96],
#       [38589, 92],
#       [39389, 96],
#       [40589, 92],
#       [40989, 96],
#       [42389, 92],
#       [47588, 96],
#       [48588, 89],
#       [49588, 86],
#       [50388, 89],
#       [52987, 86],
#       [55187, 89],
#       [55787, 86],
#       [57387, 89],
#       [60786, 86],
#       [61386, 89],
#       [67785, 85],
#       [68385, 93],
#       [69985, 89],
#       [70985, 93],
#       [73585, 52],
#       [74584, 86],
#       [77384, 89],
#       [77784, 0]],
#      '2': [[194, 100], [74584, 0]],
#      '3': [[194, 100],
#       [1594, 96],
#       [2194, 100],
#       [4794, 0],
#       [5594, 89],
#       [12993, 93],
#       [15592, 89],
#       [15992, 93],
#       [17392, 85],
#       [19192, 93],
#       [20192, 89],
#       [20592, 93],
#       [21592, 89],
#       [22391, 52],
#       [23191, 89],
#       [24991, 93],
#       [26991, 89],
#       [27791, 93],
#       [28991, 89],
#       [29790, 93],
#       [31390, 89],
#       [32390, 93],
#       [39189, 89],
#       [45788, 93],
#       [47788, 0]],
#      '4': [[194, 100],
#       [1594, 89],
#       [2794, 93],
#       [3594, 96],
#       [5394, 86],
#       [6394, 89],
#       [6794, 86],
#       [12993, 89],
#       [16992, 82],
#       [21392, 86],
#       [22591, 82],
#       [23791, 86],
#       [25591, 89],
#       [26991, 86],
#       [38589, 82],
#       [39589, 89],
#       [39989, 86],
#       [42189, 89],
#       [42789, 86],
#       [48188, 89],
#       [49588, 86],
#       [50388, 89],
#       [51587, 86],
#       [52387, 82],
#       [53187, 89],
#       [53587, 86],
#       [54387, 89],
#       [56387, 82],
#       [57787, 86],
#       [58187, 89],
#       [59986, 86],
#       [60586, 89],
#       [62586, 82]]},
#     'phases': [[0, 'buy_start'],
#      [44999, 'round_start'],
#      [78377, 'round_scored'],
#      [85377, 'round_end']],
#     'shield': [[194, 0], [47788, 25], [74584, 0]],
#     'credits': [[194, 0], [20192, 40], [40189, 0], [59786, 40]],
#     'ammo_mag': [[1794, 12],
#      [59386, 11],
#      [59786, 10],
#      [59986, 9],
#      [60186, 7],
#      [60386, 6],
#      [61786, 12],
#      [72985, 11],
#      [73185, 10],
#      [73585, 9],
#      [74184, 7]],
#     'inv_state': [[1194, 'secondary'],
#      [5394, 'none'],
#      [6394, 'melee'],
#      [21792, 'secondary'],
#      [22991, 'melee'],
#      [43789, 'secondary'],
#      [48788, 'melee'],
#      [52987, 'secondary']],
#     'ult_state': {'0': [[194, False]],
#      '1': [[194, False]],
#      '2': [[194, False]],
#      '3': [[194, False]],
#      '4': [[194, False]],
#      '5': [[194, False]],
#      '6': [[194, False]],
#      '7': [[194, False]],
#      '8': [[194, False]],
#      '9': [[194, False]]},
#     'map_region': [[6794, 'Defender Side Spawn'],
#      [18192, 'B Upper'],
#      [51188, 'Defender Side Spawn'],
#      [52187, 'A Stairs'],
#      [70985, 'A Main']],
#     'elims_count': [[394, 0, 0]],
#     'inv_primary': [[194, 'none']],
#     'ammo_reserve': [[44588, 35], [62986, 30]],
#     'firing_state': [[194, False],
#      [59386, True],
#      [62586, False],
#      [72985, True],
#      [76384, False]],
#     'assists_count': [[394, 0, 0]],
#     'inv_secondary': [[194, 'classic']],
#     'loadout_value': [[194, 0],
#      [45188, 400.0],
#      [47788, 800.0],
#      [71585, 800.0],
#      [72185, 400.0],
#      [74584, 0.0]],
#     'spike_planted': [[194, False], [71185, True], [78984, False]],
#     'assisted_count': [[394, 0, 0]],
#     'ability_charges_1': [[194, 0], [45188, 1], [72185, 0]],
#     'ability_charges_2': [[194, 0]],
#     'ability_charges_3': [[194, 0], [45188, 1], [71585, 0]],
#     'ability_charges_4': [[194, 0]]},
#    '1': {'alive': {'0': [[85383, True], [171971, False]],
#      '1': [[85383, True], [179370, False]],
#      '2': [[85383, True], [181970, False]],
#      '3': [[85383, True], [147974, False]],
#      '4': [[85383, True], [132377, False]],
#      '5': [[85383, True]],
#      '6': [[85383, True]],
#      '7': [[85383, True], [133576, False]],
#      '8': [[85383, True]],
#      '9': [[85383, True]]},
#     'elims': [[133976,
#       {'source': '4',
#        'target': '7',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': True,
#        'team_credit': 'ally'}],
#      [135176,
#       {'source': '9',
#        'target': '4',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [148374,
#       {'source': '8',
#        'target': '3',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [179570,
#       {'source': '5',
#        'target': '1',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': True,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [181970,
#       {'source': '9',
#        'target': '2',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'opponent'}]],
#     'health': {'0': [[85383, 100],
#       [86383, 96],
#       [87383, 100],
#       [90782, 89],
#       [91382, 93],
#       [93582, 89],
#       [94582, 93],
#       [96381, 89],
#       [96981, 93],
#       [100381, 89],
#       [102981, 93],
#       [103780, 89],
#       [104380, 96],
#       [104780, 93],
#       [105980, 89],
#       [106580, 85],
#       [106980, 93],
#       [108380, 89],
#       [109180, 93],
#       [111979, 89],
#       [114579, 85],
#       [115379, 89],
#       [118178, 93],
#       [128977, 89],
#       [129777, 93],
#       [130977, 89],
#       [131977, 93],
#       [134176, 100],
#       [135376, 96],
#       [139976, 88],
#       [140975, 96],
#       [141375, 100],
#       [141975, 92],
#       [142975, 96],
#       [146775, 92],
#       [148174, 93],
#       [148774, 89],
#       [150974, 86],
#       [152174, 89],
#       [153174, 86],
#       [154374, 89],
#       [156973, 86],
#       [158973, 89],
#       [162972, 86],
#       [164972, 89],
#       [165972, 0]],
#      '1': [[85383, 100],
#       [90182, 96],
#       [91382, 100],
#       [91982, 92],
#       [92782, 96],
#       [96181, 100],
#       [97181, 96],
#       [100581, 100],
#       [101581, 96],
#       [103180, 92],
#       [104980, 96],
#       [105980, 88],
#       [106980, 96],
#       [107980, 92],
#       [110380, 88],
#       [110979, 92],
#       [111779, 85],
#       [112379, 88],
#       [115179, 92],
#       [116179, 88],
#       [116979, 92],
#       [118178, 96],
#       [118978, 92],
#       [119778, 96],
#       [121378, 92],
#       [121778, 96],
#       [122378, 92],
#       [122778, 96],
#       [128577, 92],
#       [129177, 96],
#       [129977, 92],
#       [130377, 96],
#       [130777, 92],
#       [131177, 96],
#       [132976, 88],
#       [134776, 89],
#       [135376, 86],
#       [136976, 89],
#       [141375, 93],
#       [141975, 86],
#       [142975, 89],
#       [147175, 86],
#       [147974, 93],
#       [150974, 89],
#       [151574, 93],
#       [151974, 89],
#       [153774, 93],
#       [156173, 89],
#       [159373, 93],
#       [161173, 89],
#       [162972, 93],
#       [163372, 89],
#       [164772, 93],
#       [166572, 89],
#       [167372, 93],
#       [169372, 89],
#       [170371, 85],
#       [173171, 89],
#       [174371, 96],
#       [174971, 93],
#       [176971, 89],
#       [178170, 93]],
#      '2': [[85383, 100], [181970, 0]],
#      '3': [[85383, 100],
#       [86983, 96],
#       [90182, 100],
#       [90982, 78],
#       [92382, 89],
#       [93982, 93],
#       [94382, 89],
#       [94982, 93],
#       [96181, 100],
#       [97381, 89],
#       [98581, 93],
#       [100181, 81],
#       [101581, 89],
#       [101981, 85],
#       [102981, 89],
#       [104780, 93],
#       [105780, 85],
#       [106980, 93],
#       [108980, 89],
#       [110180, 85],
#       [113179, 89],
#       [114579, 85],
#       [115179, 89],
#       [115579, 85],
#       [116979, 89],
#       [118978, 93],
#       [122978, 89],
#       [123378, 93],
#       [129177, 85],
#       [129777, 89],
#       [130377, 93],
#       [132377, 89],
#       [134776, 86],
#       [136776, 89],
#       [138576, 86],
#       [138976, 89],
#       [139976, 86],
#       [142975, 89],
#       [146975, 86]],
#      '4': [[85383, 100],
#       [86383, 96],
#       [88982, 100],
#       [92182, 89],
#       [92782, 79],
#       [93182, 86],
#       [94382, 89],
#       [95382, 100],
#       [96981, 96],
#       [97381, 89],
#       [99981, 96],
#       [101781, 86],
#       [104380, 89],
#       [106180, 79],
#       [106580, 86],
#       [109180, 89],
#       [110979, 82],
#       [112979, 86],
#       [114379, 82],
#       [115379, 79],
#       [115779, 82],
#       [116179, 86],
#       [118978, 89],
#       [120378, 86],
#       [120978, 89],
#       [121778, 86],
#       [123578, 89],
#       [128977, 86],
#       [129977, 89],
#       [130577, 86],
#       [131177, 89],
#       [134376, 0]]},
#     'phases': [[85377, 'buy_start'],
#      [115377, 'round_start'],
#      [181404, 'round_scored'],
#      [188404, 'round_end']],
#     'shield': [[85383, 0]],
#     'credits': [[85383, 40], [86183, 1900]],
#     'ammo_mag': [[86183, 12],
#      [126777, 32],
#      [126977, 12],
#      [157773, 6],
#      [160573, 5],
#      [162372, 4],
#      [163572, 6]],
#     'inv_state': [[86383, 'secondary'],
#      [87583, 'melee'],
#      [117978, 'secondary'],
#      [122778, 'melee'],
#      [126577, 'secondary'],
#      [127577, 'melee'],
#      [128577, 'secondary'],
#      [131377, 'melee'],
#      [138376, 'secondary'],
#      [149174, 'melee'],
#      [150974, 'secondary']],
#     'ult_state': {'0': [[85383, False]],
#      '1': [[85383, False]],
#      '2': [[85383, False]],
#      '3': [[85383, False]],
#      '4': [[85383, False]],
#      '5': [[85383, False]],
#      '6': [[85383, False]],
#      '7': [[85383, False]],
#      '8': [[85383, False]],
#      '9': [[85383, False]]},
#     'map_region': [[89582, 'Defender Side Spawn'],
#      [103380, 'B Upper'],
#      [105780, 'A Site'],
#      [108380, 'C Link'],
#      [110779, 'C Waterfall'],
#      [113579, 'C Site'],
#      [127377, 'C Waterfall'],
#      [130577, 'C Link'],
#      [133376, 'C Gravel'],
#      [138976, 'C Link'],
#      [144175, 'A Site'],
#      [152174, 'A Link'],
#      [170171, 'A Main']],
#     'elims_count': [[85583, 0, 0]],
#     'inv_primary': [[85383, 'none']],
#     'ammo_reserve': [[86183, 35],
#      [118378, 36],
#      [145175, 35],
#      [147774, 36],
#      [154973, 24],
#      [157173, 19],
#      [163572, 17]],
#     'firing_state': [[85383, False], [160573, True], [164572, False]],
#     'assists_count': [[85583, 0, 0]],
#     'inv_secondary': [[85383, 'classic'], [154973, 'sheriff']],
#     'loadout_value': [[85383, 0],
#      [118778, 0.0],
#      [119978, 400.0],
#      [124978, 0.0],
#      [126577, 400.0],
#      [146175, 400.0],
#      [148974, 400.0],
#      [154973, 1200.0]],
#     'spike_planted': [[85383, False], [153974, True], [181970, False]],
#     'assisted_count': [[85583, 0, 0]],
#     'ability_charges_1': [[85383, 0], [119978, 1], [124978, 0], [126577, 1]],
#     'ability_charges_2': [[85383, 0]],
#     'ability_charges_3': [[85383, 0], [118778, 1], [146175, 0], [148974, 1]],
#     'ability_charges_4': [[85383, 0]]},
#    '2': {'alive': {'0': [[188569, True], [228164, False]],
#      '1': [[188569, True]],
#      '2': [[188569, True]],
#      '3': [[188569, True]],
#      '4': [[188569, True], [266158, False]],
#      '5': [[188569, True], [228164, False]],
#      '6': [[188569, True], [235163, False], [238562, True], [260959, False]],
#      '7': [[188569, True], [226964, False]],
#      '8': [[188569, True], [267158, False]],
#      '9': [[188569, True], [228564, False]]},
#     'elims': [[227564,
#       {'source': '0',
#        'target': '7',
#        'assisted': ['3'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': True,
#        'team_credit': 'ally'}],
#      [229563,
#       {'source': '9',
#        'target': '0',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [230363,
#       {'source': '4',
#        'target': '9',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [230763,
#       {'source': '6',
#        'target': '0',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [233563,
#       {'source': '2',
#        'target': '5',
#        'weapon': 'phantom',
#        'assisted': ['2'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally',
#        'weapon_type': 'primary'}],
#      [262759,
#       {'source': '3',
#        'target': '6',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [267158,
#       {'source': '3',
#        'target': '8',
#        'assisted': ['2'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [267958,
#       {'source': '8',
#        'target': '4',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}]],
#     'health': {'0': [[188569, 100],
#       [190569, 0],
#       [191768, 100],
#       [193168, 93],
#       [193768, 100],
#       [195968, 96],
#       [196368, 89],
#       [196768, 96],
#       [197368, 93],
#       [198168, 89],
#       [198568, 93],
#       [199767, 89],
#       [200967, 93],
#       [201967, 89],
#       [202367, 93],
#       [202767, 89],
#       [203167, 93],
#       [204767, 89],
#       [205767, 96],
#       [206566, 93],
#       [206966, 96],
#       [207766, 89],
#       [208766, 93],
#       [209166, 89],
#       [210366, 93],
#       [212766, 89],
#       [213766, 93],
#       [217565, 89],
#       [219765, 85],
#       [221165, 93],
#       [221764, 44],
#       [223164, 85],
#       [224164, 89],
#       [224564, 93],
#       [226564, 96],
#       [226964, 93],
#       [227364, 89],
#       [227764, 0]],
#      '1': [[188569, 100],
#       [190969, 0],
#       [191768, 96],
#       [196568, 92],
#       [197568, 96],
#       [198168, 92],
#       [199767, 96],
#       [200567, 88],
#       [201367, 96],
#       [201767, 92],
#       [206966, 96],
#       [207366, 100],
#       [207766, 92],
#       [208766, 88],
#       [209166, 92],
#       [209766, 88],
#       [210966, 92],
#       [211366, 96],
#       [212366, 92],
#       [212766, 96],
#       [216965, 92],
#       [217965, 96],
#       [218965, 92],
#       [219765, 96],
#       [223964, 92],
#       [225564, 96],
#       [227164, 92],
#       [227564, 96],
#       [230163, 92],
#       [230763, 88],
#       [231963, 92],
#       [232763, 100],
#       [234763, 92],
#       [235163, 96],
#       [236362, 88],
#       [237362, 92],
#       [237762, 88],
#       [239162, 92],
#       [241162, 88],
#       [241562, 85],
#       [243362, 88],
#       [244161, 92],
#       [247761, 96],
#       [249361, 92],
#       [249961, 77],
#       [250960, 58],
#       [251360, 42],
#       [252560, 73],
#       [253960, 85],
#       [255160, 92],
#       [257160, 96],
#       [257760, 92],
#       [258559, 88],
#       [259759, 96],
#       [261759, 88],
#       [262359, 92],
#       [263359, 88],
#       [263759, 92],
#       [266558, 82],
#       [267158, 0],
#       [267758, 32],
#       [268158, 25],
#       [268958, 29],
#       [269758, 50],
#       [270558, 39],
#       [271958, 46],
#       [273357, 14]],
#      '2': [[188569, 100], [241162, 94], [241762, 87], [242762, 81]],
#      '3': [[188569, 100],
#       [189569, 96],
#       [190569, 0],
#       [191768, 93],
#       [194768, 96],
#       [195768, 93],
#       [197968, 89],
#       [198368, 93],
#       [199367, 89],
#       [202767, 93],
#       [203767, 85],
#       [205967, 89],
#       [207166, 93],
#       [207966, 85],
#       [209166, 89],
#       [210366, 93],
#       [212566, 89],
#       [217965, 81],
#       [219165, 85],
#       [220765, 93],
#       [221964, 89],
#       [222564, 11],
#       [223964, 85],
#       [224564, 89],
#       [225364, 93],
#       [227964, 85],
#       [228963, 81],
#       [229363, 89],
#       [229763, 93],
#       [230763, 85],
#       [232563, 89],
#       [233163, 93],
#       [233563, 89],
#       [235363, 85],
#       [235763, 93],
#       [236962, 78],
#       [237562, 85],
#       [242362, 89],
#       [244561, 93],
#       [244961, 89],
#       [245561, 85],
#       [246361, 89],
#       [246761, 85],
#       [247761, 93],
#       [249161, 89],
#       [250361, 85],
#       [250960, 19],
#       [251360, 15],
#       [252760, 41],
#       [253760, 85],
#       [254160, 89],
#       [255360, 81],
#       [255760, 89],
#       [256160, 85],
#       [257160, 89],
#       [260759, 56],
#       [261359, 85],
#       [262159, 89],
#       [263559, 85],
#       [265359, 81],
#       [266158, 82],
#       [267158, 75],
#       [267758, 82],
#       [268358, 79],
#       [269758, 82],
#       [270558, 86]],
#      '4': [[188569, 100],
#       [193768, 96],
#       [198568, 86],
#       [198968, 89],
#       [199767, 86],
#       [204967, 89],
#       [207166, 86],
#       [207766, 82],
#       [208366, 86],
#       [209366, 89],
#       [209766, 86],
#       [211766, 89],
#       [212566, 93],
#       [213766, 89],
#       [215765, 82],
#       [220765, 93],
#       [221764, 89],
#       [223964, 82],
#       [224964, 89],
#       [227964, 82],
#       [228564, 79],
#       [229363, 89],
#       [230563, 86],
#       [232963, 46],
#       [233763, 50],
#       [234363, 54],
#       [235963, 64],
#       [236962, 46],
#       [237362, 50],
#       [238762, 43],
#       [239962, 32],
#       [243761, 86],
#       [244961, 82],
#       [245761, 86],
#       [246361, 89],
#       [249161, 86],
#       [250960, 61],
#       [253560, 82],
#       [254760, 89],
#       [255760, 86],
#       [257960, 96],
#       [259759, 86],
#       [260759, 39],
#       [261759, 86],
#       [263359, 82]]},
#     'phases': [[188404, 'buy_start'],
#      [218404, 'round_start'],
#      [266564, 'round_scored'],
#      [273564, 'round_end']],
#     'shield': [[188569, 0], [199367, 50], [244361, 11]],
#     'credits': [[188569, 1900], [189169, 4300]],
#     'ammo_mag': [[189369, 12],
#      [191768, 30],
#      [202767, 12],
#      [202967, 30],
#      [219765, 29],
#      [219965, 27],
#      [220165, 25],
#      [220365, 22],
#      [220565, 20],
#      [220765, 18],
#      [220965, 17],
#      [226564, 30],
#      [231563, 28],
#      [231763, 26],
#      [231963, 23],
#      [232763, 21],
#      [232963, 19],
#      [233163, 17],
#      [233363, 15],
#      [234363, 14],
#      [234763, 13],
#      [235163, 11],
#      [250561, 6],
#      [250960, 9],
#      [251160, 6],
#      [251560, 9],
#      [251760, 6],
#      [251960, 30],
#      [265558, 28],
#      [265758, 26],
#      [265958, 24],
#      [267158, 21],
#      [267358, 19],
#      [267558, 18]],
#     'inv_state': [[189569, 'secondary'],
#      [192568, 'primary'],
#      [204167, 'none'],
#      [213366, 'secondary'],
#      [215565, 'melee'],
#      [218565, 'primary'],
#      [227364, 'none'],
#      [229963, 'primary'],
#      [237962, 'none'],
#      [242362, 'primary'],
#      [267758, 'melee']],
#     'ult_state': {'0': [[188569, False]],
#      '1': [[188569, False]],
#      '2': [[188569, False]],
#      '3': [[188569, False]],
#      '4': [[188569, False]],
#      '5': [[188569, False]],
#      '6': [[188569, False]],
#      '7': [[188569, False]],
#      '8': [[188569, False]],
#      '9': [[188569, False]]},
#     'map_region': [[201367, 'B Upper'],
#      [205767, 'A Site'],
#      [216765, 'A Link'],
#      [228364, 'A Main'],
#      [231363, 'A Rubble'],
#      [239162, 'A Hut'],
#      [243761, 'A Root'],
#      [245961, 'A Rubble'],
#      [249561, 'A Root'],
#      [255360, 'A Rubble'],
#      [260159, 'A Root'],
#      [261959, 'A Hut'],
#      [263159, 'A Root'],
#      [263559, 'A Rubble'],
#      [264359, 'A Root'],
#      [268158, 'A Lobby'],
#      [272758, 'Attacker Side Spawn']],
#     'elims_count': [[188769, 0, 0], [233563, 1, 1]],
#     'inv_primary': [[188569, 'none'],
#      [192568, 'phantom'],
#      [213366, 'none'],
#      [215565, 'phantom'],
#      [268558, 'none']],
#     'ammo_reserve': [],
#     'firing_state': [[188569, False],
#      [219765, True],
#      [223164, False],
#      [231563, True],
#      [237362, False],
#      [250561, True],
#      [253960, False],
#      [265558, True],
#      [269758, False]],
#     'assists_count': [[188769, 0, 0], [233563, 1, 1], [267158, 2, 2]],
#     'inv_secondary': [[188569, 'classic'],
#      [213766, 'ghost'],
#      [215565, 'classic']],
#     'loadout_value': [[188569, 0],
#      [192568, 3300.0],
#      [199367, 4300.0],
#      [213366, 1400.0],
#      [213766, 1900.0],
#      [215565, 4300.0],
#      [218565, 4700.0],
#      [223164, 4300.0],
#      [226964, 4700.0],
#      [228763, 4300.0],
#      [229763, 3900.0],
#      [234963, 4300.0],
#      [237562, 3900.0],
#      [244361, 3076.0],
#      [268558, 176.0]],
#     'spike_planted': [[188569, False]],
#     'assisted_count': [[188769, 0, 0], [233563, 1, 1]],
#     'ability_charges_1': [[188569, 1],
#      [223164, 0],
#      [226964, 1],
#      [229763, 0],
#      [234963, 1],
#      [237562, 0]],
#     'ability_charges_2': [[188569, 0], [218565, 2], [228763, 0]],
#     'ability_charges_3': [[188569, 1], [223164, 0]],
#     'ability_charges_4': [[188569, 0]]},
#    '3': {'alive': {'0': [[273757, True], [361745, False]],
#      '1': [[273757, True], [359146, False]],
#      '2': [[273757, True], [362745, False]],
#      '3': [[273757, True], [347147, False]],
#      '4': [[273757, True], [352947, False]],
#      '5': [[273757, True], [356146, False]],
#      '6': [[273757, True]],
#      '7': [[273757, True], [306553, False]],
#      '8': [[273757, True], [345348, False]],
#      '9': [[273757, True]]},
#     'elims': [[306753,
#       {'source': '3',
#        'target': '7',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': True,
#        'team_credit': 'ally'}],
#      [345548,
#       {'source': '2',
#        'target': '8',
#        'weapon': 'phantom',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally',
#        'weapon_type': 'primary'}],
#      [347147,
#       {'source': '9',
#        'target': '3',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [353147,
#       {'source': '6',
#        'target': '4',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [359146,
#       {'source': '6',
#        'target': '1',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [361945,
#       {'source': '6',
#        'target': '0',
#        'assisted': ['5', '8'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 3,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [362345,
#       {'source': '2',
#        'target': '5',
#        'weapon': 'phantom',
#        'assisted': ['0'],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'ally',
#        'weapon_type': 'primary'}],
#      [362745,
#       {'source': '6',
#        'target': '2',
#        'assisted': ['5', '6'],
#        'headshot': True,
#        'wallbang': True,
#        'elim_number': 4,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [362745,
#       {'source': '2',
#        'target': '8',
#        'weapon': 'phantom',
#        'assisted': ['0'],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 3,
#        'first_blood': False,
#        'team_credit': 'ally',
#        'weapon_type': 'primary'}],
#      [363945,
#       {'source': '0',
#        'target': '5',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}]],
#     'health': {'0': [[273757, 100],
#       [274757, 0],
#       [276757, 89],
#       [278557, 93],
#       [280756, 96],
#       [281356, 93],
#       [284356, 89],
#       [285356, 93],
#       [288955, 89],
#       [289955, 93],
#       [291555, 96],
#       [293555, 93],
#       [296154, 96],
#       [296554, 93],
#       [298754, 89],
#       [299154, 85],
#       [299954, 93],
#       [301154, 100],
#       [301754, 96],
#       [302553, 100],
#       [303153, 93],
#       [304153, 78],
#       [304553, 93],
#       [305153, 89],
#       [306753, 100],
#       [307153, 96],
#       [308353, 93],
#       [312952, 96],
#       [313352, 93],
#       [316952, 96],
#       [318751, 85],
#       [319951, 89],
#       [324351, 93],
#       [328550, 89],
#       [330350, 93],
#       [332149, 89],
#       [332549, 93],
#       [334749, 89],
#       [335149, 93],
#       [336549, 81],
#       [337349, 85],
#       [338549, 89],
#       [339748, 93],
#       [340548, 85],
#       [341748, 93],
#       [342748, 89],
#       [344548, 93],
#       [345548, 89],
#       [347147, 92],
#       [348547, 96],
#       [349947, 92],
#       [350347, 88],
#       [351147, 92],
#       [352547, 4],
#       [353547, 82],
#       [355546, 86],
#       [358146, 0],
#       [358546, 82],
#       [359346, 89],
#       [360546, 81]],
#      '1': [[273757, 100],
#       [276957, 88],
#       [277357, 85],
#       [278557, 96],
#       [282956, 92],
#       [284356, 96],
#       [288555, 88],
#       [288955, 92],
#       [289355, 88],
#       [289955, 92],
#       [291555, 88],
#       [293555, 96],
#       [294355, 92],
#       [295354, 96],
#       [296754, 92],
#       [297154, 96],
#       [298954, 88],
#       [299954, 100],
#       [300554, 96],
#       [301154, 100],
#       [301754, 96],
#       [303353, 100],
#       [305353, 96],
#       [305753, 92],
#       [306353, 96],
#       [306753, 100],
#       [307753, 96],
#       [315952, 88],
#       [316552, 100],
#       [317951, 96],
#       [319551, 85],
#       [319951, 88],
#       [320551, 92],
#       [321351, 96],
#       [322151, 88],
#       [322751, 96],
#       [323551, 92],
#       [326550, 96],
#       [328150, 88],
#       [328550, 92],
#       [330350, 96],
#       [332149, 88],
#       [332549, 96],
#       [337949, 88],
#       [338749, 92],
#       [339349, 96],
#       [340948, 92],
#       [341948, 88],
#       [343548, 96],
#       [345348, 92],
#       [345748, 96],
#       [347147, 89],
#       [347747, 86],
#       [348547, 89],
#       [350747, 86],
#       [351147, 82],
#       [352547, 4],
#       [353147, 81],
#       [354146, 85],
#       [354546, 81],
#       [355546, 85],
#       [356346, 89],
#       [358146, 0],
#       [358546, 85]],
#      '2': [[273757, 100], [361945, 87], [362745, 0]],
#      '3': [[273757, 100],
#       [274757, 0],
#       [276557, 93],
#       [276957, 89],
#       [278357, 93],
#       [283356, 89],
#       [284556, 93],
#       [288355, 85],
#       [288955, 89],
#       [289355, 85],
#       [289755, 93],
#       [291755, 85],
#       [293355, 89],
#       [294555, 93],
#       [296954, 89],
#       [297354, 93],
#       [298554, 89],
#       [298954, 85],
#       [300354, 93],
#       [301354, 96],
#       [301754, 100],
#       [302753, 93],
#       [303353, 100],
#       [306753, 93],
#       [315152, 89],
#       [316552, 85],
#       [317951, 93],
#       [318351, 89],
#       [319551, 85],
#       [319951, 89],
#       [320351, 85],
#       [321351, 89],
#       [321751, 85],
#       [322551, 89],
#       [324151, 85],
#       [326150, 89],
#       [326550, 93],
#       [326950, 89],
#       [327350, 93],
#       [328150, 89],
#       [328950, 85],
#       [329550, 89],
#       [331750, 93],
#       [334949, 89],
#       [335349, 93],
#       [337549, 85],
#       [338949, 89],
#       [339948, 93],
#       [340948, 85],
#       [341548, 89],
#       [342548, 85],
#       [343348, 89],
#       [345148, 85],
#       [345548, 89]],
#      '4': [[273757, 100],
#       [276557, 96],
#       [277157, 93],
#       [277557, 89],
#       [277957, 86],
#       [278357, 89],
#       [283356, 86],
#       [284556, 89],
#       [287955, 86],
#       [289755, 89],
#       [290155, 82],
#       [290555, 86],
#       [293355, 89],
#       [294355, 86],
#       [294755, 89],
#       [301154, 96],
#       [301554, 100],
#       [302553, 96],
#       [303353, 100],
#       [307153, 89],
#       [307553, 86],
#       [308953, 89],
#       [312952, 86],
#       [313352, 96],
#       [313752, 89],
#       [316152, 86],
#       [316552, 100],
#       [317951, 89],
#       [318551, 86],
#       [320951, 82],
#       [322551, 86],
#       [323751, 89],
#       [327350, 86],
#       [329150, 82],
#       [329550, 86],
#       [330350, 89],
#       [331550, 86],
#       [333749, 89],
#       [334749, 86],
#       [335749, 89],
#       [336549, 86],
#       [336949, 96],
#       [337549, 86],
#       [338549, 82],
#       [339548, 86],
#       [340348, 89],
#       [340748, 86],
#       [341748, 89],
#       [342148, 86],
#       [342548, 82],
#       [345748, 86],
#       [348747, 89],
#       [350147, 86],
#       [351347, 32],
#       [351947, 86]]},
#     'phases': [[273564, 'buy_start'],
#      [303564, 'round_start'],
#      [362140, 'round_scored'],
#      [369140, 'round_end']],
#     'shield': [[273757, 11],
#      [278557, 50],
#      [288555, 8],
#      [307353, 50],
#      [362745, 0]],
#     'credits': [[273757, 4300], [279757, 1400]],
#     'ammo_mag': [[274157, 18],
#      [275157, 30],
#      [324950, 28],
#      [325150, 26],
#      [325550, 22],
#      [325750, 19],
#      [325950, 17],
#      [326150, 15],
#      [326350, 14],
#      [327950, 30],
#      [344548, 28],
#      [344748, 26],
#      [344948, 24],
#      [345148, 22],
#      [345348, 19],
#      [345548, 17],
#      [345748, 16],
#      [348547, 10],
#      [350347, 30],
#      [352947, 28],
#      [353147, 27],
#      [359946, 26],
#      [360146, 24],
#      [360346, 22],
#      [360546, 20],
#      [360746, 19],
#      [361745, 18],
#      [362345, 12],
#      [362545, 10]],
#     'inv_state': [[276557, 'primary'],
#      [287356, 'melee'],
#      [293755, 'primary'],
#      [296754, 'melee'],
#      [299154, 'primary'],
#      [303753, 'none'],
#      [305153, 'primary'],
#      [312952, 'melee'],
#      [315352, 'primary'],
#      [319151, 'melee'],
#      [320151, 'primary'],
#      [322351, 'none'],
#      [324750, 'primary'],
#      [330150, 'melee'],
#      [335549, 'primary'],
#      [341948, 'none'],
#      [343948, 'primary'],
#      [345948, 'none'],
#      [355546, 'primary']],
#     'ult_state': {'0': [[273757, False]],
#      '1': [[273757, False]],
#      '2': [[273757, False]],
#      '3': [[273757, False]],
#      '4': [[273757, False]],
#      '5': [[273757, False]],
#      '6': [[273757, False]],
#      '7': [[273757, False]],
#      '8': [[273757, False], [274157, True], [316952, False]],
#      '9': [[273757, False]]},
#     'map_region': [[276557, 'Defender Side Spawn'],
#      [287955, 'A Stairs'],
#      [292355, 'A Site'],
#      [295954, 'A Tree'],
#      [297154, 'A Site'],
#      [302753, 'A Main'],
#      [307353, 'A Site'],
#      [316152, 'A Main'],
#      [327950, 'A Link'],
#      [330950, 'A Site'],
#      [334749, 'C Link'],
#      [338349, 'C Waterfall'],
#      [344348, 'C Site']],
#     'elims_count': [[273957, 0, 1],
#      [345548, 1, 2],
#      [362345, 2, 3],
#      [362745, 3, 4]],
#     'inv_primary': [[273757, 'none'],
#      [276557, 'phantom'],
#      [322951, 'none'],
#      [324351, 'phantom'],
#      [333549, 'none'],
#      [334749, 'phantom']],
#     'ammo_reserve': [[296354, 90], [334749, 74]],
#     'firing_state': [[273757, False],
#      [324950, True],
#      [328550, False],
#      [344548, True],
#      [347947, False],
#      [352947, True],
#      [355346, False],
#      [359946, True],
#      [364745, False]],
#     'assists_count': [[273957, 0, 2]],
#     'inv_secondary': [[273757, 'classic']],
#     'loadout_value': [[273757, 176.0],
#      [276557, 3076.0],
#      [278557, 3900.0],
#      [288555, 3028.0],
#      [303753, 3428.0],
#      [304753, 3628.0],
#      [307353, 4100.0],
#      [308353, 4100.0],
#      [313352, 4500.0],
#      [322951, 1600.0],
#      [324351, 4500.0],
#      [330750, 4100.0],
#      [333149, 4500.0],
#      [333549, 1600.0],
#      [334749, 4500.0],
#      [341148, 4100.0],
#      [346148, 4100.0],
#      [346548, 3900.0],
#      [362745, 2900.0]],
#     'spike_planted': [[273757, False]],
#     'assisted_count': [[273957, 0, 1], [362345, 1, 2], [362745, 2, 3]],
#     'ability_charges_1': [[273757, 0],
#      [303753, 1],
#      [307353, 0],
#      [313352, 1],
#      [330750, 0],
#      [333149, 1],
#      [341148, 0]],
#     'ability_charges_2': [[273757, 0], [304753, 1], [346548, 0]],
#     'ability_charges_3': [[273757, 0], [308353, 1], [346148, 0]],
#     'ability_charges_4': [[273757, 0]]},
#    '4': {'alive': {'0': [[369144, True], [423537, False]],
#      '1': [[369144, True], [431936, False]],
#      '2': [[369144, True], [423337, False]],
#      '3': [[369144, True], [426137, False]],
#      '4': [[369144, True], [416338, False]],
#      '5': [[369144, True], [413538, False], [416338, True]],
#      '6': [[369144, True]],
#      '7': [[369144, True]],
#      '8': [[369144, True]],
#      '9': [[369144, True], [422937, False]]},
#     'elims': [[416338,
#       {'source': '7',
#        'target': '4',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': True,
#        'team_credit': 'opponent'}],
#      [423137,
#       {'source': '0',
#        'target': '9',
#        'assisted': ['2'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [423937,
#       {'source': '7',
#        'target': '0',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [423937,
#       {'source': '5',
#        'target': '2',
#        'assisted': ['5'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [426337,
#       {'source': '5',
#        'target': '3',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [431936,
#       {'source': '5',
#        'target': '1',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 3,
#        'first_blood': False,
#        'team_credit': 'opponent'}]],
#     'health': {'0': [[369144, 100],
#       [370144, 93],
#       [370544, 100],
#       [371144, 93],
#       [372144, 89],
#       [373744, 93],
#       [378743, 0],
#       [382343, 89],
#       [382943, 96],
#       [383742, 89],
#       [385742, 96],
#       [386342, 89],
#       [388742, 85],
#       [389342, 93],
#       [391141, 89],
#       [392741, 93],
#       [393741, 85],
#       [394941, 93],
#       [395541, 89],
#       [396741, 93],
#       [397341, 89],
#       [398740, 93],
#       [403740, 89],
#       [404540, 93],
#       [405540, 0],
#       [413538, 7],
#       [414338, 48],
#       [415138, 67],
#       [415538, 74],
#       [416338, 92],
#       [416938, 88],
#       [417538, 92],
#       [419138, 96],
#       [420338, 92],
#       [420737, 96],
#       [422137, 92]],
#      '1': [[369144, 100],
#       [370544, 96],
#       [371344, 100],
#       [373144, 96],
#       [373944, 92],
#       [375144, 96],
#       [378743, 0],
#       [380943, 96],
#       [381543, 92],
#       [383543, 88],
#       [384742, 96],
#       [386742, 92],
#       [389342, 96],
#       [391941, 88],
#       [392541, 92],
#       [394741, 96],
#       [396141, 92],
#       [396741, 96],
#       [397341, 92],
#       [397741, 96],
#       [398540, 92],
#       [402540, 96],
#       [403940, 92],
#       [404740, 96],
#       [406939, 92],
#       [407539, 88],
#       [408139, 85],
#       [408739, 96],
#       [410339, 88],
#       [410739, 96],
#       [411139, 92],
#       [412739, 88],
#       [413139, 96],
#       [414938, 92],
#       [416338, 82],
#       [417138, 86],
#       [420737, 89],
#       [421737, 86],
#       [422737, 89],
#       [425137, 85],
#       [425537, 89],
#       [427137, 86],
#       [427937, 82],
#       [428336, 86],
#       [429936, 29],
#       [430736, 86],
#       [431136, 82]],
#      '2': [[369144, 100], [423337, 0]],
#      '3': [[369144, 100],
#       [370144, 96],
#       [370544, 93],
#       [371344, 89],
#       [371744, 93],
#       [373144, 100],
#       [373544, 85],
#       [375144, 93],
#       [382343, 89],
#       [382743, 85],
#       [384742, 89],
#       [385542, 93],
#       [386342, 89],
#       [387342, 85],
#       [389342, 93],
#       [390142, 89],
#       [391341, 81],
#       [392741, 93],
#       [393541, 89],
#       [393941, 74],
#       [394741, 93],
#       [396741, 89],
#       [397541, 93],
#       [398141, 89],
#       [398940, 85],
#       [400940, 93],
#       [403740, 81],
#       [404140, 89],
#       [404540, 93],
#       [405340, 85],
#       [405939, 89],
#       [406939, 85],
#       [408739, 93],
#       [410939, 89],
#       [411539, 93],
#       [412539, 89],
#       [415138, 85],
#       [415938, 81],
#       [416338, 75],
#       [416738, 86],
#       [418138, 82],
#       [418538, 86],
#       [420538, 89],
#       [422137, 86],
#       [422737, 89],
#       [425337, 86]],
#      '4': [[369144, 100],
#       [370144, 93],
#       [370544, 100],
#       [371544, 89],
#       [374544, 79],
#       [375144, 86],
#       [377943, 89],
#       [381543, 86],
#       [382143, 82],
#       [384542, 86],
#       [386342, 89],
#       [387942, 82],
#       [388742, 89],
#       [390542, 79],
#       [391341, 82],
#       [393341, 89],
#       [393741, 86],
#       [394741, 89],
#       [398341, 86],
#       [400340, 89],
#       [403340, 86],
#       [406939, 82],
#       [408539, 86],
#       [409939, 82],
#       [410939, 86],
#       [414138, 89],
#       [414938, 82],
#       [415338, 86]]},
#     'phases': [[369140, 'buy_start'],
#      [399140, 'round_start'],
#      [431321, 'round_scored'],
#      [438321, 'round_end']],
#     'shield': [[369144, 0], [402540, 25], [423337, 0]],
#     'credits': [[369144, 1400], [369944, 3700], [380943, 1700]],
#     'ammo_mag': [[370144, 12], [380943, 6], [420737, 69], [421137, 6]],
#     'inv_state': [[370144, 'secondary'],
#      [374544, 'none'],
#      [375944, 'melee'],
#      [380943, 'secondary'],
#      [383543, 'melee'],
#      [400940, 'secondary'],
#      [403340, 'melee'],
#      [407739, 'none'],
#      [409339, 'melee'],
#      [411539, 'none'],
#      [412739, 'melee'],
#      [416538, 'secondary']],
#     'ult_state': {'0': [[369144, False], [422937, True]],
#      '1': [[369144, False]],
#      '2': [[369144, False]],
#      '3': [[369144, False]],
#      '4': [[369144, False]],
#      '5': [[369144, False], [430736, True]],
#      '6': [[369144, False]],
#      '7': [[369144, False], [434736, True]],
#      '8': [[369144, False]],
#      '9': [[369144, False]]},
#     'map_region': [[371144, 'Attacker Side Spawn'],
#      [371744, 'Defender Side Spawn'],
#      [384142, 'C Gravel'],
#      [390742, 'C Hall'],
#      [393141, 'C Site'],
#      [395941, 'C Waterfall'],
#      [399140, 'C Link'],
#      [402140, 'A Site'],
#      [407139, 'A Link'],
#      [410139, 'A Site'],
#      [411539, 'B Upper'],
#      [413938, 'Defender Side Spawn'],
#      [415738, 'A Stairs']],
#     'elims_count': [[369144, 0, 4]],
#     'inv_primary': [[369144, 'none']],
#     'ammo_reserve': [[401140, 24]],
#     'firing_state': [[369144, False]],
#     'assists_count': [[369144, 0, 2], [423137, 1, 3]],
#     'inv_secondary': [[369144, 'classic'],
#      [380943, 'sheriff'],
#      [381943, 'classic'],
#      [400940, 'sheriff'],
#      [408139, 'classic'],
#      [412739, 'sheriff']],
#     'loadout_value': [[369144, 0],
#      [380943, 800.0],
#      [381943, 0.0],
#      [399140, 800.0],
#      [400940, 1600.0],
#      [402540, 2000.0],
#      [403740, 2000.0],
#      [404940, 2000.0],
#      [408139, 1200.0],
#      [410139, 1200.0],
#      [412739, 2000.0],
#      [423337, 1600.0]],
#     'spike_planted': [[369144, False]],
#     'assisted_count': [[369144, 0, 3]],
#     'ability_charges_1': [[369144, 0], [399140, 1]],
#     'ability_charges_2': [[369144, 0], [399140, 2]],
#     'ability_charges_3': [[369144, 0],
#      [399140, 1],
#      [403740, 0],
#      [404940, 1],
#      [410139, 0]],
#     'ability_charges_4': [[369144, 0]]},
#    '5': {'alive': {'0': [[438335, True], [481529, False]],
#      '1': [[438335, True], [517324, False]],
#      '2': [[438335, True], [514925, False]],
#      '3': [[438335, True]],
#      '4': [[438335, True]],
#      '5': [[438335, True], [473730, False], [481329, True], [514325, False]],
#      '6': [[438335, True], [514925, False]],
#      '7': [[438335, True], [505326, False]],
#      '8': [[438335, True], [486529, False]],
#      '9': [[438335, True], [501926, False]]},
#     'elims': [[481529,
#       {'source': '5',
#        'target': '0',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': True,
#        'team_credit': 'opponent'}],
#      [486729,
#       {'source': '3',
#        'target': '8',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [502326,
#       {'source': '3',
#        'target': '9',
#        'assisted': ['1', '2'],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [505526,
#       {'source': '4',
#        'target': '7',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [515125,
#       {'source': '5',
#        'target': '2',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [515925,
#       {'source': '1',
#        'target': '6',
#        'assisted': ['2'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [517524,
#       {'source': '5',
#        'target': '1',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 3,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [518724,
#       {'source': '2',
#        'target': '6',
#        'weapon': 'vandal',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally',
#        'weapon_type': 'primary'}],
#      [523923,
#       {'source': '4',
#        'target': '5',
#        'assisted': ['2', '4'],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'ally'}]],
#     'health': {'0': [[438335, 100],
#       [439935, 0],
#       [441135, 93],
#       [441935, 89],
#       [443734, 63],
#       [444934, 100],
#       [447334, 89],
#       [448534, 93],
#       [448934, 89],
#       [449934, 93],
#       [453133, 89],
#       [453733, 93],
#       [454933, 100],
#       [455533, 89],
#       [456333, 96],
#       [456733, 89],
#       [457532, 96],
#       [458332, 89],
#       [458932, 93],
#       [459932, 96],
#       [460932, 93],
#       [461932, 89],
#       [462932, 85],
#       [463532, 93],
#       [463932, 89],
#       [466331, 93],
#       [467931, 96],
#       [468731, 100],
#       [469331, 89],
#       [470331, 85],
#       [470931, 89],
#       [472530, 93],
#       [472930, 89],
#       [473330, 93],
#       [474130, 96],
#       [474930, 93]],
#      '1': [[438335, 100],
#       [439335, 96],
#       [441935, 92],
#       [442934, 100],
#       [443734, 92],
#       [444534, 100],
#       [445934, 73],
#       [448534, 92],
#       [452933, 96],
#       [455533, 88],
#       [456333, 92],
#       [456933, 96],
#       [457532, 92],
#       [458532, 88],
#       [458932, 92],
#       [459532, 96],
#       [460932, 92],
#       [461732, 96],
#       [464931, 92],
#       [466931, 96],
#       [467731, 100],
#       [468331, 96],
#       [468931, 100],
#       [469331, 96],
#       [470531, 88],
#       [470931, 92],
#       [472530, 96],
#       [473130, 92],
#       [474130, 96],
#       [474730, 92],
#       [475930, 96],
#       [476730, 92],
#       [479330, 96],
#       [480929, 88],
#       [482529, 100],
#       [484129, 88],
#       [484529, 92],
#       [485529, 88],
#       [486329, 92],
#       [487928, 88],
#       [488528, 96],
#       [489128, 100],
#       [490528, 96],
#       [491528, 92],
#       [492528, 96],
#       [494128, 92],
#       [495527, 100],
#       [496727, 96],
#       [498727, 92],
#       [499527, 96],
#       [501727, 92],
#       [502526, 96],
#       [503126, 85],
#       [503526, 92],
#       [504126, 88],
#       [504526, 92],
#       [504926, 96],
#       [505526, 92],
#       [507526, 96],
#       [510125, 88],
#       [510925, 77],
#       [512125, 85],
#       [512925, 92],
#       [514925, 86]],
#      '2': [[438335, 100], [514925, 0]],
#      '3': [[438335, 100],
#       [439335, 96],
#       [439935, 0],
#       [441135, 89],
#       [442135, 85],
#       [443734, 81],
#       [446534, 89],
#       [447134, 56],
#       [447534, 0],
#       [448134, 22],
#       [448534, 59],
#       [449934, 89],
#       [452333, 93],
#       [455133, 89],
#       [457932, 85],
#       [458932, 89],
#       [459332, 93],
#       [459732, 96],
#       [460532, 89],
#       [463932, 93],
#       [465731, 85],
#       [466131, 89],
#       [466731, 85],
#       [467931, 93],
#       [468331, 100],
#       [469331, 93],
#       [470731, 85],
#       [472530, 89],
#       [472930, 93],
#       [474930, 89],
#       [475530, 93],
#       [477130, 89],
#       [478730, 93],
#       [479929, 96],
#       [480929, 89],
#       [481529, 85],
#       [482329, 93],
#       [483129, 85],
#       [483729, 89],
# ...
#    '5': {'role': 'opponent', 'character': 'fade'},
#    '6': {'role': 'opponent', 'character': 'harbor'},
#    '7': {'role': 'opponent', 'character': 'yoru'},
#    '8': {'role': 'opponent', 'character': 'killjoy'},
#    '9': {'role': 'opponent', 'character': 'breach'}},
#   'round_info': {'0': {'score': '0-0',
#     'ally_side': 'defender',
#     'buy_start': 0,
#     'round_end': 85377,
#     'round_won': False,
#     'ally_score': 0,
#     'round_start': 44999,
#     'round_scored': 78377,
#     'opponent_score': 0},
#    '1': {'score': '0-1',
#     'ally_side': 'defender',
#     'buy_start': 85377,
#     'round_end': 188404,
#     'round_won': False,
#     'ally_score': 0,
#     'round_start': 115377,
#     'round_scored': 181404,
#     'opponent_score': 1},
#    '2': {'score': '0-2',
#     'ally_side': 'defender',
#     'buy_start': 188404,
#     'round_end': 273564,
#     'round_won': True,
#     'ally_score': 0,
#     'round_start': 218404,
#     'round_scored': 266564,
#     'opponent_score': 2},
#    '3': {'score': '1-2',
#     'ally_side': 'defender',
#     'buy_start': 273564,
#     'round_end': 369140,
#     'round_won': False,
#     'ally_score': 1,
#     'round_start': 303564,
#     'round_scored': 362140,
#     'opponent_score': 2},
#    '4': {'score': '1-3',
#     'ally_side': 'defender',
#     'buy_start': 369140,
#     'round_end': 438321,
#     'round_won': False,
#     'ally_score': 1,
#     'round_start': 399140,
#     'round_scored': 431321,
#     'opponent_score': 3},
#    '5': {'score': '1-4',
#     'ally_side': 'defender',
#     'buy_start': 438321,
#     'round_end': 540082,
#     'round_won': True,
#     'ally_score': 1,
#     'round_start': 468321,
#     'round_scored': 533082,
#     'opponent_score': 4},
#    '6': {'score': '2-4',
#     'ally_side': 'defender',
#     'buy_start': 540082,
#     'round_end': 604531,
#     'round_won': True,
#     'ally_score': 2,
#     'round_start': 570082,
#     'round_scored': 597531,
#     'opponent_score': 4},
#    '7': {'score': '3-4',
#     'ally_side': 'defender',
#     'buy_start': 604531,
#     'round_end': 700106,
#     'round_won': True,
#     'ally_score': 3,
#     'round_start': 634531,
#     'round_scored': 693106,
#     'opponent_score': 4},
#    '8': {'score': '4-4',
#     'ally_side': 'defender',
#     'buy_start': 700106,
#     'round_end': 772468,
#     'round_won': True,
#     'ally_score': 4,
#     'round_start': 730106,
#     'round_scored': 765468,
#     'opponent_score': 4},
#    '9': {'score': '5-4',
#     'ally_side': 'defender',
#     'buy_start': 772468,
#     'round_end': 850283,
#     'round_won': False,
#     'ally_score': 5,
#     'round_start': 802468,
#     'round_scored': 843283,
#     'opponent_score': 4},
#    '10': {'score': '5-5',
#     'ally_side': 'defender',
#     'buy_start': 850283,
#     'round_end': 923064,
#     'round_won': False,
#     'ally_score': 5,
#     'round_start': 880283,
#     'round_scored': 916064,
#     'opponent_score': 5},
#    '11': {'score': '5-6',
#     'ally_side': 'defender',
#     'buy_start': 923064,
#     'round_end': 1015044,
#     'round_won': False,
#     'ally_score': 5,
#     'round_start': 953064,
#     'round_scored': 1008044,
#     'opponent_score': 6},
#    '12': {'score': '5-7',
#     'ally_side': 'attacker',
#     'buy_start': 1015044,
#     'round_end': 1111054,
#     'round_won': True,
#     'ally_score': 5,
#     'round_start': 1060044,
#     'round_scored': 1104054,
#     'opponent_score': 7},
#    '13': {'score': '6-7',
#     'ally_side': 'attacker',
#     'buy_start': 1111054,
#     'round_end': 1192298,
#     'round_won': True,
#     'ally_score': 6,
#     'round_start': 1141054,
#     'round_scored': 1185298,
#     'opponent_score': 7},
#    '14': {'score': '7-7',
#     'ally_side': 'attacker',
#     'buy_start': 1192298,
#     'round_end': 1283681,
#     'round_won': True,
#     'ally_score': 7,
#     'round_start': 1222298,
#     'round_scored': 1276681,
#     'opponent_score': 7},
#    '15': {'score': '8-7',
#     'ally_side': 'attacker',
#     'buy_start': 1283681,
#     'round_end': 1375064,
#     'round_won': True,
#     'ally_score': 8,
#     'round_start': 1313681,
#     'round_scored': 1368064,
#     'opponent_score': 7},
#    '16': {'score': '9-7',
#     'ally_side': 'attacker',
#     'buy_start': 1375064,
#     'round_end': 1439659,
#     'round_won': True,
#     'ally_score': 9,
#     'round_start': 1405064,
#     'round_scored': 1432659,
#     'opponent_score': 7},
#    '17': {'score': '10-7',
#     'ally_side': 'attacker',
#     'buy_start': 1439659,
#     'round_end': 1504595,
#     'round_won': True,
#     'ally_score': 10,
#     'round_start': 1469659,
#     'round_scored': 1497595,
#     'opponent_score': 7},
#    '18': {'score': '11-7',
#     'ally_side': 'attacker',
#     'buy_start': 1504595,
#     'round_end': 1600300,
#     'round_won': True,
#     'ally_score': 11,
#     'round_start': 1534595,
#     'round_scored': 1593300,
#     'opponent_score': 7},
#    '19': {'score': '12-7',
#     'ally_side': 'attacker',
#     'buy_start': 1600300,
#     'round_end': 1669369,
#     'round_won': True,
#     'ally_score': 12,
#     'round_start': 1630300,
#     'round_scored': 1662369,
#     'opponent_score': 7}},
#   'start_time': 6468128,
#   'best_weapon': 'vandal',
#   'round_totals': {'0': {'elims': 0,
#     'deaths': 1,
#     'assists': 0,
#     'healing': 0,
#     'headshots': 0,
#     'shielding': 25,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 10,
#     'was_assisted': 0,
#     'credits_spent': 40,
#     'first_blooded': 0,
#     'seconds_alive': 74,
#     'credits_earned': 80,
#     'hp_damage_taken': 100,
#     'shield_damage_taken': 25},
#    '1': {'elims': 0,
#     'deaths': 1,
#     'assists': 0,
#     'healing': 0,
#     'headshots': 0,
#     'shielding': 0,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 6,
#     'was_assisted': 0,
#     'credits_spent': 0,
#     'first_blooded': 0,
#     'seconds_alive': 96,
#     'credits_earned': 1860,
#     'hp_damage_taken': 100,
#     'shield_damage_taken': 0},
#    '2': {'elims': 1,
#     'deaths': 0,
#     'assists': 2,
#     'healing': 0,
#     'headshots': 1,
#     'shielding': 50,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 0,
#     'was_assisted': 1,
#     'credits_spent': 0,
#     'first_blooded': 0,
#     'seconds_alive': 85,
#     'credits_earned': 2400,
#     'hp_damage_taken': 19,
#     'shield_damage_taken': 39},
#    '3': {'elims': 3,
#     'deaths': 1,
#     'assists': 0,
#     'healing': 0,
#     'headshots': 0,
#     'shielding': 81,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 6,
#     'was_assisted': 2,
#     'credits_spent': 2900,
#     'first_blooded': 0,
#     'seconds_alive': 88,
#     'credits_earned': 0,
#     'hp_damage_taken': 100,
#     'shield_damage_taken': 92},
#    '4': {'elims': 0,
#     'deaths': 1,
#     'assists': 1,
#     'healing': 0,
#     'headshots': 0,
#     'shielding': 25,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 14,
#     'was_assisted': 0,
#     'credits_spent': 2000,
#     'first_blooded': 0,
#     'seconds_alive': 54,
#     'credits_earned': 2300,
#     'hp_damage_taken': 100,
#     'shield_damage_taken': 25},
#    '5': {'elims': 1,
#     'deaths': 1,
#     'assists': 3,
#     'healing': 0,
#     'headshots': 1,
#     'shielding': 92,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 25,
#     'was_assisted': 0,
#     'credits_spent': 1500,
#     'first_blooded': 0,
#     'seconds_alive': 76,
#     'credits_earned': 0,
#     'hp_damage_taken': 100,
#     'shield_damage_taken': 92},
#    '6': {'elims': 0,
#     'deaths': 2,
#     'assists': 4,
#     'healing': 11,
#     'headshots': 0,
#     'shielding': 50,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 6,
#     'was_assisted': 0,
#     'credits_spent': 2050,
#     'first_blooded': 0,
#     'seconds_alive': 57,
#     'credits_earned': 2000,
#     'hp_damage_taken': 111,
#     'shield_damage_taken': 50},
#    '7': {'elims': 3,
#     'deaths': 2,
#     'assists': 0,
#     'healing': 0,
#     'headshots': 2,
#     'shielding': 50,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 18,
#     'was_assisted': 0,
#     'credits_spent': 20,
#     'first_blooded': 0,
#     'seconds_alive': 76,
#     'credits_earned': 1220,
#     'hp_damage_taken': 100,
#     'shield_damage_taken': 50},
#    '8': {'elims': 2,
#     'deaths': 1,
#     'assists': 3,
#     'healing': 19,
#     'headshots': 1,
#     'shielding': 50,
#     'wallbangs': 0,
#     'first_bloods': 1,
#     'seconds_dead': 21,
#     'was_assisted': 1,
#     'credits_spent': 1100,
#     'first_blooded': 0,
#     'seconds_alive': 50,
#     'credits_earned': 0,
#     'hp_damage_taken': 119,
#     'shield_damage_taken': 50},
#    '9': {'elims': 0,
#     'deaths': 2,
#     'assists': 0,
#     'healing': 0,
#     'headshots': 0,
#     'shielding': 50,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 35,
#     'was_assisted': 0,
#     'credits_spent': 1800,
#     'first_blooded': 1,
#     'seconds_alive': 41,
#     'credits_earned': 3400,
#     'hp_damage_taken': 100,
#     'shield_damage_taken': 50},
#    '10': {'elims': 1,
#     'deaths': 1,
#     'assists': 0,
#     'healing': 0,
#     'headshots': 0,
#     'shielding': 50,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 32,
#     'was_assisted': 0,
#     'credits_spent': 3450,
#     'first_blooded': 1,
#     'seconds_alive': 39,
#     'credits_earned': 2100,
#     'hp_damage_taken': 100,
#     'shield_damage_taken': 50},
#    '11': {'elims': 0,
#     'deaths': 1,
#     'assists': 0,
#     'healing': 0,
#     'headshots': 0,
#     'shielding': 50,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 31,
#     'was_assisted': 0,
#     'credits_spent': 2800,
#     'first_blooded': 0,
#     'seconds_alive': 60,
#     'credits_earned': 2400,
#     'hp_damage_taken': 100,
#     'shield_damage_taken': 50},
#    '12': {'elims': 0,
#     'deaths': 1,
#     'assists': 1,
#     'healing': 0,
#     'headshots': 0,
#     'shielding': 25,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 9,
#     'was_assisted': 0,
#     'credits_spent': 760,
#     'first_blooded': 0,
#     'seconds_alive': 86,
#     'credits_earned': 1060,
#     'hp_damage_taken': 100,
#     'shield_damage_taken': 25},
#    '13': {'elims': 2,
#     'deaths': 0,
#     'assists': 0,
#     'healing': 24,
#     'headshots': 0,
#     'shielding': 50,
#     'wallbangs': 0,
#     'first_bloods': 1,
#     'seconds_dead': 0,
#     'was_assisted': 0,
#     'credits_spent': 3200,
#     'first_blooded': 0,
#     'seconds_alive': 81,
#     'credits_earned': 3300,
#     'hp_damage_taken': 24,
#     'shield_damage_taken': 48},
#    '14': {'elims': 0,
#     'deaths': 2,
#     'assists': 0,
#     'healing': 0,
#     'headshots': 0,
#     'shielding': 48,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 51,
#     'was_assisted': 0,
#     'credits_spent': 1550,
#     'first_blooded': 1,
#     'seconds_alive': 39,
#     'credits_earned': 3700,
#     'hp_damage_taken': 100,
#     'shield_damage_taken': 50},
#    '15': {'elims': 0,
#     'deaths': 1,
#     'assists': 1,
#     'healing': 0,
#     'headshots': 0,
#     'shielding': 97,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 11,
#     'was_assisted': 0,
#     'credits_spent': 1050,
#     'first_blooded': 0,
#     'seconds_alive': 79,
#     'credits_earned': 300,
#     'hp_damage_taken': 100,
#     'shield_damage_taken': 97},
#    '16': {'elims': 0,
#     'deaths': 0,
#     'assists': 0,
#     'healing': 0,
#     'headshots': 0,
#     'shielding': 92,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 0,
#     'was_assisted': 0,
#     'credits_spent': 4700,
#     'first_blooded': 0,
#     'seconds_alive': 64,
#     'credits_earned': 3000,
#     'hp_damage_taken': 0,
#     'shield_damage_taken': 42},
#    '17': {'elims': 2,
#     'deaths': 0,
#     'assists': 1,
#     'healing': 21,
#     'headshots': 2,
#     'shielding': 42,
#     'wallbangs': 1,
#     'first_bloods': 1,
#     'seconds_dead': 0,
#     'was_assisted': 2,
#     'credits_spent': 0,
#     'first_blooded': 0,
#     'seconds_alive': 64,
#     'credits_earned': 2900,
#     'hp_damage_taken': 21,
#     'shield_damage_taken': 85},
#    '18': {'elims': 1,
#     'deaths': 1,
#     'assists': 1,
#     'healing': 0,
#     'headshots': 1,
#     'shielding': 43,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 15,
#     'was_assisted': 0,
#     'credits_spent': 5800,
#     'first_blooded': 0,
#     'seconds_alive': 79,
#     'credits_earned': 7700,
#     'hp_damage_taken': 100,
#     'shield_damage_taken': 50},
#    '19': {'elims': 1,
#     'deaths': 1,
#     'assists': 1,
#     'healing': 0,
#     'headshots': 1,
#     'shielding': 50,
#     'wallbangs': 0,
#     'first_bloods': 0,
#     'seconds_dead': 0,
#     'was_assisted': 0,
#     'credits_spent': 1300,
#     'first_blooded': 0,
#     'seconds_alive': 68,
#     'credits_earned': 0,
#     'hp_damage_taken': 100,
#     'shield_damage_taken': 50}},
#   'player_totals': {'seconds_using_melee': 175,
#    'elims_with_type_melee': 1,
#    'seconds_using_ability': 134,
#    'elims_with_type_primary': 9,
#    'elims_with_weapon_melee': 1,
#    'elims_with_weapon_vandal': 5,
#    'elims_with_type_secondary': 1,
#    'elims_with_weapon_classic': 1,
#    'elims_with_weapon_phantom': 3,
#    'elims_with_weapon_spectre': 1,
#    'seconds_holding_primary_none': 495,
#    'seconds_holding_primary_judge': 28,
#    'seconds_holding_primary_vandal': 134,
#    'seconds_holding_secondary_none': 11,
#    'seconds_holding_primary_phantom': 160,
#    'seconds_holding_primary_spectre': 236,
#    'seconds_holding_secondary_ghost': 1,
#    'seconds_holding_secondary_frenzy': 13,
#    'seconds_holding_secondary_shorty': 30,
#    'seconds_holding_secondary_classic': 1359,
#    'seconds_holding_secondary_sheriff': 58},
#   'opponent_score': 7,
#   'best_weapon_type': 'primary',
#   'best_weapon_elims': 5,
#   'most_used_primary': 'spectre',
#   'most_used_secondary': 'sheriff',
#   'best_weapon_type_elims': 9,
#   'most_used_primary_seconds': 236,
#   'most_used_secondary_seconds': 58},
#  'totals': {'elims': 17,
#   'deaths': 20,
#   'assists': 18,
#   'healing': 75,
#   'headshots': 9,
#   'shielding': 1020,
#   'wallbangs': 1,
#   'first_bloods': 3,
#   'seconds_dead': 290,
#   'was_assisted': 6,
#   'credits_spent': 36020,
#   'first_blooded': 3,
#   'seconds_alive': 1356,
#   'credits_earned': 39720,
#   'hp_damage_taken': 1694,
#   'shield_damage_taken': 1020},
#  'ten_minute_averages': {'elims': 6.083113218068278,
#   'deaths': 7.156603785962679,
#   'assists': 6.440943407366412,
#   'healing': 26.83726419736005,
#   'headshots': 3.220471703683206,
#   'shielding': 364.9867930840967,
#   'wallbangs': 0.357830189298134,
#   'first_bloods': 1.073490567894402,
#   'seconds_dead': 103.7707548964589,
#   'was_assisted': 2.146981135788804,
#   'credits_spent': 12889.04341851879,
#   'first_blooded': 1.073490567894402,
#   'seconds_alive': 485.2177366882697,
#   'credits_earned': 14213.01511892188,
#   'hp_damage_taken': 606.164340671039,
#   'shield_damage_taken': 364.9867930840967},
#  'character_id': 40,
#  'user_id': 1018,
#  'match_length': '1676773',
#  'video_id': 945,
#  'card_url': 'https://forge.omnic.ai/player_card/generate/J0PtBFUhyhryIXZGhCBlVime3WDvMg4cKn0BGuEWg53fS59qRYwAkWC56pa+g7ercS9Q+%2FJOY+yETWfkO3IFw9t8HXQoDFM6CBUJEW%2FE86edCz7t09CKHcKMASbwchgqZBbdPjAeu7izsebJhUoU2Bokxh13j5F6TmQjLX+IKzM5pEpmTTkB2Ouo3839SCSDBc9H6FZ5ppFzpmLh5Y3p7BZPj9ZvCq5J4Nn7px7unpeq47D75MFbjYyK6qURyA9Fi%2FYOTmxyze7W8DTlv1erHqIBbDsN2gRRptl2kI2dx8k6h%2FM0ux%2F1a6Q5fbSCio6Qa5OR6cgS9HiZamFO7F9OdkwLOnmEsGCqDt%2Fmrc+3zDp3O6fZi6y5daJ1LC+0ARz4fnvEPcwaiwRhLnHMub+gQrTZBqlem07zO9CrP6zrXBVqbnynWeSIMaDkT7PWdfbgBrfXRAz%2FaOMn1oRJvjTc5TRK9mqBLSrAqsgWCGc%%2FXACbny+7K%2FZpkrKbpyw==',
#  'total_time': 1676773,
#  'totals_to_date': {'elims': 17,
#   'deaths': 20,
#   'assists': 18,
#   'healing': 75,
#   'headshots': 9,
#   'shielding': 1020,
#   'wallbangs': 1,
#   'first_bloods': 3,
#   'seconds_dead': 290,
#   'was_assisted': 6,
#   'credits_spent': 36020,
#   'first_blooded': 3,
#   'seconds_alive': 1356,
#   'credits_earned': 39720,
#   'hp_damage_taken': 1694,
#   'shield_damage_taken': 1020},
#  'start_time': 6464124,
#  'end_time': 8140897,
#  'start_frame': 193950,
#  'end_frame': 244260,
#  'status': 'success: completed - valorant postprocess',
#  'report': {},
#  'analysis_processed': True,
#  'analysis_status': 'completed: processing - anyalysis (insights)'}

# %%
# Observing specifically the stats col
data[0]['statistics']
# Out:
# {'map': 'Pearl',
#  'score': '13-3',
#  'allies': ['0', '1', '2', '3', '4'],
#  'player': '1',
#  'result': 'win',
#  'rounds': {'7': {'alive': {'0': [[0, True], [4800, False]],
#     '1': [[0, True], [53800, False]],
#     '2': [[0, True], [57000, False]],
#     '3': [[0, True], [112400, False]],
#     '4': [[0, True], [112400, False], [124400, True]],
#     '5': [[0, True], [41600, False], [48600, True], [53800, False]],
#     '6': [[0, True], [112400, False]],
#     '7': [[0, True], [57600, False]],
#     '8': [[0, True], [112400, False]],
#     '9': [[0, True], [42400, False]]},
#    'elims': [[42400,
#      {'source': '4',
#       'target': '9',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'ally'}],
#     [54000,
#      {'source': '6',
#       'target': '1',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [57600,
#      {'source': '3',
#       'target': '7',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}]],
#    'health': {'0': [[0, 100], [29600, 0]],
#     '1': [[0, 100], [53800, 0]],
#     '2': [[0, 100],
#      [6200, 96],
#      [6600, 100],
#      [21000, 92],
#      [21800, 100],
#      [24200, 96],
#      [24800, 100],
#      [38200, 96],
#      [39800, 100],
#      [52600, 62],
#      [53200, 58]],
#     '3': [[0, 100],
#      [1000, 96],
#      [21000, 89],
#      [21800, 96],
#      [44200, 89],
#      [44600, 96],
#      [57400, 93],
#      [58000, 89],
#      [59000, 93],
#      [59800, 89],
#      [61600, 96],
#      [62200, 89],
#      [62800, 93],
#      [64000, 96],
#      [66000, 85],
#      [67000, 93],
#      [76000, 96],
#      [76800, 93],
#      [77200, 100],
#      [77800, 93],
#      [80600, 89],
#      [82000, 93]],
#     '4': [[0, 100],
#      [1000, 96],
#      [21000, 93],
#      [21400, 96],
#      [36200, 93],
#      [36600, 96],
#      [37600, 93],
#      [38000, 96],
#      [47400, 100],
#      [47800, 96],
#      [59400, 85],
#      [60000, 96],
#      [61400, 89],
#      [62000, 93],
#      [63000, 96],
#      [64000, 93],
#      [64400, 96],
#      [67000, 93],
#      [67400, 96],
#      [69400, 93],
#      [69800, 96],
#      [76400, 93],
#      [77000, 96],
#      [82800, 100],
#      [83200, 96]]},
#    'phases': [[-25276, 'buy_start'],
#     [4723, 'round_start'],
#     [117802, 'round_scored'],
#     [124802, 'round_end']],
#    'shield': [[0, 0], [1000, 24], [53800, 0]],
#    'credits': [[0, 4800], [112600, 40], [124400, 5100]],
#    'ammo_mag': [[5400, 25], [53600, 23]],
#    'inv_state': [[1000, 'melee'], [23600, 'primary']],
#    'ult_state': {'0': [[0, False]],
#     '1': [[0, False]],
#     '2': [[0, False]],
#     '3': [[0, False]],
#     '4': [[0, True], [47000, False]],
#     '5': [[0, False]],
#     '6': [[0, False]],
#     '7': [[0, True], [5800, False]],
#     '8': [[0, True], [57000, False]],
#     '9': [[0, True]]},
#    'map_region': [[1000, 'Attacker Side Spawn'],
#     [25200, 'Mid Top'],
#     [35800, 'A Art']],
#    'elims_count': [[0, 0, 0]],
#    'inv_primary': [[0, 'none'], [1000, 'vandal'], [52000, 'spectre']],
#    'ammo_reserve': [[5400, 75]],
#    'firing_state': [[0, False], [53600, True], [55800, False]],
#    'assists_count': [[0, 0, 0]],
#    'inv_secondary': [[0, 'classic']],
#    'loadout_value': [[0, 0],
#     [1000, 3284.0],
#     [4800, 3434.0],
#     [44200, 3434.0],
#     [45400, 3284.0],
#     [52000, 1984.0],
#     [53800, 1600.0]],
#    'spike_planted': [[0, False]],
#    'assisted_count': [[0, 0, 0]],
#    'ability_charges_1': [[0, 0]],
#    'ability_charges_2': [[0, 0], [4800, 1], [45400, 0]],
#    'ability_charges_3': [[0, 0], [4800, 1], [44200, 0]],
#    'ability_charges_4': [[0, 0]]},
#   '8': {'alive': {'0': [[125000, True], [162000, False]],
#     '1': [[125000, True]],
#     '2': [[125000, True]],
#     '3': [[125000, True], [197400, False]],
#     '4': [[125000, True], [162000, False]],
#     '5': [[125000, True], [161000, False], [164000, True], [165800, False]],
#     '6': [[125000, True], [198000, False]],
#     '7': [[125000, True], [176600, False]],
#     '8': [[125000, True], [170400, False]],
#     '9': [[125000, True], [159800, False]]},
#    'elims': [[160000,
#      {'source': '4',
#       'target': '9',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'ally'}],
#     [162000,
#      {'source': '8',
#       'target': '4',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [164800,
#      {'source': '2',
#       'target': '9',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [176800,
#      {'source': '1',
#       'target': '7',
#       'weapon': 'vandal',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally',
#       'weapon_type': 'primary'}],
#     [197600,
#      {'source': '6',
#       'target': '3',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [198000,
#      {'source': '1',
#       'target': '6',
#       'weapon': 'vandal',
#       'assisted': ['3'],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'ally',
#       'weapon_type': 'primary'}]],
#    'health': {'0': [[125000, 100],
#      [126000, 0],
#      [130199, 11],
#      [130600, 30],
#      [131200, 11],
#      [134800, 0],
#      [135600, 30],
#      [136000, 19],
#      [137200, 0],
#      [138400, 4],
#      [139400, 19],
#      [140400, 22],
#      [141600, 0],
#      [170600, 22],
#      [171600, 19],
#      [176000, 22]],
#     '1': [[125000, 100]],
#     '2': [[125000, 100],
#      [128000, 0],
#      [130199, 100],
#      [131400, 96],
#      [132000, 100],
#      [157200, 96],
#      [159400, 100],
#      [162000, 93],
#      [163400, 96],
#      [170400, 93],
#      [170800, 96],
#      [197000, 89],
#      [197400, 93],
#      [198000, 96],
#      [200600, 93],
#      [201800, 96]],
#     '3': [[125000, 100],
#      [126000, 96],
#      [127800, 0],
#      [130199, 96],
#      [131400, 93],
#      [132000, 96],
#      [156400, 93],
#      [156800, 96],
#      [160000, 89],
#      [160400, 96],
#      [162800, 93],
#      [163200, 96],
#      [177000, 93],
#      [177400, 96],
#      [197000, 33]],
#     '4': [[125000, 100],
#      [126000, 96],
#      [131400, 93],
#      [132000, 96],
#      [157000, 93],
#      [157800, 96],
#      [160600, 93],
#      [161000, 96]]},
#    'phases': [[124802, 'buy_start'],
#     [154802, 'round_start'],
#     [197402, 'round_scored'],
#     [204402, 'round_end']],
#    'shield': [[125000, 0], [129800, 50]],
#    'credits': [[125000, 5100], [125600, 8100], [130199, 3350], [193800, 3650]],
#    'ammo_mag': [[126000, 12],
#     [128400, 25],
#     [175400, 24],
#     [175600, 22],
#     [175800, 20],
#     [176000, 18],
#     [176200, 17],
#     [176600, 15],
#     [176800, 14],
#     [180400, 25],
#     [194200, 23],
#     [194400, 21],
#     [194600, 20],
#     [198000, 18],
#     [198200, 17]],
#    'inv_state': [[126000, 'secondary'],
#     [130400, 'melee'],
#     [156200, 'primary'],
#     [158800, 'melee'],
#     [160600, 'primary'],
#     [195800, 'melee'],
#     [196800, 'primary'],
#     [198400, 'melee']],
#    'ult_state': {'0': [[125000, False], [130199, True]],
#     '1': [[125000, False], [198000, True]],
#     '2': [[125000, False]],
#     '3': [[125000, False], [129600, True]],
#     '4': [[125000, False]],
#     '5': [[125000, False]],
#     '6': [[125000, False], [197400, True]],
#     '7': [[125000, False]],
#     '8': [[125000, False]],
#     '9': [[125000, False], [125400, True]]},
#    'map_region': [[130199, 'Attacker Side Spawn'],
#     [131400, 'Mid Shops'],
#     [134800, 'B Club'],
#     [190800, 'B Link']],
#    'elims_count': [[125200, 0, 0], [176800, 1, 1], [198000, 2, 2]],
#    'inv_primary': [[125000, 'none'],
#     [130800, 'vandal'],
#     [154000, 'spectre'],
#     [155200, 'vandal'],
#     [163200, 'spectre'],
#     [164400, 'vandal'],
#     [168200, 'spectre'],
#     [170600, 'vandal'],
#     [182000, 'spectre'],
#     [184200, 'vandal'],
#     [203400, 'spectre']],
#    'ammo_reserve': [[126000, 36], [128600, 75], [180400, 64]],
#    'firing_state': [[125000, False],
#     [175400, True],
#     [179000, False],
#     [194200, True],
#     [196800, False],
#     [198000, True],
#     [200400, False]],
#    'assists_count': [[125200, 0, 0]],
#    'inv_secondary': [[125000, 'classic'],
#     [142800, 'ghost'],
#     [155800, 'classic'],
#     [158800, 'ghost'],
#     [160600, 'classic'],
#     [202200, 'ghost']],
#    'loadout_value': [[125000, 0],
#     [129800, 1000.0],
#     [130800, 3900.0],
#     [142800, 4400.0],
#     [154000, 3100.0],
#     [155000, 3800.0],
#     [155200, 5100.0],
#     [155800, 4600.0],
#     [158800, 5100.0],
#     [160600, 4600.0],
#     [163200, 3300.0],
#     [164400, 4600.0],
#     [168200, 3300.0],
#     [170600, 4600.0],
#     [181200, 4400.0],
#     [182000, 3100.0],
#     [182400, 3100.0],
#     [184200, 4400.0],
#     [198000, 4400.0],
#     [202200, 4900.0],
#     [203400, 3600.0]],
#    'spike_planted': [[125000, False]],
#    'assisted_count': [[125200, 0, 0], [198000, 1, 1]],
#    'ability_charges_1': [[125000, 0], [155000, 2], [181200, 1]],
#    'ability_charges_2': [[125000, 0], [155000, 2]],
#    'ability_charges_3': [[125000, 0], [155000, 1], [182400, 0]],
#    'ability_charges_4': [[125000, 0], [198000, 1]]},
#   '9': {'alive': {'0': [[204600, True], [254600, False]],
#     '1': [[204600, True]],
#     '2': [[204600, True]],
#     '3': [[204600, True], [286200, False]],
#     '4': [[204600, True], [295400, False]],
#     '5': [[204600, True], [235200, False]],
#     '6': [[204600, True], [261800, False]],
#     '7': [[204600, True], [294400, False]],
#     '8': [[204600, True], [297600, False]],
#     '9': [[204600, True], [251400, False]]},
#    'elims': [[262000,
#      {'source': '1',
#       'target': '6',
#       'weapon': 'vandal',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'ally',
#       'weapon_type': 'primary'}],
#     [286400,
#      {'source': '8',
#       'target': '3',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [294800,
#      {'source': '4',
#       'target': '7',
#       'assisted': ['1'],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [295600,
#      {'source': '8',
#       'target': '4',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [297600,
#      {'source': '1',
#       'target': '8',
#       'weapon': 'vandal',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'ally',
#       'weapon_type': 'primary'}],
#     [301600,
#      {'source': '8',
#       'target': '4',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 3,
#       'first_blood': False,
#       'team_credit': 'opponent'}]],
#    'health': {'0': [[204600, 100],
#      [205600, 0],
#      [216600, 7],
#      [217600, 4],
#      [218400, 0],
#      [231800, 7],
#      [232200, 30],
#      [234000, 0]],
#     '1': [[204600, 100]],
#     '2': [[204600, 100],
#      [239200, 96],
#      [240400, 100],
#      [262400, 96],
#      [263000, 100],
#      [263400, 96],
#      [264000, 100],
#      [274600, 96],
#      [275600, 100],
#      [286200, 96],
#      [291600, 89],
#      [292200, 96],
#      [293200, 70],
#      [294000, 78],
#      [294600, 81],
#      [295000, 85],
#      [297800, 96]],
#     '3': [[204600, 100],
#      [205600, 96],
#      [216000, 0],
#      [216600, 96],
#      [228400, 0],
#      [229000, 96],
#      [264000, 93],
#      [264400, 96]],
#     '4': [[204600, 100],
#      [205600, 96],
#      [213600, 93],
#      [214400, 96],
#      [234600, 100],
#      [235600, 96],
#      [246600, 93],
#      [247000, 96],
#      [272400, 85],
#      [272800, 96],
#      [274400, 93],
#      [275200, 96],
#      [290800, 93],
#      [292000, 96],
#      [293200, 93],
#      [294000, 96]]},
#    'phases': [[204402, 'buy_start'],
#     [234402, 'round_start'],
#     [297570, 'round_scored'],
#     [304570, 'round_end']],
#    'shield': [[204600, 50]],
#    'credits': [[204600, 3650], [205200, 7250], [216000, 7050], [278800, 7350]],
#    'ammo_mag': [[205400, 25],
#     [261800, 23],
#     [271200, 21],
#     [271400, 20],
#     [281600, 18],
#     [282000, 17],
#     [297400, 15],
#     [297600, 13],
#     [297800, 12]],
#    'inv_state': [[205600, 'primary'],
#     [213400, 'melee'],
#     [236000, 'primary'],
#     [237600, 'melee'],
#     [239000, 'primary'],
#     [274800, 'melee'],
#     [277800, 'primary'],
#     [289000, 'melee'],
#     [293400, 'primary'],
#     [294200, 'melee'],
#     [295600, 'primary'],
#     [298000, 'melee']],
#    'ult_state': {'0': [[204600, False], [205000, True]],
#     '1': [[204600, True]],
#     '2': [[204600, False], [278800, True], [303400, False]],
#     '3': [[204600, False], [205000, True], [267600, False]],
#     '4': [[204600, False]],
#     '5': [[204600, False], [210000, True]],
#     '6': [[204600, False], [205000, True]],
#     '7': [[204600, False]],
#     '8': [[204600, False]],
#     '9': [[204600, False], [205000, True]]},
#    'map_region': [[215000, 'Attacker Side Spawn'],
#     [217600, 'B Club'],
#     [293800, 'B Tunnel']],
#    'elims_count': [[204800, 0, 2], [262000, 1, 3], [297600, 2, 4]],
#    'inv_primary': [[204600, 'spectre'],
#     [205600, 'vandal'],
#     [218400, 'spectre'],
#     [219600, 'vandal'],
#     [227200, 'spectre'],
#     [230000, 'vandal'],
#     [240600, 'spectre'],
#     [245200, 'vandal'],
#     [251200, 'spectre'],
#     [253200, 'vandal'],
#     [256000, 'spectre'],
#     [257600, 'vandal'],
#     [278800, 'spectre'],
#     [282200, 'vandal'],
#     [283800, 'spectre'],
#     [284800, 'vandal']],
#    'ammo_reserve': [[205400, 75]],
#    'firing_state': [[204600, False],
#     [261800, True],
#     [264000, False],
#     [271200, True],
#     [273600, False],
#     [281600, True],
#     [284200, False],
#     [297400, True],
#     [300000, False]],
#    'assists_count': [[204800, 0, 0], [294800, 1, 1]],
#    'inv_secondary': [[204600, 'ghost'],
#     [205600, 'classic'],
#     [217400, 'ghost'],
#     [219600, 'classic'],
#     [223000, 'ghost'],
#     [229600, 'classic'],
#     [233800, 'ghost'],
#     [235600, 'classic'],
#     [276400, 'ghost'],
#     [277800, 'classic'],
#     [289600, 'ghost'],
#     [293400, 'classic'],
#     [298000, 'ghost'],
#     [300200, 'classic']],
#    'loadout_value': [[204600, 3600.0],
#     [205600, 4400.0],
#     [217400, 4900.0],
#     [218400, 3600.0],
#     [219600, 4400.0],
#     [223000, 4900.0],
#     [227200, 3600.0],
#     [229600, 3100.0],
#     [230000, 4400.0],
#     [233800, 4900.0],
#     [234600, 5100.0],
#     [235600, 4600.0],
#     [237200, 4400.0],
#     [240600, 3100.0],
#     [245200, 4400.0],
#     [251200, 3100.0],
#     [253200, 4400.0],
#     [256000, 3100.0],
#     [257600, 4400.0],
#     [262200, 4400.0],
#     [272000, 4250.0],
#     [276400, 4750.0],
#     [277800, 4250.0],
#     [278800, 2950.0],
#     [282200, 4250.0],
#     [283800, 2950.0],
#     [284800, 4250.0],
#     [289600, 4750.0],
#     [293400, 4250.0],
#     [298000, 4750.0],
#     [300200, 4250.0]],
#    'spike_planted': [[204600, False], [278800, True], [297600, False]],
#    'assisted_count': [[204800, 0, 1]],
#    'ability_charges_1': [[204600, 1], [234600, 2], [237200, 1]],
#    'ability_charges_2': [[204600, 2], [272000, 1]],
#    'ability_charges_3': [[204600, 0], [234600, 1], [262200, 0]],
#    'ability_charges_4': [[204600, 1]]},
#   '10': {'alive': {'0': [[304600, True],
#      [344800, False],
#      [351600, True],
#      [359600, False]],
#     '1': [[304600, True]],
#     '2': [[304600, True]],
#     '3': [[304600, True], [347600, False]],
#     '4': [[304600, True], [359600, False]],
#     '5': [[304600, True], [339200, False], [348400, True], [360800, False]],
#     '6': [[304600, True], [346400, False]],
#     '7': [[304600, True], [348400, False]],
#     '8': [[304600, True], [341400, False]],
#     '9': [[304600, True], [339200, False]]},
#    'elims': [[339200,
#      {'source': '1',
#       'target': '9',
#       'weapon': 'vandal',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'ally',
#       'weapon_type': 'primary'}],
#     [341600,
#      {'source': '1',
#       'target': '8',
#       'weapon': 'vandal',
#       'assisted': ['3'],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'ally',
#       'weapon_type': 'primary'}],
#     [346400,
#      {'source': '3',
#       'target': '6',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [347600,
#      {'source': '7',
#       'target': '3',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [348400,
#      {'source': '1',
#       'target': '7',
#       'weapon': 'vandal',
#       'assisted': ['3'],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 3,
#       'first_blood': False,
#       'team_credit': 'ally',
#       'weapon_type': 'primary'}]],
#    'health': {'0': [[304600, 100],
#      [314000, 22],
#      [314600, 30],
#      [320000, 22],
#      [320400, 26],
#      [322400, 19],
#      [324200, 0],
#      [326000, 4],
#      [326600, 7],
#      [328600, 4],
#      [329400, 0],
#      [347600, 15],
#      [353800, 22],
#      [357000, 41],
#      [357600, 22]],
#     '1': [[304600, 100], [346400, 77]],
#     '2': [[304600, 100],
#      [305600, 96],
#      [314000, 100],
#      [332200, 96],
#      [332600, 100],
#      [333000, 96],
#      [333600, 100],
#      [347600, 96],
#      [348000, 93],
#      [348400, 96],
#      [349400, 93],
#      [349800, 96],
#      [361200, 93],
#      [361600, 96],
#      [362400, 93],
#      [362800, 96]],
#     '3': [[304600, 100],
#      [314000, 96],
#      [316000, 93],
#      [316400, 96],
#      [330000, 0],
#      [330800, 96],
#      [342200, 93],
#      [342800, 96],
#      [346400, 85],
#      [347200, 89]],
#     '4': [[304600, 100],
#      [314000, 96],
#      [341400, 93],
#      [342200, 96],
#      [347800, 93],
#      [349000, 96]]},
#    'phases': [[304570, 'buy_start'],
#     [334570, 'round_start'],
#     [362242, 'round_scored'],
#     [369242, 'round_end']],
#    'shield': [[304600, 50], [346600, 4]],
#    'credits': [[304600, 7350], [314000, 9000], [330400, 8650]],
#    'ammo_mag': [[314000, 25],
#     [331400, 2],
#     [336200, 25],
#     [339200, 23],
#     [341200, 22],
#     [341400, 20],
#     [348200, 18],
#     [348400, 16],
#     [349000, 15],
#     [362800, 2]],
#    'inv_state': [[305600, 'melee'],
#     [314000, 'primary'],
#     [328800, 'melee'],
#     [336200, 'primary'],
#     [342000, 'melee'],
#     [346800, 'primary'],
#     [352800, 'melee'],
#     [360000, 'primary'],
#     [363200, 'melee']],
#    'ult_state': {'0': [[304600, False], [314000, True]],
#     '1': [[304600, True]],
#     '2': [[304600, False], [304800, True]],
#     '3': [[304600, False]],
#     '4': [[304600, False], [314000, True]],
#     '5': [[304600, False]],
#     '6': [[304600, False], [314000, True]],
#     '7': [[304600, False]],
#     '8': [[304600, False], [314000, True]],
#     '9': [[304600, False], [314000, True]]},
#    'map_region': [[361200, 'B Hall'], [369000, 'A Link']],
#    'elims_count': [[304800, 0, 4],
#     [339200, 1, 5],
#     [341600, 2, 6],
#     [348400, 3, 7]],
#    'inv_primary': [[304600, 'vandal']],
#    'ammo_reserve': [[314000, 75], [362800, 10]],
#    'firing_state': [[304600, False],
#     [339200, True],
#     [343600, False],
#     [348200, True],
#     [351200, False]],
#    'assists_count': [[304800, 0, 1]],
#    'inv_secondary': [[304600, 'classic'],
#     [333800, 'ghost'],
#     [335000, 'classic'],
#     [343400, 'ghost'],
#     [344600, 'classic']],
#    'loadout_value': [[304600, 4250.0],
#     [333800, 4750.0],
#     [334600, 5100.0],
#     [335000, 4600.0],
#     [337000, 4600.0],
#     [343400, 5100.0],
#     [344600, 4600.0],
#     [346600, 3664.0],
#     [351000, 3464.0]],
#    'spike_planted': [[304600, False]],
#    'assisted_count': [[304800, 0, 1], [341600, 1, 2], [348400, 2, 3]],
#    'ability_charges_1': [[304600, 1], [334600, 2], [351000, 1]],
#    'ability_charges_2': [[304600, 1], [334600, 2]],
#    'ability_charges_3': [[304600, 0], [334600, 1], [337000, 0]],
#    'ability_charges_4': [[304600, 1]]},
#   '11': {'alive': {'0': [[369400, True],
#      [411600, False],
#      [414800, True],
#      [420200, False]],
#     '1': [[369400, True]],
#     '2': [[369400, True], [429400, False]],
#     '3': [[369400, True], [423800, False]],
#     '4': [[369400, True]],
#     '5': [[369400, True],
#      [401000, False],
#      [407000, True],
#      [424000, False],
#      [430600, True],
#      [442600, False]],
#     '6': [[369400, True], [427400, False]],
#     '7': [[369400, True], [421000, False]],
#     '8': [[369400, True], [427400, False]],
#     '9': [[369400, True], [430600, False]]},
#    'elims': [[421200,
#      {'source': '4',
#       'target': '7',
#       'assisted': ['3'],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'ally'}],
#     [424000,
#      {'source': '6',
#       'target': '3',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [427600,
#      {'source': '1',
#       'target': '6',
#       'weapon': 'operator',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally',
#       'weapon_type': 'primary'}],
#     [427600,
#      {'source': '4',
#       'target': '8',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': True,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [430800,
#      {'source': '4',
#       'target': '9',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 3,
#       'first_blood': False,
#       'team_credit': 'ally'}]],
#    'health': {'0': [[369400, 100],
#      [372400, 0],
#      [390000, 4],
#      [390400, 22],
#      [391400, 0]],
#     '1': [[369400, 100], [370400, 77], [372400, 100]],
#     '2': [[369400, 100],
#      [370400, 96],
#      [373400, 100],
#      [376400, 96],
#      [376800, 100],
#      [411000, 88],
#      [411400, 100],
#      [423800, 96],
#      [428600, 93],
#      [429000, 96]],
#     '3': [[369400, 100],
#      [372600, 0],
#      [373400, 96],
#      [396800, 0],
#      [397200, 96],
#      [407400, 93],
#      [407800, 96]],
#     '4': [[369400, 100],
#      [373400, 96],
#      [376200, 93],
#      [376800, 96],
#      [398200, 100],
#      [398800, 96],
#      [401600, 93],
#      [402000, 96],
#      [403200, 93],
#      [403600, 96],
#      [408400, 93],
#      [408800, 96],
#      [413400, 93],
#      [414000, 96],
#      [418400, 100],
#      [419200, 96],
#      [420800, 74],
#      [437600, 78],
#      [439800, 74],
#      [443400, 81],
#      [444000, 74]]},
#    'phases': [[369242, 'buy_start'],
#     [399242, 'round_start'],
#     [441998, 'round_scored'],
#     [448998, 'round_end']],
#    'shield': [[369400, 4], [373000, 50]],
#    'credits': [[369400, 8650],
#     [373200, 7800],
#     [397000, 3100],
#     [447400, 100],
#     [448000, 3400]],
#    'ammo_mag': [[372600, 25],
#     [373600, 2],
#     [397200, 5],
#     [421200, 55],
#     [422200, 5],
#     [437600, 4],
#     [442400, 3]],
#    'inv_state': [[370400, 'melee'],
#     [401200, 'primary'],
#     [428000, 'melee'],
#     [436000, 'primary'],
#     [442600, 'melee']],
#    'ult_state': {'0': [[369400, False], [372400, True]],
#     '1': [[369400, True]],
#     '2': [[369400, True], [416400, False]],
#     '3': [[369400, False]],
#     '4': [[369400, False], [372400, True], [408000, False]],
#     '5': [[369400, False]],
#     '6': [[369400, False], [372400, True]],
#     '7': [[369400, False]],
#     '8': [[369400, False], [372400, True]],
#     '9': [[369400, False], [372400, True], [429000, False]]},
#    'map_region': [[371200, 'B Link'], [380000, 'B Club'], [440200, 'B Tower']],
#    'elims_count': [[369600, 0, 7], [427600, 1, 8]],
#    'inv_primary': [[369400, 'vandal'], [400000, 'operator']],
#    'ammo_reserve': [[401200, 10]],
#    'firing_state': [[369400, False],
#     [437600, True],
#     [439800, False],
#     [442400, True],
#     [444600, False]],
#    'assists_count': [[369600, 0, 1]],
#    'inv_secondary': [[369400, 'classic'],
#     [394000, 'ghost'],
#     [400000, 'classic'],
#     [433600, 'ghost'],
#     [436200, 'classic'],
#     [438000, 'shorty'],
#     [440800, 'classic']],
#    'loadout_value': [[369400, 3464.0],
#     [373000, 4400.0],
#     [394000, 4900.0],
#     [399400, 5100.0],
#     [400000, 6400.0],
#     [424800, 6400.0],
#     [431200, 6250.0],
#     [433600, 6750.0],
#     [436200, 6250.0],
#     [438000, 6400.0],
#     [440800, 6250.0]],
#    'spike_planted': [[369400, False]],
#    'assisted_count': [[369600, 0, 3]],
#    'ability_charges_1': [[369400, 1], [399400, 2]],
#    'ability_charges_2': [[369400, 2], [431200, 1]],
#    'ability_charges_3': [[369400, 0], [399400, 1], [424800, 0]],
#    'ability_charges_4': [[369400, 1]]},
#   '12': {'alive': {'0': [[449000, True], [494000, False]],
#     '1': [[449000, True], [512799, False]],
#     '2': [[449000, True]],
#     '3': [[449000, True]],
#     '4': [[449000, True]],
#     '5': [[449000, True], [519200, False], [525600, True], [535600, False]],
#     '6': [[449000, True], [536800, False]],
#     '7': [[449000, True], [535600, False]],
#     '8': [[449000, True], [546400, False]],
#     '9': [[449000, True], [543000, False]]},
#    'elims': [[512799,
#      {'source': '7',
#       'target': '1',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': True,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'opponent'}],
#     [536000,
#      {'source': '4',
#       'target': '7',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [537200,
#      {'source': '2',
#       'target': '6',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [543200,
#      {'source': '3',
#       'target': '9',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [546400,
#      {'source': '3',
#       'target': '8',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [552400,
#      {'source': '3',
#       'target': '8',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 3,
#       'first_blood': False,
#       'team_credit': 'ally'}]],
#    'health': {'0': [[449000, 100]],
#     '1': [[449000, 100], [502000, 50], [512400, 18], [512799, 0]],
#     '2': [[449000, 100],
#      [471400, 92],
#      [471800, 100],
#      [472400, 96],
#      [472800, 100],
#      [512000, 96],
#      [512799, 100],
#      [514400, 96],
#      [514799, 100],
#      [520000, 96],
#      [521400, 100],
#      [533600, 96],
#      [534000, 100],
#      [539600, 96],
#      [540000, 100],
#      [543200, 96],
#      [544000, 100],
#      [550200, 96],
#      [550600, 100]],
#     '3': [[449000, 100],
#      [450000, 96],
#      [472200, 93],
#      [472600, 96],
#      [508200, 93],
#      [509000, 96],
#      [512400, 93],
#      [512799, 96],
#      [513200, 93],
#      [513600, 96],
#      [519400, 93],
#      [520400, 96],
#      [539600, 89],
#      [541000, 96],
#      [542000, 56],
#      [544800, 22],
#      [545600, 30],
#      [546200, 19],
#      [546800, 22],
#      [549600, 26],
#      [551200, 33],
#      [552800, 30],
#      [554000, 33],
#      [554400, 22],
#      [555000, 30],
#      [556800, 15],
#      [558000, 30],
#      [558400, 15],
#      [558800, 19],
#      [560000, 30],
#      [561200, 22]],
#     '4': [[449000, 100],
#      [450000, 96],
#      [513000, 93],
#      [513799, 96],
#      [519600, 93],
#      [520000, 96],
#      [520600, 93],
#      [521200, 96],
#      [529400, 93],
#      [529800, 96],
#      [540600, 93],
#      [541000, 96],
#      [550000, 93],
#      [551200, 96]]},
#    'phases': [[448998, 'buy_start'],
#     [493998, 'round_start'],
#     [554796, 'round_scored'],
#     [561796, 'round_end']],
#    'shield': [[449000, 0]],
#    'credits': [[449000, 3400], [450000, 800], [452000, 0]],
#    'ammo_mag': [[450200, 12],
#     [452600, 6],
#     [476000, 9],
#     [476400, 6],
#     [498800, 5],
#     [499400, 4],
#     [501800, 3],
#     [503600, 33],
#     [503800, 3],
#     [506200, 6],
#     [510200, 50],
#     [510400, 6]],
#    'inv_state': [[452000, 'secondary'],
#     [453400, 'melee'],
#     [474400, 'secondary']],
#    'ult_state': {'0': [[449000, False], [539200, True]],
#     '1': [[449000, False]],
#     '2': [[449000, False]],
#     '3': [[449000, False]],
#     '4': [[449000, False]],
#     '5': [[449000, False]],
#     '6': [[449000, False]],
#     '7': [[449000, False]],
#     '8': [[449000, False]],
#     '9': [[449000, False]]},
#    'map_region': [[452000, 'Defender Side Spawn'],
#     [458200, 'B Tunnel'],
#     [475400, 'B Hall']],
#    'elims_count': [[449200, 0, 8]],
#    'inv_primary': [[449000, 'none']],
#    'ammo_reserve': [[450200, 36], [452000, 24], [504800, 21]],
#    'firing_state': [[449000, False],
#     [476400, True],
#     [478600, False],
#     [498800, True],
#     [501600, False],
#     [501800, True],
#     [504000, False]],
#    'assists_count': [[449200, 0, 1]],
#    'inv_secondary': [[449000, 'classic'], [452000, 'sheriff']],
#    'loadout_value': [[449000, 0],
#     [452000, 800.0],
#     [494000, 800.0],
#     [500800, 800.0]],
#    'spike_planted': [[449000, False], [530000, True], [556000, False]],
#    'assisted_count': [[449200, 0, 3]],
#    'ability_charges_1': [[449000, 0]],
#    'ability_charges_2': [[449000, 0]],
#    'ability_charges_3': [[449000, 0], [494000, 1], [500800, 0]],
#    'ability_charges_4': [[449000, 0]]},
#   '13': {'alive': {'0': [[561800, True], [591800, False]],
#     '1': [[561800, True]],
#     '2': [[561800, True]],
#     '3': [[561800, True], [609800, False]],
#     '4': [[561800, True]],
#     '5': [[561800, True], [603200, False]],
#     '6': [[561800, True], [611400, False]],
#     '7': [[561800, True], [603200, False]],
#     '8': [[561800, True], [616200, False]],
#     '9': [[561800, True], [608800, False]]},
#    'elims': [[609200,
#      {'source': '4',
#       'target': '9',
#       'assisted': ['3'],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'ally'}],
#     [610000,
#      {'source': '8',
#       'target': '3',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [611600,
#      {'source': '4',
#       'target': '6',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'ally'}]],
#    'health': {'0': [[561800, 100], [563800, 0]],
#     '1': [[561800, 100]],
#     '2': [[561800, 100],
#      [565800, 96],
#      [566800, 100],
#      [567200, 96],
#      [570000, 100],
#      [579600, 92],
#      [580000, 100],
#      [597000, 96],
#      [597600, 100],
#      [598800, 96],
#      [599400, 100],
#      [609800, 96],
#      [617600, 93],
#      [618400, 96]],
#     '3': [[561800, 100],
#      [562800, 0],
#      [566000, 93],
#      [566800, 96],
#      [567200, 93],
#      [568000, 89],
#      [569200, 93],
#      [569800, 96],
#      [576200, 100],
#      [577000, 96],
#      [579600, 93],
#      [580400, 0],
#      [581200, 96],
#      [582600, 93],
#      [583000, 96]],
#     '4': [[561800, 100],
#      [566000, 96],
#      [568600, 89],
#      [570000, 96],
#      [572200, 89],
#      [572600, 96],
#      [575400, 93],
#      [575800, 96],
#      [583000, 93],
#      [583400, 96],
#      [588600, 93],
#      [589000, 96],
#      [601800, 93],
#      [602200, 96],
#      [606200, 93],
#      [606800, 96],
#      [614600, 81],
#      [619600, 78],
#      [620000, 81],
#      [621600, 78]]},
#    'phases': [[561796, 'buy_start'],
#     [591796, 'round_start'],
#     [615600, 'round_scored'],
#     [622600, 'round_end']],
#    'shield': [[561800, 0], [563600, 25]],
#    'credits': [[561800, 0], [563800, 2400], [565000, 150], [581200, 0]],
#    'ammo_mag': [[565000, 12],
#     [614000, 11],
#     [614200, 10],
#     [614400, 9],
#     [616400, 8],
#     [616600, 7]],
#    'inv_state': [[566000, 'melee'],
#     [582400, 'primary'],
#     [597000, 'melee'],
#     [612000, 'primary'],
#     [618400, 'melee']],
#    'ult_state': {'0': [[561800, False]],
#     '1': [[561800, False]],
#     '2': [[561800, False]],
#     '3': [[561800, False]],
#     '4': [[561800, False]],
#     '5': [[561800, False]],
#     '6': [[561800, False]],
#     '7': [[561800, False]],
#     '8': [[561800, False]],
#     '9': [[561800, False]]},
#    'map_region': [[569800, 'B Tunnel'],
#     [587400, 'B Screen'],
#     [601000, 'B Tunnel'],
#     [609000, 'Defender Side Spawn']],
#    'elims_count': [[562000, 0, 8]],
#    'inv_primary': [[561800, 'none'], [566000, 'guardian']],
#    'ammo_reserve': [[565200, 36]],
#    'firing_state': [[561800, False], [614000, True], [618800, False]],
#    'assists_count': [[562000, 0, 1]],
#    'inv_secondary': [[561800, 'classic']],
#    'loadout_value': [[561800, 0],
#     [563600, 400.0],
#     [566000, 400.0],
#     [591800, 600.0],
#     [613000, 600.0]],
#    'spike_planted': [[561800, False]],
#    'assisted_count': [[562000, 0, 3]],
#    'ability_charges_1': [[561800, 0], [591800, 1]],
#    'ability_charges_2': [[561800, 0]],
#    'ability_charges_3': [[561800, 0], [591800, 1], [613000, 0]],
#    'ability_charges_4': [[561800, 0]]},
#   '14': {'alive': {'0': [[622800, True], [652800, False]],
#     '1': [[622800, True], [699600, False]],
#     '2': [[622800, True]],
#     '3': [[622800, True], [707200, False]],
#     '4': [[622800, True]],
#     '5': [[622800, True], [665000, False]],
#     '6': [[622800, True], [680600, False]],
#     '7': [[622800, True], [678800, False]],
#     '8': [[622800, True], [710200, False]],
#     '9': [[622800, True], [664600, False]]},
#    'elims': [[664800,
#      {'source': '4',
#       'target': '9',
#       'assisted': ['3'],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'ally'}],
#     [678800,
#      {'source': '3',
#       'target': '7',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': True,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [680800,
#      {'source': '4',
#       'target': '6',
#       'assisted': ['3'],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [700000,
#      {'source': '8',
#       'target': '1',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': True,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [707600,
#      {'source': '8',
#       'target': '3',
#       'assisted': ['7'],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 2,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [710400,
#      {'source': '2',
#       'target': '8',
#       'assisted': ['0', '4'],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}]],
#    'health': {'0': [[622800, 100], [624000, 0], [676800, 4], [682000, 0]],
#     '1': [[622800, 100], [699600, 0]],
#     '2': [[622800, 100],
#      [625400, 96],
#      [625800, 100],
#      [634400, 96],
#      [636000, 100],
#      [637400, 96],
#      [637800, 100],
#      [659600, 96],
#      [660200, 100],
#      [670200, 96],
#      [670600, 100],
#      [677200, 96],
#      [677800, 100],
#      [681600, 96],
#      [682000, 100],
#      [683000, 96],
#      [683400, 100],
#      [707200, 96],
#      [709400, 93],
#      [709800, 96]],
#     '3': [[622800, 100],
#      [624000, 0],
#      [625000, 96],
#      [625400, 93],
#      [627000, 96],
#      [634000, 89],
#      [635400, 93],
#      [636000, 96],
#      [637400, 93],
#      [638800, 96],
#      [660000, 89],
#      [660400, 96],
#      [679200, 59],
#      [680800, 15],
#      [681400, 26],
#      [682000, 44],
#      [682400, 37],
#      [684000, 44],
#      [686400, 41],
#      [688000, 0],
#      [688800, 37],
#      [690000, 44],
#      [690800, 22],
#      [692800, 48],
#      [695000, 33],
#      [695400, 37],
#      [697800, 44],
#      [699200, 15],
#      [699600, 44],
#      [701200, 37],
#      [702000, 52],
#      [704000, 0],
#      [704800, 41],
#      [705800, 44]],
#     '4': [[622800, 100],
#      [625000, 96],
#      [627200, 93],
#      [628000, 96],
#      [637400, 93],
#      [638000, 96],
#      [644200, 93],
#      [644600, 96],
#      [648000, 93],
#      [648800, 96],
#      [666800, 93],
#      [667200, 96],
#      [674200, 89],
#      [680800, 15],
#      [681800, 30],
#      [683200, 15],
#      [683600, 26],
#      [684000, 30],
#      [686600, 22],
#      [687400, 30],
#      [688200, 19],
#      [689600, 11],
#      [690800, 30],
#      [691200, 26],
#      [691600, 30],
#      [692800, 26],
#      [694400, 30],
#      [695400, 22],
#      [695800, 26],
#      [697000, 22],
#      [697600, 30],
#      [698000, 22],
#      [699800, 30],
#      [702000, 37],
#      [702400, 30],
#      [703400, 26],
#      [703800, 30],
#      [704800, 22],
#      [707200, 30],
#      [709000, 22],
#      [711000, 33],
#      [711400, 30],
#      [715000, 22],
#      [715400, 26],
#      [716200, 30]]},
#    'phases': [[622600, 'buy_start'],
#     [652600, 'round_start'],
#     [709800, 'round_scored'],
#     [716800, 'round_end']],
#    'shield': [[622800, 25], [626800, 50], [699400, 0]],
#    'credits': [[622800, 0], [624600, 2700], [626800, 1700]],
#    'ammo_mag': [[623600, 12], [687800, 11]],
#    'inv_state': [[625000, 'melee'],
#     [649600, 'primary'],
#     [662800, 'melee'],
#     [677000, 'primary'],
#     [682400, 'melee'],
#     [686800, 'primary'],
#     [688000, 'melee'],
#     [689400, 'primary']],
#    'ult_state': {'0': [[622800, False]],
#     '1': [[622800, False]],
#     '2': [[622800, False]],
#     '3': [[622800, False], [678800, True]],
#     '4': [[622800, False]],
#     '5': [[622800, False]],
#     '6': [[622800, False]],
#     '7': [[622800, False]],
#     '8': [[622800, False], [700600, True]],
#     '9': [[622800, False]]},
#    'map_region': [[625000, 'Defender Side Spawn'],
#     [627800, 'Defender Side Water'],
#     [642600, 'B Screen'],
#     [665000, 'B Tunnel'],
#     [672400, 'Defender Side Spawn']],
#    'elims_count': [[622800, 0, 8]],
#    'inv_primary': [[622800, 'guardian']],
#    'ammo_reserve': [[623200, 36]],
#    'firing_state': [[622800, False], [687800, True], [690000, False]],
#    'assists_count': [[622800, 0, 1]],
#    'inv_secondary': [[622800, 'classic']],
#    'loadout_value': [[622800, 600.0],
#     [626800, 1200.0],
#     [652800, 1550.0],
#     [656800, 1550.0],
#     [699200, 1400.0],
#     [699400, 400.0]],
#    'spike_planted': [[622800, False]],
#    'assisted_count': [[622800, 0, 3]],
#    'ability_charges_1': [[622800, 1], [652800, 2]],
#    'ability_charges_2': [[622800, 0], [652800, 1], [699200, 0]],
#    'ability_charges_3': [[622800, 0], [652800, 1], [656800, 0]],
#    'ability_charges_4': [[622800, 0]]},
#   '15': {'alive': {'0': [[717000, True], [747000, False]],
#     '1': [[717000, True], [819000, False]],
#     '2': [[717000, True], [756600, False]],
#     '3': [[717000, True], [794200, False]],
#     '4': [[717000, True]],
#     '5': [[717000, True], [752000, False]],
#     '6': [[717000, True], [808400, False]],
#     '7': [[717000, True], [756200, False]],
#     '8': [[717000, True], [819200, False]],
#     '9': [[717000, True], [800000, False]]},
#    'elims': [[756400,
#      {'source': '2',
#       'target': '7',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': True,
#       'team_credit': 'ally'}],
#     [756800,
#      {'source': '9',
#       'target': '2',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [794400,
#      {'source': '6',
#       'target': '3',
#       'assisted': [],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'opponent'}],
#     [817600,
#      {'source': '1',
#       'target': '8',
#       'weapon': 'vandal',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally',
#       'weapon_type': 'primary'}],
#     [819600,
#      {'source': '4',
#       'target': '8',
#       'assisted': ['1'],
#       'headshot': True,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}],
#     [822400,
#      {'source': '3',
#       'target': '6',
#       'assisted': [],
#       'headshot': False,
#       'wallbang': False,
#       'elim_number': 1,
#       'first_blood': False,
#       'team_credit': 'ally'}]],
#    'health': {'0': [[717000, 100], [723800, 0]],
#     '1': [[717000, 100], [816800, 87], [817400, 30], [819000, 0]],
#     '2': [[717000, 100],
#      [718000, 96],
#      [722600, 100],
#      [727400, 96],
#      [728000, 100],
#      [739000, 88],
#      [739400, 92],
#      [740000, 100],
#      [744200, 96],
#      [745200, 100]],
#     '3': [[717000, 100],
#      [722600, 96],
#      [723000, 0],
#      [725600, 96],
#      [726400, 89],
#      [727200, 96],
#      [739000, 85],
#      [739600, 96],
#      [740000, 93],
#      [742000, 96],
#      [744600, 93],
#      [745600, 96],
#      [752000, 93],
#      [753600, 96],
#      [758000, 93],
#      [758400, 96]],
#     '4': [[717000, 100],
#      [718000, 30],
#      [722000, 33],
#      [722600, 96],
#      [736800, 93],
#      [738000, 96],
#      [739000, 93],
#      [739600, 89],
#      [740000, 96],
#      [762400, 93],
#      [762800, 96],
#      [763200, 100],
#      [763600, 96],
#      [802400, 93],
#      [803000, 96],
#      [813000, 89],
#      [813600, 96],
#      [827000, 93],
#      [827400, 96]]},
#    'phases': [[716800, 'buy_start'],
#     [746800, 'round_start'],
#     [837400, 'round_scored'],
#     [844400, 'round_end']],
#    'shield': [[717000, 0],
#     [718000, 25],
#     [725400, 50],
#     [816800, 24],
#     [817400, 0]],
#    'credits': [[717000, 1700], [723400, 4300], [725400, 650]],
#    'ammo_mag': [[717000, 25],
#     [722600, 12],
#     [725000, 25],
#     [751200, 24],
#     [758800, 23],
#     [759000, 22],
#     [759200, 21],
#     [759400, 20],
#     [760400, 18],
#     [764800, 25],
#     [817000, 24],
#     [817200, 23],
#     [817400, 22],
#     [817600, 20]],
#    'inv_state': [[718000, 'primary'],
#     [725600, 'melee'],
#     [744000, 'primary'],
#     [760800, 'melee'],
#     [762200, 'primary'],
#     [780400, 'melee'],
#     [800200, 'primary']],
#    'ult_state': {'0': [[717000, False]],
#     '1': [[717000, False]],
#     '2': [[717000, False]],
#     '3': [[717000, False], [725600, True]],
#     '4': [[717000, False], [827600, True]],
#     '5': [[717000, False]],
#     '6': [[717000, False]],
#     '7': [[717000, False]],
#     '8': [[717000, False], [722600, True], [815800, False]],
#     '9': [[717000, False]]},
#    'map_region': [[718000, 'Mid Connector'],
#     [728400, 'Defender Side Spawn'],
#     [729800, 'B Tunnel'],
#     [768200, 'B Hall'],
#     [809800, 'Defender Side Spawn']],
#    'elims_count': [[717200, 0, 8], [817600, 1, 9]],
#    'inv_primary': [[717000, 'none'], [718000, 'vandal']],
#    'ammo_reserve': [[717000, 66], [722600, 36], [725000, 75], [764800, 68]],
#    'firing_state': [[717000, False],
#     [751200, True],
#     [753400, False],
#     [758800, True],
#     [762600, False],
#     [817000, True],
#     [819800, False]],
#    'assists_count': [[717200, 0, 1], [819600, 1, 2]],
#    'inv_secondary': [[717000, 'classic'],
#     [718000, 'ghost'],
#     [725600, 'classic']],
#    'loadout_value': [[717000, 0],
#     [718000, 4200.0],
#     [725400, 4800.0],
#     [725600, 4300.0],
#     [747000, 4450.0],
#     [751400, 4450.0],
#     [806200, 4250.0],
#     [816800, 3634.0],
#     [817400, 3250.0]],
#    'spike_planted': [[717000, False], [801600, True], [837400, False]],
#    'assisted_count': [[717200, 0, 3]],
#    'ability_charges_1': [[717000, 2], [806200, 1]],
#    'ability_charges_2': [[717000, 0], [747000, 1]],
#    'ability_charges_3': [[717000, 0], [747000, 1], [751400, 0]],
#    'ability_charges_4': [[717000, 0]]}},
#  'status': 'success: completed - valorant final',
#  'totals': {'elims': 9,
#   'deaths': 3,
#   'assists': 2,
#   'healing': 23,
#   'headshots': 6,
#   'shielding': 220,
#   'wallbangs': 0,
#   'first_bloods': 2,
#   'seconds_dead': 162,
#   'was_assisted': 3,
#   'credits_spent': 29060,
#   'first_blooded': 1,
#   'seconds_alive': 677,
#   'credits_earned': 33110,
#   'hp_damage_taken': 446,
#   'shield_damage_taken': 170},
#  'version': '1.0.0',
#  'end_time': 844400,
#  'gametype': 'swiftplay',
#  'opponents': ['5', '6', '7', '8', '9'],
#  'processed': True,
#  'ally_score': 13,
#  'player_ids': {'0': {'role': 'ally', 'character': 'phoenix'},
#   '1': {'role': 'self', 'character': 'jett'},
#   '2': {'role': 'ally', 'character': 'gekko'},
#   '3': {'role': 'ally', 'character': 'cypher'},
#   '4': {'role': 'ally', 'character': 'astra'},
#   '5': {'role': 'opponent', 'character': 'harbor'},
#   '6': {'role': 'opponent', 'character': 'astra'},
#   '7': {'role': 'opponent', 'character': 'jett'},
#   '8': {'role': 'opponent', 'character': 'phoenix'},
#   '9': {'role': 'opponent', 'character': 'killjoy'}},
#  'round_info': {'7': {'score': '4-3',
#    'ult_used': False,
#    'ally_side': 'attacker',
#    'buy_start': -25276,
#    'round_end': 124802,
#    'round_won': True,
#    'ally_score': 4,
#    'round_start': 4723,
#    'round_scored': 117802,
#    'spike_planted': False,
#    'opponent_score': 3},
#   '8': {'score': '5-3',
#    'ult_used': False,
#    'ally_side': 'attacker',
#    'buy_start': 124802,
#    'round_end': 204402,
#    'round_won': True,
#    'ally_score': 5,
#    'round_start': 154802,
#    'round_scored': 197402,
#    'spike_planted': False,
#    'opponent_score': 3},
#   '9': {'score': '6-3',
#    'ult_used': False,
#    'ally_side': 'attacker',
#    'buy_start': 204402,
#    'round_end': 304570,
#    'round_won': True,
#    'ally_score': 6,
#    'round_start': 234402,
#    'round_scored': 297570,
#    'spike_planted': True,
#    'opponent_score': 3},
#   '10': {'score': '7-3',
#    'ult_used': False,
#    'ally_side': 'attacker',
#    'buy_start': 304570,
#    'round_end': 369242,
#    'round_won': True,
#    'ally_score': 7,
#    'round_start': 334570,
#    'round_scored': 362242,
#    'spike_planted': False,
#    'opponent_score': 3},
#   '11': {'score': '8-3',
#    'ult_used': False,
#    'ally_side': 'attacker',
#    'buy_start': 369242,
#    'round_end': 448998,
#    'round_won': True,
#    'ally_score': 8,
#    'round_start': 399242,
#    'round_scored': 441998,
#    'spike_planted': False,
#    'opponent_score': 3},
#   '12': {'score': '9-3',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 448998,
#    'round_end': 561796,
#    'round_won': True,
#    'ally_score': 9,
#    'round_start': 493998,
#    'round_scored': 554796,
#    'spike_planted': True,
#    'opponent_score': 3},
#   '13': {'score': '10-3',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 561796,
#    'round_end': 622600,
#    'round_won': True,
#    'ally_score': 10,
#    'round_start': 591796,
#    'round_scored': 615600,
#    'spike_planted': False,
#    'opponent_score': 3},
#   '14': {'score': '11-3',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 622600,
#    'round_end': 716800,
#    'round_won': True,
#    'ally_score': 11,
#    'round_start': 652600,
#    'round_scored': 709800,
#    'spike_planted': False,
#    'opponent_score': 3},
#   '15': {'score': '12-3',
#    'ult_used': False,
#    'ally_side': 'defender',
#    'buy_start': 716800,
#    'round_end': 844400,
#    'round_won': True,
#    'ally_score': 12,
#    'round_start': 746800,
#    'round_scored': 837400,
#    'spike_planted': True,
#    'opponent_score': 3}},
#  'start_time': 0,
#  'best_weapon': 'vandal',
#  'round_totals': {'7': {'elims': 0,
#    'deaths': 1,
#    'assists': 0,
#    'healing': 0,
#    'headshots': 0,
#    'shielding': 24,
#    'wallbangs': 0,
#    'first_bloods': 0,
#    'seconds_dead': 71,
#    'was_assisted': 0,
#    'credits_spent': 4760,
#    'first_blooded': 0,
#    'seconds_alive': 53,
# ...
#   '441': {'final_time': 448550,
#    'initial_size': {'h': 0.1375, 'w': 0.03671875},
#    'initial_time': 448250,
#    'time_on_screen': 300,
#    'initial_location': {'x': -0.106640625, 'y': -0.09097222222222222},
#    'initial_head_location': {'x': -0.106640625, 'y': -0.03888888888888889}},
#   '442': {'final_time': 449050,
#    'initial_size': {'h': 0.1791666666666667, 'w': 0.0265625},
#    'initial_time': 448750,
#    'time_on_screen': 300,
#    'initial_location': {'x': -0.09140625, 'y': -0.07152777777777777},
#    'initial_head_location': {'x': -0.09140625, 'y': 0.00625}},
#   '447': {'final_time': 450550,
#    'initial_size': {'h': 0.05138888888888889, 'w': 0.01015625},
#    'initial_time': 450450,
#    'time_on_screen': 100,
#    'initial_location': {'x': 0.295703125, 'y': 0.2395833333333333},
#    'initial_head_location': {'x': 0.295703125, 'y': 0.2604166666666667}},
#   '456': {'final_time': 472550,
#    'initial_size': {'h': 0.1194444444444445, 'w': 0.034375},
#    'initial_time': 472250,
#    'time_on_screen': 300,
#    'initial_location': {'x': 0.38671875, 'y': 0.2902777777777778},
#    'initial_head_location': {'x': 0.38671875, 'y': 0.3347222222222222}},
#   '460': {'final_time': 492000,
#    'initial_size': {'h': 0.04583333333333333, 'w': 0.01171875},
#    'initial_time': 491850,
#    'time_on_screen': 150,
#    'initial_location': {'x': -0.098046875, 'y': 0.2145833333333333},
#    'initial_head_location': {'x': -0.098046875, 'y': 0.2326388888888889}},
#   '467': {'final_time': 512350,
#    'initial_size': {'h': 0.04305555555555556, 'w': 0.009375},
#    'initial_time': 511950,
#    'time_on_screen': 400,
#    'initial_location': {'x': -0.046875, 'y': 0.2340277777777778},
#    'initial_head_location': {'x': -0.046875, 'y': 0.2513888888888889}},
#   '480': {'final_time': 526650,
#    'initial_size': {'h': 0.075, 'w': 0.01875},
#    'initial_time': 526450,
#    'time_on_screen': 200,
#    'initial_location': {'x': 0.1, 'y': 0.1180555555555556},
#    'initial_head_location': {'x': 0.1, 'y': 0.1472222222222222}},
#   '484': {'final_time': 532200,
#    'initial_size': {'h': 0.07777777777777778, 'w': 0.01328125},
#    'initial_time': 528950,
#    'time_to_head': 50,
#    'targeted_time': 528950,
#    'time_on_screen': 3250,
#    'time_to_target': 0,
#    'initial_location': {'x': -0.004296875, 'y': -0.03055555555555555},
#    'targeted_head_time': 529000,
#    'initial_head_location': {'x': -0.004296875, 'y': 0.002777777777777778}},
#   '487': {'final_time': 535900,
#    'initial_size': {'h': 0.06527777777777778, 'w': 0.0109375},
#    'initial_time': 535150,
#    'targeted_time': 535400,
#    'time_on_screen': 750,
#    'time_to_target': 250,
#    'initial_location': {'x': 0.04140625, 'y': -0.03680555555555556},
#    'initial_head_location': {'x': 0.04140625, 'y': -0.009027777777777777}},
#   '493': {'final_time': 541150,
#    'initial_size': {'h': 0.04444444444444445, 'w': 0.009375},
#    'initial_time': 540500,
#    'time_to_head': 200,
#    'targeted_time': 540500,
#    'time_on_screen': 650,
#    'time_to_target': 0,
#    'initial_location': {'x': -0.0015625, 'y': -0.01111111111111111},
#    'targeted_head_time': 540700,
#    'initial_head_location': {'x': -0.0015625, 'y': 0.006944444444444444}},
#   '494': {'final_time': 541200,
#    'initial_size': {'h': 0.05555555555555555, 'w': 0.01484375},
#    'initial_time': 540500,
#    'time_on_screen': 700,
#    'initial_location': {'x': 0.194140625, 'y': 0.2597222222222222},
#    'initial_head_location': {'x': 0.194140625, 'y': 0.28125}},
#   '495': {'final_time': 541200,
#    'initial_size': {'h': 0.04444444444444445, 'w': 0.0109375},
#    'initial_time': 540850,
#    'time_on_screen': 350,
#    'initial_location': {'x': 0.11953125, 'y': 0.1375},
#    'initial_head_location': {'x': 0.11953125, 'y': 0.1548611111111111}},
#   '510': {'final_time': 544950,
#    'initial_size': {'h': 0.06666666666666667, 'w': 0.0203125},
#    'initial_time': 544700,
#    'time_on_screen': 250,
#    'initial_location': {'x': 0.03359375, 'y': -0.08333333333333333},
#    'initial_head_location': {'x': 0.03359375, 'y': -0.05902777777777778}},
#   '513': {'final_time': 545850,
#    'initial_size': {'h': 0.1027777777777778, 'w': 0.0265625},
#    'initial_time': 545750,
#    'time_on_screen': 100,
#    'initial_location': {'x': 0.0671875, 'y': -0.1125},
#    'initial_head_location': {'x': 0.0671875, 'y': -0.07291666666666667}},
#   '514': {'final_time': 546400,
#    'initial_size': {'h': 0.1069444444444444, 'w': 0.021875},
#    'initial_time': 546200,
#    'time_to_head': 0,
#    'targeted_time': 546200,
#    'time_on_screen': 200,
#    'time_to_target': 0,
#    'initial_location': {'x': 0.0, 'y': -0.04652777777777778},
#    'targeted_head_time': 546200,
#    'initial_head_location': {'x': 0.0, 'y': -0.002777777777777778}},
#   '515': {'final_time': 546550,
#    'initial_size': {'h': 0.1138888888888889, 'w': 0.0140625},
#    'initial_time': 546450,
#    'targeted_time': 546450,
#    'time_on_screen': 100,
#    'time_to_target': 0,
#    'initial_location': {'x': 0.00234375, 'y': -0.001388888888888889},
#    'initial_head_location': {'x': 0.00234375, 'y': 0.04930555555555555}},
#   '518': {'final_time': 547400,
#    'initial_size': {'h': 0.2805555555555556, 'w': 0.0765625},
#    'initial_time': 547300,
#    'time_on_screen': 100,
#    'initial_location': {'x': 0.00703125, 'y': -0.2097222222222222},
#    'initial_head_location': {'x': 0.00703125, 'y': -0.1034722222222222}},
#   '531': {'final_time': 550700,
#    'initial_size': {'h': 0.075, 'w': 0.015625},
#    'initial_time': 549550,
#    'targeted_time': 549900,
#    'time_on_screen': 1150,
#    'time_to_target': 350,
#    'initial_location': {'x': -0.19296875, 'y': -0.08194444444444444},
#    'initial_head_location': {'x': -0.19296875, 'y': -0.05138888888888889}},
#   '549': {'final_time': 594850,
#    'initial_size': {'h': 0.2444444444444444, 'w': 0.0578125},
#    'initial_time': 594450,
#    'time_on_screen': 400,
#    'initial_location': {'x': -0.05390625, 'y': -0.01944444444444444},
#    'initial_head_location': {'x': -0.05390625, 'y': 0.07708333333333334}},
#   '579': {'final_time': 614700,
#    'initial_size': {'h': 0.1166666666666667, 'w': 0.025},
#    'initial_time': 613500,
#    'time_to_head': 400,
#    'targeted_time': 613800,
#    'time_on_screen': 1200,
#    'time_to_target': 300,
#    'initial_location': {'x': -0.0328125, 'y': -0.03194444444444444},
#    'targeted_head_time': 613900,
#    'initial_head_location': {'x': -0.0328125, 'y': 0.01527777777777778}},
#   '586': {'final_time': 616000,
#    'initial_size': {'h': 0.06388888888888888, 'w': 0.0109375},
#    'initial_time': 615900,
#    'time_to_head': 0,
#    'targeted_time': 615900,
#    'time_on_screen': 100,
#    'time_to_target': 0,
#    'initial_location': {'x': 0.00078125, 'y': -0.03055555555555555},
#    'targeted_head_time': 615900,
#    'initial_head_location': {'x': 0.00078125, 'y': -0.003472222222222222}},
#   '609': {'final_time': 646350,
#    'initial_size': {'h': 0.0625, 'w': 0.01171875},
#    'initial_time': 646000,
#    'time_on_screen': 350,
#    'initial_location': {'x': -0.205859375, 'y': 0.2020833333333333},
#    'initial_head_location': {'x': -0.205859375, 'y': 0.2277777777777778}},
#   '613': {'final_time': 654800,
#    'initial_size': {'h': 0.05694444444444444, 'w': 0.01640625},
#    'initial_time': 654700,
#    'time_on_screen': 100,
#    'initial_location': {'x': -0.001953125, 'y': -0.03125},
#    'initial_head_location': {'x': -0.001953125, 'y': -0.009722222222222222}},
#   '614': {'final_time': 655300,
#    'initial_size': {'h': 0.04444444444444445, 'w': 0.009375},
#    'initial_time': 655050,
#    'time_on_screen': 250,
#    'initial_location': {'x': 0.0015625, 'y': -0.04444444444444445},
#    'initial_head_location': {'x': 0.0015625, 'y': -0.02638888888888889}},
#   '658': {'final_time': 678850,
#    'initial_size': {'h': 0.04305555555555556, 'w': 0.0140625},
#    'initial_time': 678750,
#    'time_on_screen': 100,
#    'initial_location': {'x': 0.003125, 'y': -0.1756944444444444},
#    'initial_head_location': {'x': 0.003125, 'y': -0.1604166666666667}},
#   '667': {'final_time': 681450,
#    'initial_size': {'h': 0.03194444444444444, 'w': 0.00625},
#    'initial_time': 681300,
#    'time_on_screen': 150,
#    'initial_location': {'x': -0.0515625, 'y': 0.02291666666666667},
#    'initial_head_location': {'x': -0.0515625, 'y': 0.03611111111111111}},
#   '703': {'final_time': 688900,
#    'initial_size': {'h': 0.04166666666666666, 'w': 0.00859375},
#    'initial_time': 688400,
#    'time_on_screen': 500,
#    'initial_location': {'x': -0.134765625, 'y': 0.2555555555555555},
#    'initial_head_location': {'x': -0.134765625, 'y': 0.2729166666666666}},
#   '732': {'final_time': 710250,
#    'initial_size': {'h': 0.2902777777777778, 'w': 0.0328125},
#    'initial_time': 709750,
#    'time_to_head': 250,
#    'targeted_time': 709750,
#    'time_on_screen': 500,
#    'time_to_target': 0,
#    'initial_location': {'x': 0.00234375, 'y': -0.06041666666666667},
#    'targeted_head_time': 710000,
#    'initial_head_location': {'x': 0.00234375, 'y': 0.07013888888888889}},
#   '733': {'final_time': 710050,
#    'initial_size': {'h': 0.075, 'w': 0.025},
#    'initial_time': 709950,
#    'time_on_screen': 100,
#    'initial_location': {'x': 0.14375, 'y': -0.3402777777777778},
#    'initial_head_location': {'x': 0.14375, 'y': -0.3138888888888889}},
#   '736': {'final_time': 710500,
#    'initial_size': {'h': 0.075, 'w': 0.0234375},
#    'initial_time': 710300,
#    'time_on_screen': 200,
#    'initial_location': {'x': 0.13828125, 'y': -0.3236111111111111},
#    'initial_head_location': {'x': 0.13828125, 'y': -0.2965277777777778}},
#   '737': {'final_time': 711250,
#    'initial_size': {'h': 0.2152777777777778, 'w': 0.096875},
#    'initial_time': 710900,
#    'time_on_screen': 350,
#    'initial_location': {'x': -0.25078125, 'y': -0.09652777777777778},
#    'initial_head_location': {'x': -0.25078125, 'y': -0.03194444444444444}},
#   '740': {'final_time': 712100,
#    'initial_size': {'h': 0.06944444444444445, 'w': 0.0171875},
#    'initial_time': 711500,
#    'time_on_screen': 600,
#    'initial_location': {'x': 0.109375, 'y': -0.0375},
#    'initial_head_location': {'x': 0.109375, 'y': -0.01041666666666667}},
#   '744': {'final_time': 714150,
#    'initial_size': {'h': 0.07361111111111111, 'w': 0.0265625},
#    'initial_time': 713500,
#    'time_on_screen': 650,
#    'initial_location': {'x': 0.13359375, 'y': -0.3340277777777778},
#    'initial_head_location': {'x': 0.13359375, 'y': -0.3090277777777778}},
#   '745': {'final_time': 716150,
#    'initial_size': {'h': 0.07777777777777778, 'w': 0.025},
#    'initial_time': 715750,
#    'time_on_screen': 400,
#    'initial_location': {'x': 0.13359375, 'y': -0.3333333333333333},
#    'initial_head_location': {'x': 0.13359375, 'y': -0.3055555555555556}},
#   '763': {'final_time': 750850,
#    'initial_size': {'h': 0.03888888888888889, 'w': 0.00859375},
#    'initial_time': 750700,
#    'time_on_screen': 150,
#    'initial_location': {'x': -0.195703125, 'y': 0.2666666666666667},
#    'initial_head_location': {'x': -0.195703125, 'y': 0.2819444444444444}},
#   '771': {'final_time': 759000,
#    'initial_size': {'h': 0.04722222222222222, 'w': 0.00859375},
#    'initial_time': 758450,
#    'time_to_head': 250,
#    'targeted_time': 758450,
#    'time_on_screen': 550,
#    'time_to_target': 0,
#    'initial_location': {'x': -0.004296875, 'y': -0.01527777777777778},
#    'targeted_head_time': 758700,
#    'initial_head_location': {'x': -0.004296875, 'y': 0.004166666666666667}},
#   '799': {'final_time': 817000,
#    'initial_size': {'h': 0.04444444444444445, 'w': 0.009375},
#    'initial_time': 816600,
#    'targeted_time': 816900,
#    'time_on_screen': 400,
#    'time_to_target': 300,
#    'initial_location': {'x': -0.0015625, 'y': 0.02777777777777778},
#    'initial_head_location': {'x': -0.0015625, 'y': 0.04583333333333333}},
#   '808': {'final_time': 818950,
#    'initial_size': {'h': 0.06388888888888888, 'w': 0.01015625},
#    'initial_time': 818600,
#    'targeted_time': 818800,
#    'time_on_screen': 350,
#    'time_to_target': 200,
#    'initial_location': {'x': 0.009765625, 'y': 0.0125},
#    'initial_head_location': {'x': 0.009765625, 'y': 0.04027777777777778}},
#   '810': {'final_time': 819400,
#    'initial_size': {'h': 0.09444444444444444, 'w': 0.0265625},
#    'initial_time': 819000,
#    'targeted_time': 819000,
#    'time_on_screen': 400,
#    'time_to_target': 0,
#    'initial_location': {'x': 0.0125, 'y': -0.005555555555555556},
#    'initial_head_location': {'x': 0.0125, 'y': 0.02986111111111111}},
#   '813': {'final_time': 825450,
#    'initial_size': {'h': 0.09305555555555556, 'w': 0.0109375},
#    'initial_time': 823950,
#    'time_to_head': 350,
#    'targeted_time': 824300,
#    'time_on_screen': 1500,
#    'time_to_target': 350,
#    'initial_location': {'x': 0.04609375, 'y': -0.08125},
#    'targeted_head_time': 824300,
#    'initial_head_location': {'x': 0.04609375, 'y': -0.03958333333333333}},
#   '814': {'final_time': 824950,
#    'initial_size': {'h': 0.07777777777777778, 'w': 0.01875},
#    'initial_time': 824450,
#    'time_on_screen': 500,
#    'initial_location': {'x': 0.134375, 'y': -0.3416666666666667},
#    'initial_head_location': {'x': 0.134375, 'y': -0.3111111111111111}},
#   '821': {'final_time': 857800,
#    'initial_size': {'h': 0.1638888888888889, 'w': 0.0796875},
#    'initial_time': 857600,
#    'time_on_screen': 200,
#    'initial_location': {'x': -0.00234375, 'y': -0.2708333333333333},
#    'initial_head_location': {'x': -0.00234375, 'y': -0.2243055555555556}}},
#  'most_used_primary': 'vandal',
#  'analysis_processed': True,
#  'opponents_onscreen': {'5250': 0,
#   '19600': 1,
#   '22150': 0,
#   '28700': 1,
#   '29150': 0,
#   '56500': 2,
#   '56600': 1,
#   '56700': 3,
#   '56800': 2,
#   '57200': 0,
#   '57250': 1,
#   '57450': 0,
#   '57500': 1,
#   '63100': 0,
#   '69000': 1,
#   '69500': 0,
#   '175050': 1,
#   '176700': 2,
#   '176750': 1,
#   '178250': 0,
#   '189400': 1,
#   '189550': 2,
#   '189700': 0,
#   '189750': 2,
#   '189800': 0,
#   '189850': 1,
#   '190300': 0,
#   '192950': 1,
#   '194950': 0,
#   '195300': 1,
#   '195650': 0,
#   '196850': 1,
#   '197050': 0,
#   '197150': 1,
#   '197300': 0,
#   '197700': 1,
#   '197800': 2,
#   '197900': 1,
#   '200500': 0,
#   '206850': 1,
#   '207100': 0,
#   '207800': 1,
#   '208450': 0,
#   '208700': 1,
#   '209050': 0,
#   '209550': 1,
#   '209850': 0,
#   '210300': 1,
#   '210500': 0,
#   '210700': 1,
#   '210900': 0,
#   '213600': 1,
#   '213900': 0,
#   '213950': 1,
#   '214100': 0,
#   '257850': 1,
#   '258050': 0,
#   '258100': 1,
#   '258200': 0,
#   '258250': 1,
#   '258350': 0,
#   '258450': 1,
#   '258500': 0,
#   '258649': 1,
#   '263900': 0,
#   '267550': 1,
#   '268250': 0,
#   '297050': 1,
#   '302800': 0,
#   '338750': 2,
#   '339150': 1,
#   '339350': 0,
#   '339400': 1,
#   '339450': 0,
#   '339600': 2,
#   '339650': 1,
#   '348000': 2,
#   '348050': 1,
#   '348100': 0,
#   '348150': 1,
#   '348200': 2,
#   '348250': 1,
#   '348300': 2,
#   '348350': 1,
#   '351750': 0,
#   '359550': 1,
#   '360950': 0,
#   '365750': 1,
#   '366050': 0,
#   '366400': 1,
#   '366500': 0,
#   '366550': 1,
#   '373400': 0,
#   '426900': 1,
#   '445000': 0,
#   '448250': 1,
#   '448800': 0,
#   '448850': 1,
#   '448900': 0,
#   '449050': 1,
#   '449100': 0,
#   '450450': 1,
#   '452000': 0,
#   '472250': 1,
#   '509800': 0,
#   '511950': 1,
#   '513650': 0,
#   '526450': 1,
#   '527650': 0,
#   '528950': 1,
#   '537350': 0,
#   '540500': 2,
#   '540850': 3,
#   '540900': 2,
#   '541000': 3,
#   '541200': 2,
#   '541250': 0,
#   '544700': 1,
#   '545250': 0,
#   '545750': 1,
#   '546900': 0,
#   '547300': 1,
#   '547500': 0,
#   '549550': 1,
#   '549850': 0,
#   '549900': 1,
#   '550550': 0,
#   '550600': 1,
#   '588750': 0,
#   '594450': 1,
#   '595200': 0,
#   '613500': 1,
#   '619700': 0,
#   '646000': 1,
#   '646200': 0,
#   '646250': 1,
#   '646300': 0,
#   '646350': 1,
#   '646400': 0,
#   '654700': 1,
#   '656350': 0,
#   '678750': 1,
#   '678900': 0,
#   '681300': 1,
#   '681500': 0,
#   '688400': 1,
#   '688450': 0,
#   '688500': 1,
#   '688550': 0,
#   '688600': 1,
#   '689100': 0,
#   '709750': 1,
#   '709950': 2,
#   '710100': 1,
#   '711300': 0,
#   '711500': 1,
#   '722650': 0,
#   '750700': 1,
#   '750900': 0,
#   '758450': 1,
#   '760500': 0,
#   '816600': 1,
#   '817150': 0,
#   '818600': 1,
#   '819550': 0,
#   '823950': 1,
#   '824450': 2,
#   '824600': 1,
#   '824650': 2,
#   '824900': 1,
#   '838850': 0,
#   '857600': 1,
#   '870100': 0},
#  'most_used_secondary': 'sheriff',
#  'best_weapon_type_elims': 5,
#  'most_used_primary_seconds': 309,
#  'most_used_secondary_seconds': 109}

# %% [markdown]
# ## Create Rounds DF
# - Create DF
# - Go to statistics col

# %%
from pandas import json_normalize

# Create df
df = pd.read_json('dev_data.json')
print(df.shape)

# Drop the all cols besides 'statistics' and 'user_id'
df_stats = df[['user_id','statistics']]
print(df_stats.shape)
df_stats
# Out:
# (534, 28)
# (534, 2)
#      user_id                                         statistics
# 0       1006  {'map': 'Pearl', 'score': '13-3', 'allies': ['...
# 1       1006  {'map': 'Haven', 'score': '9-13', 'allies': ['...
# 2       1006  {'map': 'Split', 'score': '13-4', 'allies': ['...
# 3       1011  {'map': 'Fracture', 'score': '14-12', 'allies'...
# 4       1011  {'map': 'Haven', 'score': '13-10', 'allies': [...
# ..       ...                                                ...
# 529     1010  {'map': 'Ascent', 'score': '13-8', 'allies': [...
# 530     1011  {'map': 'Bind', 'score': '14-12', 'allies': ['...
# 531     1011  {'map': 'unknown', 'score': '13-11', 'allies':...
# 532     1018  {'map': 'Split', 'score': '13-4', 'allies': ['...
# 533     1018  {'map': 'Lotus', 'score': '13-7', 'allies': ['...
#
# [534 rows x 2 columns]

# %% [markdown]
# ### Flattening the stats col by 1 level

# %%
flat1_df_stats = pd.json_normalize(df_stats['statistics'], max_level=0)
flat1_df_stats = pd.concat([df_stats['user_id'], flat1_df_stats], axis=1)
print(flat1_df_stats.shape)
flat1_df_stats
# Out:
# (534, 34)
#      user_id       map  score           allies player result  \
# 0       1006     Pearl   13-3  [0, 1, 2, 3, 4]      1    win
# 1       1006     Haven   9-13  [0, 1, 2, 3, 4]      4   loss
# 2       1006     Split   13-4  [0, 1, 2, 3, 4]      3    win
# 3       1011  Fracture  14-12  [0, 1, 2, 3, 4]      0    win
# 4       1011     Haven  13-10  [0, 1, 2, 3, 4]      2    win
# ..       ...       ...    ...              ...    ...    ...
# 529     1010    Ascent   13-8  [0, 1, 2, 3, 4]      0    win
# 530     1011      Bind  14-12  [0, 1, 2, 3, 4]      0    win
# 531     1011   unknown  13-11  [0, 1, 2, 3, 4]      0    win
# 532     1018     Split   13-4  [0, 1, 2, 3, 4]      3    win
# 533     1018     Lotus   13-7  [0, 1, 2, 3, 4]      2    win
#
#                                                 rounds  \
# 0    {'7': {'alive': {'0': [[0, True], [4800, False...
# 1    {'0': {'alive': {'0': [[95000, True], [140000,...
# 2    {'0': {'alive': {'0': [[3600, True], [50600, F...
# 3    {'0': {'alive': {'0': [[110199, True], [175399...
# 4    {'0': {'alive': {'0': [[73399, True], [153799,...
# ..                                                 ...
# 529  {'0': {'alive': {'0': [[49789, True], [71389, ...
# 530  {'0': {'alive': {'0': [[44988, True], [88188, ...
# 531  {'0': {'alive': {'0': [[9, True], [113209, Fal...
# 532  {'0': {'alive': {'0': [[199, True], [168177, F...
# 533  {'0': {'alive': {'0': [[194, True], [56987, Fa...
#
#                                         status  \
# 0          success: completed - valorant final
# 1          success: completed - valorant final
# 2          success: completed - valorant final
# 3          success: completed - valorant final
# 4          success: completed - valorant final
# ..                                         ...
# 529  success: completed - valorant postprocess
# 530  success: completed - valorant postprocess
# 531  success: completed - valorant postprocess
# 532  success: completed - valorant postprocess
# 533  success: completed - valorant postprocess
#
#                                                 totals version  ...  \
# 0    {'elims': 9, 'deaths': 3, 'assists': 2, 'heali...   1.0.0  ...
# 1    {'elims': 21, 'deaths': 17, 'assists': 0, 'hea...   1.0.0  ...
# 2    {'elims': 32, 'deaths': 8, 'assists': 3, 'heal...   1.0.0  ...
# 3    {'elims': 14, 'deaths': 12, 'assists': 12, 'he...   1.0.0  ...
# 4    {'elims': 15, 'deaths': 16, 'assists': 6, 'hea...   1.0.0  ...
# ..                                                 ...     ...  ...
# 529  {'elims': 12, 'deaths': 11, 'assists': 9, 'hea...     NaN  ...
# 530  {'elims': 24, 'deaths': 19, 'assists': 8, 'hea...     NaN  ...
# 531  {'elims': 23, 'deaths': 16, 'assists': 6, 'hea...     NaN  ...
# 532  {'elims': 11, 'deaths': 14, 'assists': 6, 'hea...     NaN  ...
# 533  {'elims': 17, 'deaths': 20, 'assists': 18, 'he...     NaN  ...
#
#      best_weapon_type best_weapon_elims  \
# 0             primary                 4
# 1             primary                 9
# 2             primary                 4
# 3             primary                 6
# 4             primary                 8
# ..                ...               ...
# 529           primary                 4
# 530           primary                 8
# 531           primary                 8
# 532           primary                 3
# 533           primary                 5
#
#                                      detections_totals most_used_primary  \
# 0    {'7': {'final_time': 19850, 'initial_size': {'...            vandal
# 1    {'26': {'final_time': 46900, 'initial_size': {...            vandal
# 2    {'55': {'final_time': 78100, 'initial_size': {...            vandal
# 3    {'51': {'final_time': 117249, 'initial_size': ...            vandal
# 4    {'33': {'final_time': 91399, 'initial_size': {...            vandal
# ..                                                 ...               ...
# 529                                                NaN            vandal
# 530                                                NaN           phantom
# 531                                                NaN            vandal
# 532                                                NaN           phantom
# 533                                                NaN           spectre
#
#      analysis_processed                                 opponents_onscreen  \
# 0                  True  {'5250': 0, '19600': 1, '22150': 0, '28700': 1...
# 1                  True  {'14200': 0, '46450': 1, '50800': 0, '60100': ...
# 2                  True  {'1600': 0, '77900': 1, '78000': 0, '78100': 1...
# 3                  True  {'33799': 0, '116999': 1, '117299': 0, '125449...
# 4                  True  {'6199': 0, '91199': 1, '92299': 0, '92349': 1...
# ..                  ...                                                ...
# 529                 NaN                                                NaN
# 530                 NaN                                                NaN
# 531                 NaN                                                NaN
# 532                 NaN                                                NaN
# 533                 NaN                                                NaN
#
#     most_used_secondary  best_weapon_type_elims most_used_primary_seconds  \
# 0               sheriff                       5                       309
# 1                 ghost                      14                       298
# 2               sheriff                      12                       192
# 3                frenzy                      10                      1455
# 4                frenzy                       9                      1131
# ..                  ...                     ...                       ...
# 529               ghost                       7                       507
# 530              frenzy                      12                      1268
# 531               ghost                      12                       664
# 532             sheriff                       6                       294
# 533             sheriff                       9                       236
#
#     most_used_secondary_seconds
# 0                           109
# 1                            94
# 2                           195
# 3                           137
# 4                           291
# ..                          ...
# 529                         157
# 530                         105
# 531                         139
# 532                          39
# 533                          58
#
# [534 rows x 34 columns]

# %%
flat1_df_stats.columns
# Out:
# Index(['user_id', 'map', 'score', 'allies', 'player', 'result', 'rounds',
#        'status', 'totals', 'version', 'end_time', 'gametype', 'opponents',
#        'processed', 'ally_score', 'player_ids', 'round_info', 'start_time',
#        'best_weapon', 'round_totals', 'player_totals', 'opponent_score',
#        'allies_onscreen', 'analysis_status', 'best_weapon_type',
#        'best_weapon_elims', 'detections_totals', 'most_used_primary',
#        'analysis_processed', 'opponents_onscreen', 'most_used_secondary',
#        'best_weapon_type_elims', 'most_used_primary_seconds',
#        'most_used_secondary_seconds'],
#       dtype='object')

# %%
flat1_df_stats['best_weapon_type_elims']
# Out:
# 0       5
# 1      14
# 2      12
# 3      10
# 4       9
#        ..
# 529     7
# 530    12
# 531    12
# 532     6
# 533     9
# Name: best_weapon_type_elims, Length: 534, dtype: int64

# %% [markdown]
# ### Removing some cols we don't care about from the ROUND perspective
# - Keep in mind the 'totals', 'result' are from the MATCH perspective
# - even though the map is from match perspective I need it so I am adding it in (similar to userID)
# - weapon stuff is all from match perspective, so I am dropping (some exists in rounds data anyway)
# - I think its possible to do something with 'allies_onscreen', 'opponents_onscreen', and 'detections_totals' but I am dropping for now

# %%
flat1_df_stats = flat1_df_stats.drop(['totals','score', 'allies','result', 'status','gametype','version','end_time','opponents','processed','ally_score','start_time','opponent_score','detections_totals','best_weapon_elims','most_used_primary_seconds','analysis_processed','most_used_secondary_seconds','best_weapon_type_elims','opponents_onscreen','allies_onscreen','analysis_status','player_totals','best_weapon_type','best_weapon','most_used_secondary','most_used_primary','best_weapon_type_elims'], axis=1)
print(flat1_df_stats.shape)
flat1_df_stats
# Out:
# (534, 7)
#      user_id       map player  \
# 0       1006     Pearl      1
# 1       1006     Haven      4
# 2       1006     Split      3
# 3       1011  Fracture      0
# 4       1011     Haven      2
# ..       ...       ...    ...
# 529     1010    Ascent      0
# 530     1011      Bind      0
# 531     1011   unknown      0
# 532     1018     Split      3
# 533     1018     Lotus      2
#
#                                                 rounds  \
# 0    {'7': {'alive': {'0': [[0, True], [4800, False...
# 1    {'0': {'alive': {'0': [[95000, True], [140000,...
# 2    {'0': {'alive': {'0': [[3600, True], [50600, F...
# 3    {'0': {'alive': {'0': [[110199, True], [175399...
# 4    {'0': {'alive': {'0': [[73399, True], [153799,...
# ..                                                 ...
# 529  {'0': {'alive': {'0': [[49789, True], [71389, ...
# 530  {'0': {'alive': {'0': [[44988, True], [88188, ...
# 531  {'0': {'alive': {'0': [[9, True], [113209, Fal...
# 532  {'0': {'alive': {'0': [[199, True], [168177, F...
# 533  {'0': {'alive': {'0': [[194, True], [56987, Fa...
#
#                                             player_ids  \
# 0    {'0': {'role': 'ally', 'character': 'phoenix'}...
# 1    {'0': {'role': 'ally', 'character': 'kay/o'}, ...
# 2    {'0': {'role': 'ally', 'character': 'skye'}, '...
# 3    {'0': {'role': 'self', 'character': 'breach'},...
# 4    {'0': {'role': 'ally', 'character': 'omen'}, '...
# ..                                                 ...
# 529  {'0': {'role': 'self', 'character': 'astra'}, ...
# 530  {'0': {'role': 'self', 'character': 'viper'}, ...
# 531  {'0': {'role': 'self', 'character': 'viper'}, ...
# 532  {'0': {'role': 'ally', 'character': 'yoru'}, '...
# 533  {'0': {'role': 'ally', 'character': 'yoru'}, '...
#
#                                             round_info  \
# 0    {'7': {'score': '4-3', 'ult_used': False, 'all...
# 1    {'0': {'score': '0-0', 'ult_used': False, 'all...
# 2    {'0': {'score': '0-0', 'ult_used': False, 'all...
# 3    {'0': {'score': '0-0', 'ult_used': False, 'all...
# 4    {'0': {'score': '0-0', 'ult_used': False, 'all...
# ..                                                 ...
# 529  {'0': {'score': '0-0', 'ally_side': 'attacker'...
# 530  {'0': {'score': '0-0', 'ally_side': 'defender'...
# 531  {'0': {'score': '0-0', 'ally_side': 'unknown',...
# 532  {'0': {'score': '0-0', 'ally_side': 'defender'...
# 533  {'0': {'score': '0-0', 'ally_side': 'defender'...
#
#                                           round_totals
# 0    {'7': {'elims': 0, 'deaths': 1, 'assists': 0, ...
# 1    {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...
# 2    {'0': {'elims': 1, 'deaths': 0, 'assists': 0, ...
# 3    {'0': {'elims': 0, 'deaths': 1, 'assists': 1, ...
# 4    {'0': {'elims': 0, 'deaths': 1, 'assists': 1, ...
# ..                                                 ...
# 529  {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...
# 530  {'0': {'elims': 0, 'deaths': 1, 'assists': 1, ...
# 531  {'0': {'elims': 1, 'deaths': 1, 'assists': 0, ...
# 532  {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...
# 533  {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...
#
# [534 rows x 7 columns]

# %%
flat1_df_stats['player_ids'][0]
# Out:
# {'0': {'role': 'ally', 'character': 'phoenix'},
#  '1': {'role': 'self', 'character': 'jett'},
#  '2': {'role': 'ally', 'character': 'gekko'},
#  '3': {'role': 'ally', 'character': 'cypher'},
#  '4': {'role': 'ally', 'character': 'astra'},
#  '5': {'role': 'opponent', 'character': 'harbor'},
#  '6': {'role': 'opponent', 'character': 'astra'},
#  '7': {'role': 'opponent', 'character': 'jett'},
#  '8': {'role': 'opponent', 'character': 'phoenix'},
#  '9': {'role': 'opponent', 'character': 'killjoy'}}

# %% [markdown]
# ### Flattening the player_ids col by 1 level
# - this is getting all the teammates and opponents, as well as mapping the 'player' to an ally

# %%
# Create an empty list to hold the expanded player ids
expanded_player_ids_list = []

for i, player_ids in enumerate(flat1_df_stats['player_ids']):
    mapping = {}
    for player_id, player_info in player_ids.items():
        # If the role is 'self', map it to 'ally'
        role = 'ally' if player_info['role'] == 'self' else player_info['role']
        column_name = f"{role}{player_id}_character"
        mapping[column_name] = player_info['character']
    
    # If mapping is not empty
    if mapping:
        expanded_player_ids_list.append(mapping)
        
# Create the expanded_player_ids DataFrame
expanded_player_ids = pd.DataFrame(expanded_player_ids_list)

# Concatenate the original DataFrame with the expanded columns
flat2_df_stats_chars = pd.concat([flat1_df_stats.drop('player_ids', axis=1), expanded_player_ids], axis=1)

print(flat2_df_stats_chars.shape)
flat2_df_stats_chars
# Out:
# (534, 16)
#      user_id       map player  \
# 0       1006     Pearl      1
# 1       1006     Haven      4
# 2       1006     Split      3
# 3       1011  Fracture      0
# 4       1011     Haven      2
# ..       ...       ...    ...
# 529     1010    Ascent      0
# 530     1011      Bind      0
# 531     1011   unknown      0
# 532     1018     Split      3
# 533     1018     Lotus      2
#
#                                                 rounds  \
# 0    {'7': {'alive': {'0': [[0, True], [4800, False...
# 1    {'0': {'alive': {'0': [[95000, True], [140000,...
# 2    {'0': {'alive': {'0': [[3600, True], [50600, F...
# 3    {'0': {'alive': {'0': [[110199, True], [175399...
# 4    {'0': {'alive': {'0': [[73399, True], [153799,...
# ..                                                 ...
# 529  {'0': {'alive': {'0': [[49789, True], [71389, ...
# 530  {'0': {'alive': {'0': [[44988, True], [88188, ...
# 531  {'0': {'alive': {'0': [[9, True], [113209, Fal...
# 532  {'0': {'alive': {'0': [[199, True], [168177, F...
# 533  {'0': {'alive': {'0': [[194, True], [56987, Fa...
#
#                                             round_info  \
# 0    {'7': {'score': '4-3', 'ult_used': False, 'all...
# 1    {'0': {'score': '0-0', 'ult_used': False, 'all...
# 2    {'0': {'score': '0-0', 'ult_used': False, 'all...
# 3    {'0': {'score': '0-0', 'ult_used': False, 'all...
# 4    {'0': {'score': '0-0', 'ult_used': False, 'all...
# ..                                                 ...
# 529  {'0': {'score': '0-0', 'ally_side': 'attacker'...
# 530  {'0': {'score': '0-0', 'ally_side': 'defender'...
# 531  {'0': {'score': '0-0', 'ally_side': 'unknown',...
# 532  {'0': {'score': '0-0', 'ally_side': 'defender'...
# 533  {'0': {'score': '0-0', 'ally_side': 'defender'...
#
#                                           round_totals ally0_character  \
# 0    {'7': {'elims': 0, 'deaths': 1, 'assists': 0, ...         phoenix
# 1    {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...           kay/o
# 2    {'0': {'elims': 1, 'deaths': 0, 'assists': 0, ...            skye
# 3    {'0': {'elims': 0, 'deaths': 1, 'assists': 1, ...          breach
# 4    {'0': {'elims': 0, 'deaths': 1, 'assists': 1, ...            omen
# ..                                                 ...             ...
# 529  {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...           astra
# 530  {'0': {'elims': 0, 'deaths': 1, 'assists': 1, ...           viper
# 531  {'0': {'elims': 1, 'deaths': 1, 'assists': 0, ...           viper
# 532  {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...            yoru
# 533  {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...            yoru
#
#     ally1_character ally2_character ally3_character ally4_character  \
# 0              jett           gekko          cypher           astra
# 1              yoru            jett         chamber           gekko
# 2              omen         killjoy            jett          breach
# 3         brimstone          cypher            raze            jett
# 4           killjoy            fade            jett            skye
# ..              ...             ...             ...             ...
# 529           kay/o            sova         killjoy            jett
# 530            raze            skye         chamber           astra
# 531            sova         chamber            jett           kay/o
# 532            sage            raze       brimstone            skye
# 533         killjoy            sage           viper          breach
#
#     opponent5_character opponent6_character opponent7_character  \
# 0                harbor               astra                jett
# 1             brimstone             killjoy               gekko
# 2                  sage                raze                skye
# 3                  raze           brimstone              cypher
# 4               killjoy               astra                sova
# ..                  ...                 ...                 ...
# 529                omen             killjoy               reyna
# 530                raze           brimstone               viper
# 531               reyna           brimstone                jett
# 532                jett                skye              cypher
# 533                fade              harbor                yoru
#
#     opponent8_character opponent9_character
# 0               phoenix             killjoy
# 1                  sova                jett
# 2                  omen              cypher
# 3                harbor              breach
# 4                  jett               reyna
# ..                  ...                 ...
# 529               kay/o                jett
# 530             chamber                skye
# 531                sova             chamber
# 532               reyna                omen
# 533             killjoy              breach
#
# [534 rows x 16 columns]

# %%
flat2_df_stats_chars.columns
# Out:
# Index(['user_id', 'map', 'player', 'rounds', 'round_info', 'round_totals',
#        'ally0_character', 'ally1_character', 'ally2_character',
#        'ally3_character', 'ally4_character', 'opponent5_character',
#        'opponent6_character', 'opponent7_character', 'opponent8_character',
#        'opponent9_character'],
#       dtype='object')

# %%
flat2_df_stats_chars['rounds'][0]
# Out:
# {'7': {'alive': {'0': [[0, True], [4800, False]],
#    '1': [[0, True], [53800, False]],
#    '2': [[0, True], [57000, False]],
#    '3': [[0, True], [112400, False]],
#    '4': [[0, True], [112400, False], [124400, True]],
#    '5': [[0, True], [41600, False], [48600, True], [53800, False]],
#    '6': [[0, True], [112400, False]],
#    '7': [[0, True], [57600, False]],
#    '8': [[0, True], [112400, False]],
#    '9': [[0, True], [42400, False]]},
#   'elims': [[42400,
#     {'source': '4',
#      'target': '9',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': True,
#      'team_credit': 'ally'}],
#    [54000,
#     {'source': '6',
#      'target': '1',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'opponent'}],
#    [57600,
#     {'source': '3',
#      'target': '7',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'ally'}]],
#   'health': {'0': [[0, 100], [29600, 0]],
#    '1': [[0, 100], [53800, 0]],
#    '2': [[0, 100],
#     [6200, 96],
#     [6600, 100],
#     [21000, 92],
#     [21800, 100],
#     [24200, 96],
#     [24800, 100],
#     [38200, 96],
#     [39800, 100],
#     [52600, 62],
#     [53200, 58]],
#    '3': [[0, 100],
#     [1000, 96],
#     [21000, 89],
#     [21800, 96],
#     [44200, 89],
#     [44600, 96],
#     [57400, 93],
#     [58000, 89],
#     [59000, 93],
#     [59800, 89],
#     [61600, 96],
#     [62200, 89],
#     [62800, 93],
#     [64000, 96],
#     [66000, 85],
#     [67000, 93],
#     [76000, 96],
#     [76800, 93],
#     [77200, 100],
#     [77800, 93],
#     [80600, 89],
#     [82000, 93]],
#    '4': [[0, 100],
#     [1000, 96],
#     [21000, 93],
#     [21400, 96],
#     [36200, 93],
#     [36600, 96],
#     [37600, 93],
#     [38000, 96],
#     [47400, 100],
#     [47800, 96],
#     [59400, 85],
#     [60000, 96],
#     [61400, 89],
#     [62000, 93],
#     [63000, 96],
#     [64000, 93],
#     [64400, 96],
#     [67000, 93],
#     [67400, 96],
#     [69400, 93],
#     [69800, 96],
#     [76400, 93],
#     [77000, 96],
#     [82800, 100],
#     [83200, 96]]},
#   'phases': [[-25276, 'buy_start'],
#    [4723, 'round_start'],
#    [117802, 'round_scored'],
#    [124802, 'round_end']],
#   'shield': [[0, 0], [1000, 24], [53800, 0]],
#   'credits': [[0, 4800], [112600, 40], [124400, 5100]],
#   'ammo_mag': [[5400, 25], [53600, 23]],
#   'inv_state': [[1000, 'melee'], [23600, 'primary']],
#   'ult_state': {'0': [[0, False]],
#    '1': [[0, False]],
#    '2': [[0, False]],
#    '3': [[0, False]],
#    '4': [[0, True], [47000, False]],
#    '5': [[0, False]],
#    '6': [[0, False]],
#    '7': [[0, True], [5800, False]],
#    '8': [[0, True], [57000, False]],
#    '9': [[0, True]]},
#   'map_region': [[1000, 'Attacker Side Spawn'],
#    [25200, 'Mid Top'],
#    [35800, 'A Art']],
#   'elims_count': [[0, 0, 0]],
#   'inv_primary': [[0, 'none'], [1000, 'vandal'], [52000, 'spectre']],
#   'ammo_reserve': [[5400, 75]],
#   'firing_state': [[0, False], [53600, True], [55800, False]],
#   'assists_count': [[0, 0, 0]],
#   'inv_secondary': [[0, 'classic']],
#   'loadout_value': [[0, 0],
#    [1000, 3284.0],
#    [4800, 3434.0],
#    [44200, 3434.0],
#    [45400, 3284.0],
#    [52000, 1984.0],
#    [53800, 1600.0]],
#   'spike_planted': [[0, False]],
#   'assisted_count': [[0, 0, 0]],
#   'ability_charges_1': [[0, 0]],
#   'ability_charges_2': [[0, 0], [4800, 1], [45400, 0]],
#   'ability_charges_3': [[0, 0], [4800, 1], [44200, 0]],
#   'ability_charges_4': [[0, 0]]},
#  '8': {'alive': {'0': [[125000, True], [162000, False]],
#    '1': [[125000, True]],
#    '2': [[125000, True]],
#    '3': [[125000, True], [197400, False]],
#    '4': [[125000, True], [162000, False]],
#    '5': [[125000, True], [161000, False], [164000, True], [165800, False]],
#    '6': [[125000, True], [198000, False]],
#    '7': [[125000, True], [176600, False]],
#    '8': [[125000, True], [170400, False]],
#    '9': [[125000, True], [159800, False]]},
#   'elims': [[160000,
#     {'source': '4',
#      'target': '9',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': True,
#      'team_credit': 'ally'}],
#    [162000,
#     {'source': '8',
#      'target': '4',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'opponent'}],
#    [164800,
#     {'source': '2',
#      'target': '9',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'ally'}],
#    [176800,
#     {'source': '1',
#      'target': '7',
#      'weapon': 'vandal',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'ally',
#      'weapon_type': 'primary'}],
#    [197600,
#     {'source': '6',
#      'target': '3',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'opponent'}],
#    [198000,
#     {'source': '1',
#      'target': '6',
#      'weapon': 'vandal',
#      'assisted': ['3'],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 2,
#      'first_blood': False,
#      'team_credit': 'ally',
#      'weapon_type': 'primary'}]],
#   'health': {'0': [[125000, 100],
#     [126000, 0],
#     [130199, 11],
#     [130600, 30],
#     [131200, 11],
#     [134800, 0],
#     [135600, 30],
#     [136000, 19],
#     [137200, 0],
#     [138400, 4],
#     [139400, 19],
#     [140400, 22],
#     [141600, 0],
#     [170600, 22],
#     [171600, 19],
#     [176000, 22]],
#    '1': [[125000, 100]],
#    '2': [[125000, 100],
#     [128000, 0],
#     [130199, 100],
#     [131400, 96],
#     [132000, 100],
#     [157200, 96],
#     [159400, 100],
#     [162000, 93],
#     [163400, 96],
#     [170400, 93],
#     [170800, 96],
#     [197000, 89],
#     [197400, 93],
#     [198000, 96],
#     [200600, 93],
#     [201800, 96]],
#    '3': [[125000, 100],
#     [126000, 96],
#     [127800, 0],
#     [130199, 96],
#     [131400, 93],
#     [132000, 96],
#     [156400, 93],
#     [156800, 96],
#     [160000, 89],
#     [160400, 96],
#     [162800, 93],
#     [163200, 96],
#     [177000, 93],
#     [177400, 96],
#     [197000, 33]],
#    '4': [[125000, 100],
#     [126000, 96],
#     [131400, 93],
#     [132000, 96],
#     [157000, 93],
#     [157800, 96],
#     [160600, 93],
#     [161000, 96]]},
#   'phases': [[124802, 'buy_start'],
#    [154802, 'round_start'],
#    [197402, 'round_scored'],
#    [204402, 'round_end']],
#   'shield': [[125000, 0], [129800, 50]],
#   'credits': [[125000, 5100], [125600, 8100], [130199, 3350], [193800, 3650]],
#   'ammo_mag': [[126000, 12],
#    [128400, 25],
#    [175400, 24],
#    [175600, 22],
#    [175800, 20],
#    [176000, 18],
#    [176200, 17],
#    [176600, 15],
#    [176800, 14],
#    [180400, 25],
#    [194200, 23],
#    [194400, 21],
#    [194600, 20],
#    [198000, 18],
#    [198200, 17]],
#   'inv_state': [[126000, 'secondary'],
#    [130400, 'melee'],
#    [156200, 'primary'],
#    [158800, 'melee'],
#    [160600, 'primary'],
#    [195800, 'melee'],
#    [196800, 'primary'],
#    [198400, 'melee']],
#   'ult_state': {'0': [[125000, False], [130199, True]],
#    '1': [[125000, False], [198000, True]],
#    '2': [[125000, False]],
#    '3': [[125000, False], [129600, True]],
#    '4': [[125000, False]],
#    '5': [[125000, False]],
#    '6': [[125000, False], [197400, True]],
#    '7': [[125000, False]],
#    '8': [[125000, False]],
#    '9': [[125000, False], [125400, True]]},
#   'map_region': [[130199, 'Attacker Side Spawn'],
#    [131400, 'Mid Shops'],
#    [134800, 'B Club'],
#    [190800, 'B Link']],
#   'elims_count': [[125200, 0, 0], [176800, 1, 1], [198000, 2, 2]],
#   'inv_primary': [[125000, 'none'],
#    [130800, 'vandal'],
#    [154000, 'spectre'],
#    [155200, 'vandal'],
#    [163200, 'spectre'],
#    [164400, 'vandal'],
#    [168200, 'spectre'],
#    [170600, 'vandal'],
#    [182000, 'spectre'],
#    [184200, 'vandal'],
#    [203400, 'spectre']],
#   'ammo_reserve': [[126000, 36], [128600, 75], [180400, 64]],
#   'firing_state': [[125000, False],
#    [175400, True],
#    [179000, False],
#    [194200, True],
#    [196800, False],
#    [198000, True],
#    [200400, False]],
#   'assists_count': [[125200, 0, 0]],
#   'inv_secondary': [[125000, 'classic'],
#    [142800, 'ghost'],
#    [155800, 'classic'],
#    [158800, 'ghost'],
#    [160600, 'classic'],
#    [202200, 'ghost']],
#   'loadout_value': [[125000, 0],
#    [129800, 1000.0],
#    [130800, 3900.0],
#    [142800, 4400.0],
#    [154000, 3100.0],
#    [155000, 3800.0],
#    [155200, 5100.0],
#    [155800, 4600.0],
#    [158800, 5100.0],
#    [160600, 4600.0],
#    [163200, 3300.0],
#    [164400, 4600.0],
#    [168200, 3300.0],
#    [170600, 4600.0],
#    [181200, 4400.0],
#    [182000, 3100.0],
#    [182400, 3100.0],
#    [184200, 4400.0],
#    [198000, 4400.0],
#    [202200, 4900.0],
#    [203400, 3600.0]],
#   'spike_planted': [[125000, False]],
#   'assisted_count': [[125200, 0, 0], [198000, 1, 1]],
#   'ability_charges_1': [[125000, 0], [155000, 2], [181200, 1]],
#   'ability_charges_2': [[125000, 0], [155000, 2]],
#   'ability_charges_3': [[125000, 0], [155000, 1], [182400, 0]],
#   'ability_charges_4': [[125000, 0], [198000, 1]]},
#  '9': {'alive': {'0': [[204600, True], [254600, False]],
#    '1': [[204600, True]],
#    '2': [[204600, True]],
#    '3': [[204600, True], [286200, False]],
#    '4': [[204600, True], [295400, False]],
#    '5': [[204600, True], [235200, False]],
#    '6': [[204600, True], [261800, False]],
#    '7': [[204600, True], [294400, False]],
#    '8': [[204600, True], [297600, False]],
#    '9': [[204600, True], [251400, False]]},
#   'elims': [[262000,
#     {'source': '1',
#      'target': '6',
#      'weapon': 'vandal',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': True,
#      'team_credit': 'ally',
#      'weapon_type': 'primary'}],
#    [286400,
#     {'source': '8',
#      'target': '3',
#      'assisted': [],
#      'headshot': False,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'opponent'}],
#    [294800,
#     {'source': '4',
#      'target': '7',
#      'assisted': ['1'],
#      'headshot': False,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'ally'}],
#    [295600,
#     {'source': '8',
#      'target': '4',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 2,
#      'first_blood': False,
#      'team_credit': 'opponent'}],
#    [297600,
#     {'source': '1',
#      'target': '8',
#      'weapon': 'vandal',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 2,
#      'first_blood': False,
#      'team_credit': 'ally',
#      'weapon_type': 'primary'}],
#    [301600,
#     {'source': '8',
#      'target': '4',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 3,
#      'first_blood': False,
#      'team_credit': 'opponent'}]],
#   'health': {'0': [[204600, 100],
#     [205600, 0],
#     [216600, 7],
#     [217600, 4],
#     [218400, 0],
#     [231800, 7],
#     [232200, 30],
#     [234000, 0]],
#    '1': [[204600, 100]],
#    '2': [[204600, 100],
#     [239200, 96],
#     [240400, 100],
#     [262400, 96],
#     [263000, 100],
#     [263400, 96],
#     [264000, 100],
#     [274600, 96],
#     [275600, 100],
#     [286200, 96],
#     [291600, 89],
#     [292200, 96],
#     [293200, 70],
#     [294000, 78],
#     [294600, 81],
#     [295000, 85],
#     [297800, 96]],
#    '3': [[204600, 100],
#     [205600, 96],
#     [216000, 0],
#     [216600, 96],
#     [228400, 0],
#     [229000, 96],
#     [264000, 93],
#     [264400, 96]],
#    '4': [[204600, 100],
#     [205600, 96],
#     [213600, 93],
#     [214400, 96],
#     [234600, 100],
#     [235600, 96],
#     [246600, 93],
#     [247000, 96],
#     [272400, 85],
#     [272800, 96],
#     [274400, 93],
#     [275200, 96],
#     [290800, 93],
#     [292000, 96],
#     [293200, 93],
#     [294000, 96]]},
#   'phases': [[204402, 'buy_start'],
#    [234402, 'round_start'],
#    [297570, 'round_scored'],
#    [304570, 'round_end']],
#   'shield': [[204600, 50]],
#   'credits': [[204600, 3650], [205200, 7250], [216000, 7050], [278800, 7350]],
#   'ammo_mag': [[205400, 25],
#    [261800, 23],
#    [271200, 21],
#    [271400, 20],
#    [281600, 18],
#    [282000, 17],
#    [297400, 15],
#    [297600, 13],
#    [297800, 12]],
#   'inv_state': [[205600, 'primary'],
#    [213400, 'melee'],
#    [236000, 'primary'],
#    [237600, 'melee'],
#    [239000, 'primary'],
#    [274800, 'melee'],
#    [277800, 'primary'],
#    [289000, 'melee'],
#    [293400, 'primary'],
#    [294200, 'melee'],
#    [295600, 'primary'],
#    [298000, 'melee']],
#   'ult_state': {'0': [[204600, False], [205000, True]],
#    '1': [[204600, True]],
#    '2': [[204600, False], [278800, True], [303400, False]],
#    '3': [[204600, False], [205000, True], [267600, False]],
#    '4': [[204600, False]],
#    '5': [[204600, False], [210000, True]],
#    '6': [[204600, False], [205000, True]],
#    '7': [[204600, False]],
#    '8': [[204600, False]],
#    '9': [[204600, False], [205000, True]]},
#   'map_region': [[215000, 'Attacker Side Spawn'],
#    [217600, 'B Club'],
#    [293800, 'B Tunnel']],
#   'elims_count': [[204800, 0, 2], [262000, 1, 3], [297600, 2, 4]],
#   'inv_primary': [[204600, 'spectre'],
#    [205600, 'vandal'],
#    [218400, 'spectre'],
#    [219600, 'vandal'],
#    [227200, 'spectre'],
#    [230000, 'vandal'],
#    [240600, 'spectre'],
#    [245200, 'vandal'],
#    [251200, 'spectre'],
#    [253200, 'vandal'],
#    [256000, 'spectre'],
#    [257600, 'vandal'],
#    [278800, 'spectre'],
#    [282200, 'vandal'],
#    [283800, 'spectre'],
#    [284800, 'vandal']],
#   'ammo_reserve': [[205400, 75]],
#   'firing_state': [[204600, False],
#    [261800, True],
#    [264000, False],
#    [271200, True],
#    [273600, False],
#    [281600, True],
#    [284200, False],
#    [297400, True],
#    [300000, False]],
#   'assists_count': [[204800, 0, 0], [294800, 1, 1]],
#   'inv_secondary': [[204600, 'ghost'],
#    [205600, 'classic'],
#    [217400, 'ghost'],
#    [219600, 'classic'],
#    [223000, 'ghost'],
#    [229600, 'classic'],
#    [233800, 'ghost'],
#    [235600, 'classic'],
#    [276400, 'ghost'],
#    [277800, 'classic'],
#    [289600, 'ghost'],
#    [293400, 'classic'],
#    [298000, 'ghost'],
#    [300200, 'classic']],
#   'loadout_value': [[204600, 3600.0],
#    [205600, 4400.0],
#    [217400, 4900.0],
#    [218400, 3600.0],
#    [219600, 4400.0],
#    [223000, 4900.0],
#    [227200, 3600.0],
#    [229600, 3100.0],
#    [230000, 4400.0],
#    [233800, 4900.0],
#    [234600, 5100.0],
#    [235600, 4600.0],
#    [237200, 4400.0],
#    [240600, 3100.0],
#    [245200, 4400.0],
#    [251200, 3100.0],
#    [253200, 4400.0],
#    [256000, 3100.0],
#    [257600, 4400.0],
#    [262200, 4400.0],
#    [272000, 4250.0],
#    [276400, 4750.0],
#    [277800, 4250.0],
#    [278800, 2950.0],
#    [282200, 4250.0],
#    [283800, 2950.0],
#    [284800, 4250.0],
#    [289600, 4750.0],
#    [293400, 4250.0],
#    [298000, 4750.0],
#    [300200, 4250.0]],
#   'spike_planted': [[204600, False], [278800, True], [297600, False]],
#   'assisted_count': [[204800, 0, 1]],
#   'ability_charges_1': [[204600, 1], [234600, 2], [237200, 1]],
#   'ability_charges_2': [[204600, 2], [272000, 1]],
#   'ability_charges_3': [[204600, 0], [234600, 1], [262200, 0]],
#   'ability_charges_4': [[204600, 1]]},
#  '10': {'alive': {'0': [[304600, True],
#     [344800, False],
#     [351600, True],
#     [359600, False]],
#    '1': [[304600, True]],
#    '2': [[304600, True]],
#    '3': [[304600, True], [347600, False]],
#    '4': [[304600, True], [359600, False]],
#    '5': [[304600, True], [339200, False], [348400, True], [360800, False]],
#    '6': [[304600, True], [346400, False]],
#    '7': [[304600, True], [348400, False]],
#    '8': [[304600, True], [341400, False]],
#    '9': [[304600, True], [339200, False]]},
#   'elims': [[339200,
#     {'source': '1',
#      'target': '9',
#      'weapon': 'vandal',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': True,
#      'team_credit': 'ally',
#      'weapon_type': 'primary'}],
#    [341600,
#     {'source': '1',
#      'target': '8',
#      'weapon': 'vandal',
#      'assisted': ['3'],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 2,
#      'first_blood': False,
#      'team_credit': 'ally',
#      'weapon_type': 'primary'}],
#    [346400,
#     {'source': '3',
#      'target': '6',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'ally'}],
#    [347600,
#     {'source': '7',
#      'target': '3',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'opponent'}],
#    [348400,
#     {'source': '1',
#      'target': '7',
#      'weapon': 'vandal',
#      'assisted': ['3'],
#      'headshot': False,
#      'wallbang': False,
#      'elim_number': 3,
#      'first_blood': False,
#      'team_credit': 'ally',
#      'weapon_type': 'primary'}]],
#   'health': {'0': [[304600, 100],
#     [314000, 22],
#     [314600, 30],
#     [320000, 22],
#     [320400, 26],
#     [322400, 19],
#     [324200, 0],
#     [326000, 4],
#     [326600, 7],
#     [328600, 4],
#     [329400, 0],
#     [347600, 15],
#     [353800, 22],
#     [357000, 41],
#     [357600, 22]],
#    '1': [[304600, 100], [346400, 77]],
#    '2': [[304600, 100],
#     [305600, 96],
#     [314000, 100],
#     [332200, 96],
#     [332600, 100],
#     [333000, 96],
#     [333600, 100],
#     [347600, 96],
#     [348000, 93],
#     [348400, 96],
#     [349400, 93],
#     [349800, 96],
#     [361200, 93],
#     [361600, 96],
#     [362400, 93],
#     [362800, 96]],
#    '3': [[304600, 100],
#     [314000, 96],
#     [316000, 93],
#     [316400, 96],
#     [330000, 0],
#     [330800, 96],
#     [342200, 93],
#     [342800, 96],
#     [346400, 85],
#     [347200, 89]],
#    '4': [[304600, 100],
#     [314000, 96],
#     [341400, 93],
#     [342200, 96],
#     [347800, 93],
#     [349000, 96]]},
#   'phases': [[304570, 'buy_start'],
#    [334570, 'round_start'],
#    [362242, 'round_scored'],
#    [369242, 'round_end']],
#   'shield': [[304600, 50], [346600, 4]],
#   'credits': [[304600, 7350], [314000, 9000], [330400, 8650]],
#   'ammo_mag': [[314000, 25],
#    [331400, 2],
#    [336200, 25],
#    [339200, 23],
#    [341200, 22],
#    [341400, 20],
#    [348200, 18],
#    [348400, 16],
#    [349000, 15],
#    [362800, 2]],
#   'inv_state': [[305600, 'melee'],
#    [314000, 'primary'],
#    [328800, 'melee'],
#    [336200, 'primary'],
#    [342000, 'melee'],
#    [346800, 'primary'],
#    [352800, 'melee'],
#    [360000, 'primary'],
#    [363200, 'melee']],
#   'ult_state': {'0': [[304600, False], [314000, True]],
#    '1': [[304600, True]],
#    '2': [[304600, False], [304800, True]],
#    '3': [[304600, False]],
#    '4': [[304600, False], [314000, True]],
#    '5': [[304600, False]],
#    '6': [[304600, False], [314000, True]],
#    '7': [[304600, False]],
#    '8': [[304600, False], [314000, True]],
#    '9': [[304600, False], [314000, True]]},
#   'map_region': [[361200, 'B Hall'], [369000, 'A Link']],
#   'elims_count': [[304800, 0, 4],
#    [339200, 1, 5],
#    [341600, 2, 6],
#    [348400, 3, 7]],
#   'inv_primary': [[304600, 'vandal']],
#   'ammo_reserve': [[314000, 75], [362800, 10]],
#   'firing_state': [[304600, False],
#    [339200, True],
#    [343600, False],
#    [348200, True],
#    [351200, False]],
#   'assists_count': [[304800, 0, 1]],
#   'inv_secondary': [[304600, 'classic'],
#    [333800, 'ghost'],
#    [335000, 'classic'],
#    [343400, 'ghost'],
#    [344600, 'classic']],
#   'loadout_value': [[304600, 4250.0],
#    [333800, 4750.0],
#    [334600, 5100.0],
#    [335000, 4600.0],
#    [337000, 4600.0],
#    [343400, 5100.0],
#    [344600, 4600.0],
#    [346600, 3664.0],
#    [351000, 3464.0]],
#   'spike_planted': [[304600, False]],
#   'assisted_count': [[304800, 0, 1], [341600, 1, 2], [348400, 2, 3]],
#   'ability_charges_1': [[304600, 1], [334600, 2], [351000, 1]],
#   'ability_charges_2': [[304600, 1], [334600, 2]],
#   'ability_charges_3': [[304600, 0], [334600, 1], [337000, 0]],
#   'ability_charges_4': [[304600, 1]]},
#  '11': {'alive': {'0': [[369400, True],
#     [411600, False],
#     [414800, True],
#     [420200, False]],
#    '1': [[369400, True]],
#    '2': [[369400, True], [429400, False]],
#    '3': [[369400, True], [423800, False]],
#    '4': [[369400, True]],
#    '5': [[369400, True],
#     [401000, False],
#     [407000, True],
#     [424000, False],
#     [430600, True],
#     [442600, False]],
#    '6': [[369400, True], [427400, False]],
#    '7': [[369400, True], [421000, False]],
#    '8': [[369400, True], [427400, False]],
#    '9': [[369400, True], [430600, False]]},
#   'elims': [[421200,
#     {'source': '4',
#      'target': '7',
#      'assisted': ['3'],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': True,
#      'team_credit': 'ally'}],
#    [424000,
#     {'source': '6',
#      'target': '3',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'opponent'}],
#    [427600,
#     {'source': '1',
#      'target': '6',
#      'weapon': 'operator',
#      'assisted': [],
#      'headshot': False,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'ally',
#      'weapon_type': 'primary'}],
#    [427600,
#     {'source': '4',
#      'target': '8',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': True,
#      'elim_number': 2,
#      'first_blood': False,
#      'team_credit': 'ally'}],
#    [430800,
#     {'source': '4',
#      'target': '9',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 3,
#      'first_blood': False,
#      'team_credit': 'ally'}]],
#   'health': {'0': [[369400, 100],
#     [372400, 0],
#     [390000, 4],
#     [390400, 22],
#     [391400, 0]],
#    '1': [[369400, 100], [370400, 77], [372400, 100]],
#    '2': [[369400, 100],
#     [370400, 96],
#     [373400, 100],
#     [376400, 96],
#     [376800, 100],
#     [411000, 88],
#     [411400, 100],
#     [423800, 96],
#     [428600, 93],
#     [429000, 96]],
#    '3': [[369400, 100],
#     [372600, 0],
#     [373400, 96],
#     [396800, 0],
#     [397200, 96],
#     [407400, 93],
#     [407800, 96]],
#    '4': [[369400, 100],
#     [373400, 96],
#     [376200, 93],
#     [376800, 96],
#     [398200, 100],
#     [398800, 96],
#     [401600, 93],
#     [402000, 96],
#     [403200, 93],
#     [403600, 96],
#     [408400, 93],
#     [408800, 96],
#     [413400, 93],
#     [414000, 96],
#     [418400, 100],
#     [419200, 96],
#     [420800, 74],
#     [437600, 78],
#     [439800, 74],
#     [443400, 81],
#     [444000, 74]]},
#   'phases': [[369242, 'buy_start'],
#    [399242, 'round_start'],
#    [441998, 'round_scored'],
#    [448998, 'round_end']],
#   'shield': [[369400, 4], [373000, 50]],
#   'credits': [[369400, 8650],
#    [373200, 7800],
#    [397000, 3100],
#    [447400, 100],
#    [448000, 3400]],
#   'ammo_mag': [[372600, 25],
#    [373600, 2],
#    [397200, 5],
#    [421200, 55],
#    [422200, 5],
#    [437600, 4],
#    [442400, 3]],
#   'inv_state': [[370400, 'melee'],
#    [401200, 'primary'],
#    [428000, 'melee'],
#    [436000, 'primary'],
#    [442600, 'melee']],
#   'ult_state': {'0': [[369400, False], [372400, True]],
#    '1': [[369400, True]],
#    '2': [[369400, True], [416400, False]],
#    '3': [[369400, False]],
#    '4': [[369400, False], [372400, True], [408000, False]],
#    '5': [[369400, False]],
#    '6': [[369400, False], [372400, True]],
#    '7': [[369400, False]],
#    '8': [[369400, False], [372400, True]],
#    '9': [[369400, False], [372400, True], [429000, False]]},
#   'map_region': [[371200, 'B Link'], [380000, 'B Club'], [440200, 'B Tower']],
#   'elims_count': [[369600, 0, 7], [427600, 1, 8]],
#   'inv_primary': [[369400, 'vandal'], [400000, 'operator']],
#   'ammo_reserve': [[401200, 10]],
#   'firing_state': [[369400, False],
#    [437600, True],
#    [439800, False],
#    [442400, True],
#    [444600, False]],
#   'assists_count': [[369600, 0, 1]],
#   'inv_secondary': [[369400, 'classic'],
#    [394000, 'ghost'],
#    [400000, 'classic'],
#    [433600, 'ghost'],
#    [436200, 'classic'],
#    [438000, 'shorty'],
#    [440800, 'classic']],
#   'loadout_value': [[369400, 3464.0],
#    [373000, 4400.0],
#    [394000, 4900.0],
#    [399400, 5100.0],
#    [400000, 6400.0],
#    [424800, 6400.0],
#    [431200, 6250.0],
#    [433600, 6750.0],
#    [436200, 6250.0],
#    [438000, 6400.0],
#    [440800, 6250.0]],
#   'spike_planted': [[369400, False]],
#   'assisted_count': [[369600, 0, 3]],
#   'ability_charges_1': [[369400, 1], [399400, 2]],
#   'ability_charges_2': [[369400, 2], [431200, 1]],
#   'ability_charges_3': [[369400, 0], [399400, 1], [424800, 0]],
#   'ability_charges_4': [[369400, 1]]},
#  '12': {'alive': {'0': [[449000, True], [494000, False]],
#    '1': [[449000, True], [512799, False]],
#    '2': [[449000, True]],
#    '3': [[449000, True]],
#    '4': [[449000, True]],
#    '5': [[449000, True], [519200, False], [525600, True], [535600, False]],
#    '6': [[449000, True], [536800, False]],
#    '7': [[449000, True], [535600, False]],
#    '8': [[449000, True], [546400, False]],
#    '9': [[449000, True], [543000, False]]},
#   'elims': [[512799,
#     {'source': '7',
#      'target': '1',
#      'assisted': [],
#      'headshot': False,
#      'wallbang': True,
#      'elim_number': 1,
#      'first_blood': True,
#      'team_credit': 'opponent'}],
#    [536000,
#     {'source': '4',
#      'target': '7',
#      'assisted': [],
#      'headshot': False,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'ally'}],
#    [537200,
#     {'source': '2',
#      'target': '6',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'ally'}],
#    [543200,
#     {'source': '3',
#      'target': '9',
#      'assisted': [],
#      'headshot': False,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'ally'}],
#    [546400,
#     {'source': '3',
#      'target': '8',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 2,
#      'first_blood': False,
#      'team_credit': 'ally'}],
#    [552400,
#     {'source': '3',
#      'target': '8',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 3,
#      'first_blood': False,
#      'team_credit': 'ally'}]],
#   'health': {'0': [[449000, 100]],
#    '1': [[449000, 100], [502000, 50], [512400, 18], [512799, 0]],
#    '2': [[449000, 100],
#     [471400, 92],
#     [471800, 100],
#     [472400, 96],
#     [472800, 100],
#     [512000, 96],
#     [512799, 100],
#     [514400, 96],
#     [514799, 100],
#     [520000, 96],
#     [521400, 100],
#     [533600, 96],
#     [534000, 100],
#     [539600, 96],
#     [540000, 100],
#     [543200, 96],
#     [544000, 100],
#     [550200, 96],
#     [550600, 100]],
#    '3': [[449000, 100],
#     [450000, 96],
#     [472200, 93],
#     [472600, 96],
#     [508200, 93],
#     [509000, 96],
#     [512400, 93],
#     [512799, 96],
#     [513200, 93],
#     [513600, 96],
#     [519400, 93],
#     [520400, 96],
#     [539600, 89],
#     [541000, 96],
#     [542000, 56],
#     [544800, 22],
#     [545600, 30],
#     [546200, 19],
#     [546800, 22],
#     [549600, 26],
#     [551200, 33],
#     [552800, 30],
#     [554000, 33],
#     [554400, 22],
#     [555000, 30],
#     [556800, 15],
#     [558000, 30],
#     [558400, 15],
#     [558800, 19],
#     [560000, 30],
#     [561200, 22]],
#    '4': [[449000, 100],
#     [450000, 96],
#     [513000, 93],
#     [513799, 96],
#     [519600, 93],
#     [520000, 96],
#     [520600, 93],
#     [521200, 96],
#     [529400, 93],
#     [529800, 96],
#     [540600, 93],
#     [541000, 96],
#     [550000, 93],
#     [551200, 96]]},
#   'phases': [[448998, 'buy_start'],
#    [493998, 'round_start'],
#    [554796, 'round_scored'],
#    [561796, 'round_end']],
#   'shield': [[449000, 0]],
#   'credits': [[449000, 3400], [450000, 800], [452000, 0]],
#   'ammo_mag': [[450200, 12],
#    [452600, 6],
#    [476000, 9],
#    [476400, 6],
#    [498800, 5],
#    [499400, 4],
#    [501800, 3],
#    [503600, 33],
#    [503800, 3],
#    [506200, 6],
#    [510200, 50],
#    [510400, 6]],
#   'inv_state': [[452000, 'secondary'],
#    [453400, 'melee'],
#    [474400, 'secondary']],
#   'ult_state': {'0': [[449000, False], [539200, True]],
#    '1': [[449000, False]],
#    '2': [[449000, False]],
#    '3': [[449000, False]],
#    '4': [[449000, False]],
#    '5': [[449000, False]],
#    '6': [[449000, False]],
#    '7': [[449000, False]],
#    '8': [[449000, False]],
#    '9': [[449000, False]]},
#   'map_region': [[452000, 'Defender Side Spawn'],
#    [458200, 'B Tunnel'],
#    [475400, 'B Hall']],
#   'elims_count': [[449200, 0, 8]],
#   'inv_primary': [[449000, 'none']],
#   'ammo_reserve': [[450200, 36], [452000, 24], [504800, 21]],
#   'firing_state': [[449000, False],
#    [476400, True],
#    [478600, False],
#    [498800, True],
#    [501600, False],
#    [501800, True],
#    [504000, False]],
#   'assists_count': [[449200, 0, 1]],
#   'inv_secondary': [[449000, 'classic'], [452000, 'sheriff']],
#   'loadout_value': [[449000, 0],
#    [452000, 800.0],
#    [494000, 800.0],
#    [500800, 800.0]],
#   'spike_planted': [[449000, False], [530000, True], [556000, False]],
#   'assisted_count': [[449200, 0, 3]],
#   'ability_charges_1': [[449000, 0]],
#   'ability_charges_2': [[449000, 0]],
#   'ability_charges_3': [[449000, 0], [494000, 1], [500800, 0]],
#   'ability_charges_4': [[449000, 0]]},
#  '13': {'alive': {'0': [[561800, True], [591800, False]],
#    '1': [[561800, True]],
#    '2': [[561800, True]],
#    '3': [[561800, True], [609800, False]],
#    '4': [[561800, True]],
#    '5': [[561800, True], [603200, False]],
#    '6': [[561800, True], [611400, False]],
#    '7': [[561800, True], [603200, False]],
#    '8': [[561800, True], [616200, False]],
#    '9': [[561800, True], [608800, False]]},
#   'elims': [[609200,
#     {'source': '4',
#      'target': '9',
#      'assisted': ['3'],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': True,
#      'team_credit': 'ally'}],
#    [610000,
#     {'source': '8',
#      'target': '3',
#      'assisted': [],
#      'headshot': False,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'opponent'}],
#    [611600,
#     {'source': '4',
#      'target': '6',
#      'assisted': [],
#      'headshot': False,
#      'wallbang': False,
#      'elim_number': 2,
#      'first_blood': False,
#      'team_credit': 'ally'}]],
#   'health': {'0': [[561800, 100], [563800, 0]],
#    '1': [[561800, 100]],
#    '2': [[561800, 100],
#     [565800, 96],
#     [566800, 100],
#     [567200, 96],
#     [570000, 100],
#     [579600, 92],
#     [580000, 100],
#     [597000, 96],
#     [597600, 100],
#     [598800, 96],
#     [599400, 100],
#     [609800, 96],
#     [617600, 93],
#     [618400, 96]],
#    '3': [[561800, 100],
#     [562800, 0],
#     [566000, 93],
#     [566800, 96],
#     [567200, 93],
#     [568000, 89],
#     [569200, 93],
#     [569800, 96],
#     [576200, 100],
#     [577000, 96],
#     [579600, 93],
#     [580400, 0],
#     [581200, 96],
#     [582600, 93],
#     [583000, 96]],
#    '4': [[561800, 100],
#     [566000, 96],
#     [568600, 89],
#     [570000, 96],
#     [572200, 89],
#     [572600, 96],
#     [575400, 93],
#     [575800, 96],
#     [583000, 93],
#     [583400, 96],
#     [588600, 93],
#     [589000, 96],
#     [601800, 93],
#     [602200, 96],
#     [606200, 93],
#     [606800, 96],
#     [614600, 81],
#     [619600, 78],
#     [620000, 81],
#     [621600, 78]]},
#   'phases': [[561796, 'buy_start'],
#    [591796, 'round_start'],
#    [615600, 'round_scored'],
#    [622600, 'round_end']],
#   'shield': [[561800, 0], [563600, 25]],
#   'credits': [[561800, 0], [563800, 2400], [565000, 150], [581200, 0]],
#   'ammo_mag': [[565000, 12],
#    [614000, 11],
#    [614200, 10],
#    [614400, 9],
#    [616400, 8],
#    [616600, 7]],
#   'inv_state': [[566000, 'melee'],
#    [582400, 'primary'],
#    [597000, 'melee'],
#    [612000, 'primary'],
#    [618400, 'melee']],
#   'ult_state': {'0': [[561800, False]],
#    '1': [[561800, False]],
#    '2': [[561800, False]],
#    '3': [[561800, False]],
#    '4': [[561800, False]],
#    '5': [[561800, False]],
#    '6': [[561800, False]],
#    '7': [[561800, False]],
#    '8': [[561800, False]],
#    '9': [[561800, False]]},
#   'map_region': [[569800, 'B Tunnel'],
#    [587400, 'B Screen'],
#    [601000, 'B Tunnel'],
#    [609000, 'Defender Side Spawn']],
#   'elims_count': [[562000, 0, 8]],
#   'inv_primary': [[561800, 'none'], [566000, 'guardian']],
#   'ammo_reserve': [[565200, 36]],
#   'firing_state': [[561800, False], [614000, True], [618800, False]],
#   'assists_count': [[562000, 0, 1]],
#   'inv_secondary': [[561800, 'classic']],
#   'loadout_value': [[561800, 0],
#    [563600, 400.0],
#    [566000, 400.0],
#    [591800, 600.0],
#    [613000, 600.0]],
#   'spike_planted': [[561800, False]],
#   'assisted_count': [[562000, 0, 3]],
#   'ability_charges_1': [[561800, 0], [591800, 1]],
#   'ability_charges_2': [[561800, 0]],
#   'ability_charges_3': [[561800, 0], [591800, 1], [613000, 0]],
#   'ability_charges_4': [[561800, 0]]},
#  '14': {'alive': {'0': [[622800, True], [652800, False]],
#    '1': [[622800, True], [699600, False]],
#    '2': [[622800, True]],
#    '3': [[622800, True], [707200, False]],
#    '4': [[622800, True]],
#    '5': [[622800, True], [665000, False]],
#    '6': [[622800, True], [680600, False]],
#    '7': [[622800, True], [678800, False]],
#    '8': [[622800, True], [710200, False]],
#    '9': [[622800, True], [664600, False]]},
#   'elims': [[664800,
#     {'source': '4',
#      'target': '9',
#      'assisted': ['3'],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': True,
#      'team_credit': 'ally'}],
#    [678800,
#     {'source': '3',
#      'target': '7',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': True,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'ally'}],
#    [680800,
#     {'source': '4',
#      'target': '6',
#      'assisted': ['3'],
#      'headshot': False,
#      'wallbang': False,
#      'elim_number': 2,
#      'first_blood': False,
#      'team_credit': 'ally'}],
#    [700000,
#     {'source': '8',
#      'target': '1',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': True,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'opponent'}],
#    [707600,
#     {'source': '8',
#      'target': '3',
#      'assisted': ['7'],
#      'headshot': False,
#      'wallbang': False,
#      'elim_number': 2,
#      'first_blood': False,
#      'team_credit': 'opponent'}],
#    [710400,
#     {'source': '2',
#      'target': '8',
#      'assisted': ['0', '4'],
#      'headshot': False,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'ally'}]],
#   'health': {'0': [[622800, 100], [624000, 0], [676800, 4], [682000, 0]],
#    '1': [[622800, 100], [699600, 0]],
#    '2': [[622800, 100],
#     [625400, 96],
#     [625800, 100],
#     [634400, 96],
#     [636000, 100],
#     [637400, 96],
#     [637800, 100],
#     [659600, 96],
#     [660200, 100],
#     [670200, 96],
#     [670600, 100],
#     [677200, 96],
#     [677800, 100],
#     [681600, 96],
#     [682000, 100],
#     [683000, 96],
#     [683400, 100],
#     [707200, 96],
#     [709400, 93],
#     [709800, 96]],
#    '3': [[622800, 100],
#     [624000, 0],
#     [625000, 96],
#     [625400, 93],
#     [627000, 96],
#     [634000, 89],
#     [635400, 93],
#     [636000, 96],
#     [637400, 93],
#     [638800, 96],
#     [660000, 89],
#     [660400, 96],
#     [679200, 59],
#     [680800, 15],
#     [681400, 26],
#     [682000, 44],
#     [682400, 37],
#     [684000, 44],
#     [686400, 41],
#     [688000, 0],
#     [688800, 37],
#     [690000, 44],
#     [690800, 22],
#     [692800, 48],
#     [695000, 33],
#     [695400, 37],
#     [697800, 44],
#     [699200, 15],
#     [699600, 44],
#     [701200, 37],
#     [702000, 52],
#     [704000, 0],
#     [704800, 41],
#     [705800, 44]],
#    '4': [[622800, 100],
#     [625000, 96],
#     [627200, 93],
#     [628000, 96],
#     [637400, 93],
#     [638000, 96],
#     [644200, 93],
#     [644600, 96],
#     [648000, 93],
#     [648800, 96],
#     [666800, 93],
#     [667200, 96],
#     [674200, 89],
#     [680800, 15],
#     [681800, 30],
#     [683200, 15],
#     [683600, 26],
#     [684000, 30],
#     [686600, 22],
#     [687400, 30],
#     [688200, 19],
#     [689600, 11],
#     [690800, 30],
#     [691200, 26],
#     [691600, 30],
#     [692800, 26],
#     [694400, 30],
#     [695400, 22],
#     [695800, 26],
#     [697000, 22],
#     [697600, 30],
#     [698000, 22],
#     [699800, 30],
#     [702000, 37],
#     [702400, 30],
#     [703400, 26],
#     [703800, 30],
#     [704800, 22],
#     [707200, 30],
#     [709000, 22],
#     [711000, 33],
#     [711400, 30],
#     [715000, 22],
#     [715400, 26],
#     [716200, 30]]},
#   'phases': [[622600, 'buy_start'],
#    [652600, 'round_start'],
#    [709800, 'round_scored'],
#    [716800, 'round_end']],
#   'shield': [[622800, 25], [626800, 50], [699400, 0]],
#   'credits': [[622800, 0], [624600, 2700], [626800, 1700]],
#   'ammo_mag': [[623600, 12], [687800, 11]],
#   'inv_state': [[625000, 'melee'],
#    [649600, 'primary'],
#    [662800, 'melee'],
#    [677000, 'primary'],
#    [682400, 'melee'],
#    [686800, 'primary'],
#    [688000, 'melee'],
#    [689400, 'primary']],
#   'ult_state': {'0': [[622800, False]],
#    '1': [[622800, False]],
#    '2': [[622800, False]],
#    '3': [[622800, False], [678800, True]],
#    '4': [[622800, False]],
#    '5': [[622800, False]],
#    '6': [[622800, False]],
#    '7': [[622800, False]],
#    '8': [[622800, False], [700600, True]],
#    '9': [[622800, False]]},
#   'map_region': [[625000, 'Defender Side Spawn'],
#    [627800, 'Defender Side Water'],
#    [642600, 'B Screen'],
#    [665000, 'B Tunnel'],
#    [672400, 'Defender Side Spawn']],
#   'elims_count': [[622800, 0, 8]],
#   'inv_primary': [[622800, 'guardian']],
#   'ammo_reserve': [[623200, 36]],
#   'firing_state': [[622800, False], [687800, True], [690000, False]],
#   'assists_count': [[622800, 0, 1]],
#   'inv_secondary': [[622800, 'classic']],
#   'loadout_value': [[622800, 600.0],
#    [626800, 1200.0],
#    [652800, 1550.0],
#    [656800, 1550.0],
#    [699200, 1400.0],
#    [699400, 400.0]],
#   'spike_planted': [[622800, False]],
#   'assisted_count': [[622800, 0, 3]],
#   'ability_charges_1': [[622800, 1], [652800, 2]],
#   'ability_charges_2': [[622800, 0], [652800, 1], [699200, 0]],
#   'ability_charges_3': [[622800, 0], [652800, 1], [656800, 0]],
#   'ability_charges_4': [[622800, 0]]},
#  '15': {'alive': {'0': [[717000, True], [747000, False]],
#    '1': [[717000, True], [819000, False]],
#    '2': [[717000, True], [756600, False]],
#    '3': [[717000, True], [794200, False]],
#    '4': [[717000, True]],
#    '5': [[717000, True], [752000, False]],
#    '6': [[717000, True], [808400, False]],
#    '7': [[717000, True], [756200, False]],
#    '8': [[717000, True], [819200, False]],
#    '9': [[717000, True], [800000, False]]},
#   'elims': [[756400,
#     {'source': '2',
#      'target': '7',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': True,
#      'team_credit': 'ally'}],
#    [756800,
#     {'source': '9',
#      'target': '2',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'opponent'}],
#    [794400,
#     {'source': '6',
#      'target': '3',
#      'assisted': [],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'opponent'}],
#    [817600,
#     {'source': '1',
#      'target': '8',
#      'weapon': 'vandal',
#      'assisted': [],
#      'headshot': False,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'ally',
#      'weapon_type': 'primary'}],
#    [819600,
#     {'source': '4',
#      'target': '8',
#      'assisted': ['1'],
#      'headshot': True,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'ally'}],
#    [822400,
#     {'source': '3',
#      'target': '6',
#      'assisted': [],
#      'headshot': False,
#      'wallbang': False,
#      'elim_number': 1,
#      'first_blood': False,
#      'team_credit': 'ally'}]],
#   'health': {'0': [[717000, 100], [723800, 0]],
#    '1': [[717000, 100], [816800, 87], [817400, 30], [819000, 0]],
#    '2': [[717000, 100],
#     [718000, 96],
#     [722600, 100],
#     [727400, 96],
#     [728000, 100],
#     [739000, 88],
#     [739400, 92],
#     [740000, 100],
#     [744200, 96],
#     [745200, 100]],
#    '3': [[717000, 100],
#     [722600, 96],
#     [723000, 0],
#     [725600, 96],
#     [726400, 89],
#     [727200, 96],
#     [739000, 85],
#     [739600, 96],
#     [740000, 93],
#     [742000, 96],
#     [744600, 93],
#     [745600, 96],
#     [752000, 93],
#     [753600, 96],
#     [758000, 93],
#     [758400, 96]],
#    '4': [[717000, 100],
#     [718000, 30],
#     [722000, 33],
#     [722600, 96],
#     [736800, 93],
#     [738000, 96],
#     [739000, 93],
#     [739600, 89],
#     [740000, 96],
#     [762400, 93],
#     [762800, 96],
#     [763200, 100],
#     [763600, 96],
#     [802400, 93],
#     [803000, 96],
#     [813000, 89],
#     [813600, 96],
#     [827000, 93],
#     [827400, 96]]},
#   'phases': [[716800, 'buy_start'],
#    [746800, 'round_start'],
#    [837400, 'round_scored'],
#    [844400, 'round_end']],
#   'shield': [[717000, 0],
#    [718000, 25],
#    [725400, 50],
#    [816800, 24],
#    [817400, 0]],
#   'credits': [[717000, 1700], [723400, 4300], [725400, 650]],
#   'ammo_mag': [[717000, 25],
#    [722600, 12],
#    [725000, 25],
#    [751200, 24],
#    [758800, 23],
#    [759000, 22],
#    [759200, 21],
#    [759400, 20],
#    [760400, 18],
#    [764800, 25],
#    [817000, 24],
#    [817200, 23],
#    [817400, 22],
#    [817600, 20]],
#   'inv_state': [[718000, 'primary'],
#    [725600, 'melee'],
#    [744000, 'primary'],
#    [760800, 'melee'],
#    [762200, 'primary'],
#    [780400, 'melee'],
#    [800200, 'primary']],
#   'ult_state': {'0': [[717000, False]],
#    '1': [[717000, False]],
#    '2': [[717000, False]],
#    '3': [[717000, False], [725600, True]],
#    '4': [[717000, False], [827600, True]],
#    '5': [[717000, False]],
#    '6': [[717000, False]],
#    '7': [[717000, False]],
#    '8': [[717000, False], [722600, True], [815800, False]],
#    '9': [[717000, False]]},
#   'map_region': [[718000, 'Mid Connector'],
#    [728400, 'Defender Side Spawn'],
#    [729800, 'B Tunnel'],
#    [768200, 'B Hall'],
#    [809800, 'Defender Side Spawn']],
#   'elims_count': [[717200, 0, 8], [817600, 1, 9]],
#   'inv_primary': [[717000, 'none'], [718000, 'vandal']],
#   'ammo_reserve': [[717000, 66], [722600, 36], [725000, 75], [764800, 68]],
#   'firing_state': [[717000, False],
#    [751200, True],
#    [753400, False],
#    [758800, True],
#    [762600, False],
#    [817000, True],
#    [819800, False]],
#   'assists_count': [[717200, 0, 1], [819600, 1, 2]],
#   'inv_secondary': [[717000, 'classic'],
#    [718000, 'ghost'],
#    [725600, 'classic']],
#   'loadout_value': [[717000, 0],
#    [718000, 4200.0],
#    [725400, 4800.0],
#    [725600, 4300.0],
#    [747000, 4450.0],
#    [751400, 4450.0],
#    [806200, 4250.0],
#    [816800, 3634.0],
#    [817400, 3250.0]],
#   'spike_planted': [[717000, False], [801600, True], [837400, False]],
#   'assisted_count': [[717200, 0, 3]],
#   'ability_charges_1': [[717000, 2], [806200, 1]],
#   'ability_charges_2': [[717000, 0], [747000, 1]],
#   'ability_charges_3': [[717000, 0], [747000, 1], [751400, 0]],
#   'ability_charges_4': [[717000, 0]]}}

# %%
flat2_df_stats_chars.shape
# Out:
# (534, 16)

# %% [markdown]
# ### Flattening the round_info/round_totals cols by 1 level
# - This is where the DF expands into rounds being the rows instead of matches being the rows
# - Have to parse the round info/round totals at the same time

# %%
# Initialize an empty dictionary to store map names and unique areas
map_areas = {}
for index, row in flat2_df_stats_chars.iterrows():
    # for all the rounds in each match
    for round_number, round_data in row['round_info'].items():
        # get the current/original row.
        new_row = row.to_dict()
        # exclude the original complex columns that we're flattening
        new_row.pop('rounds', None)
        new_row.pop('round_info', None)
        
        # get current map
        cur_map = new_row['map']

        # Initialize a new set for this map if it doesn't exist in map_areas
        if cur_map not in map_areas:
            map_areas[cur_map] = set()
            
        # Add round number to the new row
        new_row['round_number'] = round_number

        # Flatten rounds data into the new row
        for key, value in row['rounds'][round_number].items():
            if key == 'map_region':
                # value should be a list of lists where each sublist's second element is an area
                for sublist in value:
                    # Add the area to the set corresponding to the current map
                    map_areas[cur_map].add(sublist[1])

map_areas
# Out:
# {'Pearl': {'A Art',
#   'A Dugout',
#   'A Flowers',
#   'A Link',
#   'A Main',
#   'A Restaurant',
#   'A Secret',
#   'A Site',
#   'Attacker Side Spawn',
#   'B Club',
#   'B Hall',
#   'B Link',
#   'B Main',
#   'B Ramp',
#   'B Screen',
#   'B Site',
#   'B Tower',
#   'B Tunnel',
#   'Defender Side Records',
#   'Defender Side Spawn',
#   'Defender Side Water',
#   'Mid Connector',
#   'Mid Doors',
#   'Mid Plaza',
#   'Mid Shops',
#   'Mid Top'},
#  'Haven': {'A Garden',
#   'A Link',
#   'A Lobby',
#   'A Long',
#   'A Short',
#   'A Site',
#   'A Tower',
#   'Attacker Side Spawn',
#   'B Back',
#   'B Site',
#   'C Cubby',
#   'C Link',
#   'C Lobby',
#   'C Long',
#   'C Site',
#   'C Window',
#   'Defender Side Spawn',
#   'Mid Courtyard',
#   'Mid Doors',
#   'Mid Window'},
#  'Split': {'A Back',
#   'A Lobby',
#   'A Main',
#   'A Rafters',
#   'A Ramps',
#   'A Screens',
#   'A Sewer',
#   'A Site',
#   'A Tower',
#   'Attacker Side Spawn',
#   'B Alley',
#   'B Back',
#   'B Link',
#   'B Lobby',
#   'B Main',
#   'B Rafters',
#   'B Site',
#   'B Stairs',
#   'B Tower',
#   'Defender Side Spawn',
#   'Mid Bottom',
#   'Mid Mail',
#   'Mid Top',
#   'Mid Vent'},
#  'Fracture': {'A Dish',
#   'A Door',
#   'A Drop',
#   'A Gate',
#   'A Hall',
#   'A Link',
#   'A Main',
#   'A Rope',
#   'A Site',
#   'Attacker Side Bridge',
#   'Attacker Side Spawn',
#   'B Arcade',
#   'B Bench',
#   'B Canteen',
#   'B Generator',
#   'B Link',
#   'B Main',
#   'B Site',
#   'B Tower',
#   'B Tree',
#   'B Tunnel',
#   'Defender Side Spawn'},
#  'Ascent': {'A Garden',
#   'A Link',
#   'A Lobby',
#   'A Main',
#   'A Rafters',
#   'A Site',
#   'A Window',
#   'Attacker Side Spawn',
#   'B Back',
#   'B Lobby',
#   'B Main',
#   'B Site',
#   'Defender Side Spawn',
#   'Mid Bottom',
#   'Mid Catwalk',
#   'Mid Courtyard',
#   'Mid Cubby',
#   'Mid Link',
#   'Mid Market',
#   'Mid Pizza',
#   'Mid Top'},
#  'Lotus': {'A Door',
#   'A Drop',
#   'A Hut',
#   'A Link',
#   'A Lobby',
#   'A Main',
#   'A Root',
#   'A Rubble',
#   'A Site',
#   'A Stairs',
#   'A Top',
#   'A Tree',
#   'Attacker Side Spawn',
#   'B Main',
#   'B Pillars',
#   'B Site',
#   'B Upper',
#   'C Bend',
#   'C Door',
#   'C Gravel',
#   'C Hall',
#   'C Link',
#   'C Lobby',
#   'C Main',
#   'C Mound',
#   'C Site',
#   'C Waterfall',
#   'Defender Side Spawn'},
#  'Icebox': {'A Belt',
#   'A Nest',
#   'A Pipes',
#   'A Rafters',
#   'A Screen',
#   'A Site',
#   'Attacker Side Spawn',
#   'B Back',
#   'B Cubby',
#   'B Garage',
#   'B Green',
#   'B Hall',
#   'B Hut',
#   'B Kitchen',
#   'B Orange',
#   'B Site',
#   'B Snow Pile',
#   'B Snowman',
#   'B Tube',
#   'B Yellow',
#   'Defender Side Spawn',
#   'Mid Blue',
#   'Mid Boiler',
#   'Mid Pallet'},
#  'unknown': {''},
#  'Breeze': {'A Bridge',
#   'A Cave',
#   'A Hall',
#   'A Lobby',
#   'A Metal Doors',
#   'A Pyramids',
#   'A Rope',
#   'A Shop',
#   'A Site',
#   'A Switch',
#   'Attacker Side Snake',
#   'Attacker Side Spawn',
#   'B Back',
#   'B Elbow',
#   'B Main',
#   'B Site',
#   'B Tunnel',
#   'B Wall',
#   'B Window',
#   'Defender Side Arches',
#   'Defender Side Spawn',
#   'Mid Bottom',
#   'Mid Cannon',
#   'Mid Chute',
#   'Mid Nest',
#   'Mid Pillar',
#   'Mid Stack',
#   'Mid Top',
#   'Mid Wood Doors'},
#  'Bind': {'A Bath',
#   'A Cubby',
#   'A Exit',
#   'A Lamps',
#   'A Link',
#   'A Lobby',
#   'A Short',
#   'A Site',
#   'A Teleporter',
#   'A Tower',
#   'Attacker Side Cave',
#   'Attacker Side Spawn',
#   'B Exit',
#   'B Garden',
#   'B Hall',
#   'B Link',
#   'B Short',
#   'B Teleporter',
#   'B Window',
#   'Defender Side Spawn'}}

# %%
flat2_df_stats_chars.shape
# Out:
# (534, 16)

# %%
flat2_df_stats_chars.head(10).shape
# Out:
# (10, 16)

# %%
flat2_df_stats_chars.iloc[10:20]
# Out:
#     user_id      map player  \
# 10     1011    Split      1
# 11     1011    Lotus      3
# 12     1011   Icebox      3
# 13     1011    Haven      3
# 14     1011    Pearl      2
# 15     1011   Icebox      3
# 16     1013  unknown      0
# 17     1013  unknown      2
# 18     1013  unknown      1
# 19     1013  unknown      1
#
#                                                rounds  \
# 10  {'0': {'alive': {'0': [[110599, True], [166999...
# 11  {'0': {'alive': {'0': [[107199, True], [189399...
# 12  {'0': {'alive': {'0': [[0, True], [48399, Fals...
# 13  {'0': {'alive': {'0': [[107199, True], [153799...
# 14  {'0': {'alive': {'0': [[112799, True], [170999...
# 15  {'0': {'alive': {'0': [[482199, True], [527199...
# 16  {'21': {'alive': {'0': [[199200, True], [22920...
# 17  {'12': {'alive': {'0': [[57400, True], [102400...
# 18  {'7': {'alive': {'0': [[67600, True]], '1': [[...
# 19                                                 {}
#
#                                            round_info  \
# 10  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 11  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 12  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 13  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 14  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 15  {'0': {'score': '0-0', 'ult_used': False, 'all...
# 16  {'21': {'score': '11-10', 'ult_used': False, '...
# 17  {'12': {'score': '6-6', 'ult_used': False, 'al...
# 18  {'7': {'score': '2-5', 'ult_used': False, 'all...
# 19                                                 {}
#
#                                          round_totals ally0_character  \
# 10  {'0': {'elims': 0, 'deaths': 1, 'assists': 1, ...            raze
# 11  {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...            yoru
# 12  {'0': {'elims': 0, 'deaths': 1, 'assists': 0, ...            sage
# 13  {'0': {'elims': 2, 'deaths': 1, 'assists': 0, ...           kay/o
# 14  {'0': {'elims': 1, 'deaths': 1, 'assists': 0, ...            skye
# 15  {'0': {'elims': 1, 'deaths': 1, 'assists': 0, ...            skye
# 16  {'21': {'elims': 0, 'deaths': 0, 'assists': 0,...            raze
# 17  {'12': {'elims': 2, 'deaths': 1, 'assists': 0,...            jett
# 18  {'7': {'elims': 0, 'deaths': 0, 'assists': 0, ...            jett
# 19                                                 {}            jett
#
#    ally1_character ally2_character ally3_character ally4_character  \
# 10         killjoy           astra            sage            skye
# 11            raze          breach         killjoy            omen
# 12            jett            sova         killjoy           viper
# 13            omen            jett          breach          cypher
# 14            sova           viper         phoenix            sage
# 15           viper            jett         killjoy            sova
# 16            jett          cypher            sova           kay/o
# 17           kay/o       brimstone            raze           viper
# 18            raze           kay/o       brimstone           viper
# 19            raze           kay/o            skye       brimstone
#
#    opponent5_character opponent6_character opponent7_character  \
# 10                raze                sage               astra
# 11                omen             killjoy                jett
# 12              harbor                sova               viper
# 13                jett              cypher                fade
# 14               astra                fade              cypher
# 15                jett               viper               reyna
# 16                raze               kay/o              cypher
# 17                jett               kay/o                skye
# 18                jett                raze                skye
# 19                jett                raze               kay/o
#
#    opponent8_character opponent9_character
# 10              cypher                skye
# 11              breach                yoru
# 12             killjoy                jett
# 13              breach                omen
# 14                neon                jett
# 15                sova             killjoy
# 16                jett               viper
# 17                raze               viper
# 18               kay/o               viper
# 19              cypher                skye

# %%
def split_list_based_on_time(lst, spike_time):
    before_spike = [entry for entry in lst if entry[0] <= spike_time]
    after_spike = [entry for entry in lst if entry[0] > spike_time]
    return before_spike, after_spike

# %%
new_rows = []

# for all the matches in flat2_df_stats_chars...
for index, row in flat2_df_stats_chars.iterrows():
# for i in range(1):
    # for all the rounds in each match
    for round_number, round_data in row['round_info'].items():
        # get the current/original row.
        new_row = row.to_dict()
        
        # get current map
        cur_map = new_row['map']
        
        # get current player
        cur_player = new_row['player']
        
        # Add round number to the new row
        new_row['round_number'] = round_number
        
        # Flatten round_info data into the new row
        for key, value in round_data.items():
            new_row[f'round_info_{key}'] = value
            
        # get side
        side = new_row['round_info_ally_side']
        
        # get won 
        won = new_row['round_info_round_won']
        
        # Flatten rounds data into the new row
        for key, value in row['rounds'][round_number].items():
            
            ## UNIQUE ##
            if key == 'spike_planted':
                rounds_spike_planted = value
                print(value)

                # Initialize default values
                spike_yn = False
                time = value[0][0]

                # Iterate over the list to find the first instance of spike planted
                for item in value:
                    if item[1]:  # Check if spike was planted
                        spike_yn = item[1]
                        time = item[0]
                        break  # Stop iterating after finding the first instance

                new_row['spike_planted'] = spike_yn
                new_row['spike_time'] = time                

            if key == 'map_region':
                rounds_map_region = value
                
                # % map covered
                avalible_places = map_areas[cur_map]
                visited_places = set()

                for entry in rounds_map_region:
                    place = entry[1]
                    if place in avalible_places:
                        visited_places.add(place)

                metric = len(visited_places) / len(avalible_places)
                
                new_row[f'ally{cur_player}_prec_map_covered'] = metric
                
                # 'movement' metric (based on transisions between areas)
                transitions = set()
                previous_place = None
                movement_metric = 0

                for entry in rounds_map_region:
                    place = entry[1]
                    if previous_place is not None:
                        transition = (previous_place, place)
                        transitions.add(transition)
                    previous_place = place

                movement_metric = len(transitions)
                f'ally{cur_player}_movement_metric'
                new_row[f'ally{cur_player}_movement_metric'] = movement_metric
            
            ## MOST TIME/MAX ##
            if key == 'inv_primary':
                rounds_inv_primary = value
                
                current_gun = None
                longest_duration = 0
                start_time = rounds_inv_primary[0][0]
                end_time = rounds_inv_primary[-1][0]

                longest_gun = None

                for entry in rounds_inv_primary:
                    timestamp = entry[0]
                    gun = entry[1]

                    if current_gun is None:
                        current_gun = gun
                    elif gun != current_gun:
                        duration = timestamp - start_time
                        if duration > longest_duration:
                            longest_duration = duration
                            longest_gun = current_gun
                            gun_time = (longest_gun, longest_duration)

                        current_gun = gun
                        start_time = timestamp
                  
                new_row[f'ally{cur_player}_longest_gun_primary'] = longest_gun
                
            if key == 'inv_secondary':
                rounds_inv_secondary = value
                
                current_gun = None
                longest_duration = 0
                start_time = rounds_inv_secondary[0][0]
                end_time = rounds_inv_secondary[-1][0]

                longest_gun = None

                for entry in rounds_inv_secondary:
                    timestamp = entry[0]
                    gun = entry[1]

                    if current_gun is None:
                        current_gun = gun
                    elif gun != current_gun:
                        duration = timestamp - start_time
                        if duration > longest_duration:
                            longest_duration = duration
                            longest_gun = current_gun
                            gun_time = (longest_gun, longest_duration)

                        current_gun = gun
                        start_time = timestamp
                   
                new_row[f'ally{cur_player}_longest_gun_secondary'] = longest_gun
                
            if key == 'inv_state':
                rounds_inv_state = value

                current_inv_state = None
                longest_duration = 0
                longest_inv_state = None

                if rounds_inv_state:  # Check if the list is not empty
                    start_time = rounds_inv_state[0][0]
                    end_time = rounds_inv_state[-1][0]

                    for entry in rounds_inv_state:
                        timestamp = entry[0]
                        inv_state = entry[1]

                        if current_inv_state is None:
                            current_inv_state = inv_state
                        elif inv_state != current_inv_state:
                            duration = timestamp - start_time
                            if duration > longest_duration:
                                longest_duration = duration
                                longest_inv_state = current_inv_state

                            current_inv_state = inv_state
                            start_time = timestamp

                new_row[f'ally{cur_player}_longest_inv_state'] = longest_inv_state

            
            ## COUNT ##
            if key == 'ult_state':
                rounds_ult_state = value
                
                for player, ultimate_data in rounds_ult_state.items():
                    ultimate_usage = 0
                    previous_state = None
                    for entry in ultimate_data:
                        ultimate_state = entry[1]
                        if previous_state is not None and previous_state is True and ultimate_state is False:
                            ultimate_usage += 1
                        previous_state = ultimate_state
                    if int(player) < 5:
                        new_row[f'ally{player}_ultimate_usage'] = ultimate_usage
                    else:
                        new_row[f'opponent{int(player)-5}_ultimate_usage'] = ultimate_usage
            
            ## COUNT ##
            if key == 'elims':
                rounds_elims = value
                # Initialize the stats for all players
                player_stats = {
                    str(player): {"elims": 0, "deaths": 0, "assists": 0, "headshots": 0, "wallbangs": 0, "first_bloods": 0} 
                    for player in range(10)}
                
                ally_deaths = 0
                opponent_deaths = 0
                
                # Then, for each elimination:
                for elimination in rounds_elims:
                    elim_data = elimination[1]
                    source = elim_data['source']
                    target = elim_data['target']
                    assisted = elim_data['assisted']

                    # Increase elim count for the source player
                    player_stats[source]['elims'] += 1

                    # Increase death count for the target player
                    player_stats[target]['deaths'] += 1
                    
                    if int(target) < 5:  # If the target is an ally
                        ally_deaths += 1
                    else:  # If the target is an opponent
                        opponent_deaths += 1

                    # Increase assist count for all assisted players
                    for assist_player in assisted:
                        player_stats[assist_player]['assists'] += 1

                    # If the elimination was a headshot, increase headshot count for the source player
                    if elim_data['headshot']:
                        player_stats[source]['headshots'] += 1

                    # If the elimination was a wallbang, increase wallbang count for the source player
                    if elim_data['wallbang']:
                        player_stats[source]['wallbangs'] += 1

                    # If the elimination was the first blood, increase first_blood count for the source player
                    if elim_data['first_blood']:
                        player_stats[source]['first_bloods'] += 1

                    # Add these stats to the new_row:
                    for player, stats in player_stats.items():
                        prefix = 'ally' if int(player) < 5 else 'opponent'
                        player_num = player if int(player) < 5 else str(int(player) - 5)
                        for stat, count in stats.items():
                            new_row[f'{prefix}{player_num}_{stat}'] = count
                    
                    new_row['all_ally_dead'] = ally_deaths >= 5  # All allies are dead if there are 5 or more ally deaths
                    new_row['all_opponent_dead'] = opponent_deaths >= 5  # All opponents are dead if there are 5 or more opponent deaths
                    
                    def get_win_condition(row):
                        if not row['spike_planted']:
                            return "elimination"
                        elif row['side'] == 'attacker':
                            return "elimination" if row['all_opponent_dead'] else "spike"
                        else:  # row['side'] == 'defender'
                            return "spike" if not row['all_ally_dead'] else "elimination"

            # Then, after you have parsed and set all the other data in new_row, you would add:

            new_row['win_condition'] = get_win_condition(new_row)
            
            ## AVERAGES ## 
            if key == 'ammo_reserve':
                rounds_ammo_reserve = value
                sum_ammo_reserve = 0
                num_entries = len(rounds_ammo_reserve)

                if num_entries > 0:
                    for entry in rounds_ammo_reserve:
                        ammo_reserve_value = entry[1]
                        sum_ammo_reserve += ammo_reserve_value

                    average_ammo_reserve = sum_ammo_reserve / num_entries

                else:
                    average_ammo_reserve = 0
                    
            
                new_row[f'ally{cur_player}_avg_ammo_reserve'] = average_ammo_mag
                
            if key == 'ammo_mag':
                rounds_ammo_mag = value
                sum_ammo_mag = 0
                num_entries = len(rounds_ammo_mag)
                
                if num_entries > 0:
                    for entry in rounds_ammo_mag:
                        ammo_ammo_mag = entry[1]
                        sum_ammo_mag += ammo_ammo_mag

                    average_ammo_mag = sum_ammo_mag/ num_entries
                else:
                    average_ammo_mag = 0
                
                new_row[f'ally{cur_player}_avg_ammo_mag'] = average_ammo_mag
                
            if key == 'credits':
                rounds_credits = value
                sum_credits = 0
                num_entries = len(rounds_credits)
                
                if num_entries > 0:
                    for entry in rounds_credits:
                        credits_value = entry[1]
                        sum_credits += credits_value

                    average_credits = sum_credits / num_entries
                else:
                    average_credits = 0
                
                new_row[f'ally{cur_player}_avg_credits'] = average_credits
                
            if key == 'shield':
                rounds_shield = value
                sum_shield = 0
                num_entries = len(rounds_shield)
                
                if num_entries > 0:
                    for entry in rounds_shield:
                        shield_value = entry[1]
                        sum_shield += shield_value

                    average_shield = sum_shield / num_entries
                else:
                    average_shield = 0
                
                new_row[f'ally{cur_player}_avg_shield'] = average_shield
            
            if key == 'health':
                rounds_health = value
                for player, health_data in rounds_health.items():
                    total_health = 0
                    num_entries = len(health_data)
                    if num_entries > 0:
                        for entry in health_data:
                            health_value = entry[1]
                            total_health += health_value
                        average_health = total_health / num_entries
                    else:
                        average_health = 0
                    new_row[f'ally{player}_avg_health'] = average_health
            
            ## MAXS ## 
            if key == 'loadout_value':
                rounds_loadout_value = value
                max_loadout_value = max(rounds_loadout_value, key=lambda x: x[1])
                max_loadout_value = max_loadout_value[1]
                
                new_row[f'ally{cur_player}_max_loadout_value'] = max_loadout_value
            
            ## TOTALS ##         
            if key == 'ability_charges_1':
                rounds_ability_charges_1 = value
                total_ability_usage_1 = 0

                for i in range(len(rounds_ability_charges_1) - 1):
                    if rounds_ability_charges_1[i + 1][1] == 1:
                        total_ability_usage_1 += 1
                
                new_row[f'ally{cur_player}_total_ability_usage_1'] = total_ability_usage_1
                
            if key == 'ability_charges_2':
                rounds_ability_charges_2 = value
                total_ability_usage_2 = 0

                for i in range(len(rounds_ability_charges_2) - 1):
                    if rounds_ability_charges_2[i + 1][1] == 1:
                        total_ability_usage_2 += 1
                
                new_row[f'ally{cur_player}_total_ability_usage_2'] = total_ability_usage_2
                
            if key == 'ability_charges_3':
                rounds_ability_charges_3 = value
                total_ability_usage_3 = 0

                for i in range(len(rounds_ability_charges_3) - 1):
                    if rounds_ability_charges_3[i + 1][1] == 1:
                        total_ability_usage_3 += 1
                
                new_row[f'ally{cur_player}_total_ability_usage_3'] = total_ability_usage_3
                
            if key == 'ability_charges_4':
                rounds_ability_charges_4 = value
                total_ability_usage_4 = 0

                for i in range(len(rounds_ability_charges_4) - 1):
                    if rounds_ability_charges_4[i + 1][1] == 1:
                        total_ability_usage_4 += 1
                
                new_row[f'ally{cur_player}_total_ability_usage_4'] = total_ability_usage_4
                
            if key == 'firing_state':
                firing_state = value

                total_fire_time = 0
                start_fire = 0

                for i in range(len(firing_state) - 1):
                    if firing_state[i + 1][1] == True:
                        start_fire = firing_state[i + 1][0]
                    elif firing_state[i + 1][1] == False:
                        end_fire = firing_state[i + 1][0]
                        firing = end_fire - start_fire
                        total_fire_time += firing
                
                new_row[f'ally{cur_player}_total_firing_time'] = total_fire_time
            else:
                new_row[f'rounds_{key}'] = value


        # Getting rid of cols that we just parsed or dont need 
        new_row.pop('rounds_firing_state', None)
        new_row.pop('rounds_ability_charges_1', None)
        new_row.pop('rounds_ability_charges_2', None)
        new_row.pop('rounds_ability_charges_3', None)
        new_row.pop('rounds_ability_charges_4', None)
        new_row.pop('rounds_assisted_count', None)
        new_row.pop('rounds_assists_count', None)
        new_row.pop('rounds_loadout_value', None)
        new_row.pop('rounds_ammo_reserve', None)
        new_row.pop('rounds_map_region', None)
        new_row.pop('rounds_phases', None)
        new_row.pop('rounds_ammo_mag', None)
        new_row.pop('rounds_credits', None)
        new_row.pop('rounds_shield', None)
        new_row.pop('rounds_credits', None)
        new_row.pop('rounds_inv_primary', None)
        new_row.pop('rounds_inv_secondary', None)
        new_row.pop('rounds_inv_state', None)
        new_row.pop('rounds_health', None)
        new_row.pop('rounds_ult_state', None)
        new_row.pop('round_totals', None)
        new_row.pop('rounds_alive', None)
        new_row.pop('round_info_ally_score', None)
        new_row.pop('round_info_opponent_score', None)
        new_row.pop('rounds_elims', None)
        new_row.pop('rounds_elims_count', None)
        new_row.pop('rounds_spike_planted', None)
        # exclude the original complex columns that we're flattening
        new_row.pop('rounds', None)
        new_row.pop('round_info', None)
        # Getting rid of cols that we dont want/need    
        new_row.pop('round_info_score', None)
        new_row.pop('round_info_round_scored', None)
        new_row.pop('round_info_buy_start', None)
        new_row.pop('round_info_ult_used', None)
        new_row.pop('round_info_spike_planted', None)
    
        # fixing the naming of the players
        def adjust_keys(new_row, cur_player):
            adjusted_row = {}
            cur_player = int(cur_player)

            allies_count = 5  # define total number of allies, including 'self'

            for key, value in new_row.items():
                if key.startswith(f'ally{cur_player}'):
                    adjusted_key = key.replace(f'ally{cur_player}', 'self')
                elif key.startswith('ally'):
                    # correctly parse the ally number as an integer and remaining part of the key
                    ally_number = int(key[4:].split('_')[0])
                    ally_remaining = '_'.join(key.split('_')[1:])

                    # calculate new ally number
                    new_ally_number = (ally_number - cur_player) % allies_count

                    # construct new key with updated ally number
                    adjusted_key = 'ally' + str(new_ally_number) + '_' + ally_remaining
                else:
                    adjusted_key = key

                adjusted_row[adjusted_key] = value

            return adjusted_row

        new_row = adjust_keys(new_row, cur_player)
        
        # Append this new row to the list
        new_rows.append(new_row)

# Convert the list of new rows into a dataframe
new_df = pd.DataFrame(new_rows)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/zb/q_qnmjvn0d3gl5wfj4qzpq_40000gn/T/ipykernel_56486/3545582096.py in <module>
#     250             # Then, after you have parsed and set all the other data in new_row, you would add:
#     251
# --> 252             new_row['win_condition'] = get_win_condition(new_row)
#     253
#     254             ## AVERAGES ##
#
# /var/folders/zb/q_qnmjvn0d3gl5wfj4qzpq_40000gn/T/ipykernel_56486/3742603454.py in get_win_condition(row)
#     389
#     390             def get_win_condition(row):
# --> 391                 if not row['spike_planted']:
#     392                     return "elimination"
#     393                 elif row['side'] == 'attacker':
#
# KeyError: 'spike_planted'

# %% [markdown]
# ### Data cleaning
# - I noticed some NaNs. This happens when there is missing information
# - self_longest_gun_primary, self_longest_inv_state, self_longest_gun_secondaryis coming up as None but i think it should be 'none', so i am replacing with that
# - After investigating it seems like the elims data isnt always captured, its only 123 rows so im going to drop it

# %%
new_df['self_longest_gun_primary'] = new_df['self_longest_gun_primary'].fillna('none')
new_df['self_longest_gun_secondary'] = new_df['self_longest_gun_secondary'].fillna('none')
new_df['self_longest_inv_state'] = new_df['self_longest_inv_state'].fillna('none')

# %%
cols_with_nans = new_df.columns[new_df.isnull().any()].tolist()

# Print the list of columns with NaN values
print(cols_with_nans)
# Out:
# ['round_info_round_won', 'ally4_elims', 'ally4_deaths', 'ally4_assists', 'ally4_headshots', 'ally4_wallbangs', 'ally4_first_bloods', 'self_elims', 'self_deaths', 'self_assists', 'self_headshots', 'self_wallbangs', 'self_first_bloods', 'ally1_elims', 'ally1_deaths', 'ally1_assists', 'ally1_headshots', 'ally1_wallbangs', 'ally1_first_bloods', 'ally2_elims', 'ally2_deaths', 'ally2_assists', 'ally2_headshots', 'ally2_wallbangs', 'ally2_first_bloods', 'ally3_elims', 'ally3_deaths', 'ally3_assists', 'ally3_headshots', 'ally3_wallbangs', 'ally3_first_bloods', 'opponent0_elims', 'opponent0_deaths', 'opponent0_assists', 'opponent0_headshots', 'opponent0_wallbangs', 'opponent0_first_bloods', 'opponent1_elims', 'opponent1_deaths', 'opponent1_assists', 'opponent1_headshots', 'opponent1_wallbangs', 'opponent1_first_bloods', 'opponent2_elims', 'opponent2_deaths', 'opponent2_assists', 'opponent2_headshots', 'opponent2_wallbangs', 'opponent2_first_bloods', 'opponent3_elims', 'opponent3_deaths', 'opponent3_assists', 'opponent3_headshots', 'opponent3_wallbangs', 'opponent3_first_bloods', 'opponent4_elims', 'opponent4_deaths', 'opponent4_assists', 'opponent4_headshots', 'opponent4_wallbangs', 'opponent4_first_bloods']

# %%
# Find rows with NaN values
nan_rows = new_df[new_df.isnull().any(axis=1)]

# Print the rows with NaN values
nan_rows
# Out:
#       user_id       map player ally4_character self_character ally1_character  \
# 235      1011     Lotus      3          breach        killjoy            omen
# 238      1011     Lotus      3          breach        killjoy            omen
# 240      1011     Lotus      3          breach        killjoy            omen
# 244      1011     Lotus      3          breach        killjoy            omen
# 357      1013   unknown      2           kay/o      brimstone            raze
# ...       ...       ...    ...             ...            ...             ...
# 6359     1012  Fracture      0       brimstone        killjoy            skye
# 6958      998    Ascent      1            sage      brimstone            fade
# 7663     1001    Icebox      4          harbor           sova            jett
# 7670     1001    Icebox      4          harbor           sova            jett
# 7777     1006   unknown      0            omen           jett            sova
#
#      ally2_character ally3_character opponent5_character opponent6_character  \
# 235             yoru            raze                omen             killjoy
# 238             yoru            raze                omen             killjoy
# 240             yoru            raze                omen             killjoy
# 244             yoru            raze                omen             killjoy
# 357            viper            jett                jett               kay/o
# ...              ...             ...                 ...                 ...
# 6359            sage            jett             killjoy              breach
# 6958         chamber            raze               reyna                fade
# 7663         killjoy           viper             killjoy                jett
# 7670         killjoy           viper             killjoy                jett
# 7777         chamber           kay/o                sova                omen
#
#       ... self_avg_ammo_reserve self_total_firing_time  \
# 235   ...             15.785714                   8400
# 238   ...             25.857143                   5200
# 240   ...             21.157895                   9400
# 244   ...             24.500000                   2200
# 357   ...             12.500000                      0
# ...   ...                   ...                    ...
# 6359  ...              0.000000                      0
# 6958  ...             20.666667                      0
# 7663  ...             21.500000                      0
# 7670  ...             25.000000                      0
# 7777  ...              0.000000                      0
#
#      self_longest_gun_secondary self_max_loadout_value spike_planted  \
# 235                        none                 2600.0         False
# 238                        none                 4100.0         False
# 240                        none                 3900.0         False
# 244                        none                 4500.0         False
# 357                     classic                  928.0         False
# ...                         ...                    ...           ...
# 6359                       none                    0.0         False
# 6958                       none                 4650.0         False
# 7663                       none                 4200.0         False
# 7670                       none                 4600.0         False
# 7777                       none                    0.0         False
#
#       spike_time self_total_ability_usage_1  self_total_ability_usage_2  \
# 235       281999                          0                           0
# 238       559599                          0                           0
# 240       760999                          0                           0
# 244      1058399                          0                           1
# 357       310600                          0                           0
# ...          ...                        ...                         ...
# 6359          13                          0                           0
# 6958      537007                          0                           0
# 7663      103357                          0                           0
# 7670      333358                          0                           0
# 7777      687205                          0                           0
#
#       self_total_ability_usage_3  self_total_ability_usage_4
# 235                            0                           0
# 238                            0                           1
# 240                            0                           0
# 244                            0                           0
# 357                            0                           0
# ...                          ...                         ...
# 6359                           0                           0
# 6958                           0                           0
# 7663                           0                           0
# 7670                           0                           0
# 7777                           0                           0
#
# [123 rows x 110 columns]

# %%
# nan_rows = new_df[new_df['self_longest_inv_state'].isnull()]
# nan_rows['self_longest_inv_state']

# %%
clean_df = new_df.dropna()
clean_df = clean_df.reset_index(drop=True)

# %%
# Find rows with NaN values
nan_rows = clean_df[clean_df.isnull().any(axis=1)]

# Print the rows with NaN values
nan_rows
# Out:
# Empty DataFrame
# Columns: [user_id, map, player, ally4_character, self_character, ally1_character, ally2_character, ally3_character, opponent5_character, opponent6_character, opponent7_character, opponent8_character, opponent9_character, round_number, round_info_ally_side, round_info_round_end, round_info_round_won, round_info_round_start, ally4_elims, ally4_deaths, ally4_assists, ally4_headshots, ally4_wallbangs, ally4_first_bloods, self_elims, self_deaths, self_assists, self_headshots, self_wallbangs, self_first_bloods, ally1_elims, ally1_deaths, ally1_assists, ally1_headshots, ally1_wallbangs, ally1_first_bloods, ally2_elims, ally2_deaths, ally2_assists, ally2_headshots, ally2_wallbangs, ally2_first_bloods, ally3_elims, ally3_deaths, ally3_assists, ally3_headshots, ally3_wallbangs, ally3_first_bloods, opponent0_elims, opponent0_deaths, opponent0_assists, opponent0_headshots, opponent0_wallbangs, opponent0_first_bloods, opponent1_elims, opponent1_deaths, opponent1_assists, opponent1_headshots, opponent1_wallbangs, opponent1_first_bloods, opponent2_elims, opponent2_deaths, opponent2_assists, opponent2_headshots, opponent2_wallbangs, opponent2_first_bloods, opponent3_elims, opponent3_deaths, opponent3_assists, opponent3_headshots, opponent3_wallbangs, opponent3_first_bloods, opponent4_elims, opponent4_deaths, opponent4_assists, opponent4_headshots, opponent4_wallbangs, opponent4_first_bloods, ally4_avg_health, self_avg_health, ally1_avg_health, ally2_avg_health, ally3_avg_health, self_avg_shield, self_avg_credits, self_avg_ammo_mag, self_longest_inv_state, ally4_ultimate_usage, self_ultimate_usage, ally1_ultimate_usage, ally2_ultimate_usage, ally3_ultimate_usage, opponent0_ultimate_usage, opponent1_ultimate_usage, opponent2_ultimate_usage, opponent3_ultimate_usage, opponent4_ultimate_usage, self_prec_map_covered, self_movement_metric, self_longest_gun_primary, ...]
# Index: []
#
# [0 rows x 110 columns]

# %%
clean_df.shape
# Out:
# (7923, 110)

# %%
new_df['spike_planted']
# Out:
# <bound method Series.unique of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8041    False
# 8042    False
# 8043    False
# 8044    False
# 8045    False
# Name: spike_planted, Length: 8046, dtype: bool>

# %%
# Parsing initial DataFrame
for index, row in clean_df.iterrows():
    if row['spike_planted']:
        print('h')
#         # Spike was planted, so we split the data
#         pre_spike_end = row['spike_time'] 
#         df_pre_spike = clean_df[(clean_dfdf['round_info_round_start'] <= pre_spike_end)]
#         df_post_spike = clean_df[(clean_df['round_info_round_end'] > pre_spike_end)]
        
#         df_pre_spike['phase'] = 'pre_spike'
#         df_post_spike['phase'] = 'post_spike'

#     else:
#         # Spike was not planted, so all data belongs to pre-spike phase
#         df_pre_spike = clean_df.copy()
#         df_pre_spike['phase'] = 'pre_spike'

# # Combining dataframes
# df_spike = pd.concat([df_pre_spike, df_post_spike], ignore_index=True)

# %%
df_spike

# %%
df_pre_spike
# Out:
#       user_id    map player ally4_character self_character ally1_character  \
# 0        1006  Pearl      1         phoenix           jett           gekko
# 1        1006  Pearl      1         phoenix           jett           gekko
# 2        1006  Pearl      1         phoenix           jett           gekko
# 3        1006  Pearl      1         phoenix           jett           gekko
# 4        1006  Pearl      1         phoenix           jett           gekko
# ...       ...    ...    ...             ...            ...             ...
# 7918     1018  Lotus      2         killjoy           sage           viper
# 7919     1018  Lotus      2         killjoy           sage           viper
# 7920     1018  Lotus      2         killjoy           sage           viper
# 7921     1018  Lotus      2         killjoy           sage           viper
# 7922     1018  Lotus      2         killjoy           sage           viper
#
#      ally2_character ally3_character opponent5_character opponent6_character  \
# 0             cypher           astra              harbor               astra
# 1             cypher           astra              harbor               astra
# 2             cypher           astra              harbor               astra
# 3             cypher           astra              harbor               astra
# 4             cypher           astra              harbor               astra
# ...              ...             ...                 ...                 ...
# 7918          breach            yoru                fade              harbor
# 7919          breach            yoru                fade              harbor
# 7920          breach            yoru                fade              harbor
# 7921          breach            yoru                fade              harbor
# 7922          breach            yoru                fade              harbor
#
#       ... self_total_firing_time self_longest_gun_secondary  \
# 0     ...                   2200                       none
# 1     ...                   8600                    classic
# 2     ...                   9800                    classic
# 3     ...                   7400                    classic
# 4     ...                   4400                    classic
# ...   ...                    ...                        ...
# 7918  ...                   4999                       none
# 7919  ...                   7798                       none
# 7920  ...                  10199                       none
# 7921  ...                  10399                       none
# 7922  ...                  18799                       none
#
#      self_max_loadout_value spike_planted spike_time  \
# 0                    3434.0         False          0
# 1                    5100.0         False     125000
# 2                    5100.0         False     204600
# 3                    5100.0         False     304600
# 4                    6750.0         False     369400
# ...                     ...           ...        ...
# 7918                 4300.0         False    1283821
# 7919                 4500.0         False    1375208
# 7920                 4700.0         False    1439799
# 7921                 4700.0         False    1504791
# 7922                 4500.0         False    1600378
#
#       self_total_ability_usage_1 self_total_ability_usage_2  \
# 0                              0                          1
# 1                              1                          0
# 2                              1                          1
# 3                              1                          0
# 4                              0                          1
# ...                          ...                        ...
# 7918                           1                          4
# 7919                           2                          2
# 7920                           2                          1
# 7921                           2                          1
# 7922                           2                          1
#
#       self_total_ability_usage_3  self_total_ability_usage_4      phase
# 0                              1                           0  pre_spike
# 1                              1                           1  pre_spike
# 2                              1                           0  pre_spike
# 3                              1                           0  pre_spike
# 4                              1                           0  pre_spike
# ...                          ...                         ...        ...
# 7918                           3                           0  pre_spike
# 7919                           2                           0  pre_spike
# 7920                           1                           0  pre_spike
# 7921                           2                           0  pre_spike
# 7922                           1                           0  pre_spike
#
# [7923 rows x 111 columns]

# %%
df_post_spike
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/zb/q_qnmjvn0d3gl5wfj4qzpq_40000gn/T/ipykernel_56486/3572857179.py in <module>
# ----> 1 df_post_spike
#
# NameError: name 'df_post_spike' is not defined

# %%
clean_df.to_csv('clean_data_norm_round_total.csv', index=False)

# %%
df1 = pd.read_csv('clean_data_norm_round_total.csv')
df1
# Out:
#       user_id    map  player ally4_character self_character ally1_character  \
# 0        1006  Pearl       1         phoenix           jett           gekko
# 1        1006  Pearl       1         phoenix           jett           gekko
# 2        1006  Pearl       1         phoenix           jett           gekko
# 3        1006  Pearl       1         phoenix           jett           gekko
# 4        1006  Pearl       1         phoenix           jett           gekko
# ...       ...    ...     ...             ...            ...             ...
# 7918     1018  Lotus       2         killjoy           sage           viper
# 7919     1018  Lotus       2         killjoy           sage           viper
# 7920     1018  Lotus       2         killjoy           sage           viper
# 7921     1018  Lotus       2         killjoy           sage           viper
# 7922     1018  Lotus       2         killjoy           sage           viper
#
#      ally2_character ally3_character opponent5_character opponent6_character  \
# 0             cypher           astra              harbor               astra
# 1             cypher           astra              harbor               astra
# 2             cypher           astra              harbor               astra
# 3             cypher           astra              harbor               astra
# 4             cypher           astra              harbor               astra
# ...              ...             ...                 ...                 ...
# 7918          breach            yoru                fade              harbor
# 7919          breach            yoru                fade              harbor
# 7920          breach            yoru                fade              harbor
# 7921          breach            yoru                fade              harbor
# 7922          breach            yoru                fade              harbor
#
#       ... self_longest_gun_primary self_avg_ammo_reserve  \
# 0     ...                   vandal             24.000000
# 1     ...                   vandal             19.400000
# 2     ...                   vandal             18.222222
# 3     ...                     none             16.800000
# 4     ...                   vandal             14.142857
# ...   ...                      ...                   ...
# 7918  ...                     none             21.000000
# 7919  ...                   vandal             17.352941
# 7920  ...                     none             17.785714
# 7921  ...                   vandal             16.117647
# 7922  ...                   vandal             11.714286
#
#      self_total_firing_time  self_longest_gun_secondary  \
# 0                      2200                        none
# 1                      8600                     classic
# 2                      9800                     classic
# 3                      7400                     classic
# 4                      4400                     classic
# ...                     ...                         ...
# 7918                   4999                        none
# 7919                   7798                        none
# 7920                  10199                        none
# 7921                  10399                        none
# 7922                  18799                        none
#
#      self_max_loadout_value  spike_planted  self_total_ability_usage_1  \
# 0                    3434.0          False                           0
# 1                    5100.0          False                           1
# 2                    5100.0          False                           1
# 3                    5100.0          False                           1
# 4                    6750.0          False                           0
# ...                     ...            ...                         ...
# 7918                 4300.0          False                           1
# 7919                 4500.0          False                           2
# 7920                 4700.0          False                           2
# 7921                 4700.0          False                           2
# 7922                 4500.0          False                           2
#
#       self_total_ability_usage_2  self_total_ability_usage_3  \
# 0                              1                           1
# 1                              0                           1
# 2                              1                           1
# 3                              0                           1
# 4                              1                           1
# ...                          ...                         ...
# 7918                           4                           3
# 7919                           2                           2
# 7920                           1                           1
# 7921                           1                           2
# 7922                           1                           1
#
#       self_total_ability_usage_4
# 0                              0
# 1                              1
# 2                              0
# 3                              0
# 4                              0
# ...                          ...
# 7918                           0
# 7919                           0
# 7920                           0
# 7921                           0
# 7922                           0
#
# [7923 rows x 109 columns]
