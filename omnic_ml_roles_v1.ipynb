# %% [markdown]
# # Purpose of notebook
# This notebook is to explore the question of roles.
#
# Topics covered:
# - role information / hypothesis

# %% [markdown]
# ## Additional background / hypothesis
# * Commonly in gaming there is the concept of "role" similar to positions in sports
# * In Valorant, characters are grouped into 4 main roles and their "kit" is designed to fill that role
#     - Controller
#     - Initiator
#     - Duelist
#     - Sentinels
# * Some characters are a bit fluid (can play multiple roles) but generally the character is a good proxy for role
# * However the player can ignore the kit/character and still play a different "role" even if their character isnt designed for it
# * There are sub-roles
# * There is a general idea that in order to have the best chance of winning, you should have a 2 sentinels, 1 initiator, 1 duelist, 1 controller
#
# ### Hypothesis/questions
# * Is it possible to group players by their gameplay (how different is their gameplay)?
#     * Idea: we know the different people's ids, if we cluster the data and see how many clusters it forms (DBSCAN?) will it be similar or different to the ammount of people we have?
# * Is it possible to determine how well a player is playing the role assigned by the character but independent of character?
#     * Idea: we gather data from the "best" professionals in each character role, and treat this as the ground truth for that role
#         * then we can measure how close a player is playing that role
#         * could also attempt to classify based on the ground truth
# * It it possible to prove/disprove the team-comp sentiment?
#     * Idea: once we have a good idea of what leads to wins/losses, we can add in different character comps and see how that influeces match outcomes? basically try and see if the ratio of characters/roles actually matters
# * Is it possible to show that certain characters/roles are more important/relevant depending on the STATE of the match (what has happened??)
#     * Idea: classify/catagorize matches into opening, mid, end game based on events (like chess) to determine strategy, and then see which roles are most effective at progressing the match to the next event.
#
# Defensive:
# - sentinels: support and/or in game leader
#     - healing
#     - moving around the map (information)
#     -Cypher; Killjoy; Chamber; and Sage
#     - slowing down opponents on bomb site
#
# - initiators: recon and crowd control
#     - Sova, Skye, Fade and Gekko rely on their abilities to perform reconnaissance
#     - Breach and KAY/O specialise in disrupting enemies in their path through the use of their crowd control abilities
#
# Offensive
# - controllers: secondary entry frag and lurker
#     - Ability smoke screen
#     - Use abilities before spike plant
#     - Astra; Brimstone; Omen; Harbor and Viper.
#     - Second on the scene
#     - Omen is a flank
#
# - duelist: entry drag
#     - Damage dealers
#     - Jett; Phoenix; Raze; Reyna; Yoru and Neon.
#     - First person on an area on a map
#     - Good aim
#
#
#
# https://www.pinnacle.com/en/esports-hub/betting-articles/valorant/roles-in-valorant/gx9jvkedjdeh2ygl#:~:text=the%20team%20wins.-,What%20are%20the%20different%20roles%20in%20VALORANT%3F,%2C%20Recon%2C%20and%20Crowd%20Control.

# %%
import json
import pandas as pd

# %% [markdown]
# ## Loading the data

# %%
# Load JSON data from file
with open('dev_data.json', 'r') as f:
    data = json.load(f)

# Access an element to retrieve the keys
sample_element = data[0]
columns = sample_element.keys()
print("Columns:", columns)

num_rows = len(data)
print("Number of rows:", num_rows)
# Out:
# Columns: dict_keys(['id', 'game_id', 'map_id', 'processed', 'process_date', 'created_at', 'updated_at', 'match_id', 'result', 'score', 'statistics', 'totals', 'ten_minute_averages', 'character_id', 'user_id', 'match_length', 'video_id', 'card_url', 'total_time', 'totals_to_date', 'start_time', 'end_time', 'start_frame', 'end_frame', 'status', 'report', 'analysis_processed', 'analysis_status'])
# Number of rows: 534

# %%
# Observing a random entry
data[4]
# Out:
# {'id': 4612,
#  'game_id': 3,
#  'map_id': 32,
#  'processed': True,
#  'process_date': None,
#  'created_at': '2023-05-05T09:17:04.490Z',
#  'updated_at': '2023-05-05T18:51:37.392Z',
#  'match_id': None,
#  'result': 'win',
#  'score': '13-10',
#  'statistics': {'map': 'Haven',
#   'score': '13-10',
#   'allies': ['0', '1', '2', '3', '4'],
#   'player': '2',
#   'result': 'win',
#   'rounds': {'0': {'alive': {'0': [[73399, True], [153799, False]],
#      '1': [[73399, True], [182799, False], [189799, True], [243799, False]],
#      '2': [[73399, True], [157199, False]],
#      '3': [[73399, True], [169199, False]],
#      '4': [[73399, True], [139799, False]],
#      '5': [[73399, True], [151799, False]],
#      '6': [[73399, True], [153799, False]],
#      '7': [[73399, True], [182799, False], [189799, True]],
#      '8': [[73399, True], [183199, False], [185999, True]],
#      '9': [[73399, True], [149399, False]]},
#     'elims': [[139999,
#       {'source': '8',
#        'target': '4',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': True,
#        'team_credit': 'opponent'}],
#      [149599,
#       {'source': '1',
#        'target': '9',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [151999,
#       {'source': '3',
#        'target': '5',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [153999,
#       {'source': '1',
#        'target': '6',
#        'assisted': ['2'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [153999,
#       {'source': '8',
#        'target': '0',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [157199,
#       {'source': '8',
#        'target': '2',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 3,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [169199,
#       {'source': '8',
#        'target': '3',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 4,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [243999,
#       {'source': '7',
#        'target': '1',
#        'assisted': ['6'],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}]],
#     'health': {'0': [[73399, 100],
#       [74999, 96],
#       [75399, 100],
#       [75999, 0],
#       [79999, 100],
#       [80799, 0],
#       [81799, 100],
#       [83399, 96],
#       [83999, 100],
#       [84399, 96],
#       [84799, 100],
#       [87199, 96],
#       [87599, 100],
#       [90399, 96],
#       [91399, 100],
#       [96799, 88],
#       [97199, 96],
#       [98199, 100],
#       [119599, 92],
#       [120599, 96],
#       [121399, 100],
#       [122399, 96],
#       [122999, 100],
#       [125399, 92],
#       [125799, 100],
#       [131399, 96],
#       [132199, 100],
#       [139999, 96],
#       [140999, 100],
#       [144199, 96],
#       [145999, 100],
#       [147199, 96],
#       [152799, 67],
#       [153199, 37]],
#      '1': [[73399, 100],
#       [74999, 96],
#       [75999, 0],
#       [79799, 96],
#       [80799, 0],
#       [81799, 96],
#       [94399, 100],
#       [95399, 96],
#       [96799, 93],
#       [97799, 96],
#       [99599, 100],
#       [106799, 96],
#       [108599, 100],
#       [119199, 96],
#       [120199, 93],
#       [120999, 96],
#       [126599, 93],
#       [126999, 96],
#       [140999, 100],
#       [144999, 93],
#       [145599, 96],
#       [145999, 100],
#       [146599, 96],
#       [147399, 100],
#       [147999, 96],
#       [152999, 70],
#       [153599, 22],
#       [154399, 15],
#       [154799, 22],
#       [156799, 19],
#       [157399, 15],
#       [158599, 19],
#       [160399, 15],
#       [160999, 19],
#       [161999, 15],
#       [162799, 22],
#       [163599, 15],
#       [163999, 22],
#       [164399, 15],
#       [165199, 22],
#       [170199, 19],
#       [170999, 22],
#       [171399, 0],
#       [171799, 22],
#       [172599, 26],
#       [172999, 22],
#       [173799, 26],
#       [175599, 22],
#       [177999, 26],
#       [178799, 22],
#       [181599, 19],
#       [182199, 22],
#       [189799, 26],
#       [190599, 22],
#       [191199, 26],
#       [192199, 19],
#       [197399, 26],
#       [198799, 22],
#       [199599, 15],
#       [200599, 22],
#       [202599, 15],
#       [203399, 22],
#       [206399, 30],
#       [206799, 33],
#       [207999, 22],
#       [215999, 11],
#       [216799, 22],
#       [217599, 26],
#       [218999, 22],
#       [221199, 15],
#       [223399, 22],
#       [225199, 15],
#       [225599, 19],
#       [225999, 15],
#       [226599, 22],
#       [228399, 26],
#       [230199, 22],
#       [231399, 11],
#       [231799, 22],
#       [234399, 19],
#       [235199, 22],
#       [236599, 19],
#       [237999, 22],
#       [238799, 15],
#       [239599, 22],
#       [240599, 26],
#       [241799, 19]],
#      '2': [[73399, 100], [157199, 0]],
#      '3': [[73399, 100],
#       [74399, 96],
#       [75999, 0],
#       [79599, 96],
#       [80799, 0],
#       [81799, 96],
#       [84199, 93],
#       [84599, 96],
#       [86999, 89],
#       [87399, 96],
#       [96799, 89],
#       [97199, 96],
#       [99799, 100],
#       [106799, 96],
#       [107999, 100],
#       [110999, 96],
#       [112399, 100],
#       [119199, 96],
#       [120199, 93],
#       [121199, 96],
#       [124799, 93],
#       [125199, 96],
#       [141199, 100],
#       [144199, 96],
#       [145799, 100],
#       [146599, 93],
#       [148599, 96],
#       [153799, 93],
#       [154199, 96],
#       [160199, 100],
#       [160799, 96],
#       [163399, 100],
#       [164199, 96]],
#      '4': [[73399, 100],
#       [74399, 93],
#       [74799, 96],
#       [75999, 0],
#       [79399, 96],
#       [80799, 0],
#       [81799, 96],
#       [84199, 93],
#       [84599, 96],
#       [89399, 100],
#       [90799, 89],
#       [91199, 93],
#       [91599, 100],
#       [92199, 96],
#       [93999, 100],
#       [95199, 93],
#       [96799, 78],
#       [97199, 89],
#       [97799, 93],
#       [98399, 100],
#       [106799, 96],
#       [109199, 100],
#       [110999, 96],
#       [112599, 100],
#       [119599, 93],
#       [121199, 96],
#       [124799, 93],
#       [125199, 96],
#       [127799, 93],
#       [128399, 96],
#       [130799, 93],
#       [131199, 96],
#       [131799, 93],
#       [132199, 96]]},
#     'phases': [[73200, 'buy_start'],
#      [118200, 'round_start'],
#      [243197, 'round_scored'],
#      [250197, 'round_end']],
#     'shield': [[73399, 0]],
#     'credits': [[73399, 0], [74199, 800], [79399, 100]],
#     'ammo_mag': [[74199, 12],
#      [78999, 13],
#      [153399, 12],
#      [153599, 10],
#      [153999, 7]],
#     'inv_state': [[74999, 'melee'],
#      [102599, 'secondary'],
#      [104799, 'melee'],
#      [110999, 'secondary'],
#      [114799, 'none'],
#      [119799, 'melee'],
#      [130599, 'secondary'],
#      [134799, 'none'],
#      [139199, 'secondary']],
#     'ult_state': {'0': [[73399, False]],
#      '1': [[73399, False]],
#      '2': [[73399, False]],
#      '3': [[73399, False]],
#      '4': [[73399, False]],
#      '5': [[73399, False]],
#      '6': [[73399, False]],
#      '7': [[73399, False]],
#      '8': [[73399, False]],
#      '9': [[73399, False]]},
#     'map_region': [[74399, 'Defender Side Spawn'],
#      [79399, 'A Link'],
#      [84399, 'A Site'],
#      [125999, 'A Link'],
#      [130999, 'A Site'],
#      [132199, 'B Site'],
#      [136399, 'A Site'],
#      [144799, 'Mid Courtyard'],
#      [148399, 'Mid Doors'],
#      [153199, 'A Garden']],
#     'elims_count': [[73599, 0, 0]],
#     'inv_primary': [[73399, 'none']],
#     'ammo_reserve': [[74199, 36], [79399, 39]],
#     'firing_state': [[73399, False], [153399, True], [156199, False]],
#     'assists_count': [[73599, 0, 0], [153999, 1, 1]],
#     'inv_secondary': [[73399, 'classic'],
#      [82799, 'frenzy'],
#      [108799, 'classic'],
#      [110999, 'frenzy'],
#      [114799, 'classic'],
#      [119799, 'frenzy']],
#     'loadout_value': [[73399, 0],
#      [82799, 450.0],
#      [108799, 0.0],
#      [110999, 450.0],
#      [114799, 0.0],
#      [118399, 250.0],
#      [119799, 700.0],
#      [135999, 450.0]],
#     'spike_planted': [[73399, False], [203799, True], [243799, False]],
#     'assisted_count': [[73599, 0, 0]],
#     'ability_charges_1': [[73399, 0], [118399, 1], [135999, 0]],
#     'ability_charges_2': [[73399, 0]],
#     'ability_charges_3': [[73399, 0]],
#     'ability_charges_4': [[73399, 0]]},
#    '1': {'alive': {'0': [[250199, True]],
#      '1': [[250199, True], [329399, False]],
#      '2': [[250199, True], [290399, False]],
#      '3': [[250199, True], [325999, False]],
#      '4': [[250199, True]],
#      '5': [[250199, True], [331399, False]],
#      '6': [[250199, True], [324799, False]],
#      '7': [[250199, True], [328599, False]],
#      '8': [[250199, True], [325599, False]],
#      '9': [[250199, True], [327599, False]]},
#     'elims': [[290399,
#       {'source': '7',
#        'target': '2',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': True,
#        'team_credit': 'opponent'}],
#      [324799,
#       {'source': '1',
#        'target': '6',
#        'assisted': ['3'],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [325599,
#       {'source': '3',
#        'target': '8',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [326399,
#       {'source': '9',
#        'target': '3',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': True,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [327599,
#       {'source': '4',
#        'target': '9',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [328799,
#       {'source': '1',
#        'target': '7',
#        'assisted': ['2'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [330399,
#       {'source': '5',
#        'target': '1',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [331599,
#       {'source': '4',
#        'target': '5',
#        'assisted': ['3'],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'ally'}]],
#     'health': {'0': [[250199, 100],
#       [256399, 92],
#       [256799, 100],
#       [260999, 96],
#       [261599, 100],
#       [261999, 96],
#       [262599, 100],
#       [265199, 96],
#       [265599, 100],
#       [270199, 0],
#       [271199, 100],
#       [273399, 88],
#       [273999, 100],
#       [275599, 0],
#       [278799, 100],
#       [281599, 96],
#       [282599, 100],
#       [284399, 96],
#       [284799, 100],
#       [290399, 96],
#       [294999, 100],
#       [295599, 96],
#       [299199, 93],
#       [299599, 96],
#       [302599, 100],
#       [304199, 96],
#       [306199, 100],
#       [307199, 93],
#       [307599, 96],
#       [312399, 100],
#       [314599, 96],
#       [315199, 93],
#       [315599, 96],
#       [322799, 100],
#       [323199, 96],
#       [331799, 100],
#       [332799, 96],
#       [333999, 93],
#       [334399, 96],
#       [335199, 93],
#       [335999, 96]],
#      '1': [[250199, 100],
#       [251599, 96],
#       [252199, 93],
#       [252599, 96],
#       [253599, 93],
#       [254199, 96],
#       [257999, 100],
#       [259399, 96],
#       [259999, 100],
#       [260399, 96],
#       [261999, 100],
#       [262999, 96],
#       [264399, 93],
#       [264999, 96],
#       [266199, 100],
#       [267399, 96],
#       [270199, 0],
#       [271199, 96],
#       [273999, 93],
#       [274399, 96],
#       [275599, 0],
#       [278799, 100],
#       [281399, 96],
#       [294599, 100],
#       [295399, 96],
#       [303199, 100],
#       [305999, 96],
#       [307999, 100],
#       [308399, 96],
#       [309999, 93],
#       [310799, 96],
#       [312399, 100],
#       [314799, 96],
#       [319999, 100],
#       [320999, 96],
#       [328399, 56]],
#      '2': [[250199, 100], [290399, 0]],
#      '3': [[250199, 100],
#       [251199, 96],
#       [252399, 93],
#       [252799, 96],
#       [258199, 100],
#       [259399, 89],
#       [260999, 100],
#       [262399, 89],
#       [262799, 93],
#       [263399, 100],
#       [264399, 96],
#       [265599, 93],
#       [266199, 100],
#       [268199, 96],
#       [270199, 0],
#       [271599, 96],
#       [273399, 93],
#       [273999, 96],
#       [274399, 100],
#       [275599, 0],
#       [278799, 96],
#       [280799, 100],
#       [281799, 93],
#       [282199, 96],
#       [283199, 93],
#       [283599, 96],
#       [285399, 85],
#       [290799, 89],
#       [291199, 85],
#       [292999, 100],
#       [293599, 85],
#       [294399, 89],
#       [295199, 100],
#       [295999, 85],
#       [303399, 89],
#       [304199, 96],
#       [306999, 85],
#       [312199, 96],
#       [315399, 85],
#       [319599, 81],
#       [320199, 89],
#       [320799, 85]],
#      '4': [[250199, 100],
#       [251599, 93],
#       [253199, 96],
#       [257999, 100],
#       [259399, 96],
#       [259999, 100],
#       [262399, 89],
#       [263199, 96],
#       [264199, 93],
#       [264599, 96],
#       [268599, 93],
#       [268999, 96],
#       [270199, 0],
#       [271199, 93],
#       [272799, 96],
#       [273199, 93],
#       [273999, 85],
#       [274399, 93],
#       [274799, 96],
#       [275599, 0],
#       [278799, 96],
#       [284399, 93],
#       [285199, 96],
#       [289599, 93],
#       [289999, 96],
#       [290599, 93],
#       [291199, 96],
#       [292999, 100],
#       [293799, 96],
#       [294999, 100],
#       [296599, 96],
#       [297399, 100],
#       [297999, 96],
#       [300799, 100],
#       [301199, 96],
#       [308399, 93],
#       [308999, 96],
#       [312199, 100],
#       [313199, 96],
#       [314999, 100],
#       [315599, 96],
#       [322799, 100],
#       [323199, 96],
#       [324799, 93],
#       [325599, 96],
#       [328399, 93],
#       [329799, 96],
#       [330199, 93],
#       [331399, 22],
#       [335599, 30],
#       [336599, 15],
#       [337199, 22]]},
#     'phases': [[250197, 'buy_start'],
#      [280197, 'round_start'],
#      [330997, 'round_scored'],
#      [337997, 'round_end']],
#     'shield': [[250199, 0], [271199, 25], [290399, 0]],
#     'credits': [[250199, 100], [250999, 2000], [271199, 500], [278599, 1550]],
#     'ammo_mag': [[251199, 12],
#      [270799, 20],
#      [278599, 18],
#      [285599, 13],
#      [289599, 11],
#      [289799, 9],
#      [289999, 7],
#      [290199, 5]],
#     'inv_state': [[251399, 'melee'],
#      [278999, 'none'],
#      [281799, 'melee'],
#      [285599, 'secondary']],
#     'ult_state': {'0': [[250199, False]],
#      '1': [[250199, False]],
#      '2': [[250199, False]],
#      '3': [[250199, False]],
#      '4': [[250199, False]],
#      '5': [[250199, False]],
#      '6': [[250199, False]],
#      '7': [[250199, False]],
#      '8': [[250199, False]],
#      '9': [[250199, False]]},
#     'map_region': [[251199, 'Defender Side Spawn'],
#      [256999, 'A Site'],
#      [283199, 'A Tower'],
#      [289799, 'A Lobby']],
#     'elims_count': [[250399, 0, 0]],
#     'inv_primary': [[250199, 'none'], [273999, 'spectre'], [278999, 'none']],
#     'ammo_reserve': [[269399, 36], [285799, 39]],
#     'firing_state': [[250199, False],
#      [278599, True],
#      [280799, False],
#      [285599, True],
#      [287799, False],
#      [289599, True],
#      [292399, False]],
#     'assists_count': [[250399, 0, 1], [328799, 1, 2]],
#     'inv_secondary': [[250199, 'classic'], [279999, 'frenzy']],
#     'loadout_value': [[250199, 0],
#      [271199, 400.0],
#      [273999, 2000.0],
#      [278999, 400.0],
#      [279999, 850.0],
#      [290399, 450.0]],
#     'spike_planted': [[250199, False]],
#     'assisted_count': [[250399, 0, 0]],
#     'ability_charges_1': [[250199, 0]],
#     'ability_charges_2': [[250199, 0]],
#     'ability_charges_3': [[250199, 0]],
#     'ability_charges_4': [[250199, 0]]},
#    '2': {'alive': {'0': [[337999, True], [396599, False]],
#      '1': [[337999, True], [381999, False]],
#      '2': [[337999, True], [373799, False]],
#      '3': [[337999, True], [421199, False], [425599, True]],
#      '4': [[337999, True], [407199, False]],
#      '5': [[337999, True], [421199, False]],
#      '6': [[337999, True], [421199, False]],
#      '7': [[337999, True], [376799, False]],
#      '8': [[337999, True], [394799, False]],
#      '9': [[337999, True], [397199, False]]},
#     'elims': [[373999,
#       {'source': '8',
#        'target': '2',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': True,
#        'team_credit': 'opponent'}],
#      [376799,
#       {'source': '3',
#        'target': '7',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [382399,
#       {'source': '8',
#        'target': '1',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [395199,
#       {'source': '0',
#        'target': '8',
#        'assisted': ['4'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [397199,
#       {'source': '4',
#        'target': '9',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [397199,
#       {'source': '9',
#        'target': '0',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': True,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [407199,
#       {'source': '5',
#        'target': '4',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [429999,
#       {'source': '3',
#        'target': '5',
#        'assisted': ['4'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [431599,
#       {'source': '3',
#        'target': '6',
#        'assisted': ['1', '4'],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 3,
#        'first_blood': False,
#        'team_credit': 'ally'}]],
#     'health': {'0': [[337999, 100],
#       [339599, 0],
#       [340999, 100],
#       [341799, 0],
#       [342399, 100],
#       [346599, 96],
#       [348199, 100],
#       [350799, 96],
#       [351599, 100],
#       [351999, 96],
#       [352399, 100],
#       [357399, 96],
#       [358199, 100],
#       [359599, 96],
#       [360399, 100],
#       [365799, 96],
#       [366599, 100],
#       [373799, 96],
#       [385399, 93],
#       [385999, 96],
#       [395199, 85]],
#      '1': [[337999, 100],
#       [338999, 96],
#       [339599, 0],
#       [340999, 96],
#       [341799, 0],
#       [342199, 96],
#       [345599, 100],
#       [345999, 96],
#       [362799, 93],
#       [363599, 96]],
#      '2': [[337999, 100], [373799, 0]],
#      '3': [[337999, 100],
#       [338999, 96],
#       [339999, 0],
#       [340999, 96],
#       [341799, 0],
#       [342199, 96],
#       [344199, 93],
#       [345199, 96],
#       [345799, 100],
#       [346399, 96],
#       [358799, 93],
#       [360199, 96],
#       [361399, 93],
#       [361799, 96],
#       [364799, 93],
#       [365799, 96],
#       [366399, 93],
#       [366799, 96],
#       [376199, 78],
#       [377199, 48],
#       [378199, 89],
#       [378599, 37],
#       [379599, 48],
#       [380399, 44],
#       [380799, 48],
#       [382399, 59],
#       [384599, 96],
#       [386399, 89],
#       [387199, 93],
#       [389399, 96],
#       [408599, 100],
#       [408999, 96],
#       [418399, 93],
#       [418799, 96],
#       [419799, 93],
#       [422199, 0],
#       [427999, 96],
#       [430199, 100],
#       [431799, 11],
#       [433799, 41],
#       [437199, 19],
#       [437599, 22],
#       [438599, 33],
#       [439399, 26],
#       [439999, 37],
#       [440799, 33],
#       [442999, 37],
#       [444799, 48],
#       [445199, 44],
#       [445799, 33],
#       [446399, 44],
#       [447199, 48]],
#      '4': [[337999, 100],
#       [338999, 96],
#       [339599, 0],
#       [342599, 96],
#       [345799, 100],
#       [346599, 89],
#       [347999, 93],
#       [348399, 96],
#       [352199, 93],
#       [354399, 96],
#       [358799, 93],
#       [359199, 96],
#       [365399, 93],
#       [365999, 100],
#       [366399, 93],
#       [366799, 89],
#       [367199, 96],
#       [370999, 93],
#       [371799, 96],
#       [372399, 93],
#       [372799, 96],
#       [373799, 93],
#       [374199, 96],
#       [377199, 93],
#       [377999, 96],
#       [385799, 93],
#       [387199, 96],
#       [387999, 93],
#       [388399, 96],
#       [396999, 93],
#       [397399, 96],
#       [398599, 93],
#       [398999, 96],
#       [400199, 93],
#       [400599, 96],
#       [403199, 100],
#       [403599, 96]]},
#     'phases': [[337997, 'buy_start'],
#      [367997, 'round_start'],
#      [441409, 'round_scored'],
#      [448409, 'round_end']],
#     'shield': [[337999, 0], [340999, 50], [373799, 0]],
#     'credits': [[337999, 1550], [338799, 4550], [342199, 150]],
#     'ammo_mag': [[338999, 2],
#      [339199, 12],
#      [340199, 25],
#      [366799, 12],
#      [366999, 25],
#      [367399, 26],
#      [367599, 25],
#      [367799, 26],
#      [367999, 25],
#      [369799, 24],
#      [369999, 22],
#      [373199, 21]],
#     'inv_state': [[342199, 'melee'], [366999, 'primary'], [370999, 'none']],
#     'ult_state': {'0': [[337999, False]],
#      '1': [[337999, False]],
#      '2': [[337999, False]],
#      '3': [[337999, False], [429799, True]],
#      '4': [[337999, False]],
#      '5': [[337999, False]],
#      '6': [[337999, False]],
#      '7': [[337999, False]],
#      '8': [[337999, False], [382199, True], [423199, False]],
#      '9': [[337999, False]]},
#     'map_region': [[338999, 'Defender Side Spawn'],
#      [344399, 'A Site'],
#      [348399, 'A Link'],
#      [353999, 'A Site'],
#      [356199, 'A Link'],
#      [360399, 'A Site'],
#      [365999, 'B Site'],
#      [369199, 'A Site']],
#     'elims_count': [[337999, 0, 0]],
#     'inv_primary': [[337999, 'none'], [342199, 'vandal']],
#     'ammo_reserve': [[339199, 36], [347599, 75]],
#     'firing_state': [[337999, False],
#      [367599, True],
#      [372199, False],
#      [373199, True],
#      [375399, False]],
#     'assists_count': [[337999, 0, 2]],
#     'inv_secondary': [[337999, 'classic']],
#     'loadout_value': [[337999, 0],
#      [340999, 1000.0],
#      [342199, 3900.0],
#      [367999, 4400.0],
#      [372599, 4400.0],
#      [373799, 3400.0]],
#     'spike_planted': [[337999, False], [410199, True], [441999, False]],
#     'assisted_count': [[337999, 0, 0]],
#     'ability_charges_1': [[337999, 0], [367999, 2]],
#     'ability_charges_2': [[337999, 0]],
#     'ability_charges_3': [[337999, 0], [367999, 1], [372599, 0]],
#     'ability_charges_4': [[337999, 0]]},
#    '3': {'alive': {'0': [[448599, True], [513799, False]],
#      '1': [[448599, True], [511799, False]],
#      '2': [[448599, True], [518399, False]],
#      '3': [[448599, True], [493599, False]],
#      '4': [[448599, True], [502999, False]],
#      '5': [[448599, True], [482799, False]],
#      '6': [[448599, True], [495999, False]],
#      '7': [[448599, True]],
#      '8': [[448599, True], [516799, False]],
#      '9': [[448599, True]]},
#     'elims': [[493599,
#       {'source': '8',
#        'target': '3',
#        'assisted': ['9'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': True,
#        'team_credit': 'opponent'}],
#      [495999,
#       {'source': '4',
#        'target': '6',
#        'assisted': ['3'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [497599,
#       {'source': '5',
#        'target': '3',
#        'assisted': ['9'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [500799,
#       {'source': '4',
#        'target': '7',
#        'assisted': ['3'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [503199,
#       {'source': '9',
#        'target': '4',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [511999,
#       {'source': '8',
#        'target': '1',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [513999,
#       {'source': '9',
#        'target': '0',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [516799,
#       {'source': '2',
#        'target': '8',
#        'weapon': 'vandal',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally',
#        'weapon_type': 'primary'}],
#      [518799,
#       {'source': '9',
#        'target': '2',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 3,
#        'first_blood': False,
#        'team_credit': 'opponent'}]],
#     'health': {'0': [[448599, 100],
#       [449799, 0],
#       [450399, 100],
#       [451999, 92],
#       [452599, 100],
#       [457399, 96],
#       [457799, 100],
#       [468199, 96],
#       [468999, 100],
#       [481399, 96],
#       [481799, 100],
#       [483199, 96],
#       [483599, 100],
#       [493399, 96],
#       [505799, 100],
#       [506799, 96],
#       [511799, 93],
#       [512199, 96]],
#      '1': [[448599, 100],
#       [449799, 0],
#       [450799, 96],
#       [456599, 93],
#       [456999, 96],
#       [460399, 100],
#       [460999, 96],
#       [463199, 100],
#       [466599, 96],
#       [468599, 93],
#       [468999, 96],
#       [473999, 93],
#       [474599, 96],
#       [474999, 93],
#       [475399, 96],
#       [476999, 100],
#       [477599, 96],
#       [480199, 100],
#       [480799, 96],
#       [484999, 100],
#       [486799, 96],
#       [493599, 93],
#       [493999, 96],
#       [502799, 93],
#       [503399, 96],
#       [504799, 100],
#       [505399, 96],
#       [507399, 100],
#       [507799, 96]],
#      '2': [[448599, 100], [518399, 0]],
#      '3': [[448599, 100],
#       [449799, 0],
#       [450799, 96],
#       [452599, 100],
#       [454399, 96],
#       [454999, 93],
#       [455399, 96],
#       [456199, 100],
#       [457599, 96],
#       [458199, 100],
#       [458999, 93],
#       [459399, 96],
#       [463599, 100],
#       [464999, 96],
#       [465599, 100],
#       [466599, 96],
#       [467399, 100],
#       [467799, 96],
#       [468599, 93],
#       [469599, 96],
#       [471799, 93],
#       [473799, 100],
#       [474199, 96],
#       [474599, 100],
#       [476199, 96],
#       [483199, 93],
#       [483999, 96],
#       [485799, 100],
#       [486799, 96],
#       [488399, 93],
#       [488799, 96],
#       [489599, 93],
#       [489999, 96],
#       [492199, 59]],
#      '4': [[448599, 100],
#       [449799, 0],
#       [450399, 96],
#       [451599, 93],
#       [452599, 100],
#       [453599, 96],
#       [454999, 93],
#       [455799, 100],
#       [456799, 93],
#       [457199, 96],
#       [457599, 93],
#       [457999, 96],
#       [458399, 100],
#       [458999, 96],
#       [460199, 100],
#       [460999, 96],
#       [463199, 100],
#       [464999, 96],
#       [465599, 100],
#       [466599, 96],
#       [467199, 100],
#       [468999, 93],
#       [469399, 96],
#       [470599, 93],
#       [470999, 96],
#       [472599, 100],
#       [473799, 96],
#       [474399, 100],
#       [476199, 96],
#       [477599, 100],
#       [480799, 96],
#       [483199, 93],
#       [484399, 96],
#       [484999, 93],
#       [485799, 100],
#       [486199, 96],
#       [487399, 93],
#       [487999, 96],
#       [493199, 93],
#       [494199, 96],
#       [494599, 93],
#       [494999, 96],
#       [500199, 93],
#       [500599, 96]]},
#     'phases': [[448409, 'buy_start'],
#      [478409, 'round_start'],
#      [518010, 'round_scored'],
#      [525010, 'round_end']],
#     'shield': [[448599, 0], [450399, 50], [518399, 0]],
#     'credits': [[448599, 150], [450399, 1950]],
#     'ammo_mag': [[449599, 12],
#      [451999, 25],
#      [477199, 12],
#      [477399, 25],
#      [513999, 24],
#      [514199, 22],
#      [516399, 20],
#      [516599, 18],
#      [516799, 16],
#      [516999, 14]],
#     'inv_state': [[450399, 'melee'],
#      [465599, 'primary'],
#      [466599, 'melee'],
#      [477599, 'none'],
#      [480799, 'melee'],
#      [483999, 'none'],
#      [490399, 'primary'],
#      [491399, 'none'],
#      [494999, 'primary'],
#      [504799, 'melee'],
#      [507599, 'primary']],
#     'ult_state': {'0': [[448599, False]],
#      '1': [[448599, False]],
#      '2': [[448599, False]],
#      '3': [[448599, True], [479399, False]],
#      '4': [[448599, False]],
#      '5': [[448599, False]],
#      '6': [[448599, False]],
#      '7': [[448599, False]],
#      '8': [[448599, False], [448999, True], [479399, False]],
#      '9': [[448599, False]]},
#     'map_region': [[449599, 'Defender Side Spawn'],
#      [454599, 'A Site'],
#      [505999, 'A Long']],
#     'elims_count': [[448799, 0, 0], [516799, 1, 1]],
#     'inv_primary': [[448599, 'none'], [451999, 'vandal']],
#     'ammo_reserve': [[490799, 75]],
#     'firing_state': [[448599, False], [513999, True], [519199, False]],
#     'assists_count': [[448799, 0, 2]],
#     'inv_secondary': [[448599, 'classic']],
#     'loadout_value': [[448599, 0],
#      [450399, 1500.0],
#      [451999, 4400.0],
#      [478599, 4600.0],
#      [487999, 4350.0],
#      [492399, 4150.0],
#      [494199, 3900.0],
#      [518399, 2900.0]],
#     'spike_planted': [[448599, False]],
#     'assisted_count': [[448799, 0, 0]],
#     'ability_charges_1': [[448599, 2], [487999, 1], [494199, 0]],
#     'ability_charges_2': [[448599, 0], [478599, 1], [492399, 0]],
#     'ability_charges_3': [[448599, 0]],
#     'ability_charges_4': [[448599, 0]]},
#    '4': {'alive': {'0': [[525199, True]],
#      '1': [[525199, True]],
#      '2': [[525199, True]],
#      '3': [[525199, True], [612399, False]],
#      '4': [[525199, True]],
#      '5': [[525199, True], [602199, False]],
#      '6': [[525199, True], [616599, False]],
#      '7': [[525199, True], [561799, False]],
#      '8': [[525199, True], [613999, False]],
#      '9': [[525199, True], [607399, False]]},
#     'elims': [[561999,
#       {'source': '4',
#        'target': '7',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': True,
#        'elim_number': 1,
#        'first_blood': True,
#        'team_credit': 'ally'}],
#      [602399,
#       {'source': '1',
#        'target': '5',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [607599,
#       {'source': '4',
#        'target': '9',
#        'assisted': ['3'],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [612399,
#       {'source': '8',
#        'target': '3',
#        'assisted': ['9'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [613999,
#       {'source': '1',
#        'target': '8',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [616799,
#       {'source': '1',
#        'target': '6',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 3,
#        'first_blood': False,
#        'team_credit': 'ally'}]],
#     'health': {'0': [[525199, 100],
#       [527799, 96],
#       [528199, 100],
#       [530199, 96],
#       [530599, 100],
#       [532799, 96],
#       [533199, 100],
#       [535799, 96],
#       [536399, 100],
#       [537399, 96],
#       [537799, 100],
#       [539999, 96],
#       [540799, 100],
#       [541399, 96],
#       [542399, 100],
#       [546199, 96],
#       [547799, 100],
#       [550599, 96],
#       [550999, 100],
#       [553399, 92],
#       [553799, 96],
#       [554799, 100],
#       [556599, 96],
#       [557399, 100],
#       [568399, 92],
#       [569599, 100],
#       [569999, 96],
#       [570599, 100],
#       [607199, 96],
#       [607599, 100],
#       [607999, 96],
#       [608399, 100],
#       [610399, 96],
#       [611799, 100],
#       [612399, 96],
#       [614399, 100],
#       [616599, 96],
#       [618599, 93],
#       [618999, 96]],
#      '1': [[525199, 100],
#       [526199, 96],
#       [531799, 100],
#       [532599, 96],
#       [535799, 93],
#       [536199, 96],
#       [538799, 100],
#       [539799, 96],
#       [540799, 93],
#       [541199, 96],
#       [543199, 93],
#       [543599, 96],
#       [547799, 100],
#       [548599, 96],
#       [549399, 89],
#       [549999, 96],
#       [551999, 100],
#       [552999, 96],
#       [559199, 93],
#       [560199, 96],
#       [612599, 100],
#       [616399, 81],
#       [621199, 89],
#       [622399, 81]],
#      '2': [[525199, 100]],
#      '3': [[525199, 100],
#       [526399, 93],
#       [527399, 96],
#       [530399, 93],
#       [530799, 96],
#       [531199, 93],
#       [531799, 100],
#       [532199, 96],
#       [532999, 93],
#       [533399, 96],
#       [533999, 89],
#       [534599, 100],
#       [534999, 96],
#       [536399, 93],
#       [536799, 96],
#       [538799, 100],
#       [539999, 96],
#       [541399, 93],
#       [541799, 100],
#       [542199, 96],
#       [543799, 93],
#       [547199, 96],
#       [547999, 100],
#       [549599, 96],
#       [552999, 89],
#       [553799, 96],
#       [555599, 100],
#       [556199, 96],
#       [559599, 100],
#       [562199, 37],
#       [563599, 59],
#       [564599, 70],
#       [565199, 81],
#       [566399, 96],
#       [607599, 93],
#       [608599, 96],
#       [608999, 100],
#       [609799, 96],
#       [610399, 93],
#       [611199, 96]],
#      '4': [[525199, 100],
#       [526199, 96],
#       [527799, 100],
#       [528799, 96],
#       [531199, 93],
#       [531799, 96],
#       [533599, 93],
#       [533999, 100],
#       [535199, 93],
#       [536399, 96],
#       [536999, 93],
#       [537399, 96],
#       [539999, 93],
#       [540599, 96],
#       [541399, 93],
#       [541799, 100],
#       [542199, 96],
#       [543799, 93],
#       [544399, 89],
#       [545599, 96],
#       [547199, 93],
#       [547999, 100],
#       [549199, 93],
#       [549599, 96],
#       [551799, 89],
#       [552199, 96],
#       [552999, 89],
#       [553399, 93],
#       [553999, 96],
#       [555599, 100],
#       [556199, 96],
#       [556599, 93],
#       [557399, 96],
#       [559599, 100],
#       [564599, 93],
#       [568599, 85],
#       [568999, 93],
#       [602599, 89],
#       [602999, 93],
#       [608199, 89],
#       [608599, 93],
#       [608999, 96],
#       [611199, 93],
#       [611999, 89],
#       [612399, 96],
#       [614799, 100],
#       [616199, 93]]},
#     'phases': [[525010, 'buy_start'],
#      [555010, 'round_start'],
#      [616019, 'round_scored'],
#      [623019, 'round_end']],
#     'shield': [[525199, 0], [526999, 50]],
#     'credits': [[525199, 1950], [526999, 150]],
#     'ammo_mag': [[526999, 25],
#      [552399, 12],
#      [553399, 25],
#      [603199, 23],
#      [603399, 25],
#      [604199, 20],
#      [605799, 25]],
#     'inv_state': [[527999, 'melee'],
#      [553399, 'primary'],
#      [555599, 'none'],
#      [556599, 'melee'],
#      [559199, 'primary'],
#      [606799, 'none'],
#      [608999, 'primary'],
#      [615999, 'melee']],
#     'ult_state': {'0': [[525199, False]],
#      '1': [[525199, False], [525599, True]],
#      '2': [[525199, False]],
#      '3': [[525199, False]],
#      '4': [[525199, False], [525799, True]],
#      '5': [[525199, False]],
#      '6': [[525199, False]],
#      '7': [[525199, False]],
#      '8': [[525199, False]],
#      '9': [[525199, False]]},
#     'map_region': [[526199, 'Defender Side Spawn'],
#      [530599, 'A Site'],
#      [559999, 'A Long'],
#      [611399, 'A Lobby'],
#      [616799, 'A Garden'],
#      [617599, 'Mid Window']],
#     'elims_count': [[525199, 0, 1]],
#     'inv_primary': [[525199, 'none'],
#      [527999, 'vandal'],
#      [554599, 'judge'],
#      [555599, 'vandal']],
#     'ammo_reserve': [[526999, 75]],
#     'firing_state': [[525199, False], [603199, True], [606399, False]],
#     'assists_count': [[525199, 0, 2]],
#     'inv_secondary': [[525199, 'classic']],
#     'loadout_value': [[525199, 0],
#      [526999, 1000.0],
#      [527999, 3900.0],
#      [554599, 2850.0],
#      [555599, 3900.0]],
#     'spike_planted': [[525199, False]],
#     'assisted_count': [[525199, 0, 0]],
#     'ability_charges_1': [[525199, 0]],
#     'ability_charges_2': [[525199, 0]],
#     'ability_charges_3': [[525199, 0]],
#     'ability_charges_4': [[525199, 0]]},
#    '5': {'alive': {'0': [[623199, True]],
#      '1': [[623199, True]],
#      '2': [[623199, True]],
#      '3': [[623199, True]],
#      '4': [[623199, True]],
#      '5': [[623199, True], [692199, False]],
#      '6': [[623199, True], [660199, False]],
#      '7': [[623199, True], [688199, False]],
#      '8': [[623199, True], [689399, False]],
#      '9': [[623199, True], [689799, False]]},
#     'elims': [[660399,
#       {'source': '2',
#        'target': '6',
#        'weapon': 'classic',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': True,
#        'team_credit': 'ally'}],
#      [688399,
#       {'source': '2',
#        'target': '7',
#        'weapon': 'vandal',
#        'assisted': ['4'],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'ally',
#        'weapon_type': 'primary'}],
#      [689599,
#       {'source': '2',
#        'target': '8',
#        'weapon': 'vandal',
#        'assisted': ['4'],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 3,
#        'first_blood': False,
#        'team_credit': 'ally',
#        'weapon_type': 'primary'}],
#      [689999,
#       {'source': '3',
#        'target': '9',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [692399,
#       {'source': '1',
#        'target': '5',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}],
#      [693199,
#       {'source': '4',
#        'target': '7',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}]],
#     'health': {'0': [[623199, 100],
#       [624599, 0],
#       [626199, 100],
#       [626599, 96],
#       [627599, 100],
#       [631999, 96],
#       [632799, 100],
#       [638399, 92],
#       [639799, 100],
#       [640599, 96],
#       [641399, 100],
#       [644599, 96],
#       [644999, 100],
#       [645399, 96],
#       [646399, 100],
#       [654199, 96],
#       [655799, 88],
#       [656399, 92],
#       [657199, 96],
#       [657799, 100],
#       [658999, 96],
#       [659799, 100],
#       [660199, 96],
#       [660599, 100],
#       [660999, 96],
#       [662399, 100],
#       [676799, 96],
#       [677199, 100],
#       [682399, 96],
#       [684399, 100],
#       [688399, 92],
#       [688999, 100],
#       [695999, 96],
#       [696999, 100],
#       [697599, 96],
#       [698999, 100],
#       [699399, 96],
#       [699799, 100],
#       [705999, 96],
#       [706999, 100],
#       [708399, 92],
#       [708799, 96],
#       [709199, 100]],
#      '1': [[623199, 100],
#       [624199, 96],
#       [624599, 0],
#       [625799, 96],
#       [629599, 93],
#       [629999, 96],
#       [630599, 100],
#       [631599, 96],
#       [646199, 93],
#       [646599, 96],
#       [647199, 100],
#       [648399, 96],
#       [649999, 100],
#       [653999, 96],
#       [663999, 100],
#       [664999, 96],
#       [672599, 100],
#       [673399, 96],
#       [674399, 100],
#       [675199, 96],
#       [681799, 89],
#       [682199, 96],
#       [686399, 100],
#       [686799, 96],
#       [687599, 100],
#       [688599, 93],
#       [689599, 96],
#       [693599, 81],
#       [696199, 93],
#       [697799, 96],
#       [706599, 93],
#       [707199, 89],
#       [708399, 93],
#       [708999, 96]],
#      '2': [[623199, 100],
#       [658599, 98],
#       [659199, 90],
#       [659799, 40],
#       [681999, 98],
#       [688599, 43],
#       [697599, 85]],
#      '3': [[623199, 100],
#       [624199, 96],
#       [624599, 0],
#       [625799, 96],
#       [626199, 93],
#       [627599, 96],
#       [628999, 93],
#       [629999, 100],
#       [631599, 96],
#       [633599, 93],
#       [634199, 96],
#       [638199, 93],
#       [638799, 96],
#       [642599, 100],
#       [643599, 96],
#       [644399, 89],
#       [644799, 96],
#       [645599, 100],
#       [647399, 96],
#       [650199, 100],
#       [654199, 96],
#       [655399, 93],
#       [656799, 96],
#       [662999, 93],
#       [663999, 100],
#       [664599, 96],
#       [666999, 100],
#       [667399, 96],
#       [672199, 100],
#       [673399, 96],
#       [674399, 89],
#       [674799, 96],
#       [675799, 89],
#       [676199, 93],
#       [677599, 96],
#       [682399, 93],
#       [682999, 96],
#       [684199, 93],
#       [684599, 96],
#       [686599, 100],
#       [688599, 96],
#       [688999, 100],
#       [690599, 89],
#       [691599, 96],
#       [693599, 93],
#       [695199, 96],
#       [695999, 93],
#       [697599, 96],
#       [697999, 93],
#       [698799, 96],
#       [700799, 93],
#       [701199, 96],
#       [705799, 89],
#       [706199, 96],
#       [706999, 93],
#       [707599, 96],
#       [708399, 93],
#       [709599, 96]],
#      '4': [[623199, 100],
#       [624599, 0],
#       [626599, 96],
#       [627199, 93],
#       [628599, 96],
#       [629199, 93],
#       [629999, 96],
#       [631799, 100],
#       [632199, 93],
#       [632999, 96],
#       [633599, 93],
#       [634199, 96],
#       [635599, 93],
#       [636599, 96],
#       [638999, 81],
#       [639999, 93],
#       [640399, 96],
#       [642399, 100],
#       [643599, 96],
#       [645599, 100],
#       [646799, 96],
#       [650399, 100],
#       [652599, 96],
#       [652999, 100],
#       [654199, 96],
#       [655199, 93],
#       [655799, 96],
#       [656199, 93],
#       [657999, 96],
#       [658799, 93],
#       [659799, 96],
#       [660399, 93],
#       [660799, 96],
#       [662999, 93],
#       [663799, 100],
#       [665599, 96],
#       [672199, 100],
#       [673999, 96],
#       [674399, 100],
#       [675199, 93],
#       [676199, 96],
#       [677399, 93],
#       [677799, 96],
#       [682799, 93],
#       [683999, 96],
#       [684399, 93],
#       [684999, 96],
#       [686999, 100],
#       [690799, 89],
#       [691599, 100],
#       [692399, 96],
#       [693399, 93],
#       [696399, 96],
#       [698799, 93],
#       [702199, 96],
#       [706399, 89],
#       [706799, 96],
#       [707199, 93],
#       [708399, 89],
#       [708999, 93],
#       [709799, 96]]},
#     'phases': [[623019, 'buy_start'],
#      [653019, 'round_start'],
#      [704386, 'round_scored'],
#      [711386, 'round_end']],
#     'shield': [[623199, 50], [658599, 46], [659199, 29], [659799, 0]],
#     'credits': [[623199, 150], [625799, 2450]],
#     'ammo_mag': [[623599, 25],
#      [659399, 24],
#      [659599, 21],
#      [659799, 19],
#      [660199, 16],
#      [663799, 14],
#      [672599, 4],
#      [673199, 14],
#      [675199, 25],
#      [687599, 24],
#      [687799, 23],
#      [687999, 21],
#      [688199, 19],
#      [688399, 17],
#      [689399, 15],
#      [689599, 13],
#      [690199, 12],
#      [692199, 10],
#      [692399, 8],
#      [700599, 3],
#      [702799, 6],
#      [707399, 7],
#      [707799, 25]],
#     'inv_state': [[625799, 'melee'],
#      [648799, 'none'],
#      [650199, 'primary'],
#      [655399, 'melee'],
#      [656399, 'none'],
#      [658799, 'primary'],
#      [660399, 'none'],
#      [662599, 'melee'],
#      [663999, 'none'],
#      [670199, 'primary'],
#      [675399, 'melee'],
#      [681799, 'primary'],
#      [692599, 'melee'],
#      [699999, 'secondary'],
#      [705199, 'primary'],
#      [709999, 'melee']],
#     'ult_state': {'0': [[623199, False]],
#      '1': [[623199, True], [686199, False]],
#      '2': [[623199, False], [688599, True]],
#      '3': [[623199, False]],
#      '4': [[623199, True]],
#      '5': [[623199, False], [623599, True]],
#      '6': [[623199, False]],
#      '7': [[623199, False]],
#      '8': [[623199, False]],
#      '9': [[623199, False]]},
#     'map_region': [[624199, 'Defender Side Spawn'],
#      [628799, 'A Link'],
#      [631799, 'A Site'],
#      [656799, 'A Tower'],
#      [664199, 'A Site'],
#      [677399, 'A Link'],
#      [683599, 'A Site'],
#      [699799, 'A Tower'],
#      [704999, 'A Lobby'],
#      [708599, 'A Tower']],
#     'elims_count': [[623199, 0, 1],
#      [660399, 1, 2],
#      [688399, 2, 3],
#      [689599, 3, 4]],
#     'inv_primary': [[623199, 'vandal']],
#     'ammo_reserve': [[635399, 75],
#      [681799, 64],
#      [699999, 22],
#      [702599, 19],
#      [705199, 64],
#      [707799, 46]],
#     'firing_state': [[623199, False],
#      [659399, True],
#      [662399, False],
#      [663799, True],
#      [665999, False],
#      [687599, True],
#      [694599, False],
#      [700599, True],
#      [702799, False]],
#     'assists_count': [[623199, 0, 2]],
#     'inv_secondary': [[623199, 'classic']],
#     'loadout_value': [[623199, 3900.0],
#      [653199, 4600.0],
#      [658199, 4350.0],
#      [658599, 4254.0],
#      [659199, 3846.0],
#      [659799, 3350.0],
#      [661599, 3100.0],
#      [669599, 2900.0],
#      [689399, 2900.0]],
#     'spike_planted': [[623199, False], [690799, True], [704999, False]],
#     'assisted_count': [[623199, 0, 0], [688399, 1, 1], [689599, 2, 2]],
#     'ability_charges_1': [[623199, 0], [653199, 2], [658199, 1], [661599, 0]],
#     'ability_charges_2': [[623199, 0], [653199, 1], [669599, 0]],
#     'ability_charges_3': [[623199, 0]],
#     'ability_charges_4': [[623199, 0], [689399, 1]]},
#    '6': {'alive': {'0': [[711399, True], [770399, False]],
#      '1': [[711399, True], [769199, False]],
#      '2': [[711399, True]],
#      '3': [[711399, True]],
#      '4': [[711399, True]],
#      '5': [[711399, True], [769399, False]],
#      '6': [[711399, True], [784399, False]],
#      '7': [[711399, True], [765999, False]],
#      '8': [[711399, True], [795999, False]],
#      '9': [[711399, True], [790799, False]]},
#     'elims': [[765999,
#       {'source': '1',
#        'target': '7',
#        'assisted': ['1', '2'],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': True,
#        'team_credit': 'ally'}],
#      [769199,
#       {'source': '5',
#        'target': '1',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [769599,
#       {'source': '2',
#        'target': '5',
#        'weapon': 'vandal',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally',
#        'weapon_type': 'primary'}],
#      [770399,
#       {'source': '8',
#        'target': '0',
#        'assisted': [],
#        'headshot': False,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'opponent'}],
#      [784399,
#       {'source': '2',
#        'target': '6',
#        'weapon': 'vandal',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 2,
#        'first_blood': False,
#        'team_credit': 'ally',
#        'weapon_type': 'primary'}],
#      [790799,
#       {'source': '2',
#        'target': '9',
#        'weapon': 'vandal',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 3,
#        'first_blood': False,
#        'team_credit': 'ally',
#        'weapon_type': 'primary'}],
#      [795999,
#       {'source': '3',
#        'target': '8',
#        'assisted': [],
#        'headshot': True,
#        'wallbang': False,
#        'elim_number': 1,
#        'first_blood': False,
#        'team_credit': 'ally'}]],
#     'health': {'0': [[711399, 100],
#       [712599, 0],
#       [714199, 96],
#       [714999, 100],
#       [716999, 96],
#       [717399, 100],
#       [725799, 96],
#       [726399, 100],
#       [728199, 96],
#       [728999, 100],
#       [744199, 96],
# ...
#     'time_to_head': 200,
#     'targeted_time': 1956349,
#     'time_on_screen': 800,
#     'time_to_target': 0,
#     'initial_location': {'x': 0.0046875, 'y': -0.01388888888888889},
#     'targeted_head_time': 1956549,
#     'initial_head_location': {'x': 0.0046875, 'y': 0.008333333333333333}},
#    '2861': {'final_time': 1975249,
#     'initial_size': {'h': 0.05138888888888889, 'w': 0.0109375},
#     'initial_time': 1974249,
#     'targeted_time': 1974599,
#     'time_on_screen': 1000,
#     'time_to_target': 350,
#     'initial_location': {'x': 0.03671875, 'y': 0.01458333333333333},
#     'initial_head_location': {'x': 0.03671875, 'y': 0.03541666666666667}},
#    '2893': {'final_time': 1989449,
#     'initial_size': {'h': 0.05694444444444444, 'w': 0.0140625},
#     'initial_time': 1989149,
#     'time_on_screen': 300,
#     'initial_location': {'x': -0.43046875, 'y': 0.1479166666666667},
#     'initial_head_location': {'x': -0.43046875, 'y': 0.1701388888888889}},
#    '2971': {'final_time': 2022699,
#     'initial_size': {'h': 0.1097222222222222, 'w': 0.040625},
#     'initial_time': 2022599,
#     'time_on_screen': 100,
#     'initial_location': {'x': 0.01484375, 'y': -0.2756944444444445},
#     'initial_head_location': {'x': 0.01484375, 'y': -0.2388888888888889}},
#    '3001': {'final_time': 2041099,
#     'initial_size': {'h': 0.05138888888888889, 'w': 0.01171875},
#     'initial_time': 2040099,
#     'time_on_screen': 1000,
#     'initial_location': {'x': -0.243359375, 'y': -0.03819444444444445},
#     'initial_head_location': {'x': -0.243359375, 'y': -0.01736111111111111}},
#    '3003': {'final_time': 2041849,
#     'initial_size': {'h': 0.06527777777777778, 'w': 0.01640625},
#     'initial_time': 2041499,
#     'time_on_screen': 350,
#     'initial_location': {'x': -0.292578125, 'y': -0.01319444444444444},
#     'initial_head_location': {'x': -0.292578125, 'y': 0.0125}},
#    '3040': {'final_time': 2081749,
#     'initial_size': {'h': 0.06527777777777778, 'w': 0.0171875},
#     'initial_time': 2081649,
#     'time_on_screen': 100,
#     'initial_location': {'x': 0.00703125, 'y': 0.3479166666666667},
#     'initial_head_location': {'x': 0.00703125, 'y': 0.3729166666666667}},
#    '3117': {'final_time': 2131299,
#     'initial_size': {'h': 0.05, 'w': 0.0125},
#     'initial_time': 2130699,
#     'time_to_head': 250,
#     'targeted_time': 2130949,
#     'time_on_screen': 600,
#     'time_to_target': 250,
#     'initial_location': {'x': -0.02421875, 'y': -0.01944444444444444},
#     'targeted_head_time': 2130949,
#     'initial_head_location': {'x': -0.02421875, 'y': 0.0}},
#    '3129': {'final_time': 2139099,
#     'initial_size': {'h': 0.08888888888888889, 'w': 0.02421875},
#     'initial_time': 2138699,
#     'time_on_screen': 400,
#     'initial_location': {'x': -0.464453125, 'y': -0.04166666666666666},
#     'initial_head_location': {'x': -0.464453125, 'y': -0.008333333333333333}},
#    '3131': {'final_time': 2140149,
#     'initial_size': {'h': 0.1569444444444444, 'w': 0.0421875},
#     'initial_time': 2139199,
#     'time_on_screen': 950,
#     'initial_location': {'x': -0.16328125, 'y': -0.2201388888888889},
#     'initial_head_location': {'x': -0.16328125, 'y': -0.1604166666666667}},
#    '3132': {'final_time': 2139649,
#     'initial_size': {'h': 0.07777777777777778, 'w': 0.009375},
#     'initial_time': 2139349,
#     'targeted_time': 2139499,
#     'time_on_screen': 300,
#     'time_to_target': 150,
#     'initial_location': {'x': 0.0140625, 'y': -0.02083333333333333},
#     'initial_head_location': {'x': 0.0140625, 'y': 0.01388888888888889}},
#    '3133': {'final_time': 2140249,
#     'initial_size': {'h': 0.07777777777777778, 'w': 0.0109375},
#     'initial_time': 2139999,
#     'time_on_screen': 250,
#     'initial_location': {'x': 0.00859375, 'y': -0.02916666666666667},
#     'initial_head_location': {'x': 0.00859375, 'y': 0.004861111111111111}},
#    '3134': {'final_time': 2140449,
#     'initial_size': {'h': 0.05416666666666667, 'w': 0.0078125},
#     'initial_time': 2140299,
#     'targeted_time': 2140449,
#     'time_on_screen': 150,
#     'time_to_target': 150,
#     'initial_location': {'x': 0.0078125, 'y': -0.04375},
#     'initial_head_location': {'x': 0.0078125, 'y': -0.02013888888888889}},
#    '3135': {'final_time': 2141799,
#     'initial_size': {'h': 0.15, 'w': 0.04375},
#     'initial_time': 2140399,
#     'time_on_screen': 1400,
#     'initial_location': {'x': -0.1828125, 'y': -0.15},
#     'initial_head_location': {'x': -0.1828125, 'y': -0.09444444444444444}},
#    '3137': {'final_time': 2141549,
#     'initial_size': {'h': 0.07361111111111111, 'w': 0.0125},
#     'initial_time': 2140899,
#     'time_to_head': 0,
#     'targeted_time': 2140899,
#     'time_on_screen': 650,
#     'time_to_target': 0,
#     'initial_location': {'x': 0.003125, 'y': -0.03263888888888889},
#     'targeted_head_time': 2140899,
#     'initial_head_location': {'x': 0.003125, 'y': -0.001388888888888889}},
#    '3143': {'final_time': 2146499,
#     'initial_size': {'h': 0.03472222222222222, 'w': 0.0078125},
#     'initial_time': 2146299,
#     'time_to_head': 200,
#     'targeted_time': 2146299,
#     'time_on_screen': 200,
#     'time_to_target': 0,
#     'initial_location': {'x': 0.00234375, 'y': -0.01736111111111111},
#     'targeted_head_time': 2146499,
#     'initial_head_location': {'x': 0.00234375, 'y': -0.003472222222222222}},
#    '3153': {'final_time': 2165799,
#     'initial_size': {'h': 0.1083333333333333, 'w': 0.0546875},
#     'initial_time': 2165449,
#     'time_on_screen': 350,
#     'initial_location': {'x': 0.3890625, 'y': 0.1902777777777778},
#     'initial_head_location': {'x': 0.3890625, 'y': 0.2201388888888889}},
#    '3159': {'final_time': 2188649,
#     'initial_size': {'h': 0.1277777777777778, 'w': 0.08125},
#     'initial_time': 2188549,
#     'time_on_screen': 100,
#     'initial_location': {'x': 0.0, 'y': -0.275},
#     'initial_head_location': {'x': 0.0, 'y': -0.2472222222222222}},
#    '3171': {'final_time': 2217749,
#     'initial_size': {'h': 0.1652777777777778, 'w': 0.03671875},
#     'initial_time': 2217399,
#     'time_on_screen': 350,
#     'initial_location': {'x': -0.370703125, 'y': 0.3090277777777778},
#     'initial_head_location': {'x': -0.370703125, 'y': 0.375}}},
#   'most_used_primary': 'vandal',
#   'analysis_processed': True,
#   'opponents_onscreen': {'6199': 0,
#    '91199': 1,
#    '92299': 0,
#    '92349': 1,
#    '127399': 0,
#    '133199': 1,
#    '133449': 0,
#    '133499': 1,
#    '133549': 0,
#    '133699': 1,
#    '133749': 0,
#    '139299': 1,
#    '154649': 0,
#    '155299': 1,
#    '157649': 0,
#    '167199': 1,
#    '168649': 2,
#    '168949': 1,
#    '190349': 0,
#    '191199': 1,
#    '243499': 2,
#    '243599': 1,
#    '244599': 0,
#    '261399': 1,
#    '265699': 0,
#    '283949': 1,
#    '284349': 0,
#    '285349': 1,
#    '285449': 2,
#    '285649': 1,
#    '285749': 2,
#    '285849': 1,
#    '285949': 2,
#    '289449': 1,
#    '289499': 3,
#    '289649': 2,
#    '289699': 3,
#    '289799': 2,
#    '289849': 3,
#    '290249': 2,
#    '290299': 1,
#    '290599': 2,
#    '290799': 1,
#    '290999': 0,
#    '317549': 1,
#    '317749': 0,
#    '317799': 1,
#    '321499': 0,
#    '322249': 1,
#    '322549': 0,
#    '324449': 1,
#    '326599': 0,
#    '326899': 1,
#    '328699': 2,
#    '328849': 1,
#    '331749': 0,
#    '332549': 1,
#    '332899': 0,
#    '332949': 1,
#    '333149': 0,
#    '372999': 1,
#    '375149': 0,
#    '376899': 1,
#    '378499': 0,
#    '379349': 1,
#    '384549': 0,
#    '387149': 1,
#    '387749': 0,
#    '387799': 1,
#    '393199': 0,
#    '394449': 1,
#    '396099': 0,
#    '397749': 1,
#    '398349': 0,
#    '402499': 1,
#    '402599': 2,
#    '402649': 1,
#    '406049': 0,
#    '406949': 1,
#    '419649': 0,
#    '429349': 1,
#    '429549': 2,
#    '429899': 1,
#    '445949': 0,
#    '446749': 1,
#    '472299': 0,
#    '482999': 1,
#    '484849': 0,
#    '501799': 1,
#    '505699': 0,
#    '511249': 1,
#    '511399': 0,
#    '513549': 1,
#    '519199': 0,
#    '531399': 1,
#    '531549': 0,
#    '560499': 1,
#    '562049': 0,
#    '658649': 1,
#    '660449': 0,
#    '660499': 1,
#    '660749': 0,
#    '660799': 1,
#    '660899': 0,
#    '662049': 1,
#    '662199': 0,
#    '674299': 1,
#    '674749': 0,
#    '687199': 1,
#    '687399': 2,
#    '688099': 1,
#    '688199': 2,
#    '688349': 1,
#    '688449': 2,
#    '688549': 1,
#    '688599': 2,
#    '688799': 1,
#    '690849': 0,
#    '691799': 1,
#    '691849': 0,
#    '691899': 1,
#    '692049': 0,
#    '692099': 1,
#    '692199': 0,
#    '694749': 1,
#    '696049': 0,
#    '718699': 1,
#    '718999': 0,
#    '740999': 1,
#    '741099': 0,
#    '741149': 1,
#    '741399': 0,
#    '741449': 1,
#    '741499': 0,
#    '768799': 1,
#    '768849': 0,
#    '768949': 1,
#    '768999': 0,
#    '769049': 1,
#    '769099': 0,
#    '769499': 1,
#    '780199': 0,
#    '784049': 1,
#    '799799': 0,
#    '801249': 1,
#    '802499': 0,
#    '835549': 1,
#    '835749': 0,
#    '835799': 1,
#    '835849': 0,
#    '835999': 1,
#    '836049': 2,
#    '836149': 1,
#    '836199': 2,
#    '836249': 3,
#    '836299': 1,
#    '836349': 3,
#    '836399': 2,
#    '836449': 1,
#    '836599': 0,
#    '842499': 1,
#    '846549': 0,
#    '850949': 1,
#    '850999': 2,
#    '851099': 1,
#    '851149': 2,
#    '851299': 0,
#    '851349': 1,
#    '852299': 0,
#    '855649': 1,
#    '863249': 0,
#    '865499': 1,
#    '866049': 0,
#    '866099': 1,
#    '866749': 0,
#    '907349': 1,
#    '908749': 0,
#    '917849': 1,
#    '922499': 0,
#    '941999': 1,
#    '942149': 0,
#    '955199': 1,
#    '955299': 2,
#    '955849': 1,
#    '955899': 2,
#    '956049': 1,
#    '957299': 0,
#    '957649': 1,
#    '966999': 0,
#    '967049': 1,
#    '968499': 0,
#    '992249': 1,
#    '997149': 0,
#    '1035649': 1,
#    '1037399': 0,
#    '1054949': 1,
#    '1055649': 0,
#    '1093949': 1,
#    '1111299': 0,
#    '1115749': 1,
#    '1117599': 2,
#    '1117649': 1,
#    '1139399': 0,
#    '1143449': 1,
#    '1150749': 0,
#    '1151399': 1,
#    '1162999': 0,
#    '1198449': 1,
#    '1203249': 0,
#    '1204899': 1,
#    '1206649': 0,
#    '1209049': 1,
#    '1211649': 0,
#    '1212049': 1,
#    '1218649': 2,
#    '1218749': 1,
#    '1218799': 2,
#    '1218899': 1,
#    '1233299': 0,
#    '1237399': 1,
#    '1263149': 0,
#    '1310649': 1,
#    '1310849': 2,
#    '1310899': 1,
#    '1310999': 2,
#    '1311049': 1,
#    '1311149': 0,
#    '1311199': 1,
#    '1311299': 2,
#    '1311349': 1,
#    '1311449': 0,
#    '1313199': 1,
#    '1313699': 2,
#    '1314399': 0,
#    '1315299': 1,
#    '1315949': 0,
#    '1316399': 1,
#    '1318149': 2,
#    '1318199': 1,
#    '1318249': 2,
#    '1318299': 1,
#    '1329599': 0,
#    '1329799': 1,
#    '1329949': 0,
#    '1329999': 1,
#    '1330599': 0,
#    '1338849': 1,
#    '1338899': 0,
#    '1338949': 1,
#    '1339149': 0,
#    '1339299': 1,
#    '1339399': 0,
#    '1339449': 1,
#    '1340749': 0,
#    '1343849': 1,
#    '1344399': 0,
#    '1362249': 1,
#    '1364349': 0,
#    '1369999': 1,
#    '1371649': 0,
#    '1372749': 1,
#    '1382299': 0,
#    '1383549': 1,
#    '1387449': 2,
#    '1387699': 1,
#    '1389249': 0,
#    '1395349': 1,
#    '1396099': 0,
#    '1442999': 1,
#    '1443249': 0,
#    '1444249': 1,
#    '1451199': 0,
#    '1464099': 1,
#    '1464349': 0,
#    '1476649': 1,
#    '1477099': 0,
#    '1488249': 1,
#    '1490499': 0,
#    '1507249': 1,
#    '1507349': 0,
#    '1507399': 1,
#    '1507449': 0,
#    '1507499': 1,
#    '1507549': 0,
#    '1507699': 1,
#    '1507749': 0,
#    '1533149': 1,
#    '1533849': 0,
#    '1556349': 1,
#    '1556499': 3,
#    '1556549': 2,
#    '1556599': 1,
#    '1556649': 3,
#    '1556899': 1,
#    '1556949': 2,
#    '1557149': 1,
#    '1557249': 0,
#    '1557349': 1,
#    '1557699': 0,
#    '1557949': 1,
#    '1558449': 0,
#    '1558949': 1,
#    '1558999': 0,
#    '1559099': 1,
#    '1559149': 0,
#    '1559199': 1,
#    '1559349': 0,
#    '1560649': 1,
#    '1561599': 0,
#    '1561749': 1,
#    '1562149': 0,
#    '1568899': 1,
#    '1570149': 2,
#    '1570299': 1,
#    '1580249': 0,
#    '1584449': 1,
#    '1584999': 0,
#    '1588099': 1,
#    '1588499': 0,
#    '1657899': 1,
#    '1658449': 0,
#    '1665599': 1,
#    '1665699': 0,
#    '1665749': 1,
#    '1665849': 0,
#    '1700199': 1,
#    '1700649': 0,
#    '1776149': 1,
#    '1776299': 0,
#    '1776349': 1,
#    '1776399': 0,
#    '1783299': 1,
#    '1786999': 0,
#    '1793099': 1,
#    '1793849': 0,
#    '1795899': 1,
#    '1796749': 0,
#    '1807199': 1,
#    '1809299': 0,
#    '1827899': 1,
#    '1827999': 0,
#    '1828099': 1,
#    '1828149': 0,
#    '1836299': 1,
#    '1837049': 0,
#    '1837099': 1,
#    '1837399': 0,
#    '1856099': 1,
#    '1857149': 0,
#    '1865199': 1,
#    '1867799': 0,
#    '1868699': 1,
#    '1868899': 0,
#    '1877399': 1,
#    '1879149': 0,
#    '1949099': 1,
#    '1957749': 0,
#    '1974249': 1,
#    '1974449': 0,
#    '1974599': 1,
#    '1975349': 0,
#    '1989149': 1,
#    '1989299': 0,
#    '1989349': 1,
#    '1989649': 0,
#    '2022599': 1,
#    '2033199': 0,
#    '2040099': 1,
#    '2040349': 0,
#    '2040399': 1,
#    '2040699': 0,
#    '2040749': 1,
#    '2040849': 0,
#    '2040949': 1,
#    '2041149': 0,
#    '2041499': 1,
#    '2042299': 0,
#    '2081649': 1,
#    '2081799': 0,
#    '2130699': 1,
#    '2134499': 0,
#    '2138699': 1,
#    '2139349': 2,
#    '2139699': 1,
#    '2139999': 2,
#    '2140199': 1,
#    '2140449': 2,
#    '2140499': 1,
#    '2140899': 2,
#    '2141599': 1,
#    '2142699': 0,
#    '2146299': 1,
#    '2148649': 0,
#    '2165449': 1,
#    '2170699': 0,
#    '2188549': 1,
#    '2194299': 0,
#    '2217399': 1},
#   'most_used_secondary': 'frenzy',
#   'best_weapon_type_elims': 9,
#   'most_used_primary_seconds': 1131,
#   'most_used_secondary_seconds': 291},
#  'totals': {'elims': 15,
#   'deaths': 16,
#   'assists': 6,
#   'healing': 164,
#   'headshots': 10,
#   'shielding': 817,
#   'wallbangs': 0,
#   'first_bloods': 1,
#   'seconds_dead': 609,
#   'was_assisted': 6,
#   'credits_spent': 38700,
#   'first_blooded': 6,
#   'seconds_alive': 1456,
#   'credits_earned': 41100,
#   'hp_damage_taken': 1914,
#   'shield_damage_taken': 817},
#  'ten_minute_averages': {'elims': 3.510400326053183,
#   'deaths': 3.456394167190826,
#   'assists': 0.9811118859994793,
#   'healing': 57.79559100919868,
#   'headshots': 2.232254566310742,
#   'shielding': 204.5393256646988,
#   'wallbangs': 0.2160246354494266,
#   'first_bloods': 0.549062615100626,
#   'seconds_dead': 158.1120310960262,
#   'was_assisted': 1.080123177247133,
#   'credits_spent': 10635.4688688698,
#   'first_blooded': 0.6030687739629826,
#   'seconds_alive': 356.5306587563246,
#   'credits_earned': 11380.30380984647,
#   'hp_damage_taken': 477.1894186813064,
#   'shield_damage_taken': 202.5320967603145},
#  'character_id': 52,
#  'user_id': 1011,
#  'match_length': '2237000',
#  'video_id': 2695,
#  'card_url': 'https://forge.omnic.ai/player_card/generate/J0PtBFUhyhryIXZGhCBlVhom0SQA%2FVZ4SuoW+fgz75VkmIZTJvq1DA0scATAXduLyKSwcHo9xwmo0Ufz5CB9xzTuq%2F9k4XoYWWSjpH1h+gr6Q95q9Awr9TD5Rqhd25wvdsz7khtXuvWOZ5S0NHqLy+Qmo4iXpeVxU6VYr7koeJqzHZcmHt6%2FCBvqusz0%2FhmmI0i6bhKCqSt9RC9oIByLYYHB8MMJl3hPTtSyxgES44uPHa04Js479zGBpTOLTf2FMHR9ZjtgsOAzIkYHDhvHIcMe1E6KBvQA7ktfrPU7YgrPNAncmWhAJN5HJTiIOLpsExp8P0pgRIyWAUMNpcZpcDZSsbKZHOOl3d0VYY8bdwx5PIr9GFOCZsDJpEN2trTEbIPyZ5pLi9vzQ0L6sv2P%2FD2NMqJwOVSQLJYUEfssdB1hZUbc3tnHXYCq0P5sw+0Tx6+ZhGhzxblv9XmTdypVuPBZOg8Gr1w1wZphcfD+KCsSo%2FHQUvwyHS%2FUehxyYigT5FtqBae%2F6GFsQEOv4gEN%2FavfzCfqNPf7gsDcJJpgwTo7DY2Y38eVv67rGbJW9tSqIHxWAivYjRN08icdN8GXB7TTSKf+5dcdibvHXfYxZH310FgrD+AvGSfFB%2FxOGMTiN86cYHIFtPrBy8agEwTYIw==',
#  'total_time': 66659064,
#  'totals_to_date': {'elims': 390,
#   'deaths': 384,
#   'assists': 109,
#   'healing': 6421,
#   'headshots': 248,
#   'shielding': 22724,
#   'wallbangs': 24,
#   'first_bloods': 61,
#   'seconds_dead': 17566,
#   'was_assisted': 120,
#   'credits_spent': 1181584,
#   'first_blooded': 67,
#   'seconds_alive': 39610,
#   'credits_earned': 1264334,
#   'hp_damage_taken': 53015,
#   'shield_damage_taken': 22501},
#  'start_time': 14434999,
#  'end_time': 16671999,
#  'start_frame': 866100,
#  'end_frame': 1000320,
#  'status': 'success: completed - valorant final | completed: processing - valorant player detection | accepted: processing - valorant player detection | success: completed - valorant postprocess | accepted: processing - valorant postprocess | completed: processing - valorant static ocr | complete: processing - valorant static cnn | accepted: processing - valorant static ocr | accepted: processing - valorant static cnn | completed: processing - valorant preprocess | accepted: processing - valorant preprocess | completed: processing - valorant dynamic detection | accepted: processing - valorant dynamic detection | accepted',
#  'report': {},
#  'analysis_processed': True,
#  'analysis_status': 'completed: processing - anyalysis (insights) | accepted: processing - analysis | success: saving completed - io | accepted: saving - io'}
